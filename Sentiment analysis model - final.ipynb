# %% [markdown]
# # Sentiment Analysis

# %%
import numpy as np
import nltk
import string
import pandas as pd
import re
from nltk.classify import NaiveBayesClassifier
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('data.csv', encoding='latin')

# %%
data.columns = ['sentiment', 'id', 'date', 'query', 'user_id', 'tweet']
data.head()
# Out:
#    sentiment          id                          date     query  \
# 0          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
#
#          user_id                                              tweet
# 0  scotthamilton  is upset that he can't update his Facebook by ...
# 1       mattycus  @Kenichan I dived many times for the ball. Man...
# 2        ElleCTF    my whole body feels itchy and like its on fire
# 3         Karoli  @nationwideclass no, it's not behaving at all....
# 4       joy_wolf                      @Kwesidei not the whole crew

# %%
# we drop useless infos
data = data.drop(['id', 'date', 'query', 'user_id'], axis=1)
tweets = data['tweet']
sentiment = data['sentiment'] 
data.head()
# Out:
#    sentiment                                              tweet
# 0          0  is upset that he can't update his Facebook by ...
# 1          0  @Kenichan I dived many times for the ball. Man...
# 2          0    my whole body feels itchy and like its on fire
# 3          0  @nationwideclass no, it's not behaving at all....
# 4          0                      @Kwesidei not the whole crew

# %%
lab_to_sentiment = {0:"Negative", 2:"Neutral", 4:"Positive"}
def label_decoder(label):
  return lab_to_sentiment[label]
data.sentiment = data.sentiment.apply(lambda x: label_decoder(x))

data.head()
# Out:
#   sentiment                                              tweet
# 0  Negative  is upset that he can't update his Facebook by ...
# 1  Negative  @Kenichan I dived many times for the ball. Man...
# 2  Negative    my whole body feels itchy and like its on fire
# 3  Negative  @nationwideclass no, it's not behaving at all....
# 4  Negative                      @Kwesidei not the whole crew

# %% [markdown]
# ## Data Preprocessing

# %%
#Remove all newlines from inside a string
clean_data = [tweet.replace('\n','').strip() for tweet in tweets]
#To remove all whitespaces in the beginning and end of the string
#remove the unicodes for the single left and right quote characters
clean_data[:] = [tweet.replace(u'\u2018',"'").replace(u'\u2019',"'") for tweet in clean_data] 

#convert n't to  not
clean_data[:] = [tweet.replace('n\'t',' not') for tweet in clean_data]  

#remove any sub-string containing 'http'
clean_data[:] = [re.sub(r"^.*http.*$", '', tweet) for tweet in clean_data] 

#remove non-ASCII characters
clean_data[:] = [re.sub(r'[^\x00-\x7F]+','', tweet) for tweet in clean_data] 

clean_data[:] = [re.sub("(@[A-Za-z0–9]+)",'',tweet) for tweet in clean_data ]

#remove tweeter's RT' tags
clean_data[:] = [tweet.replace('RT','') for tweet in clean_data] 

#make all words lower case
clean_data[:] = [tweet.lower() for tweet in clean_data] 



clean_data
# Out:
# ['is upset that he ca not update his facebook by texting it... and might cry as a result  school today also. blah!',
#  ' i dived many times for the ball. managed to save 50%  the rest go out of bounds',
#  'my whole body feels itchy and like its on fire',
#  " no, it's not behaving at all. i'm mad. why am i here? because i ca not see you all over there.",
#  ' not the whole crew',
#  'need a hug',
#  " hey  long time no see! yes.. rains a bit ,only a bit  lol , i'm fine thanks , how's you ?",
#  '_k nope they did not have it',
#  ' que me muera ?',
#  "spring break in plain city... it's snowing",
#  'i just re-pierced my ears',
#  ' i could not bear to watch it.  and i thought the ua loss was embarrassing . . . . .',
#  '16 it it counts, idk why i did either. you never talk to me anymore',
#  " i would've been the first, but i did not have a gun.    not really though, zac snyder's just a doucheclown.",
#  ' i wish i got to watch it with you!! i miss you and   how was the premiere?!',
#  "hollis' death scene will hurt me severely to watch on film  wry is directors cut not out now?",
#  'about to file taxes',
#  ' ahh ive always wanted to see rent  love the soundtrack!!',
#  ' oh dear. were you drinking out of the forgotten table drinks?',
#  ' i was out most of the day so did not get much done',
#  "one of my friend called me, and asked to meet with her at mid valley today...but i've no time *sigh*",
#  '_barista i baked you a cake but i ated it',
#  'this week is not going as i had hoped',
#  'blagh class at 8 tomorrow',
#  'i hate when i have to call and wake people up',
#  'just going to cry myself to sleep after watching marley and me.',
#  'im sad now  miss.lilly',
#  'ooooh.... lol  that leslie.... and ok i wo not do it again so leslie wo not  get mad again',
#  'meh... almost lover is the exception... this track gets me depressed every time.',
#  'some1 hacked my account on aim  now i have to make a new one',
#  ' i want to go to promote gear and groove but unfornately no ride there  i may b going to the one in anaheim in may though',
#  'thought sleeping in was an option tomorrow but realizing that it now is not. evaluations in the morning and work in the afternoon!',
#  ' awe i love you too!!!! 1 am here  i miss you',
#  ' i cry my asian eyes to sleep at night',
#  "ok i'm sick and spent an hour sitting in the shower cause i was too sick to stand and held back the puke like a champ. bed now",
#  '4 ill tell ya the story later  not a good day and ill be workin for like three more hours...',
#  '',
#  ' i do not either. its depressing. i do not think i even want to know about the kids in suitcases.',
#  "bed. class 8-12. work 12-3. gym 3-5 or 6. then class 6-10. another day that's gonna fly by. i miss my girlfriend",
#  'really do not feel like getting up today... but got to study to for tomorrows practical exam...',
#  "he's the reason for the teardrops on my guitar the only one who has enough of me to break my heart",
#  'sad, sad, sad. i do not know why but i hate this feeling  i wanna sleep and i still ca not!',
#  ' awww i soo wish i was there to see you finally comfortable! im sad that i missed it',
#  "falling asleep. just heard about that tracy girl's body being found. how sad  my heart breaks for that family.",
#  " yay! i'm happy for you with your job! but that also means less time for me and you...",
#  'just checked my user timeline on my blackberry, it looks like the twanking is still happening  are ppl still having probs w/ bgs and uids?',
#  "oh man...was ironing 's fave top to wear to a meeting. burnt it",
#  'is strangely sad about lilo and samro breaking up.',
#  " oh! i'm so sorry  i did not think about that before retweeting.",
#  '',
#  " wow, tons of replies from you, may have to unfollow so i can see my friends' tweets, you're scrolling the feed a lot.",
#  'our duck and chicken are taking wayyy too long to hatch',
#  'put vacation photos online a few yrs ago. pc crashed, and now i forget the name of the site.',
#  'i need a hug',
#  ' not sure what they are, only that they are pos! as much as i want to, i dont think can trade away company assets sorry andy!',
#  ' i hate when that happens...',
#  "i have a sad feeling that dallas is not going to show up  i gotta say though, you'd think more shows would use music from the game. mmm",
#  'ugh....92 degrees tomorrow',
#  'where did u move to?  i thought u were already in sd. ?? hmmm. random u found me. glad to hear yer doing well.',
#  " i miss my ps3, it's out of commission  wutcha playing? have you copped 'blood on the sand'?",
#  'just leaving the parking lot of work!',
#  'the life is cool. but not for me.',
#  "sadly though, i've never gotten to experience the post coitus cigarette before, and now i never will.",
#  'i had such a nice day. too bad the rain comes in tomorrow at 5am',
#  ' too bad i wo not be around i lost my job and ca not even pay my phone bill lmao aw shucks',
#  'damm back to school tomorrow',
#  "mo jobs, no money.  how in the hell is min wage here 4 f'n clams an hour?",
#  '  not forever... see you soon!',
#  '_algonquin agreed, i saw the failwhale allllll day today.',
#  " oh! haha... dude i dont really look at em unless someone says hey i added you. sorry  i'm so terrible at that. i need a pop up!",
#  " i'm sure you're right...    i need to start working out with you and the nikster... or jared at least!",
#  'i really hate how people diss my bands!  trace is clearly not ugly!',
#  'gym attire today was: puma singlet, adidas shorts.......and black business socks and leather shoes  lucky did not run into any cute girls.',
#  '',
#  'no picnic  my phone smells like citrus.',
#  " my donkey is sensitive about such comments. nevertheless, he'd (and me'd) be glad to see your mug asap. charger is still awol.",
#  'no new csi tonight.  fml',
#  'i think my arms are sore from tennis',
#  'wonders why someone that u like so much can make you so unhappy in a split seccond . depressed .',
#  'sleep soon... i just hate saying bye and see you tomorrow for the night.',
#  ' just got ur newsletter, those fares really are unbelievable, shame i already booked and paid for mine',
#  "missin' the boo",
#  '1974 me too  #itm',
#  'damn... i do not have any chalk! my chalkboard is useless',
#  "had a blast at the getty villa, but hates that she's had a sore throat all day. it's just getting worse too",
#  ' hey missed ya at the meeting  sup mama',
#  "my tummy hurts.  i wonder if the hypnosis has anything to do with it? if so, it's working, i get it, stop smoking!!!",
#  'why is it always the fat ones?!',
#  " sorry, babe!!  my fam annoys me too. thankfully, they're asleep right now. muahaha. *evil laugh*",
#  ' i should have paid more attention when we covered photoshop in my webpage design class in undergrad',
#  'wednesday my b-day! do not know what 2 do!!',
#  'poor cameron (the hills)',
#  'pray for me please, the ex is threatening to start sh** at my/our babies 1st birthday party. what a jerk. and i still have a headache',
#  ' hmm  , do u really enjoy being with him ? if the problems are too constants u should think things more , find someone ulike',
#  '',
#  "so rylee,grace...wana go steve's party or not?? sadly since its easter i wnt b able 2 do much  but ohh well.....",
#  'hey, i actually won one of my bracket pools! too bad it was not the one for money',
#  ' you do not follow me, either  and i work for you!',
#  'a bad nite for the favorite teams: astros and spartans lose.  the nite out with t.w. was good.',
#  '',
#  ' i hope they will increase the capacity fast, yesterday was such a pain. got the fail whale +15 times in 2 hours....',
#  'behind on my classes for work',
#  'watching &quot;house&quot;',
#  ' remember my bum leg? strikes back this time its serious',
#  ' cool, i will. their are all kinds of complaints about this laptop online about overheating, but no recalls',
#  '',
#  'would rather the first party send bad messages than the 3rd party send mixed ones  sophmore year all over again?',
#  " it's overrated",
#  '_q i know! i heard it this afternoon and wondered the same thing. moscow is so behind the times',
#  'laying in bed with no voice..',
#  "i'm sooo sad!!! they killed off kutner on house  whyyyyyyyy",
#  ' sorry  tell them mea culpa from me and that i really am sorry.',
#  '7 it did not make any sense to me, the suicide thing. i refuse to believe that that is actually what happened.',
#  '  hope your ok.',
#  ' damn! the grind is inspirational and saddening at the same time.  do not want you to stop cuz i like what u do! much love',
#  ' yeah aw but i know i wudnt stand a chance',
#  'ugh. cant sleep. its 1:30am.',
#  'hanging in crooners. wanna sing. ca not. sucks.',
#  '_sc aaw i miss ya all too.. im leaving to bh tomorrow &quot;morning&quot; i think.. aww i wanna go to the beach w u girls!!',
#  "is pissed off that there's no asba's for a radio station.",
#  'wednesday my b-day n do not know what 2 do!',
#  'i know my life has been flipped upside down when i just thought in my head that some ramen sounds good.',
#  'i am in pain. my back and sides hurt. not to mention crying is made of fail.',
#  "late night snack, glass of oj b/c i'm &quot;down with the sickness&quot;, then back to sleep...ugh i hate getting sick...",
#  " but.. but.. but.. i'm not a big fan on camilla belle",
#  " wah i ca not see clip, must be el-stupido work filters. ca not wait 'till i get a 'puter. something else 2 blame ex 4. he broke mine",
#  "this week just seems to get longer and longer in terms of how much i need to do.. and how much i'm actually going to get done",
#  "i'm so cold",
#  " ehhh do not. weather's gonna take a turn for the ugly tomorrow",
#  ' haha its so cooooold in the d! and no  but you should still go to the show. they do some incredible stuff',
#  'hoping the tummy rumbles go away soon',
#  "_ no, no notice. they told me i'd be working tomorrow, and then i called the agency to follow up and they said it was over.",
#  'almost bedtime',
#  "i'm missing you babe..  but as long as your alive i'm happy.. yawwwnn.. i'm tired my love imma try to sleep hopefully you had a headstart",
#  'agh...snow!!!',
#  'i miss kenny powers',
#  " thank you for letting people know, but now i'm sad that the direct message i got was not actually from bridget",
#  '...and, india missed out its 100th test victory n 10th consecutive win without a loss.',
#  " i guess that's a no then.",
#  'sadly is going to bed.',
#  '1992 shame to hear this stephan',
#  " hey! i'm leavin in the morning...",
#  'was intending to finish editing my 536-page novel manuscript tonight, but that will probably not happen. and only 12 pages are left',
#  'laid around too much today... now my head hurts',
#  '202 i still have not read the 9th&amp;10th princess diaries  saving francesca made me cry at the end. hmm those are easy books.',
#  'my nokia 1110 died..',
#  "my mom might have breast cancer wo not find out anything for. like a week i'm so worried!",
#  'going to sleep. hoping tomorrow is a better day.',
#  ' lol.. wish they understood daylight savings has ended though and breakfast is an hour later  they keep waking the kids up too',
#  ' that is lame',
#  'i do not understand... i really do not',
#  'heroes just is not doing it for me this season...',
#  'living not downtown sure is not much fun.',
#  ' not calorie wise   i wish junk food was calorie free! i ate a thing of sour skittles and a big ass cherry coke!',
#  'man work is hard',
#  'getting sick  time for some hot tea, studying, and then sleeeep',
#  'getting eyebrows waxed. more pain',
#  'no phantasy star yesterday  going to work...',
#  'oh - just got all my macheist 3.0 apps - sweet. did not get the espresso serial no though although they said they sent it - oh well',
#  "picked mich st to win it all from the get go.  was feeling pretty good about that pick all the way up until......tonight.  a's lost too",
#  'is alone downstairs...working',
#  'i feel bad for doing it',
#  " is it just me, or she hates anoop. i mean seriously, she's kinda mean to him.",
#  ' yes sprint has 4g only in baltimore and chicago so far',
#  "i'm stuck awake in the middle of the night for the second day in a row. and i felt terrible yesterday.",
#  'thanks for bursting my bubble',
#  "going to school soon... ca not find anything to wear!! gosh it's so hard",
#  ' i was serious  lol',
#  ' i had on my page for sooooo long!!! until it got deleted  sad day in history',
#  '',
#  'currently at work..',
#  'grrr.. my ipods acting weird too! jai ho and thinking of you are not playing the full songs.. ughh.',
#  ' send me the dvd cos i have missed out on heaps  not happy about that!',
#  'i do not see the big deal with this website',
#  " i'm so sorry you're having to go through this. again.  #therapyfail",
#  ' far too out of the way for rail.  any other tips?',
#  "i'm not still up i swear. why do i keep losing. gaining. losing. gaining. tweeps?  so heart wrenching.",
#  'today i realized i am too good at hiding things, even i ca not find it',
#  'staying at a friends house...house sitting, neighbors are so loud-having a party',
#  ' danny im upset that i wasnt here to watch the live chat  i was in a car. for 3 hours on a trip im soooo upset!!',
#  '',
#  'borders closed at 10',
#  "downloading nin's new album &quot;the slip&quot; - when the hell did this come out? i'm so behind the times these days",
#  "just woke up an already have written some e-mail... i've to go early at university today as i have to teach at 8:30 am!",
#  'is watching the hill . . .and its making me sad',
#  'so many channels.... yet so so boring... lazy day again  may have to find a hobby',
#  ' i miss my buddy  ill be in ny on the 25th',
#  "  love the french. i tell people here in the south i'm qtr. french and they snarl at me.  french are beautiful people",
#  'opps.. as i said.. i still got one day remain and now problem come',
#  'i activated my selfcontrol block early, meaning i ca not check out the new qc.  regularizing my internal clock is might be difficult. #fb',
#  '  oh no',
#  'spencer is not a good guy.',
#  ' what about reese dying on #ttsc? and season finale next week.  #24 boring, madame president is a crazy woman.',
#  ' i hate the limited letters,too.hope you and the guys are fine?i pray for my dog,shes not well',
#  "did not get shit done today ~ i'm so screwed",
#  'wanttss to go out',
#  'is not going to sleep tonite.',
#  'too worried and tired to post tonight',
#  "could not get shit done today ~ i'm so screwed",
#  'job interview in cardiff today, wish me luck! got about 3 hours sleep',
#  " your show is whack. way worse than whack, it's wiggety-whack.    :*(:*(:*(",
#  " i really do not think people choose to be that way. but i think he chose not to accept my family's help   he might be dead by now",
#  " you're going to kill me, but i've not seen ds9. i've been waiting till i can do it in one solid week sitting.",
#  ' i think ur right!! hahaha!! 4.5 hrs now!!',
#  'i hate to see the spartans so sad',
#  'my mind and body are severely protesting this &quot;getting up&quot;  thing. had nightmares to boot',
#  " i'm goin' to follow u, since u did not  lol  go angels!",
#  '',
#  '202 i think i want to read some books but the library does not have them',
#  "my nap was interrupted so many times today  going out for japanese with the 'rents again...",
#  'kind of longs for the bus that shows up at the end of ghost world right now. ugh.',
#  " but this is canada  canada is weird. we're supposed to get snow through wednesday. ugh.",
#  "awwh babs... you look so sad underneith that shop entrance of &quot;yesterday's musik&quot;  o-: i like the look of the new transformer movie",
#  "sad that the 'feet' of my macbook just fell off",
#  "i'm gonna get up late tomorrow and it's 132am here. i gonna get tipsy by my lonesome. that's...that's just sad",
#  "i'm sweating my forthcoming trip to e3.  if i ca not find someone to crash with while i'm out there, i may be screwed.",
#  'has now gotten somebody to read his tweets, but cant get them to make an account.',
#  '  omgawd i couldnt handle my cat being in heat all the time d: d:',
#  ' i hope i can make it to the auburn show. but its not looking good for me',
#  '_henrie *thats people mag haha i couldnt fit it all in.. i dont think those pictures ever made it in the magazine tho!  haha',
#  ' congrats!!  i totally forgot to submit photos',
#  ' awww, good luck paula!! please do not work too hard  but i hope you have fun  your new album is gonna be amazing!  xxx',
#  ' now your leaving me  .... -gets sad-',
#  "i miss you twitter. my phone broke, now i'm using a stupid nokia phone. ughhh, i miss my advance phone.",
#  'shooting outside my house :o not kidding! so scared',
#  'tuesdayll start with reflection n then a lecture in stress reducing techniques. that sure might become very useful for us accompaniers',
#  'what tragedy and disaster in the news this week',
#  'yes yes still trying to find a picture that will upload correclty..',
#  'why oh why was the red sox game rained out? i was so looking forward to opening day',
#  'i still ca not find my keys.',
#  ' i know right. i dunno what is going on with twitter.',
#  'might be getting a sore throat again',
#  '   my home town. my mammy called all depressd.  pls explain y a parent let their 8yr old child walk alone? hello? its 2009!',
#  ' - i think i need to find better anti-depressants.  i think this paxil/wellbutrin combo is losing its efficacy.',
#  ' restaurant called woodntap has competitive eating tourney round tourney time. we place 2nd',
#  'is in the bathroom... wake up lakin.',
#  ' i want tacos and margarhitas  telll gay i say hello&lt;3',
#  'im lonely  keep me company! 22 female, california',
#  'bad day at the betfair office',
#  'i miss him.  ca not wait to celebrate the tar heel win this weekend though!!',
#  "i'm really cold. i do not want to go to sleep yet but there's nothing to do",
#  " is this it 4 u? its ' officially over ' 4 me this go round!",
#  "monkeys??? i just found out you my twin and you wont even write back.  i'm heartbroken",
#  '_om aww  i know i felt like that yesterday at work',
#  ' treaty is not defined',
#  'missed brent at praise band.   no fun to not have the your lead guitarist.  &lt;pout&gt;',
#  ' poor john  this is what happens when you play with fruit and a microwave! seriously though have you seen a doctor?? xxx',
#  'missing my bff  watching home and away it reminds me of her and me  we &lt;3 it. shout out to u courts',
#  '',
#  'new video card is doa.',
#  'feeling lost, naked and confused (jk, sort of).....no iphone for me.',
#  'damn i am so late at filling this appraisal form, people have almost sent it .. i was so occupied in work',
#  'missed brent at praise band.  no fun to not have your lead guitarist. &lt;pout&gt;',
#  'i think to much on the past. i cant change it. i deserved so much more then wat i got. ..but why am i still thinking about him  gah',
#  "has lost his ring. it's no-where to be seen",
#  ' ooooooh! *sealclap* see, i download shitloads of zip folders off 4chan. i have no internet moneys.  fuck yeah alicia &amp; mikey.',
#  'is still nursing my nile but glad he is feeling better. i hate when my baby is sick',
#  'is fucked to go back to ic',
#  "8 yoyoyo. my internet has been rude tonight. it just reconnected and i'm about to go to bed.",
#  " well i have uni stuff and netball  but after netbal if i've done uni stuff we can",
#  ' me too i is poor',
#  'help me forget 8th april &amp; 13th july!',
#  "dierks bentley is comin' to columbus, oh!! i wanna go so bad",
#  'i have to take my sidekick back.',
#  " congrats! i'm totally jealous! only wish my xm was working",
#  'gr8t my face is very itchy',
#  'poor socks  luvvvvv the golden retriever!! i want one sighhhh',
#  'i just saw that they found that tracy girl in a piece of luggage... how fucking terrible',
#  'aaaaand the nausea is back.',
#  ' ooh im excited and not even going 2 be there  long love youtube!',
#  'spent 1 hour to reach to axis bank only to find out today is holiday for mahavir jayanti  contd..',
#  '  i agree... the jobros dont update theres very often',
#  ' it is hilarious and i linked the clip from lj some time ago but when i went back just now it was a dead link',
#  ' oooooooo who with? (im not neither but thats because i need to study  )',
#  'have not tweeted nearly all day  posted my website tonight, hopefully that goes well  night time!',
#  ' i miss bentley',
#  'seriously needs to finish these job applications',
#  'my son vincas is sick, so i stay at home  just three tense days at work, and i am back on holiday with kids',
#  "whinging. my client&amp;boss do not understand english well. rewrote some text unreadable. it's written by v. good writer&amp;reviewed correctly.",
#  ' i do not want him to ever punch me.',
#  'sooo sick of the snow  ughh',
#  '_nemesis -------',
#  ' it does not work your fan is upset',
#  'i would like to apologize for the repeated video games live related tweets. i am going to have a stern discussion with koodo soon. stern.',
#  ' but i cant figure out how to get there / back / pay for a hotel etc',
#  'fml: so much for seniority, bc of technological ineptness, i now have to &quot;register&quot; for classes again',
#  'feels like she slept the day away.    not looking forward to any more bouts with my gallbladder.  at least i have pills now for the pain.',
#  ' but what i really want is my old bass back',
#  'mad tired today... callin it in early tonight  nighty night twittas',
#  ': take it easy, and be good to you.',
#  "i'm afraid i had bad code.",
#  "think i'm going to bed. goodniight. i hate this",
#  "  i'm here, friend, and i love you.",
#  '  all this time you did not notice i was gone...just needed db2 is it??',
#  ' is in the bathroom and i have to pee!',
#  ' but i wanted a margarita too!',
#  ' yup night workouts r the worst but unfortunetly my work schedule only allows me to go at night  its tough!',
#  "just called hillsong again - they said they could not tell me where i was on the waiting list - i do not know if it's looking so good",
#  'has 0g of milky bar left, and around 200ml of coke',
#  ' it stillllll has not arrived',
#  'mraow, i feel like dancing, but first art school wants to rape me some more.',
#  " ah! i bet it does i've been like craving to play softball or basketball !!! but i have noo time",
#  'is terrified she accidentally deleted a reference in her management assignment and hopes she doesnt get in trouble when she gets back',
#  'amazon s3 plugin not worked in my website . it need php 5 . but my hosting provider has only php 4.4  . very sad.',
#  "argh! i was suuuper sleepy an hour ago, now i'm wide awake.  hope i do not stay up all night. :-/",
#  ' i wish i was!  sold out   if you have some time let me know, i would love to hear more about what you are up to!',
#  'just watched tropic thunder. dreading tomorrow',
#  " no...he's still miss'n...",
#  'chiefdelphi is down',
#  '',
#  'playing game at home! my new boss did not call me yet...',
#  '',
#  'poor joshy is sick???   those damn tejanos!',
#  "my thoughts are with sandra cantu's family at this difficult and sad time",
#  ' i know, just wanted to let everybody know what was happening',
#  'michigan who?  i do not know them.                   *sigh*   shameful!',
#  'i have to fill two hours',
#  ' so cuuute! hey, i miss you na!  its not the same not seeing you girls everyday',
#  ' oh! did i mention it? &quot;gooooood moooorniiiiiiing&quot;  from germany! im back in my cage....or better...my office',
#  'throat is closing up and i had some string cheese. not a good idea',
#  'aww, sandra cantu is found dead in a suitcase  missing children stories never seem to go good. poor family.',
#  'wishing i was home underneath my covers',
#  'walking home from school drains all my energy',
#  "1013 i agree. the shapeshifting is a copout. i was so excited for angela's ep, i thought it was this week.  noah was awesome tho!",
#  ' dang! i would have done this if i knew it was there earlier.  any other outings planned?',
#  "i wish i was better at writing. it's taking me so long to write this paper.",
#  '..and of course... i have access to my halo 3 mythic map pack re-download.. but bad news.. not the legendary map pack... ugh.. 600ms...',
#  "2ia ...not yet unfortunately, another few weeks i've been told  how are you? i've been a little bit busy with my latest project.",
#  " ha the sun's already gone",
#  "day 2. a lot harder than day 1. let's see how day 3 goes tomorrow.",
#  'my man crush jake peavy let me down  #gayforpeavy',
#  ' megafast trip, you have time during day tom/weds? or, you going out tonight? want to see you bad. tried to warn you, tech fail',
#  'michigan state you make me sad',
#  'omg. my mouth is in so much pain  i just wanna sleep untill its time to take my braces off.',
#  '',
#  ' hey girl. the site is back.  girlyvue is back and they have even more videos.',
#  "5hleyf i'm spending time with my grandma early tomorrow and i ca not leave skittles by herself.",
#  'just got home from watching michigan state get tromped!',
#  "oh jew-bus! two years worth of classes' work is alot to organize &gt;_&lt; i'm not finishing tonight, it's not possible...my bones ache",
#  ' no exchanging for me, my laptop has not arrived',
#  ' i hope this does not last too long.  i feel miserable!',
#  ' rachel! hang outage is neccessary - i was gonna be home this wekend but dumb folk make me work   so im free f and sat until 4...',
#  ' not fun &amp; furious? the new mantra for the bay 2 breakers? it was getting 2 rambunctious;the city overreacted &amp; clamped down',
#  "_benson  my hubby (for some reason) thinks it's more important he has a good spot for red carpet for the trek movie premiere. sod!",
#  "i swear no matter how long i've been getting up at 5am, it never gets any easier. man my eyes hurts wah",
#  '_star jeffree! how do you keep your hair one color? my permanent dye fades within the week',
#  ' my reaction too  whoa, did not see that coming',
#  "still sick. feeling a bit better, got some new medicine.... hope i feel good after a night of sleep. ohh, and it's suppose to snow! wtf!",
#  ' i think maybe you should get a couple more hours of sleep, hon. how productive can you be right now if ur dog tired? i worry',
#  ' thanks a lot. learned a lot of new words but did not find what i was looking for.',
#  "wish i had all the xblm downloads all on the gamertag 'hitokyri'. this 5 gamertag thing is nonsense... and i'm tired of it",
#  'new testament test at 9:30 am',
#  ' tons no hay troll? ahhhh',
#  'stupid movies we watched... mirrors ugggggh... stooopeeed!!! rip off!',
#  '',
#  'last one!!! but still not done!!!',
#  'homework....',
#  'i do not understand why things get taken away. i did not have enough time with him its unfair. i want him back!! he was like my baby',
#  'scratch that: du in heif (two in a half) cookies. my tum just ca not take anymore shoog. poots',
#  ' i was just listening to the sweets for the first time in forever! i miss them so much  can we go to chi town for visits plz?',
#  'geez what a busy afternoon. meetings, emails, meetings and email and more meetings. 6pm and the day is still going! ah its dark and',
#  'dang!!! another spring break!!!  how cool is that???  too bad i have to work all week  oh well, more money for a phone.  ttyl everbody!!!',
#  '_kate im afraid too  ( ur reply about uni from ages ago',
#  'feeling down',
#  '1 lol they are some emotional ass men!! omg all this late night eating.. both of us are broke',
#  '_carter aww nick!! i like your hair longer, why did you cut it off?  break. my. heart.',
#  'wonder if jon lost the net',
#  "wow. the most depressing thing in the world is losing a video that you've created in a matter of seconds.  #fml",
#  '',
#  ' lmao im sorry poohpot i ate it all!',
#  'any chance  softbelly (for ) is not loud?',
#  'time to move my posterior  and lose some fat. my articulation are creaking so no more running  but im drool for some swimming',
#  'listening to nathan cry....',
#  "today sucked. i'm gonna die without chris and callum!  wahhh!",
#  'stou site not update, no info about 2/2552 exam, and open course, i must wait for mail notices and doc. um...',
#  "30...i'm sorry. i'm feeling kinda yucky myself. 5am is going to come too quick",
#  'is in love with scrappy and is missin him already',
#  "wants to hear  's song but myspace is messing with me",
#  'bad news was dad has cancer and is dying   good news new business started and  i am now a life coach practising holistic weight management',
#  '_rebecca man... intervention is soo sad',
#  "help! i need a new boyfriend... i'm stuck in a rut",
#  "i feel like a complete idiot. i'm the only one who does not get how this shit works  help me",
#  'saw an ad on craigslist for a casting call for a female host on g4. i was totally psyched! but realized it was a hoax',
#  '',
#  " yes, it will be. it's only monday",
#  'i want the new gg episode already',
#  "i miss watching rocko's modern life.",
#  'rip sandra....its so sad    how can someone do something like that??',
#  'keeping my fingers crossed for my buddy    he is not feeling well.',
#  "wait should i eat?? or be skinny for vegas!! i'm hungry!",
#  "_inovera i tried tweetdeck once and i hated it with a passion. or it hated me, i'm not sure...",
#  " btw my iphone is acting funny, dying quickly and freezing and bs.  i'm not admitting anything, just sayin",
#  'sitting here wondering why &quot;ed&quot; still has such a strong hold on me',
#  ' im sorry i got you sick.  lol. going to bed too. night!',
#  ' no internet at home, have to drive into ox to use internet because of builders!',
#  '_buscemi the weather in canada is freezing',
#  "twiggassssssss i been out of range all day  i'm back now and hopefully for good.",
#  '',
#  "anyone who reads this pray for my grandma. she's in pain",
#  "#3 woke up and was having an accident - &quot;it's pushing, it's pushing!&quot; he was crying because he could not stop from wetting his pants.",
#  'home from franklin street, i almost jumped over a fire. someone kicked it before i could.  jenny lost her shoe.',
#  ' hey! you just changed your default.',
#  'finally gave in and was bored enough to start this thing. i think the 140 is going to be a problem for me tho.  its like a myspace status.',
#  ' if oooonly we were really so lucky, eh? and awh  definitely too early for work.',
#  'buttload of homework!',
#  'needs another copy of visual studio 2008',
#  "why to we, the only school in the world, be in this week.my school is silly  anyway... look on the bright side. when i'm off, u will be in",
#  "omg i've an economics test. and i dont know all the things i have to know and omg im gonna fail",
#  ' once upon a time hundred islands was the pride of philippine tourism, but coral/clam/rare fish poaching did it in. kinda sad',
#  ' yeah, apparently i have really bad taste',
#  ' i know! i was really surprised since everyone recommends them on youtube.  i have to call them tomorrow and figure it all out.',
#  'waiting at the airport for my ride while i get harassed by 2 men trying to sell me ugly hats.. why me?!  i just want to sleep..',
#  'i left my ids at the location and now i can not go out to bars  fuckkkkkkkkkkkkk',
#  " i'm sorry i do not understand your last comment",
#  ' when is the announcement? i stayed up late last night',
#  ' this is strange, illegal torrents avlbl everywhere, legal dvd not in stock  what do i do now???',
#  'its not enough to say that imiss u',
#  'this trolley has up packed in like sardines! padre game and they remove a car?! good call mts',
#  ' jeez, i was just trying to help  haha.',
#  ' that happened to me saturday night. along with my glittery green lighter!',
#  'trying to reduce the number of cigarettes in each day!',
#  'yea it is so quiet around here cuz everyone has to work im bored to death with nobody to talk to',
#  'gotta do my cooking assignment  its too hard',
#  " okay, about the applepears, i've talked to a few people and they've all had them before. no one ever told me, never",
#  " i know!  i'm a night owl by nature, hahaha am i a time zone behind you? it's almost 1 here",
#  ' lol - nope! but i did have complete #camerafail',
#  "68  but! i'm useless if i do not sleep  it's not fair! i want all the fun as well!!!",
#  'my pookie has a uti.  i have to be nurse gabbie and get him back to 100%!!! no more sodas!!!!!!!!!!!!!!',
#  ' tweet something damn it!  and hang out with me please?',
#  '',
#  "i'm so behind in video games, and everything for that matter. i'm yesterday's news",
#  '_til_noon i did, it was the only one left but i got tempted and ate it soon as i got home  i had a chocolate velvet &amp; ate d mocha',
#  'is stressing out because my blackberry keeps flashing a red alert status for no reason!! its faking me out and i hate it!!!',
#  '',
#  'when to the shoe repair shop and the guy could not find my shoes!  so i have to go back and see if he can find them in a couple days.',
#  '_barnett i did not really see that coming',
#  'just woke up from the most vivid, sketchy, not-cool dreams of my life. time to stare at the wall with the lights on.',
#  "it'll take 3 days for my sister to get her passport",
#  ' oh my yes!! i miss',
#  'uh oh... i think i am getting sick',
#  'good god they ruined my belly button!!!',
#  'watching who framed roger rabbit. makes me miss toon town.',
#  ' renting.. but very cheap renting, and awesome house. we had 3 buying attempts fall through',
#  'running nose + spinning head = not a good combination for a meeting!',
#  '87 negative.. you lost my vote of confidence',
#  'nasty budget due and my iphone is being sent to apple today.',
#  '_noel thats bad',
#  'dammit, episode 3 of kings wo not play for some reason  stopped in the middle now wo not do anything',
#  "i'm so upset that i missed my chat and quiz online because my free internet has ceased",
#  "ca not believe it! i'm in disbelief of it all in a way really. how much can i take from people and always get hurt by others!!",
#  'car show season has started without me',
#  'my throat is raw.',
#  ' i just do not get it. what in a persons mind could even have them on some ish like this???  my prayers are with her fam for real',
#  ' i hate you. i did not need to see that. i need to call my therapist now.',
#  'twilight did not come yesterday  fingers crossed for today',
#  ' glad i was able help you feel better. i hate to see you sick  love you!',
#  'is tireddddddd. want to sleep but i have an assignment to finish and an exam tomorrow to study for',
#  'you know, i was thinking... i need money',
#  'omg..its jst teusday',
#  ' _henrie ummmmm i cant find it.',
#  'just heard that they found sandra cantu... she was only 8 yrs old',
#  ' ive forgotten how to snoo-snoo  i wonder if snoo-snoo and i will ever meet again...',
#  ' wow that last tweet made me seem like a giant sexist...sorry about that',
#  'my bathtub drain is fired: it haz 1 job 2 do, &amp; it iz fail. i got all drano on its ass, &amp; iz still not draining. i wanna shower, dangit!!',
#  'stuck at home',
#  ' mine is 1/10  how do you get it up?',
#  '',
#  '_news thank you! however, i hate to be on the same list that includes 2 convicts.',
#  'heading to altrincham, again! out of hours install',
#  'morning!!! good im bloody knackered!!! work is not for me today  helppp!!!! xxx',
#  '  i do not have a garage.  but you can park in my driveway!',
#  '  what happened?',
#  "&quot;on popular music&quot; by t.w.adorno is probably the most difficult reading ever prescribed, i'm actually struggling to continue",
#  '',
#  "we've been good. i'm not liking the snow right now, was getting used to the nice spring-like weather.  how about you?",
#  '_armstrong what a pity youtube is currently blocked in china.  i ca not see the vids.',
#  ' what happened to your show it was the hightlight of my life',
#  "this is the best leather sofa in the world!  it's in the office though which means i'm still here working",
#  'still 3 more days until my internet gets uncapped',
#  'if he does not get better in a few days, he could have something lodged in his belly',
#  'i love my atekinzz so much. &amp;&amp; i soo miss her..',
#  'i wanna sneak into the zoo and play with the kitties',
#  " oh no  hope you're not getting sick too!",
#  ' i dont think i can cause its my cousins birthday party',
#  'our sweet little man just fell asleep while waiting up for daddy and big brother to get home!  poor baby, he missed them so much today!',
#  'the angel is going to miss the athlete this weekend',
#  'trust is hard',
#  'have watched that considering today. yaknow. shawnna tomomorrow;i need my bestfriend',
#  'grr i want to keep reading but if i do i wont have anything left to read',
#  'atekinzz, where in the world are you??',
#  ' no! u supposed to be my date',
#  "pears &amp; brie, bottle of cabernet, and &quot;win a date with tad hamilton&quot;... oh gawwd my life flashed forward to when i'm 40 with my 75 cats",
#  'crap. i need more dresses too.',
#  ' yeah! i know! it was horrible!!!! ugh. saddening.',
#  ' geez ur no fun are you',
#  'i wanna be in a punk rock band again',
#  " that's a lot of angst for a tuesday afternoon",
#  "i'm very glad britney is not crazy anymore! that was one hell of a show! now i'm sad that it's over.  next up...ap at cook county!",
#  'has a huuuge headache! omg i feel like crap!',
#  ' sorry',
#  ' sorry...i was rooting for them too...',
#  'man, that took forever.',
#  '  i see.',
#  'i am listing more items on ebay to sell!  takes forever..meanwhile coleman is watching the hills season premier without me..',
#  "just got my presentation done, 23 slides done...  i'm crying for this week will be the hardest of all weeks.",
#  'just lost $160',
#  'i do not like the previously on skins thing that starts at season two. i like it when it went straight into the intro like before',
#  " ...i wish i was there...i'm pretty good at scaring the shit out of people",
#  'going to sound vain... but running out of my fav lip gloss',
#  " never again will i click on a link that screams, &quot;i'm a spider, i'm a spider&quot;. i should have known better. yucky",
#  'why is that when you have time off from work you get sick?',
#  ' same imac came out $320 more in indonesia than the states.',
#  'dammit... i need to stop buying furniture',
#  '_sil no i was half asleep and turned off the laptop after that',
#  'death is peaceful,  life however, bites',
#  'i think  lost the net ? sure hope not',
#  '',
#  'such a tough game to watch tonight for state  finally going to bed after also staying up to watch the season premiere of the hills!',
#  'seems jruby support for hpricot is now two versions behind',
#  ' unlike my sister...i still do not have one',
#  '',
#  'logging out. i need to study....',
#  'anyone else having problems accessing ttb??? i cant get on!!!',
#  'i strongly dislike people who make stupid comments and dont know the whole story',
#  "  i'm sorry emma, is swarley a goldfish? i'm sad for u.",
#  'all my tweets are already gone, are not they  missed you guys tonight.',
#  "ca not sleep again. face is kinda swollen. do not let me be allergic to the thing that'll get me to thursday. school tomorrow? doubtful.",
#  "_the_dog if izzy's on the cat tree, she'll stare him down, but if she's on the floor, he chases and she runs.",
#  "i am officially banning godaddy.com from my comp. my head hurts from the small print and i wasted $10 that could've happily gone to boba",
#  ' pretty much just scary for me',
#  " mines too... i'm finding it well hard to get fit...",
#  'good morning! ready 2 go, but i want 2 go back 2 bed',
#  'hates waiting for mails',
#  'wheat bread from the dollar store just does not toast nicely  going over my taxes and calling it an early night',
#  "why kutner? i mean i knew something was going to happen to someone but it was so sad. i &lt;3 house and it was well done, but i'm still sad",
#  ' aw ok goonite....',
#  'ill so i cant go to the cinema!!',
#  'fell asleep . . . really did not mean too  *christina*',
#  ' hey, you remember that time we used to be friends?? ;)  ugh. vomit. sick.  i need sleep',
#  "my lymph nodes are as massive as rahm emanuel's balls right now",
#  "oh no my computer sucks. i do not think i'll be able to listen to the xbox 360 fancast tonite",
#  'is missing playing my trumpet',
#  'my throat is still really sore. i was meant to be going on a 5 day camp from friday but not so sure now',
#  ' i know exactly how you feel!',
#  'at work',
#  'well bed time now. 1 am. *sighs* back to 6 am mornings for a week on wednesday.',
#  ' jesus camp? yeah...',
#  ' oh no! with everything that happened today, i forgot we were going dress shopping for the opera tomorrow.',
#  'turtles are better than my mac - lasts longer and moves faster',
#  'i am soaked. this is not pleasant',
#  ' sorry to hear about maggie.    thoughts to your mum.',
#  ', you may have to email this one to me  i hope you feel better.',
#  ' dead @ yu gettin on wen im leavin',
#  " please tell me that's somewhere close to california!!! lol!",
#  ' where are you?',
#  "stupid arranged marriages... i'll convert so you can marry me...love you!",
#  ' well he said that he is a looser, and that is what the show implies',
#  'poor sandra cantu &amp; the cantu family! my prayers go out to them! what a sick world we live in. she was only 8',
#  'fuck omg  austins always there though man &lt;3 love you',
#  ' i cried so hard when matthew died',
#  "sad that the 'feet' of my macbook just fell off : sad that the 'feet' of my macbook just fell off",
#  " - why am i the last to find out about these things? like that you're on the twitter too.",
#  ' absolutely not!!',
#  '',
#  'im soooo cold right now',
#  ' lol i kant believe cam got beat upp sooo embarasssiiiin',
#  ' good knight hun! looking forward to ur tweets again! hate that i keep missing out on the fun cuz of the time difference',
#  '',
#  "_95616 hahaa!! i just realized &quot;impune&quot; definitely isnt the word i wanted... dang. i'm so unclever.",
#  'watching old videos of dance team and such... makes me miss it',
#  "wahh  no csi anywhere! dvr'ed i love money 2 though - gonna watch it then sleep - goodnight tweeters&lt;3",
#  'struggling hard with inventory',
#  ' do you hate us?? please do not',
#  ' haha im not that ballin. i still got bills to paaaaay',
#  "i'm in one of those days when i really just want to work from home.  crap.",
#  "_e_wog wait...is it a game or just episodes? i'm so confused.",
#  '66 haha. i cried...  i guess he did....',
#  'i do not get statistics!  its all a bunch of mumbo jumbo for me.',
#  ' got it, sadly, only works for uk &amp; us at the moment',
#  'evicted',
#  'does not enjoy learning css.',
#  ' brian do not make me fuck u up lol i replied 2 ur message...did u get my # ? i miss u',
#  " i  dvr'd it and went to watch it, apparently the dish network went down so i missed it    i will have to catch a rerun!",
#  ' lmao. u may have to wait for another season to come thru. its summe boo. hot nd dry ass weather',
#  ' i ca not set my feet on the ground. the missing eyelid people might get me!',
#  '_95616 my english professor would be ashamed.',
#  '',
#  'came home from cross county, tired as',
#  'i do not want to walk home in this snow. who wants to pick me up?',
#  ' lauren is being stubborn. she loves you, you love her.  i feel so bad for you, though. it made me cry  lol!',
#  'is grouchy. and wants bmar',
#  'my heart is broken every morning dropping foo at pre school, now i understand when moms say &quot;he has my heart broken&quot;.',
#  'not feeling well and back hurts',
#  'im in the mood for some chocolate. i want..... miniature reeses cups. now',
#  "i ca not take this heat! it's like an oven in here. i feel sick nwo",
#  '',
#  'boredd. colddd  internet keeps stuffing up',
#  "i had a horrible nightmare last night which affected my sleep, now i'm really tired",
#  'im lonely  keep me company! 22 female, new york',
#  '_4_broadway lost  and it was st. ignacius prepatory school. haha.',
#  ' yeah  it was really depressing... stuff like that gets to me',
#  ' no problem, tongue-in-cheek remark.  lots of acronyms, but no nz',
#  ' hey you said matt was gonna go all ballistic... i was disappointed  good ep tho mostly',
#  'ugh horrible ending to the sandra kantu story  prayers go out.',
#  '',
#  'morning folks 7.00 am ..yawn! up &amp; away to see to horses - hope twitter is better behaved today!  last night was a travesty',
#  ' i miss mine too!',
#  ' sorry to hear about your loss.     there have been many this year so far.',
#  ' gossip girl was a repeat',
#  '2410 i reckon',
#  'finding it really hard to use twitter',
#  "i've been stuck in this house for two days",
#  'is really sad and does not really know y!!??!!!',
#  '_miles no',
#  "maybe one of these years i'll get a tax return.  a girl can dream, right?",
#  'back at work, tired as hell and i feel a cold coming',
#  " 2serious april 9th isn't coming soon enough",
#  " cream for his eye and he may have herpes - not ocular herpes, but a different strain.    he's doing okay though.",
#  'gotta repeat  whole art folio cuz old one with a whole terms work got wet',
#  "i'm ready for the weekend already. it's only monday.",
#  " umm nope..think im an insomniac ..plus i got the flu...i'lll be sleepin like a phuckin fish outta water any minute now!",
#  'has finland sleeping for the night, not really enough time',
#  ' ca not wait to try em but prolly have to wait until next weekend at the earliest',
#  'shiner is taking up all my bed and blankets!',
#  " april 9th isn't coming soon enough",
#  'wants to cry',
#  'i need to go to the bank tomorrow before i go broke...',
#  "this earthquake in italy has me sadden.  it's only three hours away from naples, where my family is",
#  'i should be sleeping, i have a stressed out week coming to me.',
#  ' yea   i am working tp hack my server to do the 12player thing for folks',
#  'has hurt her ankle!! and is going to the dr',
#  ' oh noes. how did you manage to send something to the trash can and empty it without noticing! i feel for ya',
#  "lost my free copy of radioactive so ca not put it on my ipod grr!and i ca not go out + buy 'nother coz it came with that paper",
#  'doing make up shit',
#  'photoshop, i hate it when you crash',
#  'vacations makes me feel sick!',
#  'you should not have gone',
#  'listening to murd and 9th wonder- just chillen out missing my crazy sex life',
#  '4: shooting!?!! be careful, luisa',
#  "6 i'm sure everyone has ruined my gift to you  whitney has my serious cell #...we doing easter as well?",
#  'is at beso in hollywood... so tired',
#  'i do not want to wake up early tomorrow.  damn you, work!',
#  'just finished watching the movie prayers for bobby. broke my heart',
#  ' is myki really horrible?',
#  ' i had 2 put my dog down today too  someone ran her over',
#  ' sorry to hear about your dnf run tonight. always a risk to get bad coords on an ftf!!',
#  '3223 i did get some disgruntled people when i wrote my esn, but the 1000 hits in one day made up for it. bill pulls in 250 tops',
#  "394 ohh! omg. lmao. i'm crying right now, lol! kutnerrrr was the best!",
#  'came back from running and took a shower...why does my lower stomach still hurt after exercising?',
#  'watching fallon with mom and working on a project...school is hard',
#  '56 min till home time and counting! i have a craving to visit the mac store but they will have closed by the time i get there',
#  ' i am so sorry to hear that!  take care!',
#  '  hmmm...greed is good when it motivates the individual to do better-not so much when it takes away from others',
#  ' brat! you have to rub it in, do not you.... i want a mocha',
#  "kutnerrrr!  why??? why??????  and to think that 13 is still on the show?? ugh. kutner/kal penn - you've been the bright star in ho ...",
#  ' my mom has it. i wish you the best of luck',
#  'i so hate homeworks -.- my head hurts so bad',
#  "got the ebay blues! item i want jumped from no bidders to over $100 in an hour.. still has 3 hours to go. i'd better not get my hopes up",
#  ' i know -  was a little depressed that we ate so much last night there were no leftovers today',
#  'well the pc in my living room suffered a fatal partion lost, all my itunes library is gone.. and some docs with pics....',
#  'sad day: manu out for the season',
#  ' you poor spunky...its so sad...my rotti made it to 10 and i had to go down the same path....i know how you feel',
#  'im sooo sad right now  i need a hug',
#  'wants her step brother home  im so worried, you dont even know. i hope he knows how much i care for him...',
#  ' just got done watching the hills! loved it! excited for the next episode! and im sad this is the last season!',
#  ' aww that stinks!  *hugs*',
#  "i'm tired. i feel like crap. and the world feels all crummy. make me happy, usb disco mouse.",
# ...
#  'well, so much for being productive on my 2 days off from angels',
#  ' oh gee - insomnia sucks   have you tried melatonin?',
#  '86 good to hear that we have support in netbeans. but then its netbeans you know',
#  ' i wish we would get it the same time at the rest of world. unfornately i am in cairo and have to wait for mtva to play it',
#  'heartbroken over little sandra. prayers are with the family.',
#  " i'm at 900 words, it's all can do  i'll finish tomorrow maybe",
#  ' how come ur background covers the screen but mine is in the corner?',
#  'wrote exactly three lines of dialogue tonight, then gave up.',
#  "1 my only complaint about facebook is they've changed it so much it's confusing",
#  'sliced my finger',
#  'going thru town and traffic on bypass is stink',
#  'ugh ca not sleep.  wish i had a good cuddle to  make me ass out',
#  "i hate when software update downloads updates without telling me. i never know what's downloading when it is",
#  'went to ihop again. great for a diet   at least there were no kung foo pancakes this time. -rachel-',
#  "the internet is hating me. night i s'pose.",
#  " i'm so jealous.  i missed all of opening day this year",
#  "it's so cruel having to wait for reviews to come in.  so far it looks like star trek will be the best film of the year!",
#  'debating if i should just shower now, so i can sleep a little later tomorrow',
#  'my stress always culminates with physical pain.',
#  'need to sleep. but cant',
#  'my little pinky finger hurts so much..',
#  " i'm sorry your gift card ran out.... that suck.",
#  'home for spring break. no one is home tho',
#  'i accessed oneindia.mobi from a google phone (android). it does not support indic languages',
#  'why does school take over your life so much you do not get sleep anymore  .. i am still doing school work and have more to do as well',
#  ' aw i wish i could! i ca not really speak to my yia yia because she does not speak english',
#  ' no free comp lol',
#  'getting ready to clean the house from top to bottom',
#  'crying  my friend is moving away tomorrow',
#  ' stop nomnoms!!!! ..you did not share!  night peoples!!',
#  'thinks she is getting a cold that she caught from daddy.  oh no, my trip would be ruined.',
#  '394 yeah  is it bcoz kal penn is a visiting lecturer somewhere n cant be on the show anymore? im gonna miss him',
#  'so the procrastination starts early in the quarter. i do not want to reaaaaad and write a paper',
#  "what? apparently it's 52 degress at 11pm in washington state. i miss winter already",
#  'being bored at homee',
#  "massage was great. i just spilled coke all over my desk  lame. watching the simpsons as i've finished all my hills dvds.",
#  "_carter i will wait for you at fanclub chat.. even tough you're not my favorite",
#  'has a mild left inner ear infection.. and its got this irritating &quot;blocked&quot; feeling since sunday..',
#  ' hey there! nope. my cuteness  is away for awhile',
#  "it's only tuesday",
#  'haha not even yo. i just did not know how to do that  to you on twitter  haha',
#  'someones alarm clock or a phone woke me up at 3am...still got my headache from yesterday night',
#  ' awww poor puppy is she ok?',
#  'i might break down and eat some buffalo wings tomorrow',
#  "sittin here w/kayla, i really really reallly dis-like having a brother.  he does not know when to stop. i'm waiting for the day when one of",
#  'fed bokkie too many birthday treats-sicko',
#  "'s kinda bummed. an agency just told me that i did not have the 'look' that they were going for. ladies, please help me create the 'look'",
#  'work laptop is officially dead .. not happy at all..',
#  "my goodness, it's freezing down here !!!!!",
#  ' why do you put up with him!!!!!  you should listen to your mom',
#  'is stucked in paris and ca not even travel into france (for work)',
#  ", i do not think there's one close by. last time i checked, the closest one was 70 miles away!",
#  'aaaaand back to my literature review  at least i have a friendly cup of coffee to keep me company.',
#  'i am worried that i wo not get my $900 even though i paid a buttload of tax last year !',
#  'okay, so.. still no school!!!!',
#  'is phoneless  ...now off too sleep',
#  'reeked of alcohol at the dentist this morning + was drunk when i put on my tshirt, realised it had a huge stain. dentist looked disgusted',
#  'it is really cold',
#  'cant sleep  she wants to dream!!',
#  'ca not sleep  i hate these nights when i try to go to bed early and stay awake for hours. poo!',
#  ' yeah. too bad people like a certain burrito-eating man exist.',
#  "  that's sad.",
#  'just found out that my mum  and my adopted auntie are on twitter.. check them out my mum is tessm64 and my awesome as auntie is tania38',
#  'cannot sleep....wide awake!!...and i gotta go to work later too. boy, am i going to have a crappy day.',
#  'struggling with eam law',
#  '',
#  'bouts to start 24. poor linny could not keep her eyes open.  she tired and has to work tomorrow morning. night .',
#  'my 4 year old (18 year old) is driving me around the twist...i do not want to be like this',
#  'well, that sucked.',
#  'i have to be out of my place in 3 days...any help i can get packing/painting/cleaning is much appreciated. oh. and rip my wall',
#  'opening a partially frozen beer= beer on the toaster, under the oven and all over the counter. the kitchen smells like we run a speakeasy',
#  ' no  i dont even know how to ride it',
#  ' sadly, yes. i think i need counciling now',
#  'making myself ready for school...do not feel like going, but have two tests',
#  "smugness gone. my train also failed to turn up so i'm heading for victoria followed by an unpleasant tube ride to the city.",
#  'anybody know where my ipod went?',
#  "aww this earthquake in italy has made me sad  just saw the pics on the news, it's terrible.",
#  " never been able to afford to get them out. i'd much rather go through the extraction than continue with what i deal with now.",
#  'why do other pet care people try to run others out of business? or send suspicious e-mails fishing for info?',
#  " &lt;33 codez....they've been mia tho",
#  ' doesnt work on my cell  go to sleep! =p',
#  "it's going to be nice again tomorrow and then the rain comes back. no nice weather for my birthday",
#  ' rock band is hard..on expert!!!',
#  ': roomie was home all day. all he had to do was scratch at the door. comforter has to goto large laundromat machines.',
#  'one of the hardest thing with this schedule, no one i can chat with at the end of my day usually',
#  "they killed off a character on one of my favorite shows and now i'm upset",
#  'jealous of my friends who got to see the new star trek film in austin tonight.',
#  'listening to q! i got a really bad headache and a drivin lesson in ten mins.... lucky me  i just wana sleeep!',
#  '_buscemi shut up you...i am hungry! and in britain, home of the most boring suckassy breakfast in the world!  i miss dennys!!',
#  'good morning everybody! pkoi y fais pas beau  bon coffee time!',
#  'work again',
#  'essay time....',
#  '78 hey did u talk to mom.. r they home yet? i hope they r ok.. wish i was coming home 4 easter..',
#  ' i sure wish i could go with you guys tmrw. but as per usual, school interferes.',
#  " say what??? kal penn's leaving house?! noooooo!!! awww... i totally missed it tonight",
#  'no! i lost a loyal',
#  'played another hand very bad and lost half my stack',
#  "it's 6.20pm - early days in a looooooong night at work",
#  " it's sad it's the last season.  i wanna see when spencer calls lauren!",
#  'so im done editing &quot;the phipstape&quot;. back 2 crack a brew and see what we got............. no trees though',
#  ' i do not know what half of that means',
#  'homework homework homework',
#  'worked his heart out today, doubling my weight at each station. result: stiff and pulled muscles... ouch!',
#  ' now i feel bad for unfollowing.',
#  'so... tired... god i hate the new job, and only two days in',
#  'sad about kutner being killed off my fav show house!',
#  'happy for coach stringer (hof c/o 2009!)...now if i can only finish my term paper on her',
#  "i feel like shit. this is not the way i want to spend my birthday's eve",
#  'so far i have 311 on all my sites put together,  most of them were me checking out the updates i made......',
#  'has a lot on her mind. i needs to make some moneys. and ideas. nowhere is hiring!',
#  ' miss you',
#  " i'm so sorry to hear about your dog",
#  'too much internet. how it plagues me',
#  'i miss my ex soo much',
#  '',
#  "oh i thought the pirate bay trial verdict was today :-s apparently it's in 10 days",
#  ' call me back.',
#  '',
#  'it so tired that im crying for no reason at all. im about to try to get an hour and a half in for tonight. half what i got last night.',
#  'i totally have like...  four girl options, and none of them seem viable',
#  'so far i have 311 veiws on all my sites put together,  most of them were me checking out the updates i made......',
#  "listening to bjork's all is full of love... crying",
#  'omg the hills! then i love money2, aww i think becky buckwild goes',
#  '',
#  "c'mon sean man",
#  'watching &quot;a league of their own&quot;...makes me miss mint chocolate ice cream cones and my grand ma  fuck.',
#  'lost my phone some where.maybe in the grass, its just so long, hope it does not rain',
#  ' hope you are not referring to me  say hello to your new stalker lol',
#  ' why were u sleeping?! ur gonna be up all night now  how was ur bike ride?',
#  ' but, but, but . . i wanna listen to the masters too!',
#  " i've been looking about for good stuff to write, but also been doing loads of uni work",
#  'i feel unloved. dropped 2 tweeters',
#  "off to london for the day on thursday, it's gonna be raining, oh fab  wo not see much on the london eye! still robbie wo not care bless him",
#  'completely wiped and reloaded the 8900.... lost all bbm contacts    going to bed sad.',
#  ' sayyyy whaaaa? i was not invited...',
#  'did not sleep too bad considering i have a workshop starting today. beginnings of a sore throat though',
#  '87 oh my gosh that made me emotional haha idk why!!! i dont want to get old',
#  "we're going to post some stories manually due to twitterfeed problem. that's why we've been so quiet lately ....",
#  'i do not like lukewarm showers',
#  ' - who should i contact if i need a 1099 for freelance work i did on linux.com throughout 2008? never got one.',
#  "722 connor, it's me, febi  are you really really mad at me??",
#  'need some help?! want to buy a macbook pro, but still inlove with my old powerbook!',
#  ' man america is so .. borez anyway lol i just realized you sent me msgs on here. i had no idea. i have no flash',
#  "  g'knight lovely ladies. i'm sleepy now",
#  'does anybody know how to get your electrolytes back in order? with a vitamin work? i feel sick.',
#  '8  yes, someone has not been reading my posts properly',
#  'almost through with my italian homework!  weeeeee.... now if i only understood what i was doing.',
#  'who turned the lights on? it will be time to get ip then',
#  ' twitter hates us both then.',
#  "i hate the fact that i'm genuinely excited about my last tweet",
#  ' i ca not sleep either',
#  " between that and the italy earthquake, it's been a very sad news day.",
#  ' all rain today  . garden really needs it so not quite so bad.',
#  'yawn yawn yawn!! 10 more minutes in bed',
#  ' ouch - sounds very sucky',
#  ' great idea with the itunes promo codes - they do not work in the uk itunes store though',
#  '  *cry*',
#  ' an empty rum barrel is a sad rum barrel. *shakes head* the horror, the horror.',
#  'it was a sleepless night',
#  ' she admitted to being a fake',
#  '  i love chutney......',
#  'got highly bored today scanning 24 pages for daddy. had to do it!',
#  ' you cooked risotto without me!!???',
#  'keeeerrrrriiiiii!!!!  i really have nothing better to do then post on this thing at 224am.....wonderfullll. says alot.',
#  'yay for baseball season! boo to yankees losing their first game',
#  'lost sucks  ... because i have to work today',
#  'omg exams killed me  how could i not know the difference between haif a circle and a hemisphere &lt;/3 &gt;',
#  'in bed... i suddenly feel  i wish ma was here w/me... goodnight twitterfam',
#  ' i do not like goodnights',
#  'greaaat my lappy wo not turn on  wtffffff',
#  "4rkm  you stuck in traffic then? my journey was traffic free this morning, if it's any help.",
#  'lookin like an all-nighter. i hate it when i do this to myself',
#  " you're a stranger",
#  'debbugging old vb6 code, the day could have started better . . .',
#  ' only a quarter of a percent babe  darn',
#  "coming down with a cold or bad allergies. either way, i'm miserable!",
#  '',
#  '',
#  'gah, comcast doubled our cable/internet bill w/out telling us, so we are quitting.  can anyone suggest an affordable company in bay area?',
#  'another early morn with the duchess, although she had not managed to cross her legs this time',
#  ' you left without saying hi!',
#  'l want, but i ca not sleep',
#  " when an xbox shows those three red lights, it means it's dead and needs to be fixed for a month at microsoft hq.",
#  'a king sized bed is nice but sad and lonely with no hubby, puppy, or kitty   i am over this whole conferenceing thing.',
#  'im boredd. gah  i wish i could just sleep and get it over with but ive had toooo muchh cooooffffeeeeeeeee  bahaha',
#  " if i may butt in again.  i'm done being nosey.  sorry your conversation was just so interesting!",
#  '_robinson  you fell off my list...did i offend you?',
#  '18 weeks till sisters home.. i missed her call, again! its the worst feeling in the world.',
#  'gonna try to get some sleep in this hotel room',
#  " brilliant idea. just bring as much as you think you'll spend &amp; i'll swap you. bring a brolly",
#  ' get me an autograph and shout out! you have to record it though. my computer is dead so i ca not listen.',
#  'rt  khloe just got fired from the apprentice',
#  'in biology class. my lip hurts',
#  'sorry for the next tweet...',
#  'grr not down to go to school today',
#  ' i had to get an hd tivo and just got it set up tonight in order to get channels 40 - 59.',
#  ' i asked everyone how they were doing yesterday and not a single tweet back',
#  ' ruddy money!! i like it!! still waiting here.... oh what a surprise... by state too?? hmmm....... seriously!!',
#  '_penn i am so sad  kutner was my favorite of the new team!!',
#  ' wow i did not get an &quot;hello&quot; u suck',
#  'bedtime, school tomorrow, and i still have no books  being broke suckssss',
#  'seating here helping my baby with his papers...well he is forcing me too seat with him  im sleepy',
#  'synching my contacts from my old mobile to iphone. import does not work well',
#  'i ca not concentrate',
#  "i've just spent 1 hour to enter all the bureaucratic nonsense for march. what a waste of my time",
#  'nw more confused then ever!',
#  'not feeling well again. stupid migraine making my tummy upset.  and my whole body aches, shoot me now.',
#  'reading buyology before bedtime... great premise but only turning out to be an &quot;ok&quot; book - lots of info i already knew',
#  'home! i really wana sleep, but due to wasting my free line in town i have an assignment to finish',
#  ' i also send some updates in plurk but i upload photos on twitter!  you didnt see any of my updates on plurk? zero?',
#  'omg... &quot;the reader&quot; is making me',
#  " d'oh! at least you're getting a decent exchange rate at the moment, sterling is still getting flogged",
#  'tried to download tweetdeck but it wont download',
#  "there's an inch of snow on the ground (and counting). i'm worried about the poor flowers",
#  ' why are not you a happy camper?',
#  " thanks man.  i'm so very grateful.  i feel unworthy of such attention, though, because i'm in this because of myself...",
#  "_wolfe  i miss u too. i'm totally comin back tho! lastnight was sooooooo much fun!",
#  " ohhh. i love it. ps i'm sad we did not get to hang out",
#  'and somehow i still end up in this place',
#  ' oh that is very sad, poor boy.',
#  ' _tulip27 um, that would be a hell no to the fugly poker dog pants on the cruise!  hi jonathan, sorry i missed you',
#  ...]

# %%
#remove useless words that are common in this dataset dont affect the "positivity" of the tweet 
useless = nltk.corpus.stopwords.words("english") + list(string.punctuation)

# %%
#tokenize and clean up the tweets 
tweets = []
for tweet in clean_data:
    wordlist = [word for word in nltk.word_tokenize(tweet) if word not in useless] #a list of words per tweet
    tweets.append(wordlist)
tweets[0]
# Out:
# ['upset',
#  'ca',
#  'update',
#  'facebook',
#  'texting',
#  '...',
#  'might',
#  'cry',
#  'result',
#  'school',
#  'today',
#  'also',
#  'blah']

# %% [markdown]
# ### Text Stemming

# %%
#stemming
st = nltk.stem.SnowballStemmer('english')
tweets_stemmed = []
for words in tweets:
    stemmed_words = [st.stem(word) for word in words]
    tweets_stemmed.append(stemmed_words)

tweets[:] = tweets_stemmed

# %%
posneg=pd.Series(sentiment).value_counts()
posneg
# Out:
# 4    800000
# 0    799999
# Name: sentiment, dtype: int64

# %%
def build_bow_features(words):
    return {word:True for word in words}

# %%
#remove those neutral tweets as I am only interested in neg / pos ones
text_label_pair_list = list(zip(tweets,sentiment))
text_label_pair_list[0]
text_label_pair_list[:] = [tuple for tuple in text_label_pair_list if tuple[1]!='Neutral']

train, test = train_test_split(text_label_pair_list, test_size = .20, random_state=7)

# %%
#build a list of tuples (BOW_dict, label) for all tweets
train_bow = [(build_bow_features(tuple[0]), tuple[1]) for tuple in train]
test_bow = [(build_bow_features(tuple[0]), tuple[1]) for tuple in test]

# %%
def preprocess(sentence):
    def build_bow_features(words):
        return {word:True for word in words}
    
    sentence = sentence.lower()
    sentence = sentence.replace('\n','')
    useless = nltk.corpus.stopwords.words("english") + list(string.punctuation)
    wordlist = [word for word in nltk.word_tokenize(sentence) if word not in useless]
    stemmed_words = [nltk.stem.SnowballStemmer('english').stem(word) for word in wordlist]
    Bow = [(build_bow_features(stemmed_words))]
    return Bow

preprocess("this is very beautiful and happy ")
# Out:
# [{'beauti': True, 'happi': True}]

# %%
train_bow
# Out:
# [({'lol': True,
#    'get': True,
#    "'s": True,
#    'come': True,
#    'good': True,
#    'way': True,
#    'mean': True,
#    'talent': True,
#    'author': True},
#   4),
#  ({'would': True, 'miss': True, 'dream': True, 'anymor': True}, 0),
#  ({}, 4),
#  ({'im': True,
#    'sick': True,
#    'thing': True,
#    'would': True,
#    'make': True,
#    'feel': True,
#    'better': True,
#    'palm': True,
#    'pre': True,
#    'came': True,
#    'today': True,
#    'lotteri': True,
#    '...': True},
#   0),
#  ({'sound': True, 'like': True, 'cup': True, 'tea': True, 'sign': True}, 4),
#  ({'think': True,
#    "'m": True,
#    'go': True,
#    'take': True,
#    'hot': True,
#    'bath': True,
#    'listen': True,
#    'lvatt': True},
#   4),
#  ({'feel': True, 'tire': True, 'today': True, 'go': True, 'gym': True}, 0),
#  ({'weekend': True, '...': True, 'rest': True, 'peac': True, '..final': True},
#   4),
#  ({}, 0),
#  ({'say': True, 'll': True, 'cri': True, 'hahah': True}, 0),
#  ({'miss': True, 'certain': True, 'someon': True}, 0),
#  ({'hi': True,
#    'lia': True,
#    'sorri': True,
#    'slow': True,
#    'repli': True,
#    'away': True,
#    'civilis': True,
#    'weekend': True},
#   4),
#  ({'know': True,
#    'franki': True,
#    'bever': True,
#    'maze': True,
#    'probabl': True,
#    'born': True,
#    '70': True,
#    "'s": True,
#    'earlier': True,
#    'thank': True,
#    'god': True,
#    'youtub': True,
#    '...': True,
#    'long': True,
#    'nightr': True,
#    'lol': True},
#   4),
#  ({'blazblu': True,
#    'get': True,
#    'ps3': True,
#    'hdmi': True,
#    'look': True,
#    'gorgeous': True,
#    'xbl': True,
#    'better': True,
#    'communiti': True},
#   0),
#  ({'thing': True,
#    'better': True,
#    'would': True,
#    'video': True,
#    'footag': True,
#    'us': True,
#    'see': True},
#   4),
#  ({'thank': True,
#    "'m": True,
#    'forthright': True,
#    'b/c': True,
#    'part': True,
#    'want': True,
#    'peopl': True,
#    'except': True,
#    'loss': True},
#   4),
#  ({'ummmmm': True, '...': True, 'could': True, 'fedex': True}, 4),
#  ({'epic': True,
#    'discoveri': True,
#    'win': True,
#    'found': True,
#    'work': True,
#    'channel': True,
#    'hella': True,
#    'record': True,
#    'billion': True},
#   4),
#  ({"'s": True, 'rain': True, '...': True}, 0),
#  ({"'m": True,
#    'tired..': True,
#    'hey': True,
#    'diego': True,
#    'ivan': True,
#    'spro': True,
#    'verlo': True,
#    'pronto': True,
#    'xk': True,
#    'aki': True,
#    'va': True},
#   0),
#  ({'technic': True,
#    'either': True,
#    'octopus': True,
#    'octopi': True,
#    'rare': True,
#    'octopod': True,
#    'depend': True,
#    'live': True,
#    'usa': True},
#   4),
#  ({'ty': True,
#    'recommend': True,
#    'jayn': True,
#    "'s": True,
#    'work': True,
#    'yes': True,
#    'well': True,
#    'acquaint': True},
#   4),
#  ({'peach': True,
#    'classi': True,
#    'expens': True,
#    'bottom': True,
#    'dwell': True,
#    'appl': True,
#    'eater': True,
#    'like': True,
#    'us': True},
#   0),
#  ({'_x': True,
#    'keep': True,
#    're-tweet': True,
#    've': True,
#    'got': True,
#    'get': True,
#    'back': True,
#    'might': True,
#    'cri': True},
#   0),
#  ({'didnt': True,
#    'go': True,
#    '2': True,
#    'peac': True,
#    'past': True,
#    'day': True,
#    '...': True,
#    'inde': True},
#   4),
#  ({'last': True,
#    'day': True,
#    'bohol': True,
#    'head': True,
#    'back': True,
#    'manila': True,
#    'tomorrow': True,
#    '*sigh*': True,
#    'goodby': True,
#    'sun': True,
#    'sea': True,
#    'fb': True},
#   0),
#  ({'babe': True, "'s": True, 'gone': True}, 0),
#  ({'1': True,
#    'googl': True,
#    'search': True,
#    'result': True,
#    'quot': True,
#    'want': True,
#    'see': True,
#    'someth': True,
#    'gross': True,
#    'blog': True,
#    '...': True,
#    'could': True,
#    'prouder': True},
#   4),
#  ({'done': True,
#    'finals..': True,
#    'work': True,
#    'excit': True,
#    'pif': True,
#    'next': True,
#    'week': True,
#    'head': True,
#    'st': True,
#    'loui': True,
#    'great': True,
#    'peopl': True,
#    'www.stlf.net': True,
#    'stlf': True},
#   4),
#  ({'thank': True,
#    'updat': True,
#    'feel': True,
#    'disconnect': True,
#    'live': True,
#    'away': True,
#    'long': True,
#    'memori': True,
#    'day': True,
#    'primetim': True},
#   4),
#  ({'good': True,
#    'morn': True,
#    'peep': True,
#    'gon': True,
#    'na': True,
#    'go': True,
#    'play': True,
#    'garden': True,
#    'church': True,
#    'cut': True,
#    'firewood': True,
#    'dinner': True,
#    'friend': True,
#    'redw': True,
#    'tonit': True},
#   4),
#  ({'combin': True,
#    'lower': True,
#    '5': True,
#    '8.348': True,
#    'ppl': True,
#    'name': True,
#    'miha': True,
#    '159': True,
#    'last': True,
#    'rekar': True,
#    'interest': True,
#    '...': True},
#   4),
#  ({'live': True, 'exampl': True, 'grandma': True}, 4),
#  ({}, 4),
#  ({'wonder': True,
#    'dinner': True,
#    'cuz': True,
#    'explor': True,
#    'littl': True,
#    'london': True,
#    'need': True,
#    'pack': True,
#    'trip': True,
#    'back': True,
#    'home': True,
#    'tomorrow': True,
#    'boohoo': True},
#   0),
#  ({"'m": True, 'sorri': True, 'know': True, 'feel': True, 'like': True}, 0),
#  ({'got': True,
#    'face': True,
#    'nerv': True,
#    'tell': True,
#    'act': True,
#    'like': True,
#    'ladi': True,
#    "'s": True,
#    'still': True,
#    'bitch': True,
#    'call': True,
#    'fuck': True,
#    'front': True,
#    'mom': True},
#   0),
#  ({'see': True, 'today': True}, 0),
#  ({'ok.': True, 'bye': True, 'lt': True, '333333': True}, 0),
#  ({'yepper': True,
#    'freakin': True,
#    'way': True,
#    'would': True,
#    'go': True,
#    'alon': True,
#    'one': True,
#    'feel': True,
#    'like': True,
#    'clumsi': True,
#    'oaf': True,
#    'day': True,
#    'friend': True,
#    'voic': True,
#    'help': True},
#   4),
#  ({'blazer': True,
#    'lost': True,
#    'huge': True,
#    'least': True,
#    "'m": True,
#    'eat': True,
#    'good': True,
#    'raw': True,
#    'steak': True,
#    '...': True,
#    'got': True,
#    'move': True,
#    'past': True,
#    'game': True,
#    'focus': True,
#    '2': True},
#   0),
#  ({'gon': True,
#    'na': True,
#    'go': True,
#    'run': True,
#    'tonight': True,
#    'fun': True},
#   4),
#  ({'still': True, 'babi': True}, 0),
#  ({'work': True,
#    'day': True,
#    'morrison': True,
#    'fridg': True,
#    'miss': True,
#    'ace': True,
#    'missedth': True,
#    'warmth': True,
#    '2': True,
#    'bow': True,
#    'lyk': True,
#    'll': True,
#    'rain': True,
#    '2moz': True},
#   0),
#  ({'back': True, 'nail-less': True, 'self': True}, 4),
#  ({'wow..': True,
#    '2nd': True,
#    'servic': True,
#    'never': True,
#    'ceas': True,
#    'amaz': True,
#    'see': True,
#    'mani': True,
#    'peopl': True,
#    'burst': True,
#    'even': True,
#    'run': True,
#    'jz': True,
#    'like': True,
#    'get': True,
#    'boyband': True,
#    'concert': True},
#   4),
#  ({'10ne': True,
#    'man': True,
#    'listen': True,
#    'radio': True,
#    'month': True,
#    'mean': True,
#    'realli': True,
#    '...': True,
#    "'s": True,
#    'terribl': True,
#    'lot': True,
#    'stuff': True,
#    'come': True,
#    'either': True,
#    'tho': True},
#   0),
#  ({'cathol': True,
#    'guilt': True,
#    'terribl': True,
#    'thing': True,
#    'luckili': True,
#    'got': True,
#    'long': True,
#    'time': True,
#    'ago': True,
#    'see': True,
#    'hell': True},
#   4),
#  ({'ll': True,
#    'love': True,
#    'debut': True,
#    'album': True,
#    'quot': True,
#    'daylight': True,
#    'amaz': True,
#    'full': True,
#    'deep': True,
#    'lyric': True,
#    'meaning': True,
#    'thought': True},
#   4),
#  ({'must': True,
#    'fall': True,
#    'waaaaaay': True,
#    'late': True,
#    'twitter': True,
#    "g'night": True,
#    '...': True},
#   4),
#  ({'brain': True,
#    'lego': True,
#    'master': True,
#    'builder': True,
#    'ador': True,
#    'nerdi': True,
#    'hotti': True,
#    'know': True,
#    'realiti': True,
#    'old': True,
#    'gross': True},
#   0),
#  ({}, 0),
#  ({'ruin': True, 'codi': True, 'night': True}, 0),
#  ({'rain': True,
#    'whole': True,
#    'day': True,
#    '...': True,
#    'could': True,
#    'even': True,
#    'cheer': True,
#    'band': True,
#    'like': True,
#    'hold': True,
#    'umbrella': True},
#   0),
#  ({'42': True,
#    'day': True,
#    'jona': True,
#    'brother': True,
#    'concert': True,
#    'spain': True,
#    'wooo': True,
#    'hooo': True,
#    'omg': True,
#    'cant': True,
#    'wait': True,
#    'see': True,
#    'love': True},
#   4),
#  ({'ah': True,
#    'thankgoodne': True,
#    'got': True,
#    'code': True,
#    'said': True,
#    'work': True,
#    'within': True,
#    '24': True,
#    'hour': True},
#   4),
#  ({'unless': True,
#    'u': True,
#    'make': True,
#    'reeeeal': True,
#    'mad': True,
#    'lol': True},
#   4),
#  ({'2hot2handle06': True,
#    'hi': True,
#    '...': True,
#    '..ye': True,
#    'flem': True,
#    'around': True,
#    'corner': True,
#    'actual': True,
#    'littl': True,
#    'closer': True,
#    'ruth': True,
#    'chris': True,
#    "'m": True,
#    'big': True,
#    'fan': True},
#   0),
#  ({'neighbour': True,
#    'would': True,
#    'love': True,
#    "'m": True,
#    'sure': True,
#    'got': True,
#    'rid': True,
#    'rock': True,
#    'band': True,
#    'owi': True,
#    'caus': True,
#    'over': True,
#    'long': True,
#    'stint': True,
#    'drums..': True},
#   4),
#  ({'tri': True,
#    'actual': True,
#    'use': True,
#    '...': True,
#    'work': True,
#    'go': True,
#    'dinner': True,
#    'bff': True,
#    "'s": True,
#    'bday': True,
#    'tonight': True,
#    'happi': True,
#    'hour': True,
#    'pleas': True},
#   4),
#  ({'chem': True,
#    'regent': True,
#    'coupl': True,
#    'hous': True,
#    'still': True,
#    'studi': True,
#    'extrem': True,
#    'procrastin': True},
#   0),
#  ({'heyi': True,
#    'nick': True,
#    'lovin': True,
#    'vid': True,
#    'hope': True,
#    'chanc': True,
#    'might': True,
#    'record': True,
#    'love': True,
#    'toy': True,
#    'stori': True,
#    '2.': True,
#    'pleas': True},
#   4),
#  ({'ugh': True, '*is': True, 'mortified*': True}, 0),
#  ({'know': True,
#    'sat': True,
#    'night': True,
#    'tv': True,
#    'crap': True,
#    'wish': True,
#    'could': True,
#    'see': True,
#    'mcfli': True,
#    'tonight': True,
#    'gon': True,
#    'na': True,
#    'quick': True,
#    'get': True,
#    'distract': True,
#    'easili': True,
#    'x': True},
#   0),
#  ({'finish': True,
#    'chapter': True,
#    '2': True,
#    'book': True,
#    'sure': True,
#    'im': True,
#    'go': True,
#    'post': True,
#    'ca': True,
#    'give': True,
#    'guy': True,
#    'much': True,
#    'tri': True,
#    'get': True,
#    'publish': True},
#   4),
#  ({'bad': True,
#    'mitchel': True,
#    'musso': True,
#    "'s": True,
#    'album': True,
#    'didnt': True,
#    'come': True,
#    'estonia': True,
#    'see': True,
#    "lil'wayn": True,
#    'neither': True,
#    'saaad': True},
#   0),
#  ({'109creek': True, 'yes': True, 'often': True, 'summer': True}, 4),
#  ({}, 4),
#  ({'good': True, 'morn': True, 'america': True}, 4),
#  ({'hope': True,
#    'seizur': True,
#    'better': True,
#    'generat': True,
#    "c'mon": True,
#    'kisschasi': True,
#    'ps': True,
#    'thought': True,
#    'bad': True,
#    'day': True,
#    'made': True,
#    'even': True,
#    'wors': True},
#   0),
#  ({'shop': True,
#    '...': True,
#    '..er': True,
#    'brows': True,
#    'new': True,
#    'tiffani': True,
#    'silver': True,
#    'collect': True},
#   4),
#  ({'parent': True,
#    'check': True,
#    'brother': True,
#    'auntiesnauncl': True,
#    'cousin': True,
#    'food': True,
#    'messi': True,
#    'hous': True,
#    'afterward': True,
#    'def': True},
#   0),
#  ({"'m": True,
#    'anti-mac': True,
#    'lost': True,
#    'document': True,
#    'recoveri': True},
#   0),
#  ({'note': True,
#    'mail': True,
#    'messag': True,
#    'swamp': True,
#    'good': True,
#    'thing': True,
#    'apolog': True,
#    'repli': True,
#    'tad': True,
#    'slower': True,
#    'usual': True},
#   4),
#  ({'saw': True,
#    'repli': True,
#    'head': True,
#    'away': True,
#    'understand': True,
#    'well': True},
#   4),
#  ({'alreadi': True,
#    'know': True,
#    'nathan': True,
#    'nat': True,
#    'live': True,
#    'singapor': True,
#    'tomorrow': True,
#    "'m": True,
#    'basic': True,
#    'staff': True,
#    'member': True,
#    'wasnt': True,
#    'invit': True},
#   0),
#  ({'45': True,
#    'good': True,
#    'mornin': True,
#    'ray': True,
#    'j.': True,
#    'slept': True,
#    'thru': True,
#    'mind': True,
#    'bender': True},
#   0),
#  ({'realli': True,
#    'tire': True,
#    'babysit': True,
#    'tomorrow': True,
#    'im': True,
#    'still': True,
#    'walk': True,
#    'around': True,
#    '...': True},
#   0),
#  ({'go': True,
#    'church': True,
#    'work..': True,
#    'good': True,
#    'feel': True,
#    'today': True},
#   4),
#  ({'know': True, 'pretti': True, 'scari': True}, 0),
#  ({'fix': True,
#    'sound': True,
#    'new': True,
#    'win7': True,
#    'machin': True,
#    'find': True,
#    'mic': True,
#    'stop': True,
#    'function': True},
#   0),
#  ({'hope': True,
#    "'m": True,
#    'longer': True,
#    'sick': True,
#    'tomorrow': True,
#    '...': True,
#    'mother': True,
#    "'s": True,
#    'day': True,
#    'fun..': True},
#   0),
#  ({'sad': True,
#    'week': True,
#    '2': True,
#    'ago': True,
#    'got': True,
#    'chocol': True,
#    'favorit': True,
#    'lululemon': True,
#    'jacket': True,
#    'least': True,
#    'wash': True,
#    'yay': True,
#    'good': True,
#    'though': True},
#   0),
#  ({'pick': True,
#    'blue': True,
#    'moon': True,
#    'summer': True,
#    'ale': True,
#    'way': True,
#    'back': True,
#    'work': True},
#   4),
#  ({'could': True,
#    'hang': True,
#    'fam': True,
#    'think': True,
#    'ill': True,
#    'take': True,
#    'nap': True,
#    'studi': True},
#   0),
#  ({'see': True,
#    'anyth': True,
#    'yet': True,
#    '...': True,
#    'mayb': True,
#    'need': True,
#    'time': True,
#    'load': True},
#   0),
#  ({'much': True,
#    'stayin': True,
#    'week': True,
#    'cos': True,
#    'bad': True,
#    've': True,
#    'gon': True,
#    'na': True,
#    'listen': True,
#    '1045chumfm': True,
#    'websit': True,
#    'work': True},
#   0),
#  ({'got': True,
#    'new': True,
#    'album': True,
#    'today': True,
#    're': True,
#    'go': True,
#    'concert': True,
#    'london': True,
#    'tonight': True},
#   0),
#  ({'god': True,
#    'damn': True,
#    'twitter': True,
#    'stop': True,
#    'eat': True,
#    'undelet': True,
#    'dms': True},
#   0),
#  ({'grandpa': True, 'mad': True, 'dont': True, 'even': True, 'know': True}, 0),
#  ({'pictur': True,
#    "'s": True,
#    'show': True,
#    'hope': True,
#    've': True,
#    'good': True,
#    'day': True},
#   4),
#  ({'yeah': True,
#    'itun': True,
#    'play': True,
#    'right': True,
#    'song': True,
#    'time': True},
#   4),
#  ({'yah': True, 'canada': True, 'till': True, 'later': True}, 0),
#  ({'ladi': True,
#    'fish': True,
#    'caught': True,
#    '100': True,
#    'know': True,
#    'name': True,
#    'annett': True,
#    'corni': True,
#    'like': True},
#   4),
#  ({'must': True, 'hate': True, 'camilla': True, 'bell': True}, 0),
#  ({'haha': True, 'lol': True, 'made': True, 'laugh': True}, 4),
#  ({'_v': True,
#    'haha': True,
#    'boat': True,
#    'yesterday..': True,
#    'll': True,
#    'pick': True,
#    'time': True},
#   4),
#  ({'said': True, 'go': True, 'one': True, 'day': True}, 0),
#  ({'nice': True, 'night': True, 'tomm': True}, 4),
#  ({'thank': True, 'kid': True, 'followfriday': True, 'go': True, '_kt': True},
#   4),
#  ({}, 0),
#  ({'ohh': True,
#    'love': True,
#    "'s": True,
#    'beauti': True,
#    'song': True,
#    've': True,
#    'ever': True,
#    'heard': True,
#    '=d': True,
#    'sing': True},
#   4),
#  ({'song': True, '...': True, 'phone': True, 'bone': True}, 4),
#  ({'omarion': True, 'gain': True, 'weight': True}, 0),
#  ({'hope': True, 'awesom': True, 'vacat': True}, 4),
#  ({'back': True,
#    'pool-': True,
#    'awesom': True,
#    'night': True,
#    'serious': True},
#   4),
#  ({'depress': True,
#    'nlt': True,
#    'thing': True,
#    '...': True,
#    'actual': True,
#    'watch': True,
#    'video': True,
#    'song': True,
#    'eat': True,
#    'ice': True,
#    'cream': True,
#    'tear': True},
#   0),
#  ({'home': True,
#    'trip': True,
#    'autozon': True,
#    'bank': True,
#    'chillin': True,
#    'noth': True,
#    'day': True,
#    'kinda': True,
#    'bore': True},
#   0),
#  ({'gym': True,
#    'run': True,
#    'watch': True,
#    '100': True,
#    'best': True,
#    'song': True,
#    '80': True,
#    "'s": True},
#   4),
#  ({'ca': True, 'fli': True}, 0),
#  ({'dear': True,
#    'twitter': True,
#    'give': True,
#    'summer': True,
#    'miss': True,
#    'see': True,
#    '10': True,
#    'week': True},
#   0),
#  ({'back': True, 'movi': True, "'s": True, 'twitter': True}, 4),
#  ({'sis': True,
#    'find': True,
#    'dress': True,
#    'mexican': True,
#    'll': True,
#    'see': True,
#    'anoth': True,
#    'one': True},
#   4),
#  ({'ah': True, 'monster': True, 'headach': True, 'fun': True}, 0),
#  ({'31': True, 'ok': True, 'win': True, 'point': True}, 0),
#  ({'hi': True,
#    'bryan': True,
#    'yeah': True,
#    'sort': True,
#    'though': True,
#    'ty': True,
#    'much': True,
#    'man': True,
#    'great': True,
#    'product': True,
#    'youv': True,
#    'e': True,
#    'written': True},
#   4),
#  ({'look': True,
#    'forward': True,
#    'kent': True,
#    'summerbal': True,
#    'hpu': True,
#    'happi': True,
#    'poor': True,
#    'fb': True},
#   0),
#  ({'start': True,
#    'excercis': True,
#    'program': True,
#    'yesterday..': True,
#    'feel': True,
#    'today': True},
#   0),
#  ({'woke': True, 'upp': True, 'back': True, 'hurt': True}, 0),
#  ({'team': True,
#    'hurri': True,
#    'curri': True,
#    'queer': True,
#    'race': True,
#    '3-way': True,
#    '...': True,
#    'tie': True,
#    'partay': True,
#    'thx': True,
#    'amaz': True,
#    'donor': True},
#   4),
#  ({'windstream': True,
#    "'s": True,
#    'email': True,
#    'almost': True,
#    'annoy': True,
#    'deal': True,
#    'w/': True,
#    'damn': True,
#    'bank': True},
#   0),
#  ({'new': True,
#    'e-mail': True,
#    'address': True,
#    'make': True,
#    '...': True,
#    'bulli': True},
#   0),
#  ({'ohhh': True,
#    'snaapp': True,
#    'ice': True,
#    'age': True,
#    '3': True,
#    'come': True,
#    'soon': True,
#    'woo': True},
#   4),
#  ({'2nd': True,
#    'place': True,
#    'fail': True,
#    '2': True,
#    'suckout': True,
#    "'s": True,
#    'poker': True,
#    'thank': True,
#    'host': True,
#    'leagu': True},
#   0),
#  ({'ello': True,
#    'kathi': True,
#    "'m": True,
#    'canadian': True,
#    'american': True,
#    'xd': True},
#   4),
#  ({'monday': True, 'argh': True, 'back': True, 'grind': True}, 0),
#  ({'saw': True,
#    'cutest': True,
#    'gremlin': True,
#    'gizmo': True,
#    'ferret': True,
#    'ever': True,
#    'want': True,
#    'bad': True,
#    'get': True,
#    'new': True,
#    'cage': True,
#    'first': True},
#   0),
#  ({'im': True,
#    'still': True,
#    'mad': True,
#    'hey': True,
#    'least': True,
#    'watch': True,
#    'entertain': True,
#    'tonight': True},
#   4),
#  ({'12': True,
#    'thanks..': True,
#    'bad': True,
#    're': True,
#    'fli': True,
#    '...': True},
#   0),
#  ({'gon': True, 'na': True, 'get': True, 'sunshin': True}, 4),
#  ({'hang': True,
#    'hub': True,
#    'go': True,
#    'watch': True,
#    'fring': True,
#    'love': True},
#   4),
#  ({'got': True,
#    'tip': True,
#    'get': True,
#    'jetlag': True,
#    'thank': True,
#    've': True,
#    'caffein': True,
#    'plan': True,
#    'go': True,
#    'gym': True,
#    'later': True,
#    'look': True,
#    'sun': True,
#    'way': True},
#   4),
#  ({'ugh': True, "'s": True, 'yet': True, '...': True}, 0),
#  ({'perhap': True, 'gmail': True, 'glitch': True, 'get': True, 'fix': True},
#   0),
#  ({'saturday': True, 'night': True}, 0),
#  ({'fall': True, 'ill': True, 'problem': True, 'love': True, 'jejejej': True},
#   4),
#  ({'layin': True,
#    'bed': True,
#    'listenin': True,
#    '2': True,
#    'mp3': True,
#    'player': True,
#    'waitin': True,
#    '4': True,
#    'storm': True,
#    'blow': True,
#    'ova': True},
#   0),
#  ({'ah': True,
#    'noth': True,
#    'say': True,
#    'sandal': True,
#    'like': True,
#    'today': True},
#   4),
#  ({'1': True, 'btw': True, 'priss': True, 'one': True, 'hurt': True}, 4),
#  ({'feel': True,
#    'like': True,
#    'idiot': True,
#    'sad': True,
#    'part': True,
#    'actual': True,
#    'one': True,
#    '...': True},
#   0),
#  ({'aah': True,
#    'followfriday': True,
#    'turn': True,
#    'coolest': True,
#    'guy': True,
#    'twitter': True,
#    'goe': True,
#    'film': True,
#    'noir': True,
#    '...': True},
#   4),
#  ({'mia': True, 'jimmi': True, 'sad': True}, 0),
#  ({'wish': True,
#    'leav': True,
#    'cert': True,
#    'june': True,
#    '..the': True,
#    'weather': True,
#    'amaz': True},
#   0),
#  ({'wait': True, 'lost': True, 'come': True}, 4),
#  ({}, 4),
#  ({'eatin': True,
#    'cupcak': True,
#    'bought': True,
#    'new': True,
#    'headphon': True,
#    'made': True,
#    'day': True,
#    'gahh': True,
#    'freakin': True,
#    'hot': True},
#   4),
#  ({'hide': True,
#    'berri': True,
#    'like': True,
#    'slave': True,
#    'regular': True,
#    'today': True,
#    'caught': True,
#    'massa': True,
#    'im': True,
#    'def': True,
#    'light': True,
#    'enough': True,
#    'juic': True,
#    'pour': True},
#   0),
#  ({'bore': True}, 0),
#  ({'im': True, 'tire': True, 'cant': True, 'sleep': True}, 0),
#  ({'tarot': True,
#    'read': True,
#    'question': True,
#    'quot': True,
#    'financi': True,
#    'stabl': True,
#    'answer-': True,
#    "'m": True,
#    'screw': True},
#   0),
#  ({'8688': True,
#    'haha': True,
#    'wish': True,
#    'could': True,
#    'show': True,
#    'hope': True,
#    'one': True,
#    'day': True,
#    'good': True,
#    'luck': True,
#    'fun': True,
#    '-cin': True},
#   4),
#  ({'yeeahh': True,
#    'huskieessss': True,
#    'wcws': True,
#    'champ': True,
#    'huge': True,
#    'game': True,
#    'todayyy': True,
#    'section': True,
#    'edwardsvill': True,
#    'east': True,
#    'im': True,
#    'battingg': True,
#    'come': True,
#    'watch': True},
#   4),
#  ({'miss': True, 'alreadi': True}, 0),
#  ({'one': True,
#    'would': True,
#    'think': True,
#    'technolog': True,
#    'avail': True,
#    'day': True,
#    'longer': True,
#    'problem': True},
#   4),
#  ({'uhmz': True,
#    '1': True,
#    'till': True,
#    '450': True,
#    'sub': True,
#    'ima': True,
#    'dieee': True,
#    'yay': True},
#   4),
#  ({'need': True,
#    'long': True,
#    'vacat': True,
#    'husband': True,
#    '1411': True,
#    'thing': True,
#    'alway': True,
#    'come': True,
#    'back': True},
#   0),
#  ({'gosh': True,
#    'want': True,
#    'sleep': True,
#    'without': True,
#    'bark': True,
#    'dog': True,
#    'wake': True,
#    'still': True,
#    'feel': True,
#    'tire': True},
#   0),
#  ({'pack': True,
#    '12': True,
#    'box': True,
#    '88': True,
#    'go': True,
#    'much': True,
#    'stuff': True},
#   0),
#  ({'good': True,
#    'morn': True,
#    'town': True,
#    'shop': True,
#    'inabit': True,
#    'how': True,
#    'everybodi': True},
#   4),
#  ({'happi': True, 'cry..': True}, 4),
#  ({'saw': True,
#    'movi': True,
#    'yet': True,
#    'actual': True,
#    'plan': True,
#    'watch': True,
#    'tomorrow': True,
#    '...': True},
#   0),
#  ({'good': True,
#    'way': True,
#    'know': True,
#    'fear': True,
#    'get': True,
#    'bit': True,
#    'close': True,
#    'midwestern': True,
#    'supercel': True,
#    'thunderstorm': True,
#    'small': True,
#    'plane': True,
#    'around': True,
#    '17,000': True},
#   4),
#  ({'red': True,
#    'sox': True,
#    'open': True,
#    'game': True,
#    'conflict': True,
#    'prevent': True,
#    'go': True,
#    'reschedul': True},
#   0),
#  ({'cur': True,
#    'hair': True,
#    'shampoo': True,
#    'alway': True,
#    'frizz': True,
#    '...': True,
#    'dunno': True},
#   0),
#  ({'mmkay': True,
#    'what': True,
#    'fb': True,
#    'twitter': True,
#    'absolut': True,
#    'noth': True,
#    'onlin': True,
#    'work': True,
#    'right': True},
#   0),
#  ({'love': True,
#    'walkmen': True,
#    'announc': True,
#    'us': True,
#    'summer': True,
#    'tour': True,
#    'today': True,
#    'cours': True,
#    '...': True,
#    'close': True,
#    'nashi': True},
#   0),
#  ({'revis': True, 'scienc': True, 'exam': True, 'friday': True}, 4),
#  ({}, 4),
#  ({'back': True, 'milan': True, '...': True}, 0),
#  ({'go': True,
#    'home': True,
#    'lunch': True,
#    'garden': True,
#    'lovelli': True,
#    'day': True},
#   4),
#  ({'_undaft_cow': True,
#    'oic': True,
#    "'m": True,
#    'debat': True,
#    'whether': True,
#    'wear': True,
#    'bc': True,
#    'paig': True,
#    'erin': True,
#    'alaina': True,
#    'lolz': True,
#    'll': True,
#    'see': True,
#    'tonight': True},
#   4),
#  ({'come': True,
#    'home': True,
#    'vaca': True,
#    'suppos': True,
#    'good': True,
#    'thing': True,
#    'right': True,
#    'day': True,
#    'get': True,
#    'wors': True},
#   0),
#  ({'need': True, 'text': True, 'buddi': True}, 0),
#  ({'43': True, 'shane': True, 'doesnt': True, 'like': True, 'twitter': True},
#   0),
#  ({"'s": True,
#    'happen': True,
#    "'m": True,
#    'sorri': True,
#    'long': True,
#    'trip': True,
#    'speak': True,
#    'go': True,
#    'denton': True},
#   0),
#  ({}, 4),
#  ({"'s": True, 'cute': True, 'fat': True}, 4),
#  ({'528': True,
#    'see': True,
#    'page': True,
#    'anyth': True,
#    'everyth': True,
#    'goe': True},
#   4),
#  ({'good': True, 'morn': True, 'beauti': True, 'day': True, 'tgif': True}, 4),
#  ({'hope': True, 'enjoy': True, 'sun': True, 'like': True}, 4),
#  ({'go': True,
#    'see': True,
#    'friend': True,
#    'today': True,
#    '...': True,
#    'gon': True,
#    'na': True,
#    'fun': True,
#    'outsid': True,
#    'whatev': True,
#    'xd': True},
#   4),
#  ({'ex': True,
#    'keep': True,
#    'text': True,
#    "'s": True,
#    'say': True,
#    'gon': True,
#    'na': True,
#    'go': True,
#    'work..': True,
#    'fuck': True},
#   0),
#  ({"'s": True,
#    'nice': True,
#    've': True,
#    'tweet': True,
#    'instant': True,
#    'ca': True,
#    'rememb': True,
#    'moment': True,
#    'pass': True},
#   0),
#  ({'got': True, 'result': True, 'today': True, '...': True, 'good': True}, 0),
#  ({'work': True, 'still': True}, 0),
#  ({'morn': True, 'tweep': True}, 4),
#  ({'mean': True, 'leav': True}, 4),
#  ({'today': True,
#    'll': True,
#    'back': True,
#    'home': True,
#    'later': True,
#    'want': True,
#    'see': True,
#    'wrote': True,
#    'xx': True},
#   0),
#  ({'oh': True, 'gosh': True, 'awsom': True}, 4),
#  ({'cute': True,
#    'littl': True,
#    'dean': True,
#    'lane': True,
#    'want': True,
#    'watch': True,
#    'dvds': True},
#   0),
#  ({'happi': True,
#    'divers': True,
#    'britain': True,
#    'got': True,
#    'talent': True,
#    'realli': True,
#    'deserv': True},
#   4),
#  ({'end': True,
#    'night': True,
#    'golden': True,
#    'girl': True,
#    'alway': True,
#    'win': True,
#    '...': True,
#    "'m": True,
#    'old': True,
#    'person': True},
#   0),
#  ({'mamma': True, 'get': True, 'nerv': True}, 0),
#  ({'hate': True,
#    'sick': True,
#    'wast': True,
#    'day': True,
#    'actual': True,
#    'jkjk': True},
#   0),
#  ({"'s": True,
#    'grace': True,
#    'ottawa': True,
#    'born': True,
#    'hospit': True,
#    'thought': True,
#    'meant': True,
#    'first': True},
#   4),
#  ({'tad': True,
#    'late': True,
#    'butttt': True,
#    're': True,
#    'mood': True,
#    'realli': True,
#    'good': True,
#    'scare': True,
#    'tri': True,
#    'quot': True,
#    'funni': True,
#    'game': True,
#    'thought': True,
#    'scari': True},
#   4),
#  ({'_day26': True, 'mind': True, 'convinc': True, 'keep': True, 'fight': True},
#   0),
#  ({'123': True,
#    'lol': True,
#    'love': True,
#    'talk': True,
#    'ppl': True,
#    'u': True,
#    'hit': True,
#    'w/': True,
#    'quot': True},
#   4),
#  ({'sim': True,
#    '3': True,
#    'much': True,
#    'complic': True,
#    'thought': True,
#    'would': True,
#    'alreadi': True,
#    'miss': True,
#    '2': True},
#   0),
#  ({'art': True, 'day': True}, 0),
#  ({'back': True,
#    'must': True,
#    'see': True,
#    'chop': True,
#    'hair': True,
#    'drivng': True,
#    'crazi': True},
#   4),
#  ({'ride': True,
#    'hors': True,
#    "'m": True,
#    'tire': True,
#    'time': True,
#    'sleep': True,
#    '...': True,
#    'think': True,
#    'gon': True,
#    'na': True,
#    'fall': True,
#    'asleep': True,
#    'way': True,
#    'quot': True,
#    'haha': True,
#    'xoxo': True},
#   0),
#  ({'realli': True,
#    'screw': True,
#    'good': True,
#    'thing': True,
#    'wish': True,
#    'knew': True,
#    'fix': True},
#   0),
#  ({'omg': True,
#    'doze': True,
#    'sec': True,
#    'earlier': True,
#    'think': True,
#    'got': True,
#    'whiplash': True,
#    'neck': True,
#    'head': True,
#    'fall': True,
#    'back': True,
#    'ouch': True,
#    'hate': True,
#    'morn': True},
#   0),
#  ({'yes': True,
#    'fun': True,
#    'imag': True,
#    'though': True,
#    'unlik': True,
#    'eddi': True,
#    'abfab': True,
#    'shock': True,
#    'spot': True,
#    'design': True,
#    'wear': True,
#    'quot': True,
#    'street': True,
#    'person': True},
#   4),
#  ({'_young': True,
#    'look': True,
#    'good': True,
#    'think': True,
#    'll': True,
#    'eat': True},
#   4),
#  ({'nah': True,
#    'came': True,
#    'yet': True,
#    'think': True,
#    'weekend': True,
#    'either': True,
#    'ima': True,
#    'mega': True,
#    'sad': True},
#   0),
#  ({'wes': True,
#    'reason': True,
#    'comment': True,
#    'make': True,
#    'seemic': True,
#    'desktop': True,
#    'happen': True,
#    'across': True,
#    'stream': True,
#    'hmmm': True},
#   0),
#  ({'yeah': True,
#    'seem': True,
#    'judg': True,
#    'look': True,
#    "'s": True,
#    'sweetheart': True},
#   4),
#  ({'119': True, 'better': True, 'last': True, 'night': True}, 0),
#  ({'home': True,
#    'project': True,
#    'grad': True,
#    'exhaust': True,
#    'work': True,
#    'visit': True},
#   0),
#  ({'6f': True, 'tri': True, '...': True}, 0),
#  ({'didnt': True,
#    'mean': True,
#    'scare': True,
#    'ya': True,
#    'chris': True,
#    'lol': True,
#    'ask': True,
#    'go': True,
#    'anoth': True,
#    'one': True,
#    'say': True,
#    'yes': True},
#   4),
#  ({'sick': True,
#    'bed': True,
#    'blind': True,
#    'migrain': True,
#    'sinc': True,
#    'yesterday': True},
#   0),
#  ({'feel': True, 'sick': True, 'got': True, 'shake': True, 'morn': True}, 0),
#  ({'yes': True,
#    'bed': True,
#    'yet': True,
#    'either': True,
#    'get': True,
#    'pick': True,
#    'say': True,
#    'goodby': True,
#    'll': True,
#    'back': True,
#    'soon': True,
#    'send': True,
#    'pic': True},
#   0),
#  ({'get': True, 'realli': True, 'cool': True, 'purs': True}, 4),
#  ({'619': True,
#    'hi': True,
#    'luv': True,
#    'u': True,
#    'shuda': True,
#    'said': True,
#    'goin': True,
#    'da': True,
#    'beach': True,
#    'wuda': True,
#    'went': True},
#   0),
#  ({'30th': True,
#    'birthday': True,
#    'step': True,
#    'one': True,
#    'chang': True,
#    'flat': True,
#    'tire': True,
#    'ha': True},
#   4),
#  ({'_chou': True,
#    'oh': True,
#    'thank': True,
#    'dude': True,
#    'teehe': True,
#    'though': True,
#    'sure': True,
#    'tweet': True,
#    'refer': True,
#    'still': True},
#   4),
#  ({'free': True,
#    'semtech2009': True,
#    'vanilla': True,
#    'latt': True,
#    '...': True,
#    'make': True,
#    'coffe': True,
#    'hotel': True,
#    'room': True},
#   0),
#  ({'prepar': True,
#    'cake': True,
#    'plan': True,
#    'weekend': True,
#    'hope': True,
#    'come': True,
#    'watch': True},
#   4),
#  ({'25': True, 'agre': True}, 4),
#  ({'revisando': True, 'netbean': True, '6.7': True, 'beta': True}, 4),
#  ({'yet': True,
#    'want': True,
#    'brother': True,
#    'go': True,
#    "'s": True,
#    'drunk': True,
#    'fuck': True,
#    'pot': True,
#    'head': True,
#    '...': True,
#    'w.t.f': True,
#    "'m": True,
#    'good': True,
#    'one': True,
#    'ca': True},
#   0),
#  ({'14': True, 'month': True, 'anniverseri': True, 'tomorrow': True}, 4),
#  ({}, 4),
#  ({'sinc': True,
#    '6:23.': True,
#    'dryer': True,
#    'half': True,
#    'hour': True,
#    'away': True,
#    'though': True,
#    "'s": True,
#    'good': True,
#    'guess': True},
#   0),
#  ({'aw': True,
#    'naw': True,
#    'say': True,
#    '...': True,
#    'jus': True,
#    'took': True,
#    'money': True},
#   0),
#  ({'consid': True, 'think': True, 'take': True, 'homework': True, 'bag': True},
#   4),
#  ({}, 0),
#  ({'tire': True, 'work': True}, 0),
#  ({'parti': True, 'burn': True, 'candl': True, 'end': True, 'lol': True}, 4),
#  ({'want': True, 'remind': True, 'love': True}, 4),
#  ({'figur': True,
#    'great': True,
#    'market': True,
#    'ploy': True,
#    'chanc': True,
#    'dude': True,
#    'sheeet': True,
#    'gal': True,
#    'lol': True,
#    'ask': True,
#    'digit': True,
#    'imma': True,
#    'give': True,
#    'em': True,
#    'blog': True,
#    'instead': True,
#    'yesss': True,
#    '...': True},
#   4),
#  ({'chanc': True, 'watch': True, 'espn': True, 'hmmmm': True}, 4),
#  ({'heart': True, 'hurt': True, 'soo': True, 'bad': True, 'right': True}, 0),
#  ({'omg': True,
#    'need': True,
#    'drink': True,
#    'somebodi': True,
#    'help': True,
#    'better': True,
#    'yet': True,
#    'someon': True,
#    'get': True,
#    'shot': True,
#    '151': True},
#   0),
#  ({'know': True,
#    "'d": True,
#    'go': True,
#    'bat': True,
#    'anti-happi': True,
#    'ordin': True,
#    'unfortun': True,
#    "'s": True,
#    'tabl': True},
#   0),
#  ({'funni': True,
#    'week': True,
#    '..': True,
#    'riot': True,
#    'abd': True,
#    'back': True,
#    'kennel': True,
#    'didnt': True,
#    'work': True,
#    'foster': True,
#    'home': True,
#    'fault': True},
#   0),
#  ({}, 0),
#  ({'done': True, 'bitch': True, 'total': True, 'kick': True, 'ass': True}, 4),
#  ({'13': True, 'stanley': True, 'cup': True}, 0),
#  ({'want': True, 'monday': True, 'tomorrow': True}, 0),
#  ({'love': True,
#    'sun': True,
#    'last': True,
#    'week': True,
#    'shame': True,
#    'work': True,
#    'start': True,
#    '2moro': True},
#   0),
#  ({'lame-o-rama': True,
#    'go': True,
#    'fuck': True,
#    'bore': True,
#    'offffffiiiiccceeee': True,
#    'fuckkkkk': True,
#    "'m": True,
#    'sombodi': True,
#    'text': True,
#    '618.709.8541': True},
#   0),
#  ({'fuck': True,
#    "'s": True,
#    'retarded': True,
#    'mean': True,
#    'sure': True,
#    'sometim': True,
#    'stuff': True,
#    '...': True,
#    'need': True,
#    'care': True,
#    'reserach': True},
#   0),
#  ({'8tive': True,
#    'lt': True,
#    'need': True,
#    'get': True,
#    'f**k': True,
#    'dick': True,
#    '...': True,
#    '.keep': True,
#    'name': True,
#    'ur': True,
#    'mouth': True,
#    'irrelevant..': True,
#    'k': True,
#    'thank': True,
#    'real': True},
#   4),
#  ({'ughhh': True,
#    '...': True,
#    'work': True,
#    'slow': True,
#    'crawl': True,
#    'last': True,
#    'hour': True},
#   0),
#  ({'7': True, 'thank': True, 'youu': True, 'okay': True}, 4),
#  ({'wine': True,
#    'time': True,
#    'great': True,
#    'run': True,
#    'week': True,
#    'sorri': True,
#    'frazzl': True,
#    'construction=stress': True},
#   0),
#  ({"'m": True,
#    'wash': True,
#    'hous': True,
#    'love': True,
#    'teenag': True,
#    'haterz': True,
#    'eg': True,
#    'blogtv': True,
#    'last': True,
#    'night': True,
#    "'s": True,
#    'sound': True,
#    'kept': True,
#    'hear': True},
#   0),
#  ({'damn': True,
#    'step': True,
#    'rediff': True,
#    'forum': True,
#    '...': True,
#    'new': True,
#    'shoe': True},
#   0),
#  ({}, 0),
#  ({'ah': True, 'beauti': True, 'twitter': True}, 4),
#  ({'one': True,
#    'weekend': True,
#    'sinc': True,
#    'begin': True,
#    'yr': True,
#    'think': True,
#    'know': True,
#    '...': True,
#    'that': True,
#    'self': True,
#    'employ': True,
#    'suppos': True},
#   4),
#  ({'see': True}, 4),
#  ({'83': True,
#    "'m": True,
#    'pretti': True,
#    'fuck': True,
#    'fab': True,
#    'right': True,
#    "'s": True},
#   4),
#  ({'fed': True, 'concern': True}, 0),
#  ({"'s": True, 'sad': True}, 0),
#  ({'phone': True, 'keep': True, 'eat': True, 'sim': True, 'game': True}, 0),
#  ({'pull': True, 'lower': True, 'back': True, 'muscl': True}, 0),
#  ({'watch': True,
#    'punk': True,
#    "'d": True,
#    'tonight': True,
#    'laugh': True,
#    'ass': True},
#   4),
#  ({'complet': True,
#    'dumbass': True,
#    'lick': True,
#    'knife': True,
#    'cut': True,
#    'tongu': True},
#   0),
#  ({'want': True,
#    'sim': True,
#    '3': True,
#    '...': True,
#    'anyon': True,
#    'know': True,
#    'buy': True,
#    'much': True},
#   0),
#  ({'way': True,
#    'back': True,
#    'manchest': True,
#    'buy': True,
#    'lot': True,
#    'bit': True,
#    'bob': True,
#    'leaver': True,
#    'parti': True},
#   0),
#  ({}, 4),
#  ({"'m": True,
#    'gon': True,
#    'na': True,
#    'watch': True,
#    'open': True,
#    'hehe': True},
#   4),
#  ({'didnt': True,
#    'want': True,
#    'leav': True,
#    'twitter': True,
#    'haha': True,
#    'im': True,
#    'backk': True,
#    'watch': True,
#    'notebook': True},
#   4),
#  ({'there': True,
#    'electr': True,
#    'hous': True,
#    'right': True,
#    'phone': True,
#    'die': True,
#    'pls': True,
#    'quick': True,
#    'shout': True,
#    "c'mon": True},
#   0),
#  ({'omg': True, 'comput': True, 'angri': True}, 0),
#  ({}, 4),
#  ({'hope': True, 'thing': True, 'get': True, 'better': True}, 0),
#  ({'saw': True, '...': True, '..awwwwww': True}, 0),
#  ({'cancel': True,
#    'zune': True,
#    'doesnt': True,
#    'make': True,
#    'jizzinmyp': True},
#   0),
#  ({'swear': True,
#    'god': True,
#    're': True,
#    'joke': True,
#    'go': True,
#    'break': True,
#    'heart': True},
#   0),
#  ({'cook': True, 'cake': True}, 4),
#  ({'girl': True,
#    'join': True,
#    'anytim': True,
#    'let': True,
#    'know': True,
#    'drink': True,
#    '10am': True,
#    'fun': True,
#    '10pm': True,
#    'haha': True,
#    'jk': True},
#   4),
#  ({'21': True,
#    'like': True,
#    'korea': True,
#    'food': True,
#    'particular': True,
#    'barbecu': True,
#    'cheap': True,
#    'countri': True,
#    'need': True,
#    'pay': True,
#    '40.00': True,
#    'rmb': True,
#    '7': True,
#    'u.s.': True,
#    'dollar': True},
#   4),
#  ({'head': True,
#    'mine': True,
#    'hard': True,
#    'go': True,
#    'last': True,
#    'time': True},
#   0),
#  ({'dont': True, 'think': True, 'meaghan': True}, 4),
#  ({'6f2ft': True,
#    'hai': True,
#    '...': True,
#    'belum': True,
#    'hik': True,
#    'help': True},
#   0),
#  ({}, 4),
#  ({'_68': True,
#    'oh': True,
#    'good': True,
#    'netherland': True,
#    'origin': True,
#    'mum': True,
#    '5': True,
#    'minut': True,
#    'car': True,
#    'away': True,
#    'kind': True,
#    'lucki': True},
#   4),
#  ({'30': True,
#    'someth': True,
#    'adult': True,
#    '1st': True,
#    'flight': True,
#    'lol': True,
#    '41': True,
#    'would': True,
#    'realli': True,
#    'cool': True},
#   4),
#  ({'1': True,
#    'wish': True,
#    'could': True,
#    'get': True,
#    'lip': True,
#    'ring': True},
#   4),
#  ({}, 4),
#  ({'get': True,
#    'everyth': True,
#    'togeth': True,
#    'leav': True,
#    'europ': True,
#    'hour': True},
#   4),
#  ({'end': True,
#    'instal': True,
#    'vistash': True,
#    '...': True,
#    'anoth': True,
#    'way': True},
#   0),
#  ({'follow': True,
#    'drop': True,
#    'like': True,
#    'fli': True,
#    'suppos': True,
#    'might': True,
#    'one': True,
#    'find': True,
#    'interest': True},
#   4),
#  ({'afternoon': True, 'todd': True}, 4),
#  ({'dammit': True, 'could': True, 'get': True, "'m": True, 'hilton': True}, 0),
#  ({'pink': True,
#    'one': True,
#    'right': True,
#    'nice': True,
#    '9th': True,
#    '8': True,
#    'e-mail': True,
#    'confus': True},
#   0),
#  ({'good': True, 'morn': True, 'luck': True, 'math': True, 'test': True}, 4),
#  ({'old': True, 'convers': True, 're': True, 'fun': True, 'go': True}, 4),
#  ({'tour': True,
#    'ancient': True,
#    'rome': True,
#    'today': True,
#    'saw': True,
#    'beauiti': True,
#    'place': True,
#    'world': True,
#    '...': True,
#    'miss': True,
#    'home': True,
#    '.and': True,
#    'mean': True,
#    'amin': True},
#   0),
#  ({'wed': True, 'singer': True}, 4),
#  ({'cos': True,
#    'peep': True,
#    'want': True,
#    'molten': True,
#    'mouth': True,
#    '...': True,
#    'heeeeeeheeee': True},
#   4),
#  ({'_design': True,
#    'that': True,
#    'good': True,
#    'bout': True,
#    'stuck': True,
#    'car': True,
#    'strom': True,
#    '2night': True,
#    'parkin': True,
#    'lot': True},
#   0),
#  ({'ugh': True,
#    'need': True,
#    'arrowroot': True,
#    'powder': True,
#    'must': True,
#    'put': True,
#    'pant': True,
#    'go': True,
#    'shop': True},
#   0),
#  ({'friday': True,
#    'tomorrow': True,
#    'big': True,
#    'swear': True,
#    'day': True,
#    'turn': True,
#    "'s": True,
#    'f***ing': True,
#    'clever': True,
#    'ca': True,
#    'wait': True},
#   4),
#  ({'hmmm~': True,
#    'smell': True,
#    'thal': True,
#    'yumm-o': True,
#    'ryt': True,
#    'nw': True,
#    'guess': True,
#    "'s": True,
#    'readi': True,
#    'tuck': True,
#    'oledi': True},
#   4),
#  ({'21': True,
#    '_pina_14': True,
#    'especi': True,
#    'w/': True,
#    'current': True,
#    'situat': True,
#    "'s": True,
#    'pretti': True,
#    'easi': True,
#    'get': True,
#    'lost': True,
#    'footi': True,
#    'oppos': True,
#    'rl': True},
#   0),
#  ({'sound': True, 'fun': True}, 4),
#  ({'medic': True, 'health': True, 'day': True, 'home': True, 'mmm': True}, 4),
#  ({'awesom': True,
#    'birthday': True,
#    'far': True,
#    'cake': True,
#    'spent': True,
#    'time': True,
#    'wit': True,
#    'famili': True,
#    'talk': True,
#    'friend': True},
#   4),
#  ({'look': True,
#    'pictur': True,
#    'guy': True,
#    'everi': True,
#    'time': True,
#    'die': True,
#    'draw': True},
#   4),
#  ({'prettypinkpearl': True, 'chat': True, 'room': True, 'launch': True}, 4),
#  ({'wow': True, 'im': True, 'sorri': True, '...': True}, 0),
#  ({'yeah': True, "'m": True, 'stupid': True}, 4),
#  ({'3gamealli': True,
#    'yes': True,
#    'heard': True,
#    'alreadi': True,
#    'beta': True,
#    'code': True,
#    'point': True},
#   4),
#  ({'yes': True, 'pic': True, 'thing': True, 'new': True, 'music': True}, 0),
#  ({'posibil': True}, 4),
#  ({'thank': True,
#    'know': True,
#    'load': True,
#    'crap': True,
#    'joke': True,
#    'sometim': True,
#    'funni': True},
#   4),
#  ({}, 4),
#  ({'leav': True,
#    'near': True,
#    '3': True,
#    'month': True,
#    'without': True,
#    'peanut': True,
#    'butter': True,
#    'right': True},
#   0),
#  ({}, 4),
#  ({'possibl': True,
#    '2': True,
#    'amplifi': True,
#    'word': True,
#    'slut': True,
#    'place': True,
#    'booyah': True,
#    'front': True,
#    'follow': True,
#    'open': True,
#    'palm': True,
#    'shove': True,
#    'nose': True,
#    'cours': True},
#   4),
#  ({'happi': True, 'birthday': True, 'ya': True}, 4),
#  ({'damn': True,
#    'pigeon': True,
#    'friend': True,
#    'found': True,
#    'mani': True,
#    'differ': True,
#    'way': True,
#    'get': True,
#    'rid': True,
#    'even': True,
#    'make': True,
#    'look': True,
#    'like': True,
#    'accid': True},
#   4),
#  ({'plant': True,
#    'camelia': True,
#    'rose': True,
#    'annual': True,
#    'back': True,
#    'yard': True,
#    'today': True,
#    'guess': True,
#    'skillset': True,
#    'fall': True},
#   4),
#  ({'dinner': True, 'hey': True, 'darlin': True}, 4),
#  ({'realli': True, 'put': True, 'pic': True, 'guess': True}, 0),
#  ({'belfast': True,
#    'last': True,
#    'night': True,
#    'great': True,
#    'fun': True,
#    'catch': True,
#    'wit': True,
#    'laura': True,
#    'loadsa': True,
#    'laugh': True},
#   4),
#  ({'_marisa': True,
#    'gloomi': True,
#    'one': True,
#    'day': True,
#    'half': True,
#    'day..': True,
#    'sunni': True},
#   4),
#  ({'way': True,
#    'pick': True,
#    'dresser': True,
#    'crib': True,
#    'babi': True,
#    'good': True,
#    'littl': True,
#    'girl': True,
#    'come': True,
#    'june': True,
#    'look': True,
#    'forward': True,
#    'arriv': True},
#   4),
#  ({'ve': True, 'run': True, 'dreamtim': True, 'tea': True}, 0),
#  ({'babi': True,
#    "'m": True,
#    'sorri': True,
#    'omg': True,
#    'gain': True,
#    'weight': True,
#    'back': True,
#    'lost': True},
#   0),
#  ({'technolog': True, 'amaz': True, 'someon': True, 'get': True}, 4),
#  ({'7x_bat_angel': True, 'thank': True, 'doll': True}, 4),
#  ({'im': True, 'sad': True, 'miss': True, 'kitti': True}, 0),
#  ({"'m": True,
#    'sorri': True,
#    'let': True,
#    "'s": True,
#    'set': True,
#    'fire': True},
#   0),
#  ({'manag': True,
#    'chang': True,
#    'outfit': True,
#    'well': True,
#    'love': True,
#    'wore': True,
#    'made': True,
#    'look': True,
#    'fairer': True},
#   4),
#  ({'123': True,
#    'problem': True,
#    'anyth': True,
#    'help': True,
#    'spread': True,
#    'word': True},
#   4),
#  ({'aw': True,
#    'paint': True,
#    'toe': True,
#    'nail': True,
#    'scare': True,
#    'much': True},
#   0),
#  ({'justt': True, 'got': True, 'bck': True, 'badboyi': True, 'uh': True}, 0),
#  ({'need': True,
#    'dm': True,
#    'address': True,
#    'thank': True,
#    'girlfriend': True},
#   4),
#  ({'unhappi': True,
#    'fake': True,
#    'wentworth': True,
#    'miller': True,
#    'twitter': True,
#    'account': True},
#   0),
#  ({}, 4),
#  ({'bbl': True,
#    'trynz': True,
#    'get': True,
#    'follow': True,
#    '100': True,
#    'weekend': True,
#    'let': True,
#    'mak': True,
#    'happen': True,
#    'back': True,
#    'later': True,
#    'love': True},
#   4),
#  ({'still': True,
#    'wait': True,
#    'fajr': True,
#    'morn': True,
#    'prayer': True,
#    'come': True,
#    'effect': True,
#    'hour': True,
#    'status': True,
#    'wide': True,
#    'awak': True},
#   0),
#  ({'34.': True, 'believ': True, 'dumb': True, 'younger': True, 'miss': True},
#   0),
#  ({'good': True,
#    'morn': True,
#    'tweet': True,
#    'busi': True,
#    'day': True,
#    '2day': True,
#    'let': True,
#    'get': True,
#    'alot': True,
#    'done': True},
#   4),
#  ({'need': True,
#    'holiday': True,
#    'realli': True,
#    'dont': True,
#    'want': True,
#    'go': True,
#    'back': True,
#    '6th': True,
#    'form': True,
#    'tommorowww': True},
#   0),
#  ({'_becca': True,
#    'lol..': True,
#    'realisedni': True,
#    'fav': True,
#    'tv': True,
#    'show': True,
#    'nick': True,
#    'jona': True,
#    'hero': True},
#   4),
#  ({'lone': True, 'night': True, 'start': True, '2': True, 'fade': True}, 0),
#  ({}, 4),
#  ({'happen': True,
#    'otherday': True,
#    'googl': True,
#    'ima': True,
#    'geek': True,
#    'like': True,
#    'turn': True,
#    'manufactur': True,
#    'fault': True,
#    'happi': True},
#   0),
#  ({'tire': True,
#    'activ': True,
#    'day..': True,
#    'sooo': True,
#    'much': True,
#    'fun': True,
#    'get': True,
#    'rest': True,
#    'go': True,
#    'school': True,
#    'tomorrow': True},
#   4),
#  ({'hittin': True,
#    'sheet': True,
#    'lil': True,
#    'earli': True,
#    'hope': True,
#    'good': True,
#    'day': True,
#    'tomorrow': True,
#    'goodlookin': True,
#    'jenn': True},
#   4),
#  ({'googl': True,
#    'baller': True,
#    'lol': True,
#    'thought': True,
#    'mayb': True,
#    'someth': True,
#    'naughti': True,
#    'lololol': True,
#    'thank': True},
#   4),
#  ({'_dm': True,
#    "'s": True,
#    'good': True,
#    'friend': True,
#    'said': True,
#    'exam': True,
#    'hard': True,
#    'ahah': True},
#   4),
#  ({'hahha': True,
#    '...': True,
#    '1': True,
#    'hun': True,
#    'jus': True,
#    'walk': True,
#    'away': True,
#    'sorri': True,
#    'ur': True,
#    'piss': True},
#   0),
#  ({'think': True,
#    'everyth': True,
#    'happen': True,
#    '4': True,
#    'reason': True,
#    'u': True,
#    'learn': True,
#    'mistak': True,
#    'chang': True,
#    'strategi': True,
#    'roll': True},
#   4),
#  ({'82883': True,
#    'dock': True,
#    'browni': True,
#    'point': True,
#    'nickelodean': True,
#    'theme': True,
#    'yay': True,
#    'spongebob': True,
#    'gon': True,
#    'na': True,
#    'tri': True,
#    'go': True,
#    'ride': True,
#    'today': True,
#    'get': True,
#    'funni': True,
#    'cake': True},
#   4),
#  ({'ca': True,
#    'chang': True,
#    'certain': True,
#    'sit': True,
#    'rotat': True,
#    'like': True,
#    'k': True},
#   4),
#  ({'rehears': True, '8:15': True, 'tomorrow': True}, 0),
#  ({'want': True, 'nao': True, 'robot': True, 'red': True}, 4),
#  ({'aww': True,
#    'thank': True,
#    'ms.': True,
#    'mcgraw': True,
#    'realli': True,
#    'need': True,
#    'hug': True},
#   4),
#  ({'blue': True,
#    'green': True,
#    'violet': True,
#    'new': True,
#    'hair': True,
#    'color': True,
#    'got': True,
#    'wash': True,
#    'rain': True},
#   0),
#  ({'import': True,
#    'check': True,
#    'pm': True,
#    "'s": True,
#    'ha': True,
#    'asap': True},
#   0),
#  ({'bak': True, 'construct': True}, 4),
#  ({'24lbsofboost': True, 'thank': True}, 0),
#  ({'doubt': True,
#    'll': True,
#    'hear': True,
#    'even': True,
#    'season': True,
#    'hope': True,
#    'jenson': True,
#    'certan': True,
#    'subject': True},
#   4),
#  ({'sure': True,
#    'tell': True,
#    'lovebox': True,
#    'digit': True,
#    'wristband': True,
#    'great': True,
#    'hear': True},
#   4),
#  ({'beer': True}, 0),
#  ({'man': True, 'hate': True, 'clean': True, 't^t': True}, 0),
#  ({'_magazin': True,
#    'know': True,
#    'pict': True,
#    'thought': True,
#    'realli': True,
#    'fish': True,
#    'kept': True,
#    'long': True,
#    'done': True,
#    'cri': True,
#    'left': True},
#   0),
#  ({'thank': True,
#    'cheemaro': True,
#    'see': True,
#    'vamp': True,
#    'diari': True,
#    'parent': True,
#    'discret': True,
#    'advis': True,
#    'kerr': True,
#    'smith': True,
#    'import': True,
#    'role': True},
#   4),
#  ({'know': True,
#    'abl': True,
#    'make': True,
#    'work': True,
#    'day': True,
#    'doubt': True,
#    'surviv': True,
#    'concert': True,
#    'tonight': True,
#    'probabl': True,
#    'gon': True,
#    'na': True,
#    'sleep': True,
#    'instead': True},
#   0),
#  ({'come': True,
#    'spain': True,
#    've': True,
#    'fan': True,
#    '5': True,
#    'year': True,
#    'never': True,
#    'abl': True,
#    'see': True,
#    'guy': True,
#    'live': True,
#    'x': True},
#   0),
#  ({'_rov': True,
#    'yay': True,
#    'cuz': True,
# ...
#    'jack': True,
#    'haha': True},
#   4),
#  ({'great': True,
#    'start': True,
#    '...': True,
#    'sinc': True,
#    'laptop': True,
#    'decid': True,
#    'beotch': True,
#    'die': True,
#    'morn': True},
#   0),
#  ({'go': True, 'sleep': True, 'long': True, 'day': True}, 4),
#  ({'bye': True,
#    'anip': True,
#    '...': True,
#    'tar': True,
#    'tri': True,
#    'catch': True,
#    'rest..': True,
#    'hihi': True,
#    '*hug': True,
#    'all*': True},
#   4),
#  ({'one': True,
#    'biggest': True,
#    'key': True,
#    'success': True,
#    'realiz': True,
#    'door': True,
#    'lock': True},
#   4),
#  ({'mtv': True, 'movi': True, 'award': True}, 4),
#  ({'seen': True,
#    'latest': True,
#    'staging/truss': True,
#    'collaps': True,
#    'festiv': True,
#    'oh': True,
#    'dear': True},
#   0),
#  ({'rain': True, 'day': True, 'noth': True, 'im': True, 'bore': True}, 0),
#  ({'wow': True, "'s": True, 'realli': True, 'surpris': True}, 0),
#  ({'love': True,
#    'post': True,
#    'first': True,
#    'video': True,
#    'respons': True,
#    'youtub': True,
#    'wait': True,
#    'person': True,
#    'approv': True,
#    '...': True},
#   4),
#  ({'phone': True,
#    'broke': True,
#    'that': True,
#    'havent': True,
#    'keep': True,
#    'touch': True,
#    'miss': True,
#    'though': True,
#    'im': True,
#    'get': True,
#    'new': True,
#    'wednesday': True},
#   0),
#  ({'lost': True,
#    'check': True,
#    'ca': True,
#    'find': True,
#    'anywher': True,
#    'goe': True,
#    'money': True,
#    "'s": True,
#    'us': True,
#    'cant': True,
#    'ask': True,
#    'send': True},
#   0),
#  ({'whoa': True,
#    '...': True,
#    "'m": True,
#    'sick': True,
#    'want': True,
#    'work': True,
#    'fml': True},
#   0),
#  ({'think': True,
#    'power': True,
#    'adapt': True,
#    'macbook': True,
#    'pro': True,
#    'got': True,
#    'fri': True,
#    '...': True},
#   0),
#  ({'sure': True, 'wish': True, 'better': True, 'mood': True}, 0),
#  ({'hit': True, 'squirel': True, 'poor': True, 'lil': True, 'guy': True}, 0),
#  ({'david': True,
#    'hope': True,
#    'u': True,
#    'grood': True,
#    'time': True,
#    'sd': True,
#    'counti': True,
#    'fair': True,
#    'goin': True,
#    '2': True,
#    'go': True,
#    'could': True,
#    'well': True,
#    'fun': True,
#    'gr8': True,
#    'voic': True},
#   0),
#  ({'awak': True, 'yet': True, 'miss': True, 'much': True}, 0),
#  ({'shhh': True,
#    'give': True,
#    'away': True,
#    'dvr': True,
#    "'d": True,
#    'talk': True},
#   4),
#  ({'dont': True, 'say': True}, 0),
#  ({'excit': True,
#    'wed': True,
#    'saturday': True,
#    'rememb': True,
#    'havta': True,
#    'buy': True,
#    'present': True},
#   0),
#  ({'4tunecookiesam': True,
#    'grill': True,
#    'bacon': True,
#    'chees': True,
#    'burger': True,
#    'backyard': True,
#    'lol': True},
#   4),
#  ({'ca': True,
#    'sleep': True,
#    'watch': True,
#    'risqu': True,
#    'foreign': True,
#    'film': True,
#    'alon': True,
#    'bed': True},
#   0),
#  ({'watch': True,
#    'natur': True,
#    'program': True,
#    'anim': True,
#    'planet': True,
#    'hope': True,
#    'see': True,
#    'noth': True,
#    'die': True},
#   0),
#  ({}, 0),
#  ({'woke': True,
#    'without': True,
#    'hangov': True,
#    '...': True,
#    'got': True,
#    'ta': True,
#    'put': True,
#    'famili': True,
#    'two': True,
#    'hour': True,
#    'itll': True},
#   0),
#  ({'ugh': True, 'rooki': True, 'made': True, 'basket': True}, 0),
#  ({'oh': True, 'must': True, 'nice': True, 'twitpic': True, 'mate': True}, 4),
#  ({}, 0),
#  ({'thank': True}, 4),
#  ({'well': True,
#    'ive': True,
#    'final': True,
#    'got': True,
#    'deck': True,
#    'yawn': True,
#    'creepin': True,
#    'bad': True,
#    'feel': True,
#    'may': True,
#    'www.toolittletoolate.com': True},
#   4),
#  ({'oop': True,
#    'accident': True,
#    'fell': True,
#    'love': True,
#    'gay': True,
#    'guy': True},
#   0),
#  ({'131': True, 'let': True, "'s": True, 'aim': True, 'weekend': True}, 4),
#  ({'realli': True,
#    'need': True,
#    'tidi': True,
#    'desk': True,
#    'lost': True,
#    'key': True,
#    '3': True,
#    'time': True,
#    'alreadi': True,
#    '10.20': True},
#   0),
#  ({'wish': True, '18': True, 'follow': True, '...': True}, 0),
#  ({'awww': True,
#    'miss': True,
#    'good': True,
#    'day': True,
#    'went': True,
#    'bowl': True,
#    'sorri': True,
#    'catch': True,
#    'soon': True,
#    'xxx': True},
#   0),
#  ({'ear': True,
#    'itchi': True,
#    'need': True,
#    'rememb': True,
#    'put': True,
#    'sunscreen': True},
#   0),
#  ({}, 0),
#  ({'last': True,
#    'drive': True,
#    'ktis': True,
#    'cant': True,
#    'wait': True,
#    '4': True,
#    'construct': True,
#    'done': True},
#   0),
#  ({'everyon': True,
#    'decid': True,
#    'go': True,
#    'groceri': True,
#    'shop': True,
#    'today': True,
#    'rain': True,
#    'park': True,
#    'aw': True,
#    'left': True,
#    'macho': True,
#    'car': True},
#   0),
#  ({'friend': True,
#    'twitter': True,
#    "'m": True,
#    'grab': True,
#    'beer': True,
#    'bucan': True,
#    'join': True,
#    're': True,
#    'near': True},
#   4),
#  ({'good': True, 'morn': True, 'tweopl': True}, 4),
#  ({'quot': True,
#    'want': True,
#    'pcd': True,
#    'nicol': True,
#    'im': True,
#    'love': True},
#   4),
#  ({'wish': True,
#    'kristel': True,
#    'didnt': True,
#    'phone': True,
#    'silent': True,
#    'timeee': True},
#   4),
#  ({'batteri': True, 'die': True}, 0),
#  ({'damn': True, '...': True, '.dnt': True, 'kno': True}, 0),
#  ({'exhaust': True, 'reason': True, '...': True}, 0),
#  ({'twitter': True, 'revok': True, 'nudg': True, 'privilidg': True}, 0),
#  ({'somebodi': True,
#    'mess': True,
#    'dish': True,
#    'dvr': True,
#    'record': True,
#    'gone': True,
#    'grrrrrr': True,
#    'ca': True,
#    'wait': True,
#    'corrupt': True,
#    'harddriv': True,
#    'thing': True,
#    'past': True},
#   0),
#  ({'june': True, '21st': True, 'yet': True}, 4),
#  ({'teeth': True, 'hurt': True, 'lil': True, 'bit': True}, 0),
#  ({'sad': True, 'face': True}, 0),
#  ({'fed': True,
#    'sourdough': True,
#    'earlier': True,
#    'look': True,
#    'pretti': True,
#    'healthi': True,
#    'real': True,
#    'bubbl': True,
#    'jump': True,
#    'kitchen': True,
#    'enjoy': True,
#    'shabbat': True},
#   4),
#  ({'communiti': True, 'action': True, 'make': True, 'sleepi': True}, 0),
#  ({'problem': True,
#    'hunni': True,
#    'need': True,
#    'coffe': True,
#    'ooooo': True,
#    'starbuck': True},
#   4),
#  ({'firebug': True,
#    'quit': True,
#    'work': True,
#    '2': True,
#    'day': True,
#    'ago': True,
#    "'m": True,
#    'lost': True,
#    'without': True},
#   0),
#  ({'eff': True, 'phone': True, 'dead': True}, 0),
#  ({'finish': True,
#    'workout': True,
#    'prais': True,
#    'god': True,
#    'caus': True,
#    'hard': True,
#    'get': True,
#    'good': True,
#    'asthma': True,
#    'stuff': True},
#   4),
#  ({'ever': True, 'come': True, 'back': True, 'ff': True}, 0),
#  ({'nadal': True,
#    'lose': True,
#    'french': True,
#    'open': True,
#    'absolut': True,
#    'shocker': True,
#    'bad': True,
#    'see': True,
#    'match': True},
#   0),
#  ({'nop': True, 'aint': True, 'twitter': True}, 4),
#  ({'yeah': True,
#    'work': True,
#    'like': True,
#    'clock': True,
#    '--': True,
#    'cuckoo': True},
#   4),
#  ({}, 0),
#  ({'ha': True, 'let': True, 'guess': True}, 4),
#  ({'yes': True,
#    'sad': True,
#    'cinema': True,
#    'kelheim': True,
#    'film': True,
#    'quot': True,
#    'hannah': True,
#    'montana': True},
#   4),
#  ({'work': True,
#    '...': True,
#    'yay': True,
#    'sleep': True,
#    'gmornin': True,
#    'goodnight': True,
#    'tweetheart': True},
#   4),
#  ({'ugh': True,
#    '...': True,
#    'like': True,
#    'drunk': True,
#    'call': True,
#    'bothersom': True,
#    'work': True,
#    'peopl': True,
#    'ca': True,
#    'sleep': True},
#   0),
#  ({'u': True, 'onlin': True, 'hotmail': True}, 4),
#  ({'soul': True,
#    'train': True,
#    'missed..bi': True,
#    'me..fo': True,
#    'sho': True},
#   0),
#  ({'want': True,
#    'work': True,
#    'oprah': True,
#    'everyon': True,
#    'vacat': True,
#    '1700': True},
#   0),
#  ({'doggi': True, 'social': True}, 4),
#  ({'man': True,
#    'didnt': True,
#    'win': True,
#    'trackl': True,
#    'squarespac': True},
#   0),
#  ({'100th': True, 'update..': True}, 4),
#  ({"'m": True,
#    'still': True,
#    'mark': True,
#    'two': True,
#    'slide': True,
#    'present': True,
#    'applertc': True,
#    'look': True,
#    'like': True,
#    "'s": True,
#    'go': True,
#    'long': True,
#    'night': True},
#   0),
#  ({'nice': True}, 4),
#  ({'182x': True, 'name': True}, 4),
#  ({'way': True,
#    'home': True,
#    "'m": True,
#    'realli': True,
#    'burnt': True,
#    'love': True,
#    'swim': True},
#   4),
#  ({}, 0),
#  ({'day': True,
#    'one': True,
#    'palm': True,
#    'pre': True,
#    'hunt': True,
#    'sold': True,
#    '5': True,
#    'locat': True,
#    '...': True,
#    'tri': True,
#    'next': True,
#    'mon': True},
#   0),
#  ({'dude': True,
#    "'m": True,
#    'watch': True,
#    'csi': True,
#    'miami': True,
#    'goe': True,
#    'ny': True,
#    'work': True,
#    'peopl': True,
#    'ahhh': True,
#    '...': True,
#    'today': True,
#    'good': True,
#    'day': True,
#    'lol': True},
#   4),
#  ({'dj': True,
#    'traci': True,
#    'young': True,
#    "'s": True,
#    'eatin': True,
#    'wendi': True,
#    'damn': True,
#    'girl': True,
#    "'m": True,
#    'hungri': True,
#    '...': True,
#    'chicken': True,
#    'breast': True,
#    'brown': True,
#    'rice': True,
#    'lick': True,
#    'wrapper': True,
#    'get': True,
#    'lmao': True},
#   0),
#  ({'get': True,
#    'well': True,
#    'soon': True,
#    'keri': True,
#    'look': True,
#    'sing': True,
#    'voic': True},
#   4),
#  ({'*jealous*': True,
#    'wish': True,
#    'go': True,
#    'stonelov': True,
#    'tonight': True,
#    'work': True,
#    'till': True,
#    '8.30': True,
#    'im': True,
#    'skint': True},
#   0),
#  ({'beauti': True, 'yummi': True, 'lunch': True, 'way': True, 'go': True}, 4),
#  ({'love': True,
#    'see': True,
#    'you/film': True,
#    '_22': True,
#    'ladi': True,
#    'wonder': True},
#   4),
#  ({'goodi': True, 'good': True}, 4),
#  ({'lol': True,
#    'glad': True,
#    'ok.': True,
#    'laugh': True,
#    'thought': True,
#    'though': True},
#   4),
#  ({'whoa': True,
#    'get': True,
#    'tweet': True,
#    'sleep': True,
#    'maricl': True,
#    'anyways..': True,
#    'goodmorn': True},
#   4),
#  ({'cute': True}, 4),
#  ({'well': True,
#    "'s": True,
#    'cold': True,
#    'got': True,
#    'noth': True,
#    '2': True},
#   0),
#  ({'twitterfail': True,
#    'fuck': True,
#    'hard': True,
#    'right': True,
#    '...': True,
#    'annoy': True},
#   0),
#  ({'boy': True,
#    'stomach': True,
#    'bug': True,
#    'officiali': True,
#    'say': True,
#    'uncl': True,
#    '...': True},
#   0),
#  ({'creat': True, 'twitter': True, 'acccount': True}, 4),
#  ({'see': True,
#    'ca': True,
#    'find': True,
#    'nice': True,
#    'simp': True,
#    'one': True},
#   4),
#  ({'guess': True,
#    'sound': True,
#    'rather': True,
#    'nice': True,
#    'haha': True,
#    'today': True,
#    'weather': True,
#    'cold': True,
#    'compar': True,
#    'rest': True,
#    'week': True},
#   0),
#  ({'wonder': True,
#    'heck': True,
#    'get': True,
#    'twitter': True,
#    'neverrr': True,
#    'use': True,
#    'lol': True,
#    'bout': True,
#    'often': True,
#    "'m": True,
#    'guitar': True,
#    'txt': True},
#   4),
#  ({'iphon': True,
#    'quot': True,
#    'open': True,
#    'download': True,
#    'app': True,
#    'thing': True,
#    'forgot': True,
#    'cord': True,
#    'home': True},
#   0),
#  ({'beatz': True,
#    'mad': True,
#    'u': True,
#    'miss': True,
#    'good': True,
#    'show': True},
#   0),
#  ({'dw': True, 'either': True}, 0),
#  ({'ca': True,
#    'stand': True,
#    'ravenna': True,
#    'tonight': True,
#    "'s": True,
#    'realli': True,
#    'nice': True},
#   4),
#  ({'_roob': True}, 0),
#  ({'dinner': True,
#    'break': True,
#    'weight': True,
#    'watcher': True,
#    'soup': True,
#    'realli': True,
#    'want': True,
#    'chees': True,
#    'burger': True},
#   0),
#  ({'caught': True, 'stupid': True, 'cold': True}, 0),
#  ({"g'night": True,
#    'rest': True,
#    'worldwid': True,
#    'tweep': True,
#    'live': True,
#    'weird': True,
#    'time': True,
#    'zone': True,
#    'mine': True},
#   4),
#  ({'talk': True,
#    'small': True,
#    'window': True,
#    'welcom': True,
#    'back': True,
#    'busbi': True,
#    "'s": True,
#    'doubl': True,
#    'actual': True,
#    'spell': True,
#    'aim': True,
#    'f': True,
#    "'d": True},
#   4),
#  ({'friend': True,
#    'think': True,
#    'im': True,
#    'total': True,
#    'freak': True,
#    'tell': True,
#    'youtub': True,
#    'twitter': True},
#   0),
#  ({'sad': True}, 0),
#  ({'hey': True,
#    'chgd': True,
#    'pic': True,
#    'us': True,
#    '...': True,
#    "'m": True,
#    'gon': True,
#    'na': True,
#    'look': True,
#    'word': True},
#   4),
#  ({}, 4),
#  ({'work': True, '930': True}, 0),
#  ({'cool': True,
#    'll': True,
#    'tri': True,
#    'make': True,
#    'next': True,
#    'week': True},
#   4),
#  ({'vacat': True,
#    'awesom': True,
#    'relax': True,
#    'coffe': True,
#    'pocki': True,
#    'give': True,
#    'week': True,
#    'good': True,
#    'start': True},
#   4),
#  ({'tom': True,
#    'today': True,
#    'school': True,
#    'play': True,
#    'pov': True,
#    'break': True,
#    'almost': True,
#    'cri': True,
#    'show': True,
#    'sao': True,
#    'paulo': True,
#    'wish': True,
#    'could': True},
#   0),
#  ({"'s": True,
#    'lunch': True,
#    'break': True,
#    'come': True,
#    'close': True,
#    'kind': True,
#    'hot': True,
#    'humid': True,
#    'today': True,
#    'nice': True,
#    're': True,
#    'shade': True,
#    'oh': True,
#    'well': True,
#    'back': True,
#    'file': True,
#    'dod': True,
#    '...': True},
#   0),
#  ({'_say13': True, 'fun': True, 'whatev': True}, 4),
#  ({'okay': True, 'guess': True, 'wo': True, 'thunderstorm': True}, 0),
#  ({'still': True,
#    'dress': True,
#    'ceremoni': True,
#    'feel': True,
#    'like': True,
#    've': True,
#    'live': True,
#    'cap': True,
#    'gown': True,
#    'month': True,
#    'graduat': True,
#    'friday': True,
#    'night': True},
#   4),
#  ({'wonka': True,
#    'nerd': True,
#    'candi': True,
#    'mmmmmmmmmm': True,
#    'yummi': True},
#   4),
#  ({'hey': True,
#    'welcom': True,
#    'confus': True,
#    'get': True,
#    'find': True,
#    'th': True,
#    'easiest': True,
#    'palc': True,
#    'ot': True,
#    'home': True},
#   4),
#  ({'chuf': True, 'mean': True, 'happi': True, 'case': True, 'awesom': True},
#   4),
#  ({'im': True, 'cold': True, 'iphon': True, 'good': True}, 0),
#  ({'81': True, 'le': True, 'suck': True}, 0),
#  ({'71': True,
#    'love': True,
#    'ice': True,
#    'road': True,
#    'trucker': True,
#    '...': True,
#    'sooo': True,
#    'glad': True,
#    'alex': True,
#    'back': True},
#   4),
#  ({"'s": True, 'right': True, '...': True}, 0),
#  ({'dish': True, 'excit': True, 'lighter': True, 'note': True, 'brown': True},
#   4),
#  ({'heart': True,
#    'hurt': True,
#    'imagin': True,
#    'shit': True,
#    'skin': True,
#    're': True,
#    'twenti': True,
#    'stuff': True,
#    'smeer': True,
#    'shame': True},
#   0),
#  ({'copi': True,
#    'past': True,
#    'someth': True,
#    'need': True,
#    'phone': True,
#    'mom': True,
#    'send': True,
#    'pictur': True,
#    'text': True,
#    'test': True,
#    'avail': True},
#   0),
#  ({'140': True,
#    'tri': True,
#    'efusjon': True,
#    'natur': True,
#    'antioxid': True,
#    'energi': True,
#    'drink': True,
#    'acai': True,
#    'berri': True,
#    'caffein': True,
#    'free': True,
#    'crash': True,
#    'www.myefusjon.com/teamandrea': True},
#   4),
#  ({'offici': True,
#    'certifi': True,
#    'cpr': True,
#    'peopl': True,
#    'actual': True,
#    'think': True,
#    'might': True,
#    'made': True,
#    'manikin': True,
#    'come': True,
#    'life': True},
#   4),
#  ({'think': True,
#    'ill': True,
#    'wait': True,
#    'till': True,
#    'come': True,
#    'dvd': True},
#   0),
#  ({'yeah': True,
#    'total': True,
#    'sweet': True,
#    'peopl': True,
#    'like': True,
#    'u': True,
#    'reason': True,
#    'need': True,
#    'medic': True,
#    '26': True,
#    'world': True},
#   4),
#  ({'say': True,
#    'good': True,
#    'afternoon': True,
#    'ulan': True,
#    'cold': True,
#    'brrrrr': True,
#    '...': True,
#    'lone': True},
#   0),
#  ({'awesom': True, 'champagn': True, 'someth': True}, 4),
#  ({'tweet': True,
#    'good': True,
#    'morn': True,
#    'final': True,
#    'awak': True,
#    'feel': True,
#    'littl': True,
#    'guilti': True,
#    'there': True,
#    '30min': True,
#    'left': True,
#    'morning..': True,
#    'oh': True,
#    'well': True,
#    'parti': True,
#    'arvo': True,
#    'woot': True},
#   4),
#  ...]

# %%
print(len(train_bow),len(test_bow))
# Out:
# 1279999 320000

# %%
train_bow
# Out:
# [({'lol': True,
#    'get': True,
#    "'s": True,
#    'come': True,
#    'good': True,
#    'way': True,
#    'mean': True,
#    'talent': True,
#    'author': True},
#   4),
#  ({'would': True, 'miss': True, 'dream': True, 'anymor': True}, 0),
#  ({}, 4),
#  ({'im': True,
#    'sick': True,
#    'thing': True,
#    'would': True,
#    'make': True,
#    'feel': True,
#    'better': True,
#    'palm': True,
#    'pre': True,
#    'came': True,
#    'today': True,
#    'lotteri': True,
#    '...': True},
#   0),
#  ({'sound': True, 'like': True, 'cup': True, 'tea': True, 'sign': True}, 4),
#  ({'think': True,
#    "'m": True,
#    'go': True,
#    'take': True,
#    'hot': True,
#    'bath': True,
#    'listen': True,
#    'lvatt': True},
#   4),
#  ({'feel': True, 'tire': True, 'today': True, 'go': True, 'gym': True}, 0),
#  ({'weekend': True, '...': True, 'rest': True, 'peac': True, '..final': True},
#   4),
#  ({}, 0),
#  ({'say': True, 'll': True, 'cri': True, 'hahah': True}, 0),
#  ({'miss': True, 'certain': True, 'someon': True}, 0),
#  ({'hi': True,
#    'lia': True,
#    'sorri': True,
#    'slow': True,
#    'repli': True,
#    'away': True,
#    'civilis': True,
#    'weekend': True},
#   4),
#  ({'know': True,
#    'franki': True,
#    'bever': True,
#    'maze': True,
#    'probabl': True,
#    'born': True,
#    '70': True,
#    "'s": True,
#    'earlier': True,
#    'thank': True,
#    'god': True,
#    'youtub': True,
#    '...': True,
#    'long': True,
#    'nightr': True,
#    'lol': True},
#   4),
#  ({'blazblu': True,
#    'get': True,
#    'ps3': True,
#    'hdmi': True,
#    'look': True,
#    'gorgeous': True,
#    'xbl': True,
#    'better': True,
#    'communiti': True},
#   0),
#  ({'thing': True,
#    'better': True,
#    'would': True,
#    'video': True,
#    'footag': True,
#    'us': True,
#    'see': True},
#   4),
#  ({'thank': True,
#    "'m": True,
#    'forthright': True,
#    'b/c': True,
#    'part': True,
#    'want': True,
#    'peopl': True,
#    'except': True,
#    'loss': True},
#   4),
#  ({'ummmmm': True, '...': True, 'could': True, 'fedex': True}, 4),
#  ({'epic': True,
#    'discoveri': True,
#    'win': True,
#    'found': True,
#    'work': True,
#    'channel': True,
#    'hella': True,
#    'record': True,
#    'billion': True},
#   4),
#  ({"'s": True, 'rain': True, '...': True}, 0),
#  ({"'m": True,
#    'tired..': True,
#    'hey': True,
#    'diego': True,
#    'ivan': True,
#    'spro': True,
#    'verlo': True,
#    'pronto': True,
#    'xk': True,
#    'aki': True,
#    'va': True},
#   0),
#  ({'technic': True,
#    'either': True,
#    'octopus': True,
#    'octopi': True,
#    'rare': True,
#    'octopod': True,
#    'depend': True,
#    'live': True,
#    'usa': True},
#   4),
#  ({'ty': True,
#    'recommend': True,
#    'jayn': True,
#    "'s": True,
#    'work': True,
#    'yes': True,
#    'well': True,
#    'acquaint': True},
#   4),
#  ({'peach': True,
#    'classi': True,
#    'expens': True,
#    'bottom': True,
#    'dwell': True,
#    'appl': True,
#    'eater': True,
#    'like': True,
#    'us': True},
#   0),
#  ({'_x': True,
#    'keep': True,
#    're-tweet': True,
#    've': True,
#    'got': True,
#    'get': True,
#    'back': True,
#    'might': True,
#    'cri': True},
#   0),
#  ({'didnt': True,
#    'go': True,
#    '2': True,
#    'peac': True,
#    'past': True,
#    'day': True,
#    '...': True,
#    'inde': True},
#   4),
#  ({'last': True,
#    'day': True,
#    'bohol': True,
#    'head': True,
#    'back': True,
#    'manila': True,
#    'tomorrow': True,
#    '*sigh*': True,
#    'goodby': True,
#    'sun': True,
#    'sea': True,
#    'fb': True},
#   0),
#  ({'babe': True, "'s": True, 'gone': True}, 0),
#  ({'1': True,
#    'googl': True,
#    'search': True,
#    'result': True,
#    'quot': True,
#    'want': True,
#    'see': True,
#    'someth': True,
#    'gross': True,
#    'blog': True,
#    '...': True,
#    'could': True,
#    'prouder': True},
#   4),
#  ({'done': True,
#    'finals..': True,
#    'work': True,
#    'excit': True,
#    'pif': True,
#    'next': True,
#    'week': True,
#    'head': True,
#    'st': True,
#    'loui': True,
#    'great': True,
#    'peopl': True,
#    'www.stlf.net': True,
#    'stlf': True},
#   4),
#  ({'thank': True,
#    'updat': True,
#    'feel': True,
#    'disconnect': True,
#    'live': True,
#    'away': True,
#    'long': True,
#    'memori': True,
#    'day': True,
#    'primetim': True},
#   4),
#  ({'good': True,
#    'morn': True,
#    'peep': True,
#    'gon': True,
#    'na': True,
#    'go': True,
#    'play': True,
#    'garden': True,
#    'church': True,
#    'cut': True,
#    'firewood': True,
#    'dinner': True,
#    'friend': True,
#    'redw': True,
#    'tonit': True},
#   4),
#  ({'combin': True,
#    'lower': True,
#    '5': True,
#    '8.348': True,
#    'ppl': True,
#    'name': True,
#    'miha': True,
#    '159': True,
#    'last': True,
#    'rekar': True,
#    'interest': True,
#    '...': True},
#   4),
#  ({'live': True, 'exampl': True, 'grandma': True}, 4),
#  ({}, 4),
#  ({'wonder': True,
#    'dinner': True,
#    'cuz': True,
#    'explor': True,
#    'littl': True,
#    'london': True,
#    'need': True,
#    'pack': True,
#    'trip': True,
#    'back': True,
#    'home': True,
#    'tomorrow': True,
#    'boohoo': True},
#   0),
#  ({"'m": True, 'sorri': True, 'know': True, 'feel': True, 'like': True}, 0),
#  ({'got': True,
#    'face': True,
#    'nerv': True,
#    'tell': True,
#    'act': True,
#    'like': True,
#    'ladi': True,
#    "'s": True,
#    'still': True,
#    'bitch': True,
#    'call': True,
#    'fuck': True,
#    'front': True,
#    'mom': True},
#   0),
#  ({'see': True, 'today': True}, 0),
#  ({'ok.': True, 'bye': True, 'lt': True, '333333': True}, 0),
#  ({'yepper': True,
#    'freakin': True,
#    'way': True,
#    'would': True,
#    'go': True,
#    'alon': True,
#    'one': True,
#    'feel': True,
#    'like': True,
#    'clumsi': True,
#    'oaf': True,
#    'day': True,
#    'friend': True,
#    'voic': True,
#    'help': True},
#   4),
#  ({'blazer': True,
#    'lost': True,
#    'huge': True,
#    'least': True,
#    "'m": True,
#    'eat': True,
#    'good': True,
#    'raw': True,
#    'steak': True,
#    '...': True,
#    'got': True,
#    'move': True,
#    'past': True,
#    'game': True,
#    'focus': True,
#    '2': True},
#   0),
#  ({'gon': True,
#    'na': True,
#    'go': True,
#    'run': True,
#    'tonight': True,
#    'fun': True},
#   4),
#  ({'still': True, 'babi': True}, 0),
#  ({'work': True,
#    'day': True,
#    'morrison': True,
#    'fridg': True,
#    'miss': True,
#    'ace': True,
#    'missedth': True,
#    'warmth': True,
#    '2': True,
#    'bow': True,
#    'lyk': True,
#    'll': True,
#    'rain': True,
#    '2moz': True},
#   0),
#  ({'back': True, 'nail-less': True, 'self': True}, 4),
#  ({'wow..': True,
#    '2nd': True,
#    'servic': True,
#    'never': True,
#    'ceas': True,
#    'amaz': True,
#    'see': True,
#    'mani': True,
#    'peopl': True,
#    'burst': True,
#    'even': True,
#    'run': True,
#    'jz': True,
#    'like': True,
#    'get': True,
#    'boyband': True,
#    'concert': True},
#   4),
#  ({'10ne': True,
#    'man': True,
#    'listen': True,
#    'radio': True,
#    'month': True,
#    'mean': True,
#    'realli': True,
#    '...': True,
#    "'s": True,
#    'terribl': True,
#    'lot': True,
#    'stuff': True,
#    'come': True,
#    'either': True,
#    'tho': True},
#   0),
#  ({'cathol': True,
#    'guilt': True,
#    'terribl': True,
#    'thing': True,
#    'luckili': True,
#    'got': True,
#    'long': True,
#    'time': True,
#    'ago': True,
#    'see': True,
#    'hell': True},
#   4),
#  ({'ll': True,
#    'love': True,
#    'debut': True,
#    'album': True,
#    'quot': True,
#    'daylight': True,
#    'amaz': True,
#    'full': True,
#    'deep': True,
#    'lyric': True,
#    'meaning': True,
#    'thought': True},
#   4),
#  ({'must': True,
#    'fall': True,
#    'waaaaaay': True,
#    'late': True,
#    'twitter': True,
#    "g'night": True,
#    '...': True},
#   4),
#  ({'brain': True,
#    'lego': True,
#    'master': True,
#    'builder': True,
#    'ador': True,
#    'nerdi': True,
#    'hotti': True,
#    'know': True,
#    'realiti': True,
#    'old': True,
#    'gross': True},
#   0),
#  ({}, 0),
#  ({'ruin': True, 'codi': True, 'night': True}, 0),
#  ({'rain': True,
#    'whole': True,
#    'day': True,
#    '...': True,
#    'could': True,
#    'even': True,
#    'cheer': True,
#    'band': True,
#    'like': True,
#    'hold': True,
#    'umbrella': True},
#   0),
#  ({'42': True,
#    'day': True,
#    'jona': True,
#    'brother': True,
#    'concert': True,
#    'spain': True,
#    'wooo': True,
#    'hooo': True,
#    'omg': True,
#    'cant': True,
#    'wait': True,
#    'see': True,
#    'love': True},
#   4),
#  ({'ah': True,
#    'thankgoodne': True,
#    'got': True,
#    'code': True,
#    'said': True,
#    'work': True,
#    'within': True,
#    '24': True,
#    'hour': True},
#   4),
#  ({'unless': True,
#    'u': True,
#    'make': True,
#    'reeeeal': True,
#    'mad': True,
#    'lol': True},
#   4),
#  ({'2hot2handle06': True,
#    'hi': True,
#    '...': True,
#    '..ye': True,
#    'flem': True,
#    'around': True,
#    'corner': True,
#    'actual': True,
#    'littl': True,
#    'closer': True,
#    'ruth': True,
#    'chris': True,
#    "'m": True,
#    'big': True,
#    'fan': True},
#   0),
#  ({'neighbour': True,
#    'would': True,
#    'love': True,
#    "'m": True,
#    'sure': True,
#    'got': True,
#    'rid': True,
#    'rock': True,
#    'band': True,
#    'owi': True,
#    'caus': True,
#    'over': True,
#    'long': True,
#    'stint': True,
#    'drums..': True},
#   4),
#  ({'tri': True,
#    'actual': True,
#    'use': True,
#    '...': True,
#    'work': True,
#    'go': True,
#    'dinner': True,
#    'bff': True,
#    "'s": True,
#    'bday': True,
#    'tonight': True,
#    'happi': True,
#    'hour': True,
#    'pleas': True},
#   4),
#  ({'chem': True,
#    'regent': True,
#    'coupl': True,
#    'hous': True,
#    'still': True,
#    'studi': True,
#    'extrem': True,
#    'procrastin': True},
#   0),
#  ({'heyi': True,
#    'nick': True,
#    'lovin': True,
#    'vid': True,
#    'hope': True,
#    'chanc': True,
#    'might': True,
#    'record': True,
#    'love': True,
#    'toy': True,
#    'stori': True,
#    '2.': True,
#    'pleas': True},
#   4),
#  ({'ugh': True, '*is': True, 'mortified*': True}, 0),
#  ({'know': True,
#    'sat': True,
#    'night': True,
#    'tv': True,
#    'crap': True,
#    'wish': True,
#    'could': True,
#    'see': True,
#    'mcfli': True,
#    'tonight': True,
#    'gon': True,
#    'na': True,
#    'quick': True,
#    'get': True,
#    'distract': True,
#    'easili': True,
#    'x': True},
#   0),
#  ({'finish': True,
#    'chapter': True,
#    '2': True,
#    'book': True,
#    'sure': True,
#    'im': True,
#    'go': True,
#    'post': True,
#    'ca': True,
#    'give': True,
#    'guy': True,
#    'much': True,
#    'tri': True,
#    'get': True,
#    'publish': True},
#   4),
#  ({'bad': True,
#    'mitchel': True,
#    'musso': True,
#    "'s": True,
#    'album': True,
#    'didnt': True,
#    'come': True,
#    'estonia': True,
#    'see': True,
#    "lil'wayn": True,
#    'neither': True,
#    'saaad': True},
#   0),
#  ({'109creek': True, 'yes': True, 'often': True, 'summer': True}, 4),
#  ({}, 4),
#  ({'good': True, 'morn': True, 'america': True}, 4),
#  ({'hope': True,
#    'seizur': True,
#    'better': True,
#    'generat': True,
#    "c'mon": True,
#    'kisschasi': True,
#    'ps': True,
#    'thought': True,
#    'bad': True,
#    'day': True,
#    'made': True,
#    'even': True,
#    'wors': True},
#   0),
#  ({'shop': True,
#    '...': True,
#    '..er': True,
#    'brows': True,
#    'new': True,
#    'tiffani': True,
#    'silver': True,
#    'collect': True},
#   4),
#  ({'parent': True,
#    'check': True,
#    'brother': True,
#    'auntiesnauncl': True,
#    'cousin': True,
#    'food': True,
#    'messi': True,
#    'hous': True,
#    'afterward': True,
#    'def': True},
#   0),
#  ({"'m": True,
#    'anti-mac': True,
#    'lost': True,
#    'document': True,
#    'recoveri': True},
#   0),
#  ({'note': True,
#    'mail': True,
#    'messag': True,
#    'swamp': True,
#    'good': True,
#    'thing': True,
#    'apolog': True,
#    'repli': True,
#    'tad': True,
#    'slower': True,
#    'usual': True},
#   4),
#  ({'saw': True,
#    'repli': True,
#    'head': True,
#    'away': True,
#    'understand': True,
#    'well': True},
#   4),
#  ({'alreadi': True,
#    'know': True,
#    'nathan': True,
#    'nat': True,
#    'live': True,
#    'singapor': True,
#    'tomorrow': True,
#    "'m": True,
#    'basic': True,
#    'staff': True,
#    'member': True,
#    'wasnt': True,
#    'invit': True},
#   0),
#  ({'45': True,
#    'good': True,
#    'mornin': True,
#    'ray': True,
#    'j.': True,
#    'slept': True,
#    'thru': True,
#    'mind': True,
#    'bender': True},
#   0),
#  ({'realli': True,
#    'tire': True,
#    'babysit': True,
#    'tomorrow': True,
#    'im': True,
#    'still': True,
#    'walk': True,
#    'around': True,
#    '...': True},
#   0),
#  ({'go': True,
#    'church': True,
#    'work..': True,
#    'good': True,
#    'feel': True,
#    'today': True},
#   4),
#  ({'know': True, 'pretti': True, 'scari': True}, 0),
#  ({'fix': True,
#    'sound': True,
#    'new': True,
#    'win7': True,
#    'machin': True,
#    'find': True,
#    'mic': True,
#    'stop': True,
#    'function': True},
#   0),
#  ({'hope': True,
#    "'m": True,
#    'longer': True,
#    'sick': True,
#    'tomorrow': True,
#    '...': True,
#    'mother': True,
#    "'s": True,
#    'day': True,
#    'fun..': True},
#   0),
#  ({'sad': True,
#    'week': True,
#    '2': True,
#    'ago': True,
#    'got': True,
#    'chocol': True,
#    'favorit': True,
#    'lululemon': True,
#    'jacket': True,
#    'least': True,
#    'wash': True,
#    'yay': True,
#    'good': True,
#    'though': True},
#   0),
#  ({'pick': True,
#    'blue': True,
#    'moon': True,
#    'summer': True,
#    'ale': True,
#    'way': True,
#    'back': True,
#    'work': True},
#   4),
#  ({'could': True,
#    'hang': True,
#    'fam': True,
#    'think': True,
#    'ill': True,
#    'take': True,
#    'nap': True,
#    'studi': True},
#   0),
#  ({'see': True,
#    'anyth': True,
#    'yet': True,
#    '...': True,
#    'mayb': True,
#    'need': True,
#    'time': True,
#    'load': True},
#   0),
#  ({'much': True,
#    'stayin': True,
#    'week': True,
#    'cos': True,
#    'bad': True,
#    've': True,
#    'gon': True,
#    'na': True,
#    'listen': True,
#    '1045chumfm': True,
#    'websit': True,
#    'work': True},
#   0),
#  ({'got': True,
#    'new': True,
#    'album': True,
#    'today': True,
#    're': True,
#    'go': True,
#    'concert': True,
#    'london': True,
#    'tonight': True},
#   0),
#  ({'god': True,
#    'damn': True,
#    'twitter': True,
#    'stop': True,
#    'eat': True,
#    'undelet': True,
#    'dms': True},
#   0),
#  ({'grandpa': True, 'mad': True, 'dont': True, 'even': True, 'know': True}, 0),
#  ({'pictur': True,
#    "'s": True,
#    'show': True,
#    'hope': True,
#    've': True,
#    'good': True,
#    'day': True},
#   4),
#  ({'yeah': True,
#    'itun': True,
#    'play': True,
#    'right': True,
#    'song': True,
#    'time': True},
#   4),
#  ({'yah': True, 'canada': True, 'till': True, 'later': True}, 0),
#  ({'ladi': True,
#    'fish': True,
#    'caught': True,
#    '100': True,
#    'know': True,
#    'name': True,
#    'annett': True,
#    'corni': True,
#    'like': True},
#   4),
#  ({'must': True, 'hate': True, 'camilla': True, 'bell': True}, 0),
#  ({'haha': True, 'lol': True, 'made': True, 'laugh': True}, 4),
#  ({'_v': True,
#    'haha': True,
#    'boat': True,
#    'yesterday..': True,
#    'll': True,
#    'pick': True,
#    'time': True},
#   4),
#  ({'said': True, 'go': True, 'one': True, 'day': True}, 0),
#  ({'nice': True, 'night': True, 'tomm': True}, 4),
#  ({'thank': True, 'kid': True, 'followfriday': True, 'go': True, '_kt': True},
#   4),
#  ({}, 0),
#  ({'ohh': True,
#    'love': True,
#    "'s": True,
#    'beauti': True,
#    'song': True,
#    've': True,
#    'ever': True,
#    'heard': True,
#    '=d': True,
#    'sing': True},
#   4),
#  ({'song': True, '...': True, 'phone': True, 'bone': True}, 4),
#  ({'omarion': True, 'gain': True, 'weight': True}, 0),
#  ({'hope': True, 'awesom': True, 'vacat': True}, 4),
#  ({'back': True,
#    'pool-': True,
#    'awesom': True,
#    'night': True,
#    'serious': True},
#   4),
#  ({'depress': True,
#    'nlt': True,
#    'thing': True,
#    '...': True,
#    'actual': True,
#    'watch': True,
#    'video': True,
#    'song': True,
#    'eat': True,
#    'ice': True,
#    'cream': True,
#    'tear': True},
#   0),
#  ({'home': True,
#    'trip': True,
#    'autozon': True,
#    'bank': True,
#    'chillin': True,
#    'noth': True,
#    'day': True,
#    'kinda': True,
#    'bore': True},
#   0),
#  ({'gym': True,
#    'run': True,
#    'watch': True,
#    '100': True,
#    'best': True,
#    'song': True,
#    '80': True,
#    "'s": True},
#   4),
#  ({'ca': True, 'fli': True}, 0),
#  ({'dear': True,
#    'twitter': True,
#    'give': True,
#    'summer': True,
#    'miss': True,
#    'see': True,
#    '10': True,
#    'week': True},
#   0),
#  ({'back': True, 'movi': True, "'s": True, 'twitter': True}, 4),
#  ({'sis': True,
#    'find': True,
#    'dress': True,
#    'mexican': True,
#    'll': True,
#    'see': True,
#    'anoth': True,
#    'one': True},
#   4),
#  ({'ah': True, 'monster': True, 'headach': True, 'fun': True}, 0),
#  ({'31': True, 'ok': True, 'win': True, 'point': True}, 0),
#  ({'hi': True,
#    'bryan': True,
#    'yeah': True,
#    'sort': True,
#    'though': True,
#    'ty': True,
#    'much': True,
#    'man': True,
#    'great': True,
#    'product': True,
#    'youv': True,
#    'e': True,
#    'written': True},
#   4),
#  ({'look': True,
#    'forward': True,
#    'kent': True,
#    'summerbal': True,
#    'hpu': True,
#    'happi': True,
#    'poor': True,
#    'fb': True},
#   0),
#  ({'start': True,
#    'excercis': True,
#    'program': True,
#    'yesterday..': True,
#    'feel': True,
#    'today': True},
#   0),
#  ({'woke': True, 'upp': True, 'back': True, 'hurt': True}, 0),
#  ({'team': True,
#    'hurri': True,
#    'curri': True,
#    'queer': True,
#    'race': True,
#    '3-way': True,
#    '...': True,
#    'tie': True,
#    'partay': True,
#    'thx': True,
#    'amaz': True,
#    'donor': True},
#   4),
#  ({'windstream': True,
#    "'s": True,
#    'email': True,
#    'almost': True,
#    'annoy': True,
#    'deal': True,
#    'w/': True,
#    'damn': True,
#    'bank': True},
#   0),
#  ({'new': True,
#    'e-mail': True,
#    'address': True,
#    'make': True,
#    '...': True,
#    'bulli': True},
#   0),
#  ({'ohhh': True,
#    'snaapp': True,
#    'ice': True,
#    'age': True,
#    '3': True,
#    'come': True,
#    'soon': True,
#    'woo': True},
#   4),
#  ({'2nd': True,
#    'place': True,
#    'fail': True,
#    '2': True,
#    'suckout': True,
#    "'s": True,
#    'poker': True,
#    'thank': True,
#    'host': True,
#    'leagu': True},
#   0),
#  ({'ello': True,
#    'kathi': True,
#    "'m": True,
#    'canadian': True,
#    'american': True,
#    'xd': True},
#   4),
#  ({'monday': True, 'argh': True, 'back': True, 'grind': True}, 0),
#  ({'saw': True,
#    'cutest': True,
#    'gremlin': True,
#    'gizmo': True,
#    'ferret': True,
#    'ever': True,
#    'want': True,
#    'bad': True,
#    'get': True,
#    'new': True,
#    'cage': True,
#    'first': True},
#   0),
#  ({'im': True,
#    'still': True,
#    'mad': True,
#    'hey': True,
#    'least': True,
#    'watch': True,
#    'entertain': True,
#    'tonight': True},
#   4),
#  ({'12': True,
#    'thanks..': True,
#    'bad': True,
#    're': True,
#    'fli': True,
#    '...': True},
#   0),
#  ({'gon': True, 'na': True, 'get': True, 'sunshin': True}, 4),
#  ({'hang': True,
#    'hub': True,
#    'go': True,
#    'watch': True,
#    'fring': True,
#    'love': True},
#   4),
#  ({'got': True,
#    'tip': True,
#    'get': True,
#    'jetlag': True,
#    'thank': True,
#    've': True,
#    'caffein': True,
#    'plan': True,
#    'go': True,
#    'gym': True,
#    'later': True,
#    'look': True,
#    'sun': True,
#    'way': True},
#   4),
#  ({'ugh': True, "'s": True, 'yet': True, '...': True}, 0),
#  ({'perhap': True, 'gmail': True, 'glitch': True, 'get': True, 'fix': True},
#   0),
#  ({'saturday': True, 'night': True}, 0),
#  ({'fall': True, 'ill': True, 'problem': True, 'love': True, 'jejejej': True},
#   4),
#  ({'layin': True,
#    'bed': True,
#    'listenin': True,
#    '2': True,
#    'mp3': True,
#    'player': True,
#    'waitin': True,
#    '4': True,
#    'storm': True,
#    'blow': True,
#    'ova': True},
#   0),
#  ({'ah': True,
#    'noth': True,
#    'say': True,
#    'sandal': True,
#    'like': True,
#    'today': True},
#   4),
#  ({'1': True, 'btw': True, 'priss': True, 'one': True, 'hurt': True}, 4),
#  ({'feel': True,
#    'like': True,
#    'idiot': True,
#    'sad': True,
#    'part': True,
#    'actual': True,
#    'one': True,
#    '...': True},
#   0),
#  ({'aah': True,
#    'followfriday': True,
#    'turn': True,
#    'coolest': True,
#    'guy': True,
#    'twitter': True,
#    'goe': True,
#    'film': True,
#    'noir': True,
#    '...': True},
#   4),
#  ({'mia': True, 'jimmi': True, 'sad': True}, 0),
#  ({'wish': True,
#    'leav': True,
#    'cert': True,
#    'june': True,
#    '..the': True,
#    'weather': True,
#    'amaz': True},
#   0),
#  ({'wait': True, 'lost': True, 'come': True}, 4),
#  ({}, 4),
#  ({'eatin': True,
#    'cupcak': True,
#    'bought': True,
#    'new': True,
#    'headphon': True,
#    'made': True,
#    'day': True,
#    'gahh': True,
#    'freakin': True,
#    'hot': True},
#   4),
#  ({'hide': True,
#    'berri': True,
#    'like': True,
#    'slave': True,
#    'regular': True,
#    'today': True,
#    'caught': True,
#    'massa': True,
#    'im': True,
#    'def': True,
#    'light': True,
#    'enough': True,
#    'juic': True,
#    'pour': True},
#   0),
#  ({'bore': True}, 0),
#  ({'im': True, 'tire': True, 'cant': True, 'sleep': True}, 0),
#  ({'tarot': True,
#    'read': True,
#    'question': True,
#    'quot': True,
#    'financi': True,
#    'stabl': True,
#    'answer-': True,
#    "'m": True,
#    'screw': True},
#   0),
#  ({'8688': True,
#    'haha': True,
#    'wish': True,
#    'could': True,
#    'show': True,
#    'hope': True,
#    'one': True,
#    'day': True,
#    'good': True,
#    'luck': True,
#    'fun': True,
#    '-cin': True},
#   4),
#  ({'yeeahh': True,
#    'huskieessss': True,
#    'wcws': True,
#    'champ': True,
#    'huge': True,
#    'game': True,
#    'todayyy': True,
#    'section': True,
#    'edwardsvill': True,
#    'east': True,
#    'im': True,
#    'battingg': True,
#    'come': True,
#    'watch': True},
#   4),
#  ({'miss': True, 'alreadi': True}, 0),
#  ({'one': True,
#    'would': True,
#    'think': True,
#    'technolog': True,
#    'avail': True,
#    'day': True,
#    'longer': True,
#    'problem': True},
#   4),
#  ({'uhmz': True,
#    '1': True,
#    'till': True,
#    '450': True,
#    'sub': True,
#    'ima': True,
#    'dieee': True,
#    'yay': True},
#   4),
#  ({'need': True,
#    'long': True,
#    'vacat': True,
#    'husband': True,
#    '1411': True,
#    'thing': True,
#    'alway': True,
#    'come': True,
#    'back': True},
#   0),
#  ({'gosh': True,
#    'want': True,
#    'sleep': True,
#    'without': True,
#    'bark': True,
#    'dog': True,
#    'wake': True,
#    'still': True,
#    'feel': True,
#    'tire': True},
#   0),
#  ({'pack': True,
#    '12': True,
#    'box': True,
#    '88': True,
#    'go': True,
#    'much': True,
#    'stuff': True},
#   0),
#  ({'good': True,
#    'morn': True,
#    'town': True,
#    'shop': True,
#    'inabit': True,
#    'how': True,
#    'everybodi': True},
#   4),
#  ({'happi': True, 'cry..': True}, 4),
#  ({'saw': True,
#    'movi': True,
#    'yet': True,
#    'actual': True,
#    'plan': True,
#    'watch': True,
#    'tomorrow': True,
#    '...': True},
#   0),
#  ({'good': True,
#    'way': True,
#    'know': True,
#    'fear': True,
#    'get': True,
#    'bit': True,
#    'close': True,
#    'midwestern': True,
#    'supercel': True,
#    'thunderstorm': True,
#    'small': True,
#    'plane': True,
#    'around': True,
#    '17,000': True},
#   4),
#  ({'red': True,
#    'sox': True,
#    'open': True,
#    'game': True,
#    'conflict': True,
#    'prevent': True,
#    'go': True,
#    'reschedul': True},
#   0),
#  ({'cur': True,
#    'hair': True,
#    'shampoo': True,
#    'alway': True,
#    'frizz': True,
#    '...': True,
#    'dunno': True},
#   0),
#  ({'mmkay': True,
#    'what': True,
#    'fb': True,
#    'twitter': True,
#    'absolut': True,
#    'noth': True,
#    'onlin': True,
#    'work': True,
#    'right': True},
#   0),
#  ({'love': True,
#    'walkmen': True,
#    'announc': True,
#    'us': True,
#    'summer': True,
#    'tour': True,
#    'today': True,
#    'cours': True,
#    '...': True,
#    'close': True,
#    'nashi': True},
#   0),
#  ({'revis': True, 'scienc': True, 'exam': True, 'friday': True}, 4),
#  ({}, 4),
#  ({'back': True, 'milan': True, '...': True}, 0),
#  ({'go': True,
#    'home': True,
#    'lunch': True,
#    'garden': True,
#    'lovelli': True,
#    'day': True},
#   4),
#  ({'_undaft_cow': True,
#    'oic': True,
#    "'m": True,
#    'debat': True,
#    'whether': True,
#    'wear': True,
#    'bc': True,
#    'paig': True,
#    'erin': True,
#    'alaina': True,
#    'lolz': True,
#    'll': True,
#    'see': True,
#    'tonight': True},
#   4),
#  ({'come': True,
#    'home': True,
#    'vaca': True,
#    'suppos': True,
#    'good': True,
#    'thing': True,
#    'right': True,
#    'day': True,
#    'get': True,
#    'wors': True},
#   0),
#  ({'need': True, 'text': True, 'buddi': True}, 0),
#  ({'43': True, 'shane': True, 'doesnt': True, 'like': True, 'twitter': True},
#   0),
#  ({"'s": True,
#    'happen': True,
#    "'m": True,
#    'sorri': True,
#    'long': True,
#    'trip': True,
#    'speak': True,
#    'go': True,
#    'denton': True},
#   0),
#  ({}, 4),
#  ({"'s": True, 'cute': True, 'fat': True}, 4),
#  ({'528': True,
#    'see': True,
#    'page': True,
#    'anyth': True,
#    'everyth': True,
#    'goe': True},
#   4),
#  ({'good': True, 'morn': True, 'beauti': True, 'day': True, 'tgif': True}, 4),
#  ({'hope': True, 'enjoy': True, 'sun': True, 'like': True}, 4),
#  ({'go': True,
#    'see': True,
#    'friend': True,
#    'today': True,
#    '...': True,
#    'gon': True,
#    'na': True,
#    'fun': True,
#    'outsid': True,
#    'whatev': True,
#    'xd': True},
#   4),
#  ({'ex': True,
#    'keep': True,
#    'text': True,
#    "'s": True,
#    'say': True,
#    'gon': True,
#    'na': True,
#    'go': True,
#    'work..': True,
#    'fuck': True},
#   0),
#  ({"'s": True,
#    'nice': True,
#    've': True,
#    'tweet': True,
#    'instant': True,
#    'ca': True,
#    'rememb': True,
#    'moment': True,
#    'pass': True},
#   0),
#  ({'got': True, 'result': True, 'today': True, '...': True, 'good': True}, 0),
#  ({'work': True, 'still': True}, 0),
#  ({'morn': True, 'tweep': True}, 4),
#  ({'mean': True, 'leav': True}, 4),
#  ({'today': True,
#    'll': True,
#    'back': True,
#    'home': True,
#    'later': True,
#    'want': True,
#    'see': True,
#    'wrote': True,
#    'xx': True},
#   0),
#  ({'oh': True, 'gosh': True, 'awsom': True}, 4),
#  ({'cute': True,
#    'littl': True,
#    'dean': True,
#    'lane': True,
#    'want': True,
#    'watch': True,
#    'dvds': True},
#   0),
#  ({'happi': True,
#    'divers': True,
#    'britain': True,
#    'got': True,
#    'talent': True,
#    'realli': True,
#    'deserv': True},
#   4),
#  ({'end': True,
#    'night': True,
#    'golden': True,
#    'girl': True,
#    'alway': True,
#    'win': True,
#    '...': True,
#    "'m": True,
#    'old': True,
#    'person': True},
#   0),
#  ({'mamma': True, 'get': True, 'nerv': True}, 0),
#  ({'hate': True,
#    'sick': True,
#    'wast': True,
#    'day': True,
#    'actual': True,
#    'jkjk': True},
#   0),
#  ({"'s": True,
#    'grace': True,
#    'ottawa': True,
#    'born': True,
#    'hospit': True,
#    'thought': True,
#    'meant': True,
#    'first': True},
#   4),
#  ({'tad': True,
#    'late': True,
#    'butttt': True,
#    're': True,
#    'mood': True,
#    'realli': True,
#    'good': True,
#    'scare': True,
#    'tri': True,
#    'quot': True,
#    'funni': True,
#    'game': True,
#    'thought': True,
#    'scari': True},
#   4),
#  ({'_day26': True, 'mind': True, 'convinc': True, 'keep': True, 'fight': True},
#   0),
#  ({'123': True,
#    'lol': True,
#    'love': True,
#    'talk': True,
#    'ppl': True,
#    'u': True,
#    'hit': True,
#    'w/': True,
#    'quot': True},
#   4),
#  ({'sim': True,
#    '3': True,
#    'much': True,
#    'complic': True,
#    'thought': True,
#    'would': True,
#    'alreadi': True,
#    'miss': True,
#    '2': True},
#   0),
#  ({'art': True, 'day': True}, 0),
#  ({'back': True,
#    'must': True,
#    'see': True,
#    'chop': True,
#    'hair': True,
#    'drivng': True,
#    'crazi': True},
#   4),
#  ({'ride': True,
#    'hors': True,
#    "'m": True,
#    'tire': True,
#    'time': True,
#    'sleep': True,
#    '...': True,
#    'think': True,
#    'gon': True,
#    'na': True,
#    'fall': True,
#    'asleep': True,
#    'way': True,
#    'quot': True,
#    'haha': True,
#    'xoxo': True},
#   0),
#  ({'realli': True,
#    'screw': True,
#    'good': True,
#    'thing': True,
#    'wish': True,
#    'knew': True,
#    'fix': True},
#   0),
#  ({'omg': True,
#    'doze': True,
#    'sec': True,
#    'earlier': True,
#    'think': True,
#    'got': True,
#    'whiplash': True,
#    'neck': True,
#    'head': True,
#    'fall': True,
#    'back': True,
#    'ouch': True,
#    'hate': True,
#    'morn': True},
#   0),
#  ({'yes': True,
#    'fun': True,
#    'imag': True,
#    'though': True,
#    'unlik': True,
#    'eddi': True,
#    'abfab': True,
#    'shock': True,
#    'spot': True,
#    'design': True,
#    'wear': True,
#    'quot': True,
#    'street': True,
#    'person': True},
#   4),
#  ({'_young': True,
#    'look': True,
#    'good': True,
#    'think': True,
#    'll': True,
#    'eat': True},
#   4),
#  ({'nah': True,
#    'came': True,
#    'yet': True,
#    'think': True,
#    'weekend': True,
#    'either': True,
#    'ima': True,
#    'mega': True,
#    'sad': True},
#   0),
#  ({'wes': True,
#    'reason': True,
#    'comment': True,
#    'make': True,
#    'seemic': True,
#    'desktop': True,
#    'happen': True,
#    'across': True,
#    'stream': True,
#    'hmmm': True},
#   0),
#  ({'yeah': True,
#    'seem': True,
#    'judg': True,
#    'look': True,
#    "'s": True,
#    'sweetheart': True},
#   4),
#  ({'119': True, 'better': True, 'last': True, 'night': True}, 0),
#  ({'home': True,
#    'project': True,
#    'grad': True,
#    'exhaust': True,
#    'work': True,
#    'visit': True},
#   0),
#  ({'6f': True, 'tri': True, '...': True}, 0),
#  ({'didnt': True,
#    'mean': True,
#    'scare': True,
#    'ya': True,
#    'chris': True,
#    'lol': True,
#    'ask': True,
#    'go': True,
#    'anoth': True,
#    'one': True,
#    'say': True,
#    'yes': True},
#   4),
#  ({'sick': True,
#    'bed': True,
#    'blind': True,
#    'migrain': True,
#    'sinc': True,
#    'yesterday': True},
#   0),
#  ({'feel': True, 'sick': True, 'got': True, 'shake': True, 'morn': True}, 0),
#  ({'yes': True,
#    'bed': True,
#    'yet': True,
#    'either': True,
#    'get': True,
#    'pick': True,
#    'say': True,
#    'goodby': True,
#    'll': True,
#    'back': True,
#    'soon': True,
#    'send': True,
#    'pic': True},
#   0),
#  ({'get': True, 'realli': True, 'cool': True, 'purs': True}, 4),
#  ({'619': True,
#    'hi': True,
#    'luv': True,
#    'u': True,
#    'shuda': True,
#    'said': True,
#    'goin': True,
#    'da': True,
#    'beach': True,
#    'wuda': True,
#    'went': True},
#   0),
#  ({'30th': True,
#    'birthday': True,
#    'step': True,
#    'one': True,
#    'chang': True,
#    'flat': True,
#    'tire': True,
#    'ha': True},
#   4),
#  ({'_chou': True,
#    'oh': True,
#    'thank': True,
#    'dude': True,
#    'teehe': True,
#    'though': True,
#    'sure': True,
#    'tweet': True,
#    'refer': True,
#    'still': True},
#   4),
#  ({'free': True,
#    'semtech2009': True,
#    'vanilla': True,
#    'latt': True,
#    '...': True,
#    'make': True,
#    'coffe': True,
#    'hotel': True,
#    'room': True},
#   0),
#  ({'prepar': True,
#    'cake': True,
#    'plan': True,
#    'weekend': True,
#    'hope': True,
#    'come': True,
#    'watch': True},
#   4),
#  ({'25': True, 'agre': True}, 4),
#  ({'revisando': True, 'netbean': True, '6.7': True, 'beta': True}, 4),
#  ({'yet': True,
#    'want': True,
#    'brother': True,
#    'go': True,
#    "'s": True,
#    'drunk': True,
#    'fuck': True,
#    'pot': True,
#    'head': True,
#    '...': True,
#    'w.t.f': True,
#    "'m": True,
#    'good': True,
#    'one': True,
#    'ca': True},
#   0),
#  ({'14': True, 'month': True, 'anniverseri': True, 'tomorrow': True}, 4),
#  ({}, 4),
#  ({'sinc': True,
#    '6:23.': True,
#    'dryer': True,
#    'half': True,
#    'hour': True,
#    'away': True,
#    'though': True,
#    "'s": True,
#    'good': True,
#    'guess': True},
#   0),
#  ({'aw': True,
#    'naw': True,
#    'say': True,
#    '...': True,
#    'jus': True,
#    'took': True,
#    'money': True},
#   0),
#  ({'consid': True, 'think': True, 'take': True, 'homework': True, 'bag': True},
#   4),
#  ({}, 0),
#  ({'tire': True, 'work': True}, 0),
#  ({'parti': True, 'burn': True, 'candl': True, 'end': True, 'lol': True}, 4),
#  ({'want': True, 'remind': True, 'love': True}, 4),
#  ({'figur': True,
#    'great': True,
#    'market': True,
#    'ploy': True,
#    'chanc': True,
#    'dude': True,
#    'sheeet': True,
#    'gal': True,
#    'lol': True,
#    'ask': True,
#    'digit': True,
#    'imma': True,
#    'give': True,
#    'em': True,
#    'blog': True,
#    'instead': True,
#    'yesss': True,
#    '...': True},
#   4),
#  ({'chanc': True, 'watch': True, 'espn': True, 'hmmmm': True}, 4),
#  ({'heart': True, 'hurt': True, 'soo': True, 'bad': True, 'right': True}, 0),
#  ({'omg': True,
#    'need': True,
#    'drink': True,
#    'somebodi': True,
#    'help': True,
#    'better': True,
#    'yet': True,
#    'someon': True,
#    'get': True,
#    'shot': True,
#    '151': True},
#   0),
#  ({'know': True,
#    "'d": True,
#    'go': True,
#    'bat': True,
#    'anti-happi': True,
#    'ordin': True,
#    'unfortun': True,
#    "'s": True,
#    'tabl': True},
#   0),
#  ({'funni': True,
#    'week': True,
#    '..': True,
#    'riot': True,
#    'abd': True,
#    'back': True,
#    'kennel': True,
#    'didnt': True,
#    'work': True,
#    'foster': True,
#    'home': True,
#    'fault': True},
#   0),
#  ({}, 0),
#  ({'done': True, 'bitch': True, 'total': True, 'kick': True, 'ass': True}, 4),
#  ({'13': True, 'stanley': True, 'cup': True}, 0),
#  ({'want': True, 'monday': True, 'tomorrow': True}, 0),
#  ({'love': True,
#    'sun': True,
#    'last': True,
#    'week': True,
#    'shame': True,
#    'work': True,
#    'start': True,
#    '2moro': True},
#   0),
#  ({'lame-o-rama': True,
#    'go': True,
#    'fuck': True,
#    'bore': True,
#    'offffffiiiiccceeee': True,
#    'fuckkkkk': True,
#    "'m": True,
#    'sombodi': True,
#    'text': True,
#    '618.709.8541': True},
#   0),
#  ({'fuck': True,
#    "'s": True,
#    'retarded': True,
#    'mean': True,
#    'sure': True,
#    'sometim': True,
#    'stuff': True,
#    '...': True,
#    'need': True,
#    'care': True,
#    'reserach': True},
#   0),
#  ({'8tive': True,
#    'lt': True,
#    'need': True,
#    'get': True,
#    'f**k': True,
#    'dick': True,
#    '...': True,
#    '.keep': True,
#    'name': True,
#    'ur': True,
#    'mouth': True,
#    'irrelevant..': True,
#    'k': True,
#    'thank': True,
#    'real': True},
#   4),
#  ({'ughhh': True,
#    '...': True,
#    'work': True,
#    'slow': True,
#    'crawl': True,
#    'last': True,
#    'hour': True},
#   0),
#  ({'7': True, 'thank': True, 'youu': True, 'okay': True}, 4),
#  ({'wine': True,
#    'time': True,
#    'great': True,
#    'run': True,
#    'week': True,
#    'sorri': True,
#    'frazzl': True,
#    'construction=stress': True},
#   0),
#  ({"'m": True,
#    'wash': True,
#    'hous': True,
#    'love': True,
#    'teenag': True,
#    'haterz': True,
#    'eg': True,
#    'blogtv': True,
#    'last': True,
#    'night': True,
#    "'s": True,
#    'sound': True,
#    'kept': True,
#    'hear': True},
#   0),
#  ({'damn': True,
#    'step': True,
#    'rediff': True,
#    'forum': True,
#    '...': True,
#    'new': True,
#    'shoe': True},
#   0),
#  ({}, 0),
#  ({'ah': True, 'beauti': True, 'twitter': True}, 4),
#  ({'one': True,
#    'weekend': True,
#    'sinc': True,
#    'begin': True,
#    'yr': True,
#    'think': True,
#    'know': True,
#    '...': True,
#    'that': True,
#    'self': True,
#    'employ': True,
#    'suppos': True},
#   4),
#  ({'see': True}, 4),
#  ({'83': True,
#    "'m": True,
#    'pretti': True,
#    'fuck': True,
#    'fab': True,
#    'right': True,
#    "'s": True},
#   4),
#  ({'fed': True, 'concern': True}, 0),
#  ({"'s": True, 'sad': True}, 0),
#  ({'phone': True, 'keep': True, 'eat': True, 'sim': True, 'game': True}, 0),
#  ({'pull': True, 'lower': True, 'back': True, 'muscl': True}, 0),
#  ({'watch': True,
#    'punk': True,
#    "'d": True,
#    'tonight': True,
#    'laugh': True,
#    'ass': True},
#   4),
#  ({'complet': True,
#    'dumbass': True,
#    'lick': True,
#    'knife': True,
#    'cut': True,
#    'tongu': True},
#   0),
#  ({'want': True,
#    'sim': True,
#    '3': True,
#    '...': True,
#    'anyon': True,
#    'know': True,
#    'buy': True,
#    'much': True},
#   0),
#  ({'way': True,
#    'back': True,
#    'manchest': True,
#    'buy': True,
#    'lot': True,
#    'bit': True,
#    'bob': True,
#    'leaver': True,
#    'parti': True},
#   0),
#  ({}, 4),
#  ({"'m": True,
#    'gon': True,
#    'na': True,
#    'watch': True,
#    'open': True,
#    'hehe': True},
#   4),
#  ({'didnt': True,
#    'want': True,
#    'leav': True,
#    'twitter': True,
#    'haha': True,
#    'im': True,
#    'backk': True,
#    'watch': True,
#    'notebook': True},
#   4),
#  ({'there': True,
#    'electr': True,
#    'hous': True,
#    'right': True,
#    'phone': True,
#    'die': True,
#    'pls': True,
#    'quick': True,
#    'shout': True,
#    "c'mon": True},
#   0),
#  ({'omg': True, 'comput': True, 'angri': True}, 0),
#  ({}, 4),
#  ({'hope': True, 'thing': True, 'get': True, 'better': True}, 0),
#  ({'saw': True, '...': True, '..awwwwww': True}, 0),
#  ({'cancel': True,
#    'zune': True,
#    'doesnt': True,
#    'make': True,
#    'jizzinmyp': True},
#   0),
#  ({'swear': True,
#    'god': True,
#    're': True,
#    'joke': True,
#    'go': True,
#    'break': True,
#    'heart': True},
#   0),
#  ({'cook': True, 'cake': True}, 4),
#  ({'girl': True,
#    'join': True,
#    'anytim': True,
#    'let': True,
#    'know': True,
#    'drink': True,
#    '10am': True,
#    'fun': True,
#    '10pm': True,
#    'haha': True,
#    'jk': True},
#   4),
#  ({'21': True,
#    'like': True,
#    'korea': True,
#    'food': True,
#    'particular': True,
#    'barbecu': True,
#    'cheap': True,
#    'countri': True,
#    'need': True,
#    'pay': True,
#    '40.00': True,
#    'rmb': True,
#    '7': True,
#    'u.s.': True,
#    'dollar': True},
#   4),
#  ({'head': True,
#    'mine': True,
#    'hard': True,
#    'go': True,
#    'last': True,
#    'time': True},
#   0),
#  ({'dont': True, 'think': True, 'meaghan': True}, 4),
#  ({'6f2ft': True,
#    'hai': True,
#    '...': True,
#    'belum': True,
#    'hik': True,
#    'help': True},
#   0),
#  ({}, 4),
#  ({'_68': True,
#    'oh': True,
#    'good': True,
#    'netherland': True,
#    'origin': True,
#    'mum': True,
#    '5': True,
#    'minut': True,
#    'car': True,
#    'away': True,
#    'kind': True,
#    'lucki': True},
#   4),
#  ({'30': True,
#    'someth': True,
#    'adult': True,
#    '1st': True,
#    'flight': True,
#    'lol': True,
#    '41': True,
#    'would': True,
#    'realli': True,
#    'cool': True},
#   4),
#  ({'1': True,
#    'wish': True,
#    'could': True,
#    'get': True,
#    'lip': True,
#    'ring': True},
#   4),
#  ({}, 4),
#  ({'get': True,
#    'everyth': True,
#    'togeth': True,
#    'leav': True,
#    'europ': True,
#    'hour': True},
#   4),
#  ({'end': True,
#    'instal': True,
#    'vistash': True,
#    '...': True,
#    'anoth': True,
#    'way': True},
#   0),
#  ({'follow': True,
#    'drop': True,
#    'like': True,
#    'fli': True,
#    'suppos': True,
#    'might': True,
#    'one': True,
#    'find': True,
#    'interest': True},
#   4),
#  ({'afternoon': True, 'todd': True}, 4),
#  ({'dammit': True, 'could': True, 'get': True, "'m": True, 'hilton': True}, 0),
#  ({'pink': True,
#    'one': True,
#    'right': True,
#    'nice': True,
#    '9th': True,
#    '8': True,
#    'e-mail': True,
#    'confus': True},
#   0),
#  ({'good': True, 'morn': True, 'luck': True, 'math': True, 'test': True}, 4),
#  ({'old': True, 'convers': True, 're': True, 'fun': True, 'go': True}, 4),
#  ({'tour': True,
#    'ancient': True,
#    'rome': True,
#    'today': True,
#    'saw': True,
#    'beauiti': True,
#    'place': True,
#    'world': True,
#    '...': True,
#    'miss': True,
#    'home': True,
#    '.and': True,
#    'mean': True,
#    'amin': True},
#   0),
#  ({'wed': True, 'singer': True}, 4),
#  ({'cos': True,
#    'peep': True,
#    'want': True,
#    'molten': True,
#    'mouth': True,
#    '...': True,
#    'heeeeeeheeee': True},
#   4),
#  ({'_design': True,
#    'that': True,
#    'good': True,
#    'bout': True,
#    'stuck': True,
#    'car': True,
#    'strom': True,
#    '2night': True,
#    'parkin': True,
#    'lot': True},
#   0),
#  ({'ugh': True,
#    'need': True,
#    'arrowroot': True,
#    'powder': True,
#    'must': True,
#    'put': True,
#    'pant': True,
#    'go': True,
#    'shop': True},
#   0),
#  ({'friday': True,
#    'tomorrow': True,
#    'big': True,
#    'swear': True,
#    'day': True,
#    'turn': True,
#    "'s": True,
#    'f***ing': True,
#    'clever': True,
#    'ca': True,
#    'wait': True},
#   4),
#  ({'hmmm~': True,
#    'smell': True,
#    'thal': True,
#    'yumm-o': True,
#    'ryt': True,
#    'nw': True,
#    'guess': True,
#    "'s": True,
#    'readi': True,
#    'tuck': True,
#    'oledi': True},
#   4),
#  ({'21': True,
#    '_pina_14': True,
#    'especi': True,
#    'w/': True,
#    'current': True,
#    'situat': True,
#    "'s": True,
#    'pretti': True,
#    'easi': True,
#    'get': True,
#    'lost': True,
#    'footi': True,
#    'oppos': True,
#    'rl': True},
#   0),
#  ({'sound': True, 'fun': True}, 4),
#  ({'medic': True, 'health': True, 'day': True, 'home': True, 'mmm': True}, 4),
#  ({'awesom': True,
#    'birthday': True,
#    'far': True,
#    'cake': True,
#    'spent': True,
#    'time': True,
#    'wit': True,
#    'famili': True,
#    'talk': True,
#    'friend': True},
#   4),
#  ({'look': True,
#    'pictur': True,
#    'guy': True,
#    'everi': True,
#    'time': True,
#    'die': True,
#    'draw': True},
#   4),
#  ({'prettypinkpearl': True, 'chat': True, 'room': True, 'launch': True}, 4),
#  ({'wow': True, 'im': True, 'sorri': True, '...': True}, 0),
#  ({'yeah': True, "'m": True, 'stupid': True}, 4),
#  ({'3gamealli': True,
#    'yes': True,
#    'heard': True,
#    'alreadi': True,
#    'beta': True,
#    'code': True,
#    'point': True},
#   4),
#  ({'yes': True, 'pic': True, 'thing': True, 'new': True, 'music': True}, 0),
#  ({'posibil': True}, 4),
#  ({'thank': True,
#    'know': True,
#    'load': True,
#    'crap': True,
#    'joke': True,
#    'sometim': True,
#    'funni': True},
#   4),
#  ({}, 4),
#  ({'leav': True,
#    'near': True,
#    '3': True,
#    'month': True,
#    'without': True,
#    'peanut': True,
#    'butter': True,
#    'right': True},
#   0),
#  ({}, 4),
#  ({'possibl': True,
#    '2': True,
#    'amplifi': True,
#    'word': True,
#    'slut': True,
#    'place': True,
#    'booyah': True,
#    'front': True,
#    'follow': True,
#    'open': True,
#    'palm': True,
#    'shove': True,
#    'nose': True,
#    'cours': True},
#   4),
#  ({'happi': True, 'birthday': True, 'ya': True}, 4),
#  ({'damn': True,
#    'pigeon': True,
#    'friend': True,
#    'found': True,
#    'mani': True,
#    'differ': True,
#    'way': True,
#    'get': True,
#    'rid': True,
#    'even': True,
#    'make': True,
#    'look': True,
#    'like': True,
#    'accid': True},
#   4),
#  ({'plant': True,
#    'camelia': True,
#    'rose': True,
#    'annual': True,
#    'back': True,
#    'yard': True,
#    'today': True,
#    'guess': True,
#    'skillset': True,
#    'fall': True},
#   4),
#  ({'dinner': True, 'hey': True, 'darlin': True}, 4),
#  ({'realli': True, 'put': True, 'pic': True, 'guess': True}, 0),
#  ({'belfast': True,
#    'last': True,
#    'night': True,
#    'great': True,
#    'fun': True,
#    'catch': True,
#    'wit': True,
#    'laura': True,
#    'loadsa': True,
#    'laugh': True},
#   4),
#  ({'_marisa': True,
#    'gloomi': True,
#    'one': True,
#    'day': True,
#    'half': True,
#    'day..': True,
#    'sunni': True},
#   4),
#  ({'way': True,
#    'pick': True,
#    'dresser': True,
#    'crib': True,
#    'babi': True,
#    'good': True,
#    'littl': True,
#    'girl': True,
#    'come': True,
#    'june': True,
#    'look': True,
#    'forward': True,
#    'arriv': True},
#   4),
#  ({'ve': True, 'run': True, 'dreamtim': True, 'tea': True}, 0),
#  ({'babi': True,
#    "'m": True,
#    'sorri': True,
#    'omg': True,
#    'gain': True,
#    'weight': True,
#    'back': True,
#    'lost': True},
#   0),
#  ({'technolog': True, 'amaz': True, 'someon': True, 'get': True}, 4),
#  ({'7x_bat_angel': True, 'thank': True, 'doll': True}, 4),
#  ({'im': True, 'sad': True, 'miss': True, 'kitti': True}, 0),
#  ({"'m": True,
#    'sorri': True,
#    'let': True,
#    "'s": True,
#    'set': True,
#    'fire': True},
#   0),
#  ({'manag': True,
#    'chang': True,
#    'outfit': True,
#    'well': True,
#    'love': True,
#    'wore': True,
#    'made': True,
#    'look': True,
#    'fairer': True},
#   4),
#  ({'123': True,
#    'problem': True,
#    'anyth': True,
#    'help': True,
#    'spread': True,
#    'word': True},
#   4),
#  ({'aw': True,
#    'paint': True,
#    'toe': True,
#    'nail': True,
#    'scare': True,
#    'much': True},
#   0),
#  ({'justt': True, 'got': True, 'bck': True, 'badboyi': True, 'uh': True}, 0),
#  ({'need': True,
#    'dm': True,
#    'address': True,
#    'thank': True,
#    'girlfriend': True},
#   4),
#  ({'unhappi': True,
#    'fake': True,
#    'wentworth': True,
#    'miller': True,
#    'twitter': True,
#    'account': True},
#   0),
#  ({}, 4),
#  ({'bbl': True,
#    'trynz': True,
#    'get': True,
#    'follow': True,
#    '100': True,
#    'weekend': True,
#    'let': True,
#    'mak': True,
#    'happen': True,
#    'back': True,
#    'later': True,
#    'love': True},
#   4),
#  ({'still': True,
#    'wait': True,
#    'fajr': True,
#    'morn': True,
#    'prayer': True,
#    'come': True,
#    'effect': True,
#    'hour': True,
#    'status': True,
#    'wide': True,
#    'awak': True},
#   0),
#  ({'34.': True, 'believ': True, 'dumb': True, 'younger': True, 'miss': True},
#   0),
#  ({'good': True,
#    'morn': True,
#    'tweet': True,
#    'busi': True,
#    'day': True,
#    '2day': True,
#    'let': True,
#    'get': True,
#    'alot': True,
#    'done': True},
#   4),
#  ({'need': True,
#    'holiday': True,
#    'realli': True,
#    'dont': True,
#    'want': True,
#    'go': True,
#    'back': True,
#    '6th': True,
#    'form': True,
#    'tommorowww': True},
#   0),
#  ({'_becca': True,
#    'lol..': True,
#    'realisedni': True,
#    'fav': True,
#    'tv': True,
#    'show': True,
#    'nick': True,
#    'jona': True,
#    'hero': True},
#   4),
#  ({'lone': True, 'night': True, 'start': True, '2': True, 'fade': True}, 0),
#  ({}, 4),
#  ({'happen': True,
#    'otherday': True,
#    'googl': True,
#    'ima': True,
#    'geek': True,
#    'like': True,
#    'turn': True,
#    'manufactur': True,
#    'fault': True,
#    'happi': True},
#   0),
#  ({'tire': True,
#    'activ': True,
#    'day..': True,
#    'sooo': True,
#    'much': True,
#    'fun': True,
#    'get': True,
#    'rest': True,
#    'go': True,
#    'school': True,
#    'tomorrow': True},
#   4),
#  ({'hittin': True,
#    'sheet': True,
#    'lil': True,
#    'earli': True,
#    'hope': True,
#    'good': True,
#    'day': True,
#    'tomorrow': True,
#    'goodlookin': True,
#    'jenn': True},
#   4),
#  ({'googl': True,
#    'baller': True,
#    'lol': True,
#    'thought': True,
#    'mayb': True,
#    'someth': True,
#    'naughti': True,
#    'lololol': True,
#    'thank': True},
#   4),
#  ({'_dm': True,
#    "'s": True,
#    'good': True,
#    'friend': True,
#    'said': True,
#    'exam': True,
#    'hard': True,
#    'ahah': True},
#   4),
#  ({'hahha': True,
#    '...': True,
#    '1': True,
#    'hun': True,
#    'jus': True,
#    'walk': True,
#    'away': True,
#    'sorri': True,
#    'ur': True,
#    'piss': True},
#   0),
#  ({'think': True,
#    'everyth': True,
#    'happen': True,
#    '4': True,
#    'reason': True,
#    'u': True,
#    'learn': True,
#    'mistak': True,
#    'chang': True,
#    'strategi': True,
#    'roll': True},
#   4),
#  ({'82883': True,
#    'dock': True,
#    'browni': True,
#    'point': True,
#    'nickelodean': True,
#    'theme': True,
#    'yay': True,
#    'spongebob': True,
#    'gon': True,
#    'na': True,
#    'tri': True,
#    'go': True,
#    'ride': True,
#    'today': True,
#    'get': True,
#    'funni': True,
#    'cake': True},
#   4),
#  ({'ca': True,
#    'chang': True,
#    'certain': True,
#    'sit': True,
#    'rotat': True,
#    'like': True,
#    'k': True},
#   4),
#  ({'rehears': True, '8:15': True, 'tomorrow': True}, 0),
#  ({'want': True, 'nao': True, 'robot': True, 'red': True}, 4),
#  ({'aww': True,
#    'thank': True,
#    'ms.': True,
#    'mcgraw': True,
#    'realli': True,
#    'need': True,
#    'hug': True},
#   4),
#  ({'blue': True,
#    'green': True,
#    'violet': True,
#    'new': True,
#    'hair': True,
#    'color': True,
#    'got': True,
#    'wash': True,
#    'rain': True},
#   0),
#  ({'import': True,
#    'check': True,
#    'pm': True,
#    "'s": True,
#    'ha': True,
#    'asap': True},
#   0),
#  ({'bak': True, 'construct': True}, 4),
#  ({'24lbsofboost': True, 'thank': True}, 0),
#  ({'doubt': True,
#    'll': True,
#    'hear': True,
#    'even': True,
#    'season': True,
#    'hope': True,
#    'jenson': True,
#    'certan': True,
#    'subject': True},
#   4),
#  ({'sure': True,
#    'tell': True,
#    'lovebox': True,
#    'digit': True,
#    'wristband': True,
#    'great': True,
#    'hear': True},
#   4),
#  ({'beer': True}, 0),
#  ({'man': True, 'hate': True, 'clean': True, 't^t': True}, 0),
#  ({'_magazin': True,
#    'know': True,
#    'pict': True,
#    'thought': True,
#    'realli': True,
#    'fish': True,
#    'kept': True,
#    'long': True,
#    'done': True,
#    'cri': True,
#    'left': True},
#   0),
#  ({'thank': True,
#    'cheemaro': True,
#    'see': True,
#    'vamp': True,
#    'diari': True,
#    'parent': True,
#    'discret': True,
#    'advis': True,
#    'kerr': True,
#    'smith': True,
#    'import': True,
#    'role': True},
#   4),
#  ({'know': True,
#    'abl': True,
#    'make': True,
#    'work': True,
#    'day': True,
#    'doubt': True,
#    'surviv': True,
#    'concert': True,
#    'tonight': True,
#    'probabl': True,
#    'gon': True,
#    'na': True,
#    'sleep': True,
#    'instead': True},
#   0),
#  ({'come': True,
#    'spain': True,
#    've': True,
#    'fan': True,
#    '5': True,
#    'year': True,
#    'never': True,
#    'abl': True,
#    'see': True,
#    'guy': True,
#    'live': True,
#    'x': True},
#   0),
#  ({'_rov': True,
#    'yay': True,
#    'cuz': True,
# ...
#    'jack': True,
#    'haha': True},
#   4),
#  ({'great': True,
#    'start': True,
#    '...': True,
#    'sinc': True,
#    'laptop': True,
#    'decid': True,
#    'beotch': True,
#    'die': True,
#    'morn': True},
#   0),
#  ({'go': True, 'sleep': True, 'long': True, 'day': True}, 4),
#  ({'bye': True,
#    'anip': True,
#    '...': True,
#    'tar': True,
#    'tri': True,
#    'catch': True,
#    'rest..': True,
#    'hihi': True,
#    '*hug': True,
#    'all*': True},
#   4),
#  ({'one': True,
#    'biggest': True,
#    'key': True,
#    'success': True,
#    'realiz': True,
#    'door': True,
#    'lock': True},
#   4),
#  ({'mtv': True, 'movi': True, 'award': True}, 4),
#  ({'seen': True,
#    'latest': True,
#    'staging/truss': True,
#    'collaps': True,
#    'festiv': True,
#    'oh': True,
#    'dear': True},
#   0),
#  ({'rain': True, 'day': True, 'noth': True, 'im': True, 'bore': True}, 0),
#  ({'wow': True, "'s": True, 'realli': True, 'surpris': True}, 0),
#  ({'love': True,
#    'post': True,
#    'first': True,
#    'video': True,
#    'respons': True,
#    'youtub': True,
#    'wait': True,
#    'person': True,
#    'approv': True,
#    '...': True},
#   4),
#  ({'phone': True,
#    'broke': True,
#    'that': True,
#    'havent': True,
#    'keep': True,
#    'touch': True,
#    'miss': True,
#    'though': True,
#    'im': True,
#    'get': True,
#    'new': True,
#    'wednesday': True},
#   0),
#  ({'lost': True,
#    'check': True,
#    'ca': True,
#    'find': True,
#    'anywher': True,
#    'goe': True,
#    'money': True,
#    "'s": True,
#    'us': True,
#    'cant': True,
#    'ask': True,
#    'send': True},
#   0),
#  ({'whoa': True,
#    '...': True,
#    "'m": True,
#    'sick': True,
#    'want': True,
#    'work': True,
#    'fml': True},
#   0),
#  ({'think': True,
#    'power': True,
#    'adapt': True,
#    'macbook': True,
#    'pro': True,
#    'got': True,
#    'fri': True,
#    '...': True},
#   0),
#  ({'sure': True, 'wish': True, 'better': True, 'mood': True}, 0),
#  ({'hit': True, 'squirel': True, 'poor': True, 'lil': True, 'guy': True}, 0),
#  ({'david': True,
#    'hope': True,
#    'u': True,
#    'grood': True,
#    'time': True,
#    'sd': True,
#    'counti': True,
#    'fair': True,
#    'goin': True,
#    '2': True,
#    'go': True,
#    'could': True,
#    'well': True,
#    'fun': True,
#    'gr8': True,
#    'voic': True},
#   0),
#  ({'awak': True, 'yet': True, 'miss': True, 'much': True}, 0),
#  ({'shhh': True,
#    'give': True,
#    'away': True,
#    'dvr': True,
#    "'d": True,
#    'talk': True},
#   4),
#  ({'dont': True, 'say': True}, 0),
#  ({'excit': True,
#    'wed': True,
#    'saturday': True,
#    'rememb': True,
#    'havta': True,
#    'buy': True,
#    'present': True},
#   0),
#  ({'4tunecookiesam': True,
#    'grill': True,
#    'bacon': True,
#    'chees': True,
#    'burger': True,
#    'backyard': True,
#    'lol': True},
#   4),
#  ({'ca': True,
#    'sleep': True,
#    'watch': True,
#    'risqu': True,
#    'foreign': True,
#    'film': True,
#    'alon': True,
#    'bed': True},
#   0),
#  ({'watch': True,
#    'natur': True,
#    'program': True,
#    'anim': True,
#    'planet': True,
#    'hope': True,
#    'see': True,
#    'noth': True,
#    'die': True},
#   0),
#  ({}, 0),
#  ({'woke': True,
#    'without': True,
#    'hangov': True,
#    '...': True,
#    'got': True,
#    'ta': True,
#    'put': True,
#    'famili': True,
#    'two': True,
#    'hour': True,
#    'itll': True},
#   0),
#  ({'ugh': True, 'rooki': True, 'made': True, 'basket': True}, 0),
#  ({'oh': True, 'must': True, 'nice': True, 'twitpic': True, 'mate': True}, 4),
#  ({}, 0),
#  ({'thank': True}, 4),
#  ({'well': True,
#    'ive': True,
#    'final': True,
#    'got': True,
#    'deck': True,
#    'yawn': True,
#    'creepin': True,
#    'bad': True,
#    'feel': True,
#    'may': True,
#    'www.toolittletoolate.com': True},
#   4),
#  ({'oop': True,
#    'accident': True,
#    'fell': True,
#    'love': True,
#    'gay': True,
#    'guy': True},
#   0),
#  ({'131': True, 'let': True, "'s": True, 'aim': True, 'weekend': True}, 4),
#  ({'realli': True,
#    'need': True,
#    'tidi': True,
#    'desk': True,
#    'lost': True,
#    'key': True,
#    '3': True,
#    'time': True,
#    'alreadi': True,
#    '10.20': True},
#   0),
#  ({'wish': True, '18': True, 'follow': True, '...': True}, 0),
#  ({'awww': True,
#    'miss': True,
#    'good': True,
#    'day': True,
#    'went': True,
#    'bowl': True,
#    'sorri': True,
#    'catch': True,
#    'soon': True,
#    'xxx': True},
#   0),
#  ({'ear': True,
#    'itchi': True,
#    'need': True,
#    'rememb': True,
#    'put': True,
#    'sunscreen': True},
#   0),
#  ({}, 0),
#  ({'last': True,
#    'drive': True,
#    'ktis': True,
#    'cant': True,
#    'wait': True,
#    '4': True,
#    'construct': True,
#    'done': True},
#   0),
#  ({'everyon': True,
#    'decid': True,
#    'go': True,
#    'groceri': True,
#    'shop': True,
#    'today': True,
#    'rain': True,
#    'park': True,
#    'aw': True,
#    'left': True,
#    'macho': True,
#    'car': True},
#   0),
#  ({'friend': True,
#    'twitter': True,
#    "'m": True,
#    'grab': True,
#    'beer': True,
#    'bucan': True,
#    'join': True,
#    're': True,
#    'near': True},
#   4),
#  ({'good': True, 'morn': True, 'tweopl': True}, 4),
#  ({'quot': True,
#    'want': True,
#    'pcd': True,
#    'nicol': True,
#    'im': True,
#    'love': True},
#   4),
#  ({'wish': True,
#    'kristel': True,
#    'didnt': True,
#    'phone': True,
#    'silent': True,
#    'timeee': True},
#   4),
#  ({'batteri': True, 'die': True}, 0),
#  ({'damn': True, '...': True, '.dnt': True, 'kno': True}, 0),
#  ({'exhaust': True, 'reason': True, '...': True}, 0),
#  ({'twitter': True, 'revok': True, 'nudg': True, 'privilidg': True}, 0),
#  ({'somebodi': True,
#    'mess': True,
#    'dish': True,
#    'dvr': True,
#    'record': True,
#    'gone': True,
#    'grrrrrr': True,
#    'ca': True,
#    'wait': True,
#    'corrupt': True,
#    'harddriv': True,
#    'thing': True,
#    'past': True},
#   0),
#  ({'june': True, '21st': True, 'yet': True}, 4),
#  ({'teeth': True, 'hurt': True, 'lil': True, 'bit': True}, 0),
#  ({'sad': True, 'face': True}, 0),
#  ({'fed': True,
#    'sourdough': True,
#    'earlier': True,
#    'look': True,
#    'pretti': True,
#    'healthi': True,
#    'real': True,
#    'bubbl': True,
#    'jump': True,
#    'kitchen': True,
#    'enjoy': True,
#    'shabbat': True},
#   4),
#  ({'communiti': True, 'action': True, 'make': True, 'sleepi': True}, 0),
#  ({'problem': True,
#    'hunni': True,
#    'need': True,
#    'coffe': True,
#    'ooooo': True,
#    'starbuck': True},
#   4),
#  ({'firebug': True,
#    'quit': True,
#    'work': True,
#    '2': True,
#    'day': True,
#    'ago': True,
#    "'m": True,
#    'lost': True,
#    'without': True},
#   0),
#  ({'eff': True, 'phone': True, 'dead': True}, 0),
#  ({'finish': True,
#    'workout': True,
#    'prais': True,
#    'god': True,
#    'caus': True,
#    'hard': True,
#    'get': True,
#    'good': True,
#    'asthma': True,
#    'stuff': True},
#   4),
#  ({'ever': True, 'come': True, 'back': True, 'ff': True}, 0),
#  ({'nadal': True,
#    'lose': True,
#    'french': True,
#    'open': True,
#    'absolut': True,
#    'shocker': True,
#    'bad': True,
#    'see': True,
#    'match': True},
#   0),
#  ({'nop': True, 'aint': True, 'twitter': True}, 4),
#  ({'yeah': True,
#    'work': True,
#    'like': True,
#    'clock': True,
#    '--': True,
#    'cuckoo': True},
#   4),
#  ({}, 0),
#  ({'ha': True, 'let': True, 'guess': True}, 4),
#  ({'yes': True,
#    'sad': True,
#    'cinema': True,
#    'kelheim': True,
#    'film': True,
#    'quot': True,
#    'hannah': True,
#    'montana': True},
#   4),
#  ({'work': True,
#    '...': True,
#    'yay': True,
#    'sleep': True,
#    'gmornin': True,
#    'goodnight': True,
#    'tweetheart': True},
#   4),
#  ({'ugh': True,
#    '...': True,
#    'like': True,
#    'drunk': True,
#    'call': True,
#    'bothersom': True,
#    'work': True,
#    'peopl': True,
#    'ca': True,
#    'sleep': True},
#   0),
#  ({'u': True, 'onlin': True, 'hotmail': True}, 4),
#  ({'soul': True,
#    'train': True,
#    'missed..bi': True,
#    'me..fo': True,
#    'sho': True},
#   0),
#  ({'want': True,
#    'work': True,
#    'oprah': True,
#    'everyon': True,
#    'vacat': True,
#    '1700': True},
#   0),
#  ({'doggi': True, 'social': True}, 4),
#  ({'man': True,
#    'didnt': True,
#    'win': True,
#    'trackl': True,
#    'squarespac': True},
#   0),
#  ({'100th': True, 'update..': True}, 4),
#  ({"'m": True,
#    'still': True,
#    'mark': True,
#    'two': True,
#    'slide': True,
#    'present': True,
#    'applertc': True,
#    'look': True,
#    'like': True,
#    "'s": True,
#    'go': True,
#    'long': True,
#    'night': True},
#   0),
#  ({'nice': True}, 4),
#  ({'182x': True, 'name': True}, 4),
#  ({'way': True,
#    'home': True,
#    "'m": True,
#    'realli': True,
#    'burnt': True,
#    'love': True,
#    'swim': True},
#   4),
#  ({}, 0),
#  ({'day': True,
#    'one': True,
#    'palm': True,
#    'pre': True,
#    'hunt': True,
#    'sold': True,
#    '5': True,
#    'locat': True,
#    '...': True,
#    'tri': True,
#    'next': True,
#    'mon': True},
#   0),
#  ({'dude': True,
#    "'m": True,
#    'watch': True,
#    'csi': True,
#    'miami': True,
#    'goe': True,
#    'ny': True,
#    'work': True,
#    'peopl': True,
#    'ahhh': True,
#    '...': True,
#    'today': True,
#    'good': True,
#    'day': True,
#    'lol': True},
#   4),
#  ({'dj': True,
#    'traci': True,
#    'young': True,
#    "'s": True,
#    'eatin': True,
#    'wendi': True,
#    'damn': True,
#    'girl': True,
#    "'m": True,
#    'hungri': True,
#    '...': True,
#    'chicken': True,
#    'breast': True,
#    'brown': True,
#    'rice': True,
#    'lick': True,
#    'wrapper': True,
#    'get': True,
#    'lmao': True},
#   0),
#  ({'get': True,
#    'well': True,
#    'soon': True,
#    'keri': True,
#    'look': True,
#    'sing': True,
#    'voic': True},
#   4),
#  ({'*jealous*': True,
#    'wish': True,
#    'go': True,
#    'stonelov': True,
#    'tonight': True,
#    'work': True,
#    'till': True,
#    '8.30': True,
#    'im': True,
#    'skint': True},
#   0),
#  ({'beauti': True, 'yummi': True, 'lunch': True, 'way': True, 'go': True}, 4),
#  ({'love': True,
#    'see': True,
#    'you/film': True,
#    '_22': True,
#    'ladi': True,
#    'wonder': True},
#   4),
#  ({'goodi': True, 'good': True}, 4),
#  ({'lol': True,
#    'glad': True,
#    'ok.': True,
#    'laugh': True,
#    'thought': True,
#    'though': True},
#   4),
#  ({'whoa': True,
#    'get': True,
#    'tweet': True,
#    'sleep': True,
#    'maricl': True,
#    'anyways..': True,
#    'goodmorn': True},
#   4),
#  ({'cute': True}, 4),
#  ({'well': True,
#    "'s": True,
#    'cold': True,
#    'got': True,
#    'noth': True,
#    '2': True},
#   0),
#  ({'twitterfail': True,
#    'fuck': True,
#    'hard': True,
#    'right': True,
#    '...': True,
#    'annoy': True},
#   0),
#  ({'boy': True,
#    'stomach': True,
#    'bug': True,
#    'officiali': True,
#    'say': True,
#    'uncl': True,
#    '...': True},
#   0),
#  ({'creat': True, 'twitter': True, 'acccount': True}, 4),
#  ({'see': True,
#    'ca': True,
#    'find': True,
#    'nice': True,
#    'simp': True,
#    'one': True},
#   4),
#  ({'guess': True,
#    'sound': True,
#    'rather': True,
#    'nice': True,
#    'haha': True,
#    'today': True,
#    'weather': True,
#    'cold': True,
#    'compar': True,
#    'rest': True,
#    'week': True},
#   0),
#  ({'wonder': True,
#    'heck': True,
#    'get': True,
#    'twitter': True,
#    'neverrr': True,
#    'use': True,
#    'lol': True,
#    'bout': True,
#    'often': True,
#    "'m": True,
#    'guitar': True,
#    'txt': True},
#   4),
#  ({'iphon': True,
#    'quot': True,
#    'open': True,
#    'download': True,
#    'app': True,
#    'thing': True,
#    'forgot': True,
#    'cord': True,
#    'home': True},
#   0),
#  ({'beatz': True,
#    'mad': True,
#    'u': True,
#    'miss': True,
#    'good': True,
#    'show': True},
#   0),
#  ({'dw': True, 'either': True}, 0),
#  ({'ca': True,
#    'stand': True,
#    'ravenna': True,
#    'tonight': True,
#    "'s": True,
#    'realli': True,
#    'nice': True},
#   4),
#  ({'_roob': True}, 0),
#  ({'dinner': True,
#    'break': True,
#    'weight': True,
#    'watcher': True,
#    'soup': True,
#    'realli': True,
#    'want': True,
#    'chees': True,
#    'burger': True},
#   0),
#  ({'caught': True, 'stupid': True, 'cold': True}, 0),
#  ({"g'night": True,
#    'rest': True,
#    'worldwid': True,
#    'tweep': True,
#    'live': True,
#    'weird': True,
#    'time': True,
#    'zone': True,
#    'mine': True},
#   4),
#  ({'talk': True,
#    'small': True,
#    'window': True,
#    'welcom': True,
#    'back': True,
#    'busbi': True,
#    "'s": True,
#    'doubl': True,
#    'actual': True,
#    'spell': True,
#    'aim': True,
#    'f': True,
#    "'d": True},
#   4),
#  ({'friend': True,
#    'think': True,
#    'im': True,
#    'total': True,
#    'freak': True,
#    'tell': True,
#    'youtub': True,
#    'twitter': True},
#   0),
#  ({'sad': True}, 0),
#  ({'hey': True,
#    'chgd': True,
#    'pic': True,
#    'us': True,
#    '...': True,
#    "'m": True,
#    'gon': True,
#    'na': True,
#    'look': True,
#    'word': True},
#   4),
#  ({}, 4),
#  ({'work': True, '930': True}, 0),
#  ({'cool': True,
#    'll': True,
#    'tri': True,
#    'make': True,
#    'next': True,
#    'week': True},
#   4),
#  ({'vacat': True,
#    'awesom': True,
#    'relax': True,
#    'coffe': True,
#    'pocki': True,
#    'give': True,
#    'week': True,
#    'good': True,
#    'start': True},
#   4),
#  ({'tom': True,
#    'today': True,
#    'school': True,
#    'play': True,
#    'pov': True,
#    'break': True,
#    'almost': True,
#    'cri': True,
#    'show': True,
#    'sao': True,
#    'paulo': True,
#    'wish': True,
#    'could': True},
#   0),
#  ({"'s": True,
#    'lunch': True,
#    'break': True,
#    'come': True,
#    'close': True,
#    'kind': True,
#    'hot': True,
#    'humid': True,
#    'today': True,
#    'nice': True,
#    're': True,
#    'shade': True,
#    'oh': True,
#    'well': True,
#    'back': True,
#    'file': True,
#    'dod': True,
#    '...': True},
#   0),
#  ({'_say13': True, 'fun': True, 'whatev': True}, 4),
#  ({'okay': True, 'guess': True, 'wo': True, 'thunderstorm': True}, 0),
#  ({'still': True,
#    'dress': True,
#    'ceremoni': True,
#    'feel': True,
#    'like': True,
#    've': True,
#    'live': True,
#    'cap': True,
#    'gown': True,
#    'month': True,
#    'graduat': True,
#    'friday': True,
#    'night': True},
#   4),
#  ({'wonka': True,
#    'nerd': True,
#    'candi': True,
#    'mmmmmmmmmm': True,
#    'yummi': True},
#   4),
#  ({'hey': True,
#    'welcom': True,
#    'confus': True,
#    'get': True,
#    'find': True,
#    'th': True,
#    'easiest': True,
#    'palc': True,
#    'ot': True,
#    'home': True},
#   4),
#  ({'chuf': True, 'mean': True, 'happi': True, 'case': True, 'awesom': True},
#   4),
#  ({'im': True, 'cold': True, 'iphon': True, 'good': True}, 0),
#  ({'81': True, 'le': True, 'suck': True}, 0),
#  ({'71': True,
#    'love': True,
#    'ice': True,
#    'road': True,
#    'trucker': True,
#    '...': True,
#    'sooo': True,
#    'glad': True,
#    'alex': True,
#    'back': True},
#   4),
#  ({"'s": True, 'right': True, '...': True}, 0),
#  ({'dish': True, 'excit': True, 'lighter': True, 'note': True, 'brown': True},
#   4),
#  ({'heart': True,
#    'hurt': True,
#    'imagin': True,
#    'shit': True,
#    'skin': True,
#    're': True,
#    'twenti': True,
#    'stuff': True,
#    'smeer': True,
#    'shame': True},
#   0),
#  ({'copi': True,
#    'past': True,
#    'someth': True,
#    'need': True,
#    'phone': True,
#    'mom': True,
#    'send': True,
#    'pictur': True,
#    'text': True,
#    'test': True,
#    'avail': True},
#   0),
#  ({'140': True,
#    'tri': True,
#    'efusjon': True,
#    'natur': True,
#    'antioxid': True,
#    'energi': True,
#    'drink': True,
#    'acai': True,
#    'berri': True,
#    'caffein': True,
#    'free': True,
#    'crash': True,
#    'www.myefusjon.com/teamandrea': True},
#   4),
#  ({'offici': True,
#    'certifi': True,
#    'cpr': True,
#    'peopl': True,
#    'actual': True,
#    'think': True,
#    'might': True,
#    'made': True,
#    'manikin': True,
#    'come': True,
#    'life': True},
#   4),
#  ({'think': True,
#    'ill': True,
#    'wait': True,
#    'till': True,
#    'come': True,
#    'dvd': True},
#   0),
#  ({'yeah': True,
#    'total': True,
#    'sweet': True,
#    'peopl': True,
#    'like': True,
#    'u': True,
#    'reason': True,
#    'need': True,
#    'medic': True,
#    '26': True,
#    'world': True},
#   4),
#  ({'say': True,
#    'good': True,
#    'afternoon': True,
#    'ulan': True,
#    'cold': True,
#    'brrrrr': True,
#    '...': True,
#    'lone': True},
#   0),
#  ({'awesom': True, 'champagn': True, 'someth': True}, 4),
#  ({'tweet': True,
#    'good': True,
#    'morn': True,
#    'final': True,
#    'awak': True,
#    'feel': True,
#    'littl': True,
#    'guilti': True,
#    'there': True,
#    '30min': True,
#    'left': True,
#    'morning..': True,
#    'oh': True,
#    'well': True,
#    'parti': True,
#    'arvo': True,
#    'woot': True},
#   4),
#  ...]

# %% [markdown]
# ## Train the model

# %%
sentiment_classifier = NaiveBayesClassifier.train(train_bow)

# %%
accuracy=nltk.classify.util.accuracy(sentiment_classifier, train_bow)*100

# %%
print(accuracy)
# Out:
# 80.223733768542

# %%
import pickle

# %%
# Save the Modle to file in the current working directory

Pkl_Filename = "SentimentAnalysisModel2.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(sentiment_classifier, file)
