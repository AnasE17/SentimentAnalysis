# %% [markdown]
# # Sentiment Analysis

# %%
from __future__ import division
import pandas as pd
import numpy as np
import requests
import nltk
import string
import re
import os
from os import path
from time import sleep
from collections import Counter
from nltk.classify import NaiveBayesClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from textblob import TextBlob 
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('Sentiment.csv', encoding='utf-8')
tweets = data['text']
sentiment = data['sentiment'] 
data.head()
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                     1.0   Neutral                0.6578  None of the above
# 1                     1.0  Positive                0.6333  None of the above
# 2                     1.0   Neutral                0.6629  None of the above
# 3                     1.0  Positive                1.0000  None of the above
# 4                     1.0  Positive                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold  ... relevant_yn_gold  \
# 0                     1.0000            NaN  ...              NaN
# 1                     1.0000            NaN  ...              NaN
# 2                     0.6629            NaN  ...              NaN
# 3                     0.7039            NaN  ...              NaN
# 4                     1.0000            NaN  ...              NaN
#
#   retweet_count  sentiment_gold subject_matter_gold  \
# 0             5             NaN                 NaN
# 1            26             NaN                 NaN
# 2            27             NaN                 NaN
# 3           138             NaN                 NaN
# 4           156             NaN                 NaN
#
#                                                 text tweet_coord  \
# 0  RT @NancyLeeGrahn: How did everyone feel about...         NaN
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...         NaN
# 2  RT @TJMShow: No mention of Tamir Rice and the ...         NaN
# 3  RT @RobGeorge: That Carly Fiorina is trending ...         NaN
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...         NaN
#
#                tweet_created            tweet_id  tweet_location  \
# 0  2015-08-07 09:54:46 -0700  629697200650592256             NaN
# 1  2015-08-07 09:54:46 -0700  629697199560069120             NaN
# 2  2015-08-07 09:54:46 -0700  629697199312482304             NaN
# 3  2015-08-07 09:54:45 -0700  629697197118861312           Texas
# 4  2015-08-07 09:54:45 -0700  629697196967903232             NaN
#
#                 user_timezone
# 0                       Quito
# 1                         NaN
# 2                         NaN
# 3  Central Time (US & Canada)
# 4                     Arizona
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
#Remove all newlines from inside a string
clean_data = [tweet.replace('\n','').strip() for tweet in tweets]
#To remove all whitespaces in the beginning and end of the string
#remove the unicodes for the single left and right quote characters
clean_data[:] = [tweet.replace(u'\u2018',"'").replace(u'\u2019',"'") for tweet in clean_data] 

#convert n't to  not
clean_data[:] = [tweet.replace('n\'t',' not') for tweet in clean_data]  

#remove any sub-string containing 'http'
clean_data[:] = [re.sub(r"^.*http.*$", '', tweet) for tweet in clean_data] 

#remove non-ASCII characters
clean_data[:] = [re.sub(r'[^\x00-\x7F]+','', tweet) for tweet in clean_data] 

#remove tweeter's RT' tags
clean_data[:] = [tweet.replace('RT','') for tweet in clean_data] 

#make all words lower case
clean_data[:] = [tweet.lower() for tweet in clean_data] 

clean_data
# Out:
# [' @nancyleegrahn: how did everyone feel about the climate change question last night? exactly. #gopdebate',
#  '',
#  ' @tjmshow: no mention of tamir rice and the #gopdebate was held in cleveland? wow.',
#  " @robgeorge: that carly fiorina is trending -- hours after her debate -- above any of the men in just-completed #gopdebate says she's on ",
#  '',
#  ' @gregabbott_tx: @tedcruz: "on my first day i will rescind every illegal executive action taken by barack obama." #gopdebate @foxnews',
#  '',
#  'going on #msnbc live with @thomasaroberts around 2 pm et.  #gopdebate',
#  'deer in the headlights  @lizzwinstead: ben carson, may be the only brain surgeon who has performed a lobotomy on himself. #gopdebate',
#  '',
#  '@jgreendc @realdonaldtrump in all fairness #billclinton owns that phrase.#gopdebate',
#  '',
#  '',
#  '',
#  " @pattonoswalt: i loved scott walker as mark harmon's romantic rival in summer school. look it up. #gopdebate",
#  "hey @chrischristie exploiting the tragedy of 9/11 for your own political gain is @rudygiulianigop's thing #gopdebate",
#  '',
#  '',
#  "reason comment is funny 'in case you're ignorant' is the #gop #tcot are the reason the government is not working for the people #gopdebate",
#  ' @pamelageller: huckabee: paying for transgender surgery for soldiers, sailors and airmen does not make our country safer #ha #gopdebate',
#  ' @chucknellis: cruz has class &amp; truth, that gets my vote! #gopdebate',
#  '',
#  ' @erinmallorylong: no *i* hate planned parenthood and women more! no i hate planned parenthood and women more!!!!! #gopdebate',
#  '',
#  '',
#  '#gopdebate rankings: worst to be performance - rubio, kasich, christie, bush, trump, cruz, walker, paul, huckabee, carson.',
#  '',
#  " @feministabulous: it's not a competition, but how have we moved so far on gay rights but women's rights is worse than it's ever been? #g",
#  '',
#  '',
#  "@fbhw they're going to need to borrow the train horn for the next #gopdebate ! the little bell was wimpy! #hornmeansyouredone",
#  ' @lisavikingstad: ted cruz at the #gopdebate will be like ted cruz in bed. he will keep a confusingly sad look on his face and refuse to ',
#  '',
#  '',
#  '',
#  ' @amymek: the torched has been passed -&gt;.@candycrowley is no longer the most famous political assassin! congratulations @megynkelly, u wi',
#  ' @stockwizards3: trump/carson ticket would win in a landslide...@realdonaldtrump @seanhannity @anncoulter #republican #potus #trump2016 ',
#  '',
#  ' @ali: after the fox news #gopdebate, we primary voters are none the wiser on the policy plans these folks are putting forth. journalism ',
#  " @itsashlyperez: listening to fetty wap while packing because i'm a true american #gopdebate #doesthishashtagexpire?",
#  ' @mgell: trump is a cross between the shrug emoji and president business from the lego movie. #gopdebate',
#  '',
#  " @rowdygentleman: if you're planning out a #gopdebate drinking game right now, you're a rowdy gentleman.",
#  '',
#  'trump thinks criticism of his misogynistic remarks is a "political correctness" problem. nope, it\'s a pervasive #sexism problem. #gopdebate',
#  '',
#  ' @palmaceiahome1: the goal of #foxnews last night was to take out trump and pave the way for a rino like bush or kasich. #gopdebate',
#  '',
#  '@danscavino: #gopdebate w/ @realdonaldtrump delivered the highest ratings in the history of presidential debates. #trump2016 fox say thanks',
#  ' @gov: most-tweeted @govmikehuckabee #gopdebate moment: saying purpose of military "to kill people/break things" re trans servicemembers',
#  '',
#  ' @megynkelly: .@chrisstirewalt: big moments were @randpaul vs. @chrischristie, and @realdonaldtrump reaction to women question. #kellyfil',
#  " @stylemom: here's a question, why in the hell are women &amp; our body parts even in this debate? foh, stop it, it's not 1965 wtf #gopdebate",
#  "@rushlimbaugh americans getting beheaded overseas and @megynkelly is worried whether @realdonaldtrump calls rosie o'donnell fat? #gopdebate",
#  ' @chucknellis: i wo not defend @foxnews, they were far from fair or balanced last night, but name calling is juvenile. #gopdebate',
#  ' @theskysgoneout: to non-christians, #gopdebate "god" questions underline how little anyone really cares about religious minorities. chri',
#  '',
#  ' @factcheckdotorg: .@jebbush said he cut fl taxes by $19b. but that includes cuts in estate taxes mandated by federal law. #gopdebate. ht',
#  '',
#  ' @karrattipaul: join isis and sign your death warrant,signed @tedcruz next president of the us#gopdebate #wakeupamerica #cruzcrew htt',
#  '',
#  '',
#  '',
#  '',
#  ' @thejimhughes: if we want to stop sending foreign aid to places that burn our flag can we start with berkeley? #gopdebate',
#  '',
#  '',
#  "trying to decide if it's too early to come back to twitter fulltime. was gonna wait closer to election but the #gopdebate may have me hooked",
#  " @mspackyetti: donald trump's campaign reveals 1 important thing: twitter trolls are real people.and they vote. that should scare eve",
#  '',
#  '',
#  ' @hlllary: oh, one more thing. did anyone hear anything about affordable child care for working families last night in the #gopdebate ? i',
#  '',
#  '@marthamaccallum @billhemmer #gopdebate bill and martha were the a team in the first debate. 2nd debate was an ambush.',
#  'the country\'s going to hell and megyn kelly on #foxnews is attacking trump for a "war on women?" #gopdebate',
#  '',
#  " @snarkydemo: #donaldtrump said he's not politically correct.  which, of course, is trumpspeak for let's face it, i'm huge asshole. #",
#  '',
#  " @davidcicilline: this is the worst episode of the apprentice that i've ever seen. #gopdebate",
#  ' @govmikehuckabee: luntz: "as the lines go up, they almost reach 100. it almost never happens in the dial research we do." #gopdebatehtt',
#  ' @lolhayley: "the purpose of the military is to kill people and break things." - something an actual man running for president just said ',
#  'wondering if i could get the republican party to pay for my liver transplant after playing @mtaibbi #gopdebate drinking game last night.',
#  '',
#  " @tedcruz: if elected, on my first day as president, i'll rescind every illegal and unconstitutional executive order enacted by pres. oba",
#  '',
#  ' @bruneski: was upstairs putting the kids to bed. how many questions about climate change did i miss? #gopdebate #gopclowncar',
#  '',
#  '',
#  '',
#  '',
#  "even though she's a super conservative reporter, i actually like megyn kelly's interview style &amp; she did great at the #gopdebate",
#  " @kingsthings: the #gopdebate is not a debate at all. it's a series of 1 minute opportunities to avoid answering a question one candidate",
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  " @cariisie: none of them have made trump look out of place or foolish yet. think about that. when you're done crying, think about it agai",
#  ' @akbarjenkins: maybe the gop just got piven &amp; cloward confused with pinkard &amp; bowden? "she thinks i steal cars..." @kevinbaker @kevinmkr',
#  '',
#  ' @jrehling: #gopdebate donald trump says that he does not have time for political correctness. how does calling women "fat pigs" save him ',
#  '',
#  'i think @realdonaldtrump was caught by surprise by that first question and was never able to recover his equilibrium. #gopdebate',
#  '',
#  '',
#  '',
#  '',
#  'trump just said @jebbush is a true gentleman &amp; then they started violently 69ing. #gopdebate',
#  ' @cameronesposito: ugh will these guys ever shut up about how much they respect women? #gopdebate',
#  " @snarkydemo: what did the #gopdebate teach us about a future president trump?  america probably wo not be safe, except if we're attacked ",
#  '',
#  ' @amymek: "god has blessed the republican party with many great candidates, @thedemocrats ca not even find one" - @marcorubio #gopdebate',
#  '',
#  ' @mattyiceaz: scott walker ca not even carry his own state. #gopdebate',
#  '',
#  ' @smethanie: sure, god told me i should run, and the tooth fairy agreed and all the teletubbies voted yes, so here i am. #gopdebate',
#  ' @palmaceiahome1: trump should have told megyn kelly to go to hell! #foxnews #gopdebate',
#  ' @palmaceiahome1: caller on the rush limbaugh show:"i have lost all respect for fox news." #foxnews #gopdebate',
#  ' @realdonaldtrump: "@stinger_inc: @realdonaldtrump  @megynkelly\'s behaviour at the #gopdebate was astonishingly biased."',
#  '',
#  '',
#  ' @kraig4u: #gopdebate  the order was to "take out trump", but i wonder if fox news was the one who took the "order" seriously. @heidil_rn',
#  '',
#  ' @amymek: we all owe @realdonaldtrump a huge thank you 4 exposing to the world@megynkelly, chris wallace, &amp; @frankluntz are true rhinos!',
#  '',
#  '',
#  ' @pattonoswalt: "have any of you received a word from god?" = "are any of you soup-sandwich crazy?" #gopdebate',
#  ' @frankconniff: fox news #gopdebate interviewer to candidates: "what\'s your take on these gop talking points i\'m feeding you?"',
#  ' @lesliemac: but the murder of black ppl is just fine- just not unborn black babies? #goplogic #gopdebate',
#  ' @hillaryclinton: missing jon stewart already. #gopdebate #jonvoyage -h',
#  ' @charlottelaws: chris christie is really standing out at the #gopdebate',
#  ' @libertyjibbet: hey .@realdonaldtrump you know who did not whine about "unfair" questions? @carlyfiorina grow a set why do not ya\'. #gopde',
#  'you ca not be pro-life and have watched that 2 hour abortion last night.#gopdebate #forkedtongue #iseeorangepeople',
#  ' @danscavino: .@megynkelly,you failed the american people tonight. you tried to make history, by destroying @realdonaldtrump. #kellyfai',
#  ' @edstetzer: btw... when you mix politics and religion, you get politics. #gopdebate',
#  '',
#  '@megynkelly @bretbaier @foxnews wtf was up with chris wallace attacking #trump2016 on bankruptcy then giving rubio a softball? #gopdebate',
#  '',
#  '',
#  " @tuxcedocat: all republican dopefuls who say they'll take us back to 2009 on 'day one' will never see one day in white house! #gopdebate",
#  '',
#  '',
#  '',
#  ' @scorpionspriest: best moment of the #gopdebate last night: rand telling christie to go get another hug from obama.',
#  " @johnfugelsang: if you missed either #gopdebate all you need to know is there's no $ for struggling americans and unlimited $ for war.",
#  " @pfikac: .@jebbush 'we are on the verge of the greatest time to be alive in this world but washington is holding us back' #mysa #txlege ",
#  '',
#  ' @siteroi: @governorperry fights back against "what will you do abt immigration" q. says border is porous, and that must be fixed first. ',
#  'summary is the #gopdebate: status quo shit show',
#  '',
#  " @sallykohn: hey look, it's 10 men standing on a stage arguing why they should get to control women's bodies and choices. #gopdebate",
#  '',
#  ' @chrisjzullo: last night at the #gopdebate all i saw was a bunch of rich and old despots with zero solutions to our nations problems #un',
#  '',
#  ' @rfhkerry: if you think any of these people are qualified...unfollow me.  #gopdebate',
#  '',
#  '',
#  '#gopdebate the talking heads put on the debate now the talking heads are telling us how the debates went. maybe we wasted our time watching',
#  '',
#  '',
#  '',
#  '',
#  ' @maureenjohnson: "where do you think women should sleep when they have the curse? the shed? or in an open field, not on your property?\' ',
#  '"i think god\'s a pretty fair guy" -ben carson, neurosurgeon, on his belief modern day taxation should be based on an ancient book#gopdebate',
#  ' @nancyleegrahn: the cheers from #gopdebate  audience aftertrump defiantly named @rosie as the woman he called "fat pig" were the voices ',
#  '',
#  'overall the main thing we learned from the #gopdebate is that only straight, white, men matter.',
#  '@usfree4life i thought @seanhannity had the best post #gopdebate interviews of the night, gave them all a chance 2straighten their position.',
#  '',
#  '@megynkelly @bretbaier #chriswallace, #america is criticizing ur performances during #gopdebate b/c u did a really bad job as "moderators."',
#  '@govmikehuckabee: luntz: "as the lines go up, they almost reach 100. it almost never happens in the dial research we do." #gopdebate rigged',
#  ' @oftenimprudent: i wish we could teach teenage girls to love themselves as much as donald trump loves himself. #gopdebate',
#  ' @amymek: conservatives are a people without a network! #gopdebate @foxnews',
#  " @bhowl_: how come there's no talk about climate change? has anyone here even seen california right now? #gopdebate #debatewithbernie",
#  '',
#  " @chrisjzullo: last night they could have have raised their hands. i'm a spoiled billionaire, i'm an oligarch, i'm a racist, i'm a religi",
#  '#gopdebate 2016 #teamdrbencarson @realbencarson  wow! brilliant, cool, calm &amp; collected.#empowering',
#  ' @soopermexican: ted cruz does not appreciate your emphatically sarcastic air quotes, megan kelly. #gopdebate',
#  " @benjamminwalker: under no circumstances should 10 men dictate abortion rights to women. it's the 21st century, we are better than that.",
#  '',
#  '',
#  '#gopdebate @foxnews @realdonaldtrump  in1996 you called @billclinton a two timing slut.  do you stand by that statement!?',
#  '',
#  'imho #gopdebate winners #marcorubio #kasich #donaldtrump losers #scottwalker #randpaul #bencarson all others were completely forgettable',
#  '',
#  '',
#  '',
#  ' @billyeichner: thank you all for watching the #gopdebate tonight. @julieklausner and i had a blast writing it.',
#  '@theblaze the real war on women!@realdonaldtrump @megynkelly @rushlimbaugh #gopdebate @anncoulter',
#  '',
#  '',
#  '',
#  " @allthingsflynn: this trump vs. fox news conflict is quite the conundrum. it's like the personification of greed vs. hate. who do i root",
#  ' @carlyfiorina: i know how extraordinary this nation is. #gopdebate',
#  '',
#  '#rubio still my preference but i can see point of his critics over opportunism, inconsistency #gopdebate',
#  'did @realdonaldtrump ever tell @megynkelly to go wait in the car? her bad attitude suggests it. #waronwomen #gopdebate',
#  '',
#  '',
#  ' @realdonaldtrump: "@frankluntz: i\'m getting a lot of @megynkelly hatemail tonight.  #gopdebate" she is totally overrated and angry. she',
#  '',
#  '#jonvoyage was half as long as the #gopdebate  but twice as intelligible.',
#  " @lisabloom: not a single question in last night's #gopdebate about the most urgent issue of our time: climate change.",
#  '#gopdebate what was up with #foxnews &amp; their "gotcha" questions? they seemed designed to elicit typical political "spin" responses. #tlot',
#  'after the #gopdebate all of the promises being made by startups at this tech conference seem quite reasonable.',
#  '',
#  ' @carlyfiorina: the highest calling of leadership is to challenge the status quo &amp; unlock potential in others. #gopdebate. #carly2016',
#  '',
#  ' @deray: before the #gopdebate began, did not the moderators say that 8 million ppl were discussing "racial issues"? what happened to thos',
#  " @feministabulous: there's nothing like listening to ten dudes who will never need an abortion, talk about whether i should have a right ",
#  " @senwhitehouse: fox silenced by koch billions too? not a single question at last night's #gopdebate to #climatechange deniers about mond",
#  ' @tyriquex: these republicans are rich, they do not care about the poverty of america &amp; they definitely do not care bout the poverty of bla',
#  'so we just had an office chat about the #gopdebate,  &amp; i was outed as both a flaming liberal and a politics geek. probably not surprising.',
#  'catching up on my #gopdebate @lindseygrahamsc what a childish &amp; cheap move to call out @billclinton &amp; @hillaryclinton on a 17 year old story',
#  '',
#  ' @kesgardner: all ted cruz does is attack other republicans. #gopdebate',
#  '',
#  ' @frankconniff: hard to say who won the #gopdebate - bernie or hillary?',
#  " @larhunter: if donald trump wins the election, then we'll know we're on the biff-stole-the-almanac timeline. #gopdebate",
#  '',
#  " @cenkuygur: chris christie just said you have to work two more years before retiring.and that you'll get tens of thousands less you paid",
#  '',
#  ' @edwrather: the biggest losers in the debate were the fox moderators who attacked instead of moderating #gopdebate',
#  ' @whitneyneal: trump has yet to give a single, evidence-based answer to a direct question about policy. that should frighten you. #gopdeb',
#  "on my way to the studio -- about to appear on @cnn to discuss last night's #gopdebate. tune in!",
#  '',
#  ' @grneyedmandy: women who shame other women for having abortions deserve to be shamed for having no soul or self respect. #plannedparen',
#  " @amandajogomez: me: *watches the #gopdebate *me: *looks directly into the camera like i'm on the office*",
#  " @icaruspundit: donald trump's closing statement is every dinner conversation had at the villages, ever. #gopdebate",
#  ' @thexclass: "when the rich wage war it\'s the poor who die." jean-paul sartre this is now gop foreign policy. #gopdebate',
#  '',
#  ' @seabassthephish: s/o to the gop for being proud of defeating teachers union even though they just wanted higher wages #gopdebate',
#  " @writeintrump: obama better not leave his prayer rug behind in the oval office when i get elected because i'll throw it out.   #gopdebate",
#  '@chucknellis @foxnews you got that right! #gopdebate',
#  " @mrskimcam: trump just said the u.s. is stupid, so let's vote him president. wtf people. #gopdebate",
#  'so excited for @johnkasich #gopdebate #kasich4us #republicandebate #kasich2016 been waiting for 20 years!!',
#  ' @chadpergram: rep engel is 2nd major jewish democrat to announce opposition to iran deal during #gopdebate, following schumer opposition.',
#  '',
#  ' @tommychong: are any of these dudes for the legalization of marijuana, or what? #gopdebate',
#  " @cberesniova: what i learned from the #gopdebate:some guy's dad was a mailman. jesus christ is everyone's running mate. the gop has run",
#  '',
#  ' @damienfahey: i french-kissed jesus christ! - every candidate #gopdebate',
#  "#gopdebate #closingstatements @govmikehuckabee just be honest. u were defs talking about @realdonaldtrump coz he's stealing ur schtick",
#  'when cnn, msnbc ,and the new york times praise fox moderators then you know the moderators fucked up. #gopdebate',
#  ' @kesgardner: trump is a lunatic. #gopdebate',
#  'cruz has class &amp; truth, that gets my vote! #gopdebate',
#  " @kesgardner: assclown: i'm the only reason anyone is even talking about illegal immigration. keep digging, donald! #gopdebate",
#  ' @berniesanders: tom hanks. finally. somebody who makes some sense. #gopdebate #debatewithbernie',
#  ' @southernhomo: olivia pope would not vote for any of these guys #gopdebate',
#  'all #gop candidates want to reduce taxes while #huckabee wants to legalize prostitution and drugs so we can tax it. #gopdebate',
#  " @kesgardner: hi fox panel, can you just ask donald every single question? hand him a shovel while you're at it so he can keep digging. #",
#  '',
#  '',
#  ' @berniesanders: oh. it was just a movie trailer. #gopdebate #debatewithbernie',
#  ' @tacticaldissent: so sally kohn &amp; debbie wasserman schultz both  praising megyn kelly tonight. that should tell you everything you need ',
#  '',
#  "funniest line coming fr #republican 'people are frustrated, they're fed up, they do not think the government's working for them' #gopdebate",
#  'and donald trump is an absolute nut! so entertaining lol #gopdebate',
#  '',
#  '',
#  ' @danscavino: .@megynkelly trying 2show up @realdonaldtrump w @foxnews. trying 2take him down. trying 2destroy him. not happening. #kelly',
#  ' @gov: most-tweeted #gopdebate moment for @realbencarson: saying he would not publicize to the world his answer on waterboarding.',
#  "i give him a e for his big ego. #gopdebate a's are earned for excellence. rhymes with rump.",
#  'passion of the #gopdebate #religiousupamovie',
#  '',
#  ' @ohnoshetwitnt: ca not wait to see which lannister they kill off in the next episode of #gopdebate',
#  ' @kesgardner: brutal question to the assclown from megan kelly. the lesson here: be careful what you tweet on twitter! #gopdebate',
#  '',
#  'trump changed his mind on supporting paial bih aboion because a friend changed their mind on aborting &amp; had a great kid. #gopdebate',
#  'best closing statement: @realbencarson #gopdebate',
#  '',
#  ' @lesleyabravanel: trump sycophants want to know what @megynkelly\'s "hidden agenda" was last night. answer is simple: it\'s called a vagin',
#  '',
#  'donald trump is a really nasty piece of work. hope he disappears quickly. #gopdebate',
#  ' @amaraconda: fetuses are not unborn babies they are clusters of cells stop shaming people who want/have had aboions #gopdebate',
#  '',
#  '',
#  ' @pattonoswalt: despite what huckabee says, i always make sure my prostitute and her pimp pay fica and pension. #gopdebate',
#  '',
#  '@foxnews did great by challenging the candidates in #gopdebate. if these candidates ca not handle a tough question they could never b #potus',
#  '',
#  '',
#  'the number of times that ronald reagan is mentioned in the #gopdebate is too damn high',
#  ' @pattonoswalt: if trump is against "p.c. culture," i\'m suddenly 100% for it. not even kidding. what a howling shit-cave of a human. #gop',
#  ' @carljacksonshow: #bencarson great close! he operates on brains so he does not worry about skin color. #gopdebate',
#  ' @davante_r: women that would be offended by trumps "misogyny" most certainly do not vote republican.find a new fake issue faux news.#',
#  ' @auntcol54: keep religion out of politics! #gopdebate',
#  ' @dianneg: "i wo not be bought &amp; i wo not be sold" @randpaul after reiterating his points against @realdonaldtrump during #gopdebate',
#  ' @wilw: boy, i bet the mood in the clown car is going to be tense when these jerks leave the #gopdebate.',
#  ' @campeauelliot: dr. ben carson did a great job tonight! loved your closing statement! @realbencarson #gopdebate',
#  ' @redheadandright: meet the new darling of the left  megyn gotcha kelly. #gopdebate @foxnews #donaldtrump #megynkelly',
#  '@foxnewspolitics: behind the fox debate: how the anchors hashed out the questions #gopdebate they failed',
#  "did anyone get trashed playing @rollingstone's #gopdebate drinking game?   #drinkinggame",
#  'if #donaldtrump donates to u..he can call in a favor years later?? sounds like #thegodfathernot #potus thats legal?#gopdebate #gopclowncar',
#  ' @jediane9: ugh to think there were actually people sitting on their couch last night saying yes yes this is reasonable. #gopdebate',
#  '',
#  " @kesgardner: if politics can be even partially rational, trump's campaign for the gop nomination just ended. #gopdebate",
#  '',
#  ' @chrisjzullo: scott walker chooses killing mother rather than aborting unborn embryo. this is reason other countries give us that funny ',
#  'ca not #uniteblue: abortion is a talking point in the #gopdebate since #ppsellsbabyparts',
#  " @k_mcq: closing statements reminisce about an america that no longer exists after ted kennedy's 1965 immigration and nationality act. #g",
#  '',
#  ' @maureenjohnson: ted cruz is going to personally take away your telescope and try you as a witch. #gopdebate',
#  '@realdonaldtrump you killed it last night at the #gopdebate glad to have some that cares for america  #makeamericagreatagain',
#  ' @youngblkrepub: when the #gopdebate is more exciting than anything else on tv in the past 10 years....',
#  " @abbijacobson: shiiiittt, it's tough to say who is making me more horny. #gopdebate",
#  '',
#  "@bullriders1 @olivianuzzi @daveweigel the #gopdebate was better than i thought it'd be, though candidates finessed issues with sound bytes.",
#  '',
#  '',
#  '',
#  ' @thejimhughes: there will be a lot of jobs available if bush serves 2 terms, because most conservatives will have committed suicide. #go',
#  'huh. watching @foxnews debate #1 and so far, the moderators and the participants are better! #gopdebate',
#  ' @3chicspolitico: donald trump insulted @megynkelly and all women and not one man on stage confronted him. none of them are worthy to be ',
#  '',
#  ' @andreatantaros: about last night. are you watching @outnumberedfnc ? we got @ericbolling and all the good stuff from the #gopdebate on ',
#  '',
#  ' @kesgardner: and...rand paul lands the first haymaker of the night. #gopdebate',
#  ' @tarasetmayer: coming up on @wilkowmajority at 1220pm live! @siriusxm #patriot125 post #gopdebate',
#  '',
#  '#fff: highlights from this week include #nationalunderwearday, the #gopdebate, and #jonvoyage. officially. the. worst. week. ever.#tgif',
#  ' @greenspaceguy: @thedailyshow jon stewart can feel comfortable w/retirement as #gopdebate solved all problems(personal &amp; scientific) htt',
#  ' @kesgardner: of course, the assclown wo not pledge not to run as a third party candidate. #gopdebate',
#  '',
#  ' @eqphoto: just remember no matter wins the #gopdebate everyone who watched it loses #alcoholpoisoning',
#  " @anthonymarlowe: #trump #video it cost 4 times more than the $700m it would've if it were being managed by @realdonaldtrump #gopdebate h",
#  '@megynkelly you disgraced yourself last night... #gopdebate',
#  ' @proginosko: prediction: in the final #gopdebate donald trump will tear off his #missionimpossible mask to reveal a smirking jon stewart.',
#  '',
#  ' @bbcjonsopel: in midst of #gopdebate came big blow to @barackobama with announcement that leading jewish democrat, sen. schumer, wo not b',
#  ' @kesgardner: ted cruz is angling himself to be a slightly less loony version of donald trump. #gopdebate',
#  'meet the new darling of the left  megyn gotcha kelly. #gopdebate @foxnews #donaldtrump #megynkelly',
#  ' @toddstarnes: that abortion question  disgusting. #gopdebate',
#  '@nytimes and @cnn praised @foxnews and they thought they did a good job #gopdebate not a good thing',
#  '',
#  ' @jstephencarter: my #hottake: carly fiorina became a 1st tier candidate yesterday. otherwise, #gopdebate changed nothing/will be ancient',
#  '',
#  'when cnn and the new york times are praising the @foxnews moderators, you know they did it completely wrong. #gopdebate',
#  '',
#  '',
#  '',
#  " @tusk81: not one candidate spoke up against trump's mass-deportation plan, &amp; not one condemned his racist comments. latinos wo not forget",
#  '',
#  ' @gerryduggan: the kryptonian science council was more worried about climate change than these scary people. #gopdebate',
#  "withholding my very valuable presidential endorsement until i hear about everyone's point of view on the 2nd amendment #gopdebate",
#  '',
#  ' @mikedrucker: "ronald reagan never had an abortion with isis and women don\'t need them either!" - basically everyone tonight #gopdebate',
#  '',
#  ' @gregabbott_tx: @scottwalker: "every part of the world @hillaryclinton has touched is worse today" #truth #gopdebate @foxnews',
#  '@chrischristie won the #gopdebate last night. only candidate who answered questions directly and not afraid to take on tough issues.',
#  '',
#  ' @govmikehuckabee: .@fredbarnes, @weeklystandard: "mike huckabee was the star of the luntz focus group show. when he spoke, the feedback ',
#  'watching the primetime #gopdebate this afternoon, i think @bencarson2016 was the real winner, quiet but effective',
#  ' @toddstarnes: and here comes the gay marriage gotcha section.#gopdebate',
#  '',
#  '',
#  ' @govmikehuckabee: re china: you deal with a playground bully by punching them in the face &amp; putting them on the ground b/c they only res',
#  ' @ali: lots of republicans in my facebook and twitter timelines are ticked at fox news for running that hatchet job of a debate. #gopdeba',
#  'i wo not defend @foxnews, they were far from fair or balanced last night, but name calling is juvenile. #gopdebate',
#  ' @catholiclisa: hats off to ben carson for using the term "useful idiots" re: hillary clinton and the secular progressive movement. #gopd',
#  '@megynkelly your fox team talked for 31 minutes of #gopdebate while walker talked for 5. your obvious goal was to ambush everyone. pathetic.',
#  ' @johnamato: i actually agree with @andreatantaros on something. she said @realdonaldtrump did not hurt himself in #gopdebate and i concur.',
#  ' @donniewahlberg: like ben carsons brain. mike huckabees heart. marco rubios soul. chris christies fight. john kasichs hope. add carly fi',
#  '',
#  '',
#  ' @dykstradame: the #gopdebate was like a super crappy cage fight of blustering, bumbling, old wrinkled-up tuckus clinchers without the ca',
#  ' @govmikehuckabee: the military is not a social experiment. the purpose of the military is to kill people and break things. #imwithhuck #',
#  '',
#  '@tvmojoe just curious, have i missed your ratings tweet about the #gopdebate?',
#  '@megynkelly #gopdebate kelly is no role model does not speak for me or my prof friends rosie? now a real woman @carlyfiorina kelly is a poser',
#  'donald trump... #whatajoke #gopdebate',
#  ' @funnyordie: this feels like fox news tried to be the cool parents that let their kids have a party &amp; now the house is on fire. #gopdeba',
#  " @patriotmom61: it's unconscionable that @foxnews moderators asked all the candidates except santorum foreign policy&amp; nat sec questions i",
#  ' @chipmarks14: "the military is not a social experiment. its purpose is to kill people and break things."- mike huckabee #gopdebate',
#  ' @crissghoul: you are not pro life. you are pro control. you are pro religion. you are pro you.  this is never about the mother. #gopdeba',
#  '',
#  '',
#  ' @nevagphx1: @carlyfiorina magnificent at the first #gopdebate. i support ted cruz as potus, but would support you as running mate or pot',
#  "if you're a woman who supports r party please wake up and get informed. #gopdebate",
#  '',
#  'primary is still a long way away, so my favorites could change, and i hope we see more of these candidates than just sound bites. #gopdebate',
#  '',
#  '',
#  '',
#  ' @marmel: "my mother worked..."- nobody #gopdebate',
#  " @newswriter2: so we have americans getting beheaded overseas and @megynkelly is worried whether @realdonaldtrump calls rosie o'donnell f",
#  '',
#  'elections, democracy, and political debates as entertainment.  not a particularly sterling quality of our federal republic.  #gopdebate',
#  '@chrischristie @randpaul americans fear not. people who live in fear are not free and have no liberty. fear is unamerican #gopdebate',
#  '',
#  '',
#  ' @rachelmartinart: i wonder if the #gopdebate will address actual solutions for climate change and clean energy. #debatewithbernie',
#  ' @vivigold197: @realdonaldtrump: misogynist, ignorant, xenophobic and greedy: another proof that money does not buy class. #gopdebate #go',
#  '',
#  '',
#  ' @waynedupreeshow: disagree all you want#gopdebate was hit job on @realdonaldtrump and calculated mute job on @sentedcruz @realbencarso',
#  'i actually agree with @andreatantaros on something. she said @realdonaldtrump did not hurt himself in #gopdebate and i concur.',
#  '',
#  '',
#  ' @ambertozer: just got caught up on the #gopdebate and felt like i should write a joke about it but the biggest joke of all was the whole',
#  " @joshcomers: jeb makes me want to blow rails with w before we wreck his dad's car. #gopdebate",
#  'keep religion out of politics! #gopdebate',
#  'the second-tier #gopdebate participants would have had an audience if they debated bernie sanders.',
#  'what is chris cristie on about re: abortions? this is absurd. #gopdebate',
#  '',
#  "i'm eating lunch out and these two old ladies discussing the #gopdebate is giving me life. they shading shit outta christie and trump.",
#  " @ali_davis: tonight's #gopdebate was an important reminder that these guys think of women as carrying cases for fetuses.",
#  ' @realbencarson: may the lord guide my words tonight, let his wisdom be my thoughts. #gopdebate',
#  ' @thejimhughes: note to kasich - the question was not about "love" it was about "gay marriage" #thebigdodge #gopdebate',
#  '',
#  ' @palmaceiahome1: rush limbaugh to megyn kelly "i know no democrat candidate would be treated the way megyn kelly treated trump." #foxnew',
#  ' @deray: trump literally said that he donates to politicians and then calls them later to get what he wants. he literally just said that.',
#  '',
#  '#gopdebate none of the presidential candidates brought a fucking gom jabbar, i mean at least liven up your crazy',
#  '',
#  '',
#  '',
#  '',
#  ' @pattonoswalt: i want @berniesanders to quietly walk out onto this stage and five-point-palm-exploding-heart all these hollow beasts. #g',
#  '#gopdebate debate was good once they quit throwing crap at @realdonaldtrump and got substantive.  candidates handled the "gotcha" questions.',
#  '',
#  " @pattonoswalt: are they going to ask lenny kravitz's penis one question? this is very disrespectful. #gopdebate",
#  'so who watched the gop debate last night and saw trump #donaldtrump #gopdebate @realdonaldtrump #trumpforpresident',
#  '',
#  "wonder how much of tonight's #@megynkelly show will be about her  #gopdebate #foxnews",
#  '',
#  ' @3chicspolitico: trump calling @megynkelly a bimbo is reprehensible. this is about choosing a candidate for president not the jerry spri',
#  '#repeal was the word of the night. #gopdebate',
#  ' @rebleber: not mentioned in the #gopdebate:voting rightsclimate changegun violencepolice shootingsstudent debtinequality',
#  '',
#  '',
#  ' @govmikehuckabee: .@foxnews focus group: "he was very articulate, very relatable, &amp; made a lot of good points." #imwithhuck #gopdebateh',
#  '',
#  '',
#  '#gop wants to #defundpp and #huckabee wants to legalize prostitution and drugs.  #gopdebate',
#  'favorite jeb line "taking on the teacher\'s unions, and beating them" sure that empowers kids disenfranchise the ones who teach em #gopdebate',
#  '',
#  'if the newest b52 was built in the 60s like huckabee complained, does not that mean st. ronnie should have built more? #gopdebate',
#  ' @waynedupreeshow: maybe on the next #kellyfile @megynkelly will go after @krauthammer 20 year positions because he switched parties too',
#  ' @g_humbertson: perry says he would rather send @carlyfiorina to negotiate with iran than john kerry. #gopdebate',
#  'not a fan of #foxnews @megynkelly but she deserves better than to be called bimbo by #ldonaldtrump for doing her job#gopdebate #uniteblue',
#  '',
#  ' @rachlwhitehurst: i ca not tell if these are just bad cramps or my uterus trying to flee the country as i watch the #gopdebate',
#  ' @kumailn: and now the realization dawns on us. "holy shit. i\'ve been watching fox news." #gopdebate',
#  'hey .@realdonaldtrump you know who did not whine about "unfair" questions? @carlyfiorina grow a set why do not ya\'. #gopdebate',
#  '',
#  "john kasich seems like a decent guy shame he'll drowned out by the loonies in the #gop #gopdebate",
#  '',
#  '',
#  '',
#  '',
#  ' @cmclymer: fun fact: in this party of super patriots, not a single candidate on stage has served a day in the military.#gopdebate',
#  '',
#  ' @kelkulus: surprise twist: kevin spacey appears on stage, taps his ring on the podium, then pushes all 10 candidates in front of a train',
#  '@exjon @essmailpatricia @cuffymeh trump supporters threaten to take nerf ball home after hard hit.#gopdebate #trumpspeepeehurts',
#  '',
#  " @mattyiceaz: irony: watching 10 men debate women's right to choose. #gopdebate",
#  '',
#  '',
#  '',
#  '',
#  '',
#  ' @marmel: my mother worked.their mothers worked.your mothers worked.nobody mentioned their mothers.nobody.#gopdebate',
#  '',
#  ' @iamthedenk: #gopdebate tonight. really just wanna see who can cut the best promo.',
#  'john oliver: the new jon stewart. ca not wait for his coverage of #gopdebate #jonvoyage',
#  ' @littleladycassy: #gopdebate loving fiorina. smart and on point!',
#  ' @catie__warren: as a reminder. less than 3 percent of what #plannedparenthood does deals with abortions. but this debate wo not tell you ',
#  ' @k_mcq: gop base voters have been targeted by leftist terror campaigns for years, &amp; the gop establishment relentlessly manipulates that.',
#  ' @milesorionfeld: "are you not entertained?!?!?!" then #trump throws a severed head into the crowd. #gopdebate',
#  '',
#  " @thatchrisgore: i'm not really sure about president, but ted cruz would make an excellent marvel villain. #gopdebate #tedcruz #marvel",
#  ' @zellieimani: during debates on terrorism, do not expect anyone to bring up white supremacist organizations engaging in terrorism. #kkkor',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '#gopdebate did not offer a single solution to any salient issues',
#  '#gopdebate so which presidential candidate stuck their thing into the presidential electric sharpener',
#  '',
#  " @annebayefsky: .@sentedcruz: any american who leaves &amp; joins #isis should lose their passport. so there's no coming home. #gopdebate",
#  '',
#  '@joshbretow dude i totally thought the pftcommenter pic from the #gopdebate was photo shopped, guess not, hahaha so righteous',
#  ' @anergo_teacher: seriously, #trump is dangerous for the whole world. #gopdebate',
#  ' @joehudsonsmall: "would you really let a mother die, rather than have an abortion?"was seriously being asked of a presidential hopeful',
#  'jeb bush: "i defunded planned parenthood"....he is proud that he denied thousands of women access to life saving healthcare...#gopdebate',
#  '',
#  " @pamelageller: now we know rand's strategy - he's going after trump. he's got nothing to lose - he is nowhere anyway #gopdebate",
#  '',
#  ' @pattonoswalt: "that concludes our debate! please welcome the koch brothers who will choose an ideological broodmare from our whore-stab',
#  " @colmorrisdavis: amusing to hear men who chose not to serve in the military talk tough about using other people's kids to backup their b",
#  'is god going to be like the co-president or something? #gopdebate #eleventhdebater',
#  '',
#  'kind of glad i did not get to watch the #gopdebate yesterday. better for my mental health! ',
#  '@bipartisanism well, technically we did not, but the supreme court said we did.  #gopdebate',
#  'maybe the gop just got piven &amp; cloward confused with pinkard &amp; bowden? "she thinks i steal cars..." @kevinbaker @kevinmkruse #gopdebate',
#  ' @amaraconda: i swear to god if another cis white man speaks on aboion like they know what its like being pregnant......... #gopdebate',
#  'fun game: when re-watching the #gopdebate replace the word "god" with "koch bros" or "reagan."',
#  '@elianabenador @politicalshort @samlove0313love @_andybryant @ebenjones @mjgranger1 #gopdebate trump too selfish &amp; immature to have power.',
#  'after my #gopdebate tweet-athon i think i gained 200 political satirists followers but lost 250 of my teacher peeps.  u ca not win them all.',
#  ' @fakedansavage: kelly: "you call women you do not like \'fat pigs,\' \'dogs,\' and \'disgusting animals.\'" trump: "only rosie o\'donnell." crow',
#  ' @ethicistforhire: ten rich narcissists spouting nihilistic applause lines is not a debate. it is a zeitgeist #gopdebate',
#  'really thought @marcorubio had a solid performance last night! #gopdebate',
#  "smartest &amp; wisest man in the room last night barely got any speaking time, i'm a little salty about that #gopdebate @realbencarson",
#  '',
#  '',
#  ' @writeintrump: hey megan kelly, ask kelly osbourne how attacking me this week worked out for her.  #gopdebate',
#  ' @megynkelly: .@tedcruz gets powerful response from @frankluntz focus group. #kellyfile #gopdebate',
#  'why is god &amp; religion important in an election? religion should not play a part in the decision making in your country. #gopdebate',
#  "that pose is so awkward. who in the hell did she work with?  she's stiff, not natural. kinda like the #gopdebate last night. @pissed_pat",
#  ' @goddessjaz: the discussion of racist police violence was over before i finished typing that tweet. #gopdebate #kkkorgop',
#  '',
#  '',
#  "if you're sick of #gopdebate analysis, wait until sunday night when @iamjohnoliver and @lastweektonight are locks to make us all lol.",
#  'i dont care if you think you dont have time to be pc, being respectful to women is something that should be in your nature #gopdebate',
#  '',
#  '',
#  "it's not a coincidence that you could not watch the #gopdebate unless you had cable.",
#  '',
#  " @writeintrump: i'm at the #gopdebate after party. rand paul could not get in since the bar we're at does not allow poodles.",
#  '@megynkelly thinks high ratings for @foxnews #gopdebate were because of her! hate to break it to you honey.@realdonaldtrump',
#  'walked out of a restaurant last night even before my meal came feeling sick to my stomach #gopdebate',
#  "winners of the #gopdebate as far as i'm concerned:@carlyfiorina @johnkasich @realbencarson @marcorubio",
#  '',
#  '#gopdebate both debate stages were so filled with liars, traitors, double-talking cheaters, deceiving misogynists it stunk to high heaven.',
#  '',
#  " @writeintrump: anyone know why megan kelly was so pissed at me during the #gopdebate? i'm pretty sure i was never married to her.",
#  ' @jayedilla: surprise surprise, @govmikehuckabee thinks #trans life is a "social experiment" #gopdebate',
#  ' @boblonsberry: biggest losers in the #gopdebate were @megynkelly and chris wallace. cynical, arrogant, condescending game-show hosts.',
#  '',
#  '',
#  '.@billhemmer did you ask romney if his "moment had passed?"  would you have asked reagan in 1980 the same? worst question of the #gopdebate',
#  " @pattonoswalt: they're talking about hilary like she's john wick. i love it. #gopdebate",
#  '',
#  '',
#  'trumptastic #gopdebate',
#  ' @mattyiceaz: us economy added 215,000 jobs in july. this must be the result of "job-killing obamacare" republicans talked about last nig',
#  '"@carlyfiorina was one of the biggest winners thursday night without even stepping on the prime-time stage." -@cnn #gopdebate',
#  '',
#  'how did everyone feel about the climate change question last night? exactly. #gopdebate',
#  '',
#  '',
#  'trump should have told megyn kelly to go to hell! #foxnews #gopdebate',
#  'bring on the democratic debate already. please &amp; thank you #gopdebate',
#  'everyone still talking about what a great job @realbencarson did at the #gopdebate last night. articulate and very good points made. ',
#  ' @tedcruz: we need a new commander-in-chief who will stand up to our enemies and that has credibility #gopdebate #cruzcrew',
#  '',
#  '',
#  ' @bg440_: jindall and fiorina are the only two that stand out in the opening act #gopdebate',
#  "@jkarsh pffft. since when does fox care about lady viewers? plus, megyn's sole goal in the #gopdebate was to come out the winner.",
#  ' @jfreewright: last time i heard "stupid" &amp; "idiot" used so liberally in a debate was during a race for the president of my kindergarten ',
#  '',
#  '',
#  '',
#  '',
#  '#gopdebate was a great theatrical performance. they should do broadway.',
#  'omg @megynkelly! i am not a fox news fan and not a clinton fan.. but she did an amazing job last night, impressed with her qs. #gopdebate',
#  'although the occasional dick, @realdonaldtrump sure knows how to keep these political debates alive and exciting. #gopdebate',
#  " @laurengreenberg: so... it's okay to kill people if you're in the military, but it's not okay to get an abortion if you're a rape victim",
#  '',
#  "so, it's official; the gop 2016 platform is less abortion, more war. that's it. that's what they are after. #gopdebate #priorities",
#  ' @pattonoswalt: "kill people and break things," huckabee just described the gop. #gopdebate',
#  ' @sallykohn: i think @megynkelly won #gopdebate!  hard hitting questions of concern to majority of voter, not just fringe gop base. #me',
#  '@ambitiouspaul "our skin does not make us who we are.. it\'s our brain"... how is that a sellout? #gopdebate',
#  '',
#  " @writeintrump: #gopdebate after party update:  rubio, cruz, and bush are huddled in the corner speaking spanish. i think they're plottin",
#  ' @lilagracerose: .@megynkelly abortion is never medically necessary. why are you touting @ppact talking points in question to @scottwalke',
#  '',
#  'abortion is a talking point in the #gopdebate since #ppsellsbabyparts',
#  '',
#  '',
#  " @fredzeppelin12: priceless. @carlyfiorina cleans chris matthew's clock post-debate. this woman is a contender#gopdebate #gocarly  h",
#  "@npr rip niloy.  this is why #islam ic #fundamentalists must die.  it's either them or normal humans.  #isis #irandeal #gopdebate",
#  '',
#  '',
#  ' @amymek: after this debate, my opinion changed the most about @foxnews, @megynkelly, @bretbaier &amp; chris wallace! utterly disappointed#g',
#  '',
#  '#gopdebate #hillary2016 i share some sentiments, i have some favorites on #gop side, but i have no enthusiasm, do not want to vote for any.',
#  ' @rwsurfergirl: fox news is obviously trying to influence the makeup of the republican field.   #gopdebate  #gopdebates',
#  "hadiyah: rand paul rocking that wet and wavy. ooh kill'em! #gopdebate",
#  " @sethanikeem: @phaedrabonewits #gopdebate spoiler ale: a rich, white guy tells the country how he's going to help other rich, white gu",
#  'anybody get some free tacos last night? #gopdebate',
#  'hadiyah: jen bush looks like an art teacher for an inner city school and everyday his car gets vandalized.  #gopdebate',
#  'hadiyah: lets see jeb bush try to solve a common core math problem. #gopdebate',
#  'hadiyah: bruh, ben carson is boring af! he need to punch trump in the face so he can get in the game. #gopdebate',
#  'hadiyah: somebody needs to get the water off the stage before trump and paul start tossing drinks at each other. #gopdebate',
#  '',
#  "hadiyah: so when do we get to police brutality and black lives? i bet ben carson gets that question. that's if they even ask it. #gopdebate",
#  "@kesgardner agreed. still, he's the one everyone is talking about. #mystified #gopdebate",
#  " @pattonoswalt: donald trump's views on immigration are based solely on the first 8 minutes of scarface. #gopdebate",
#  '',
#  "maybe if we should paying attention to every little thing #donaldtrump sez....he's not a novelty anymore! #gopdebate #gopclowncar",
#  '',
#  '',
#  ' @billmaher: ben carson doubts hillary will be the dem nominee?? ben, do you still have your brain-cutting tools? and a mirror? ok, lie d',
#  "trump's lead shows just how low the bar is for gop nomination &amp; speaks to base approval of their elected leaders! #gopdebate #uniteblue #p2",
#  '',
#  "@pharris830 @shareaholic that's too extreme and violates the first amendment #gopdebate",
#  '',
#  '',
#  '(cont)#gopdebate  losers:  rand @randpaul (too combative and mean) and @realdonaldtrump (the fix was in)  biggest loser: foxnews credibility',
#  ' @imraansiddiqi: jeb bush - "i\'m gonna have to earn this."-said no bush, ever.#gopdebate',
#  ' @megynkelly: .@realbencarson:  there is no such thing as a politically correct war #gopdebate',
#  ' @anergo_teacher: imagine a #trump administration dealing with a us-russia crisis. wwiii #gopdebate',
#  '',
#  '',
#  '',
#  ' @chronfalkenberg: "we do not project power from bankruptcy court. we\'re borrowing a million dollars a minute." rand paul. #gopdebate',
#  '',
#  '',
#  ' @daveweigel: i believe that the phrase "if i am the nominee, i will not run as an independent" was uttered. #gopdebate',
#  " @mrgeorgewallace: the other candidates are stayin' pretty calm considering they assume dr. carson's gonna mug them at some point. #gopde",
#  " @nerdist: trump's really great in orange is the new orange #gopdebate",
#  ' @andreafed: @deb_libby half the republican base has dementia. they probably found it riveting (when not confusing the tv w/the toaster).',
#  '',
#  ' @ninjaeconomics: what are the best drinking games for the #gopdebate tonight?',
#  " @pattonoswalt: wait, does rand paul want to marry a gun? not saying that's a deal-breaker for me, but still... #gopdebate",
#  '',
#  " @chrchcurmudgeon: i'd vote for a hologram of calvin coolidge moonwalking across the stage right about now.#gopdebate",
#  " @thefriddle: trump: mexico!!!rubio: majority of illegals are not mexican.that's what grandstanding vs understanding real issue looks ",
#  'the #gopdebate was like a super crappy cage fight of blustering, bumbling, old wrinkled-up tuckus clinchers without the cage.',
#  ' @norsu2: rand paul could drop out of top 10 w dreadful, petulent debate. fiorina moves up #gopdebate #tcot',
#  '',
#  ' @daveweigel: the official debate line-up from l-r: loser, loser, loser, loser, classy, loser, loser, loser, loser, loser. #gopdebate',
#  '',
#  '',
#  '',
# ...
#  '',
#  '',
#  'the abortion portion of the #gopdebate sure degenerated into one big "let mommy die" off, did not it?',
#  '',
#  '#gopdebate was a joke',
#  '',
#  " @lesleyabravanel: my girl hillary clinton whips and nae naes like nobody's business. that's why trump had to pay her to come to his wedd",
#  ' @dreamweasel: fox news: "why is a smug, sexist asshole that people support bc he\'s a smug, sexist asshole acting like a smug, sexist ass',
#  '',
#  '',
#  ' @k_mcq: megyn kelly is acting like an sjw repeating @ppact talking points &amp; taking insults against feminists personally. waste of space!',
#  '',
#  'ugh to think there were actually people sitting on their couch last night saying yes yes this is reasonable. #gopdebate',
#  " @goldengateblond: megyn kelly better be careful with her tone or she'll be called the worst thing possible: a feminist. #gopdebate",
#  '@sallykohn @megynkelly megyn you are now officially charted on the moonbat hit parade.  #megynkelly #gopdebate',
#  '',
#  " @ergeekgoddess: yo #gopdebate, i'm really happy for you, i'mma let you finish. but #jonstewart had one of the best tv shows of all time.",
#  'kasich making a better showing so far than i thought he would #gopdebate',
#  '',
#  " @sarahbh319: @onerationale i'm on the fence between huckabee and cruz. honorable mention to rubio. #gopdebate",
#  'how dare @megynkelly ask @realdonaldtrump his history of being a male chauvinist! do we expect our president to have integrity?! #gopdebate',
#  ' @clairechansen: hey trump, refraining calling women "fat pigs" and "whores" is not being politically correct, it\'s being a decent human. ',
#  ' @jessecox: this just in: women have less rights then babies. #gopdebate',
#  '',
#  ' @nicolet_e86: @megynkelly @frankluntz i used to like you but not anymore. you should read the tweets - you did an awful job tonight. #go',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ' @shannonbream: the donor class feeds the political class, govt keeps getting bigger - says @govmikehuckabee #gopdebate',
#  '@carlyfiorina magnificent at the first #gopdebate. i support ted cruz as potus, but would support you as running mate or potus. honesty!',
#  " @einial: did rubio's ears get bigger during this debate? #gopdebate",
#  '',
#  '',
#  '',
#  '"would you really let a mother die, rather than have an abortion?"was seriously being asked of a presidential hopeful in 2015. #gopdebate',
#  '.@tajmagruder say it with me, gop: bashing .@hillaryclinton is not a campaign platform! #gopdebate',
#  '',
#  '@kylebrandt in the #gopdebate fox made @megynkelly play the womens victim she was not professional. she was a raging b all night',
#  'early2000s: i did political theater w/"billionaires for bush (or gore)" re corruption of $ in politics. #gopdebate trump: "i buy \'em all!"',
#  '',
#  '',
#  " @tinymuslimah: everybody wanna be a jesus freak till it's time to feed the poor. #gopdebate",
#  '',
#  ' @bbcjonsopel: listening to donald #trump2016 you get impression he could start a fight in an empty room #gopdebate',
#  ' @thefriddle: i miss the days when conservatives wanted a @gop presidential candidate who was, you know, a conservative... #trump #gopdeb',
#  'heard clip from #gopdebate about #nsa w/ #christie &amp; #paul . #christie supports #nsa past actions.so he agrees w/#obama &amp; #democrats right?',
#  " @tombx7m: will someone please tell megyn it's not about her.#kellyfile #gopdebate",
#  '"but what about the next 10 words?" - @pres_bartlet #gopdebate',
#  '',
#  'i hate that i missed the #gopdebate last night but these @foxnews high lights are on point. ',
#  '',
#  '',
#  ' @k_mcq: megyn kelly on trump: he ca not just keep just going after everyone attacks him! yes, he can, ms. "i\'m offended!" feminist. #go',
#  "beeteedubs.  if you have to play 'lesser-of-17-evils' with your party ... perhaps you need a new party.  #p2 #tcot #gopdebate",
#  '',
#  ' @freedomjames7: john kasich is a rino.#gopdebate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "@therightscoop well @frankluntz focus group certainly does not match today's #gopdebate polls",
#  ' @docrocktex26: this is who wants to "lead" your country. this is who wants to make decisions on your behalf. this was their opening case',
#  ' @deray: scott walker is dangerous. he is deep in his own world and is most comfortable there, it seems. dangerous. #gopdebate',
#  'lets not pretend the bar for potus is very high now.  its somewhere between sh*t and syphilis#gopdebate #tcot',
#  's/o to the gop for being proud of defeating teachers union even though they just wanted higher wages #gopdebate',
#  '',
#  ' @tananarivedue: as @shaunking pointed out, #gopdebate had a huge audience of poc ready to learn. what we learned was mostly just scary. ',
#  '',
#  "i do not give a flying fuck about what hollywood celebs think about last night's #gopdebate. they know who they want to win already. f-them.",
#  ' @fakedansavage: trump: "if i\'m the nominee, i will not run as an independent." #gopdebate',
#  ' @persianpolitik: @woodruffbets @thedailybeast and you just proved @realdonaldtrump point on bad journalists from the #gopdebate ca not ev',
#  ' @chadhastyradio: really, the only people who seem upset with @bretbaier &amp; @megynkelly &amp; fox are the people who backed trump. #gopdebate',
#  '@deb_libby half the republican base has dementia. they probably found it riveting (when not confusing the tv w/the toaster). #gopdebate',
#  ' @marcorubio: this election better be about the future, not the past. #gopdebate',
#  "i do not agree with @megynkelly but she is by no means a bimbo, #donaldtrump.as a woman, i find trump's comments disgusting.#gopdebate",
#  " @deray: christie comes across as a bully. but the bully that reminds you that he hurts people because it's in their best interests. #gop",
#  '',
#  " @k_mcq: it's embarrassing that a brilliant, stunning woman like megyn kelly uses sjw, feminist propaganda to attack republicans. #gopdeb",
#  ' @kerryepp: a debate should be between 2 candidates. not between a candidate and a moderator. the moderators should be time keepers only.',
#  '#gopdebate why do politicians stick to the same old topics, pro-life, pro-choice? gay marriage. let it go..these are personal choices!',
#  'i mean, why should it matter if the questions were unfair? you did not bother answering them anyway @realdonaldtrump #gopdebate',
#  '',
#  'todd palin &amp; rand paul have closed down a senor frogs in puerto vallarta together after a day of rigorous jet skiing #gopdebate',
#  ' @didikatz: mistake to think #gopdebate would be fun. seeing deep sickness us conservatism has become bastardized &amp; spawned by @foxnews v',
#  '#gopdebate  was interesting to watch, some candidates had some good points about the how the economy has change in the 10 yrs .',
#  'debate preformances:kasich a-rubio a-carson b+christie b+trump bbush bcruz b-huckabee b-paul c+walker c#gopdebate #kasich #rubio',
#  ' @wnd_txt: #trump is a man  who is substance.a fighter.the intellectual class will never be able to understand a hands on person like tru',
#  '',
#  ' @phillyd: i went to a gay wedding. "applause"and there were black people there too!"standing ovation"#gopdebate',
#  '',
#  ' @kumailn: "we have the military for a reason. to fuck shit up!!!" #gopdebate',
#  '',
#  ' @writeintrump: jeb bush refers to himself as vito corleone. i always thought he was fredo.  #gopdebate',
#  ' @maureenjohnson: "women or guns? which are the most people?" #gopdebate',
#  '',
#  '',
#  " @learjetter: #foxnews used crazy&gt; @dwstweets to stir the #drama pot, and that's unprofessional! @foxnews #gopdebate @julietteisabell @",
#  '',
#  ' @themattfowler: mr. trump, this next question is for you. please explain this pathetic taking of the stone cold stunner #gopdebate htt',
#  '',
#  '@realdonaldtrump hires actors for his announcement. how many did he pay to click the @drudge_repo survey ? #gopdebate #trump',
#  " @libertyladyusa: yes ma'am @conservvoice @kerrypicket ~&gt; @megynkelly megyn you disappointed me! #gopdebate ",
#  " @theladygrantham: do not be donald trump dear, it's very middle class. #gopdebate",
#  '',
#  'i want to point on one more time, that a real question, in a real presidential debate was "what did god say to you?" #gopdebate',
#  '',
#  '',
#  '',
#  '#gopdebate carly fiorina called hillary a liar 3x on @hardball_chris then not more than 5 minutes later, she says she never did that#liar',
#  'i know the audience erupted last night re: @realdonaldtrump and rosie line of ques, but how could you want that guy for a prez? #gopdebate',
#  '',
#  ' @nancyleegrahn: this #gopdebate is a giant commercial for @hillaryclinton for president. thank you god.',
#  ' @daveanthony: chewbacca should be up there just roaring every once in a while.  would fit right in.  #gopdebate',
#  '#gopdebate field seems terrified of mentioning obama in a negative light.',
#  '',
#  '',
#  " @writeintrump: i knew the war in iraq was a bad idea, just like i knew letting that blind guy cut rand paul's hair was a bad idea.  #gop",
#  'yay, social issues next!!! #gopdebate',
#  '',
#  '',
#  ' @mammals_suck: i am shocked* that over an hour into the #gopdebate &amp; there have been no qs about police brutality &amp; #blacklivesmatter ',
#  '',
#  ' @jeffsimmons2050: #gopdebate takeaway  presence matters. i see presence as a blend of believability,  articulation of #integrity w/ edg',
#  '',
#  ' @jrehling: #gopdebate donald trump is what bruce wayne would have turned into if his parents lived.',
#  '',
#  '',
#  '',
#  '',
#  'american women take note: when @@realdonaldtrump justified his piggish attacks on women at the #gopdebate, not 1 man on stage called him out',
#  ' @feministabulous: if you "hate abortion" then you should not defund planned parenthood because that\'s a surefire way to increase abortion',
#  ' @leahrboss: @carlyfiorina spanked the boys tonight. she was not even on my radar. is now. #gopdebate',
#  '',
#  'jeb looks like beavis when he smiles. #gopdebate',
#  '',
#  '',
#  '',
#  '@berniesanders @scottwalker that man did not say one intelligent thing. i mean... none of them did. #berniesanders #gopdebate #feelthebern',
#  'i have a serious #gopdebate hangover today.',
#  '',
#  ' @marnus3: the perfect remedy for a #gopdebate hangover is to #ff @pharris830 @mharvey816  @comebackdecade  @glentheplumber  @rfschatten',
#  '@realdonaldtrump got "trumped" by @megynkelly #gopdebate',
#  '',
#  ' @keemstarx: the black guy is smart as fuck! #gopdebate trump should make him his vp.',
#  'i thought @megynkelly did an awesome job at the #gopdebate personally',
#  "@megynkelly u disappointed me in last night's #gopdebate. u should've asked @realdonaldtrump q's that are pertinent 2 duties of a president.",
#  ' @gahtbomb: mike huckabee: "the purpose of the military is to kill people and break things" #gopdebate',
#  " @ag_texas: hillary clinton's response to the #gopdebate: those guys are ok, but can they secure thousands of votes from illegals?",
#  " @writeintrump: every time that bell rings rand paul's little poodle ears keep perking up.  #gopdebate",
#  ' @whinenot: rush: "not one of the 9 other candidates on the stage joined megan kelly in going after donald trump" #gopdebate',
#  ' @writeintrump: rand paul\'s haircut is really distracting. i almost yelled "rand get your leash it\'s time for your walk."  #gopdebate',
#  'tired of the shills in media for hillary.  will henceforth be known to me as #shillary.  #gopdebate',
#  ' @almightygod: ben carson: "god\'s a pretty fair guy." i guess he\'s never read the bible. #job #pharaoh #shebears  #gopdebate',
#  ' @writeintrump: cheap tactic by rand paul getting the same haircut as my poodle to distract me.  #gopdebate',
#  '',
#  "john kasich seems like a decent guy. pity he's a republican. #gopdebate",
#  '',
#  " @rmconservative: cruz's line about #campaignconservative cuts 2 the core of the issue with gop &amp; also the shortcomings of #gopdebate htt",
#  '',
#  "last night's #gopdebate proved everything we already knew about the white patriarchal elitist homophobic party the gop is.",
#  '"[trump] has no integrity, no character, and no principles, and he\'s proud of it." - @mattwalshblogagreed #gopdebate #trump',
#  ' @linnyitssn: also funny how constitution loving republicans structurally violate the constitution by bringing religion into politics. #g',
#  " @oaaselect: i'm a radical for capitalism and individual rights looking for a heroic candidate.  #gopdebate",
#  '',
#  " @megynkelly: who is your favorite from tonight's #gopdebate on @foxnews?",
#  '#gopdebate the fix was in from the get-go.first off, question about pledging support should have been addressed directly 2 @realdonaldtrump',
#  '',
#  '@realbencarson excellent job last night at the #gopdebate. class act all around. proud to have you as a republican candidate. #bencarson',
#  '',
#  '',
#  " @marcorubio: .@skye820 if we're going to make this an american century, we've got to empower small businesses. thanks for your question ",
#  ' @pattonoswalt: "my god is named \'bruce springsteen\'. go listen to \'jungleland\' and get a fucking clue," -- christie. #gopdebate',
#  'i saw @megynkelly reach down and scratch her balls once after she picked about her 10th fight with @realdonaldtrump #gopdebate #tcot',
#  " @thepatriot143: my winner overall of today's #gopdebate 's is @carlyfiorina she really stood out among all gop candidates",
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'i do not know if i should laugh or cry after last nights #gopdebate.',
#  " @pillary56: there's a difference between not being politically correct and being a massive jerk, mr. trump #gopdebate",
#  'my thoughts: perry and fiorina must replace paul and kasich in the top ten. jindal needs to step it up and replace christie. #gopdebate',
#  " @marcorubio: if i'm our nominee, we'll be the party of the future. #gopdebate",
#  '@sentedcruz had best answer of night in response to immigration. its not stupidity, it is how both sides want it.  #gopdebate',
#  '',
#  '',
#  '@krauthammer sorry the downfall of trump in last nights debate is greatly exaggerated #gopdebate',
#  'moderator: "@scottwalker,when you \'rip up the iran deal on day 1\',what then?" walker: "i remember tying yellow ribbons on trees." #gopdebate',
#  ' @ccalbos: "tell us how god speaks to you.." what is happening? is this real life?  #gopdebate',
#  ' @gusramsey: snl does not have a big enough cast to spoof this. #gopdebate',
#  'bbcworld:  bbcjonsopel: in midst of #gopdebate came big blow to barackobama with announcement that leading jewish democrat, sen. schumer,',
#  ' @ccalbos: huckabee: "the military is to kill people and break things." on behalf of military families...f you. #gopdebate',
#  '',
#  '',
#  '',
#  '18 hours later looking back: my biggest gaffe of the #gopdebate was repeatedly tagging victor cruz (@teamvic) instead of ted cruz (@tedcruz)',
#  "it's real scary that liberals are allowed 2 walk around after committing horrific crimes against humanity. #gopdebate  #plannedbutcherhood",
#  "i'd like to thank the other 9 candidates at the #gopdebate who took trump to task for once again trying to #fatshame @rosie. but, i ca not...",
#  'gotta love @megynkelly #gopdebate',
#  ' @numbersmuncher: donald trump is the guy who flips the risk board over once he realizes he ca not overtake asia. #gopdebate',
#  '',
#  '.@foxnews should replace @megynkelly with @marthamaccallum in future debates. maccallum did a much better job in early debate. #gopdebate',
#  '',
#  '',
#  "#gopdebate or old white rich conservative dudes on parade. that's a childhood nightmare of mine.",
#  '.@ljcambria @realdonaldtrump do not forget to vote for him! especislly when he has to go independent! #lulz  #huckster #rnc #gop #gopdebate',
#  '',
#  ' @writeintrump: i not only made hillary clinton go to my wedding, but i also made her be my best man.  #gopdebate',
#  'rand paul could drop out of top 10 w dreadful, petulent debate. fiorina moves up #gopdebate #tcot',
#  ' @nerdist: i gotta say it\'s refreshing to hear a presidential debate where everyone is correctly pronouncing "nuclear" #gopdebate',
#  '',
#  '',
#  '',
#  ' @freedomtexasmom: my love for @megynkelly died tonight at the #gopdebate #foxnews #trumpcruz2016 #makeamericagreatagain',
#  ...]

# %%
#remove useless words that are common in this dataset dont affect the "positivity" of the tweet 
useless = nltk.corpus.stopwords.words("english") + list(string.punctuation) + ['``', "''",'gop','debate','gopdeb','gopdebate','gopdebates','fox','news','foxnew','foxnews', 'amp']

# %%
#tokenize and clean up the tweets 
tweets = []
for tweet in clean_data:
    wordlist = [word for word in nltk.word_tokenize(tweet) if word not in useless] #a list of words per tweet
    tweets.append(wordlist)
tweets[0]
# Out:
# ['nancyleegrahn',
#  'everyone',
#  'feel',
#  'climate',
#  'change',
#  'question',
#  'last',
#  'night',
#  'exactly']

# %% [markdown]
# ### Text Stemming

# %%
#stemming
st = nltk.stem.SnowballStemmer('english')
tweets_stemmed = []
for words in tweets:
    stemmed_words = [st.stem(word) for word in words]
    tweets_stemmed.append(stemmed_words)

tweets[:] = tweets_stemmed

# %% [markdown]
# ### Visualise Positives vs. Negatives Ratio

# %%
posneg=pd.Series(sentiment).value_counts()
posneg
# Out:
# Negative    8493
# Neutral     3142
# Positive    2236
# Name: sentiment, dtype: int64

# %%
def build_bow_features(words):
    return {word:True for word in words}

# %%
#remove those neutral tweets as I am only interested in neg / pos ones
text_label_pair_list = list(zip(tweets,sentiment))
text_label_pair_list[0]
text_label_pair_list[:] = [tuple for tuple in text_label_pair_list if tuple[1]!='Neutral']

train, test = train_test_split(list(zip(tweets,sentiment)), test_size = .1, random_state=7)
train
# Out:
# [([], 'Negative'),
#  (['jjauthor',
#    'polici',
#    'barack',
#    'obama',
#    'manag',
#    'provid',
#    'neither',
#    'peac',
#    'prosper',
#    'realdonaldtrump',
#    'tedcruz'],
#   'Negative'),
#  (['dougstanhop',
#    'hillari',
#    'come',
#    'everi',
#    'angl',
#    'strike',
#    'ground',
#    'pound',
#    'arm',
#    'bar',
#    "'s",
#    'unstopp',
#    'think',
#    'wr'],
#   'Neutral'),
#  (['lrihendri',
#    'tedcruz',
#    'presid',
#    'alway',
#    'tell',
#    'truth',
#    'said',
#    'would'],
#   'Neutral'),
#  (['lukewearechang', 'evid', 'hack', 'talk', 'come', 'syria'], 'Negative'),
#  ([], 'Negative'),
#  (['tatianak',
#    'fact',
#    'wasnt',
#    'even',
#    'liter',
#    'pundit',
#    'say',
#    'rememb',
#    'time',
#    'said',
#    'x',
#    'bish',
#    'bout'],
#   'Negative'),
#  ([], 'Negative'),
#  (['rwsurfergirl', 'thank', 're', 'rais', 'realdonaldtrump', "'s", 'rate'],
#   'Negative'),
#  (['order',
#    'cruz',
#    'rubio',
#    'carson',
#    'walker',
#    'think',
#    'rand',
#    'okay',
#    'trump',
#    'hurt',
#    'jeb',
#    'much'],
#   'Positive'),
#  (['fieldnegro',
#    'happiest',
#    'person',
#    'america',
#    'today',
#    'watch',
#    'debat',
#    'hrc'],
#   'Neutral'),
#  (['rwsurfergirl',
#    'wo',
#    'admit',
#    'republican',
#    'leader',
#    'right',
#    'mean',
#    'realdonaldtrump',
#    'double-digit',
#    'lead',
#    'gopd'],
#   'Positive'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  ([], 'Positive'),
#  (['rwsurfergirl', 'thank', 're', 'rais', 'realdonaldtrump', "'s", 'rate'],
#   'Positive'),
#  (['chaunceydevega',
#    'kasich',
#    'enough',
#    'sociopath',
#    'kill',
#    'useless',
#    'eater',
#    'type',
#    'nomine'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['smethani',
#    'sure',
#    'god',
#    'told',
#    'run',
#    'tooth',
#    'fairi',
#    'agre',
#    'teletubbi',
#    'vote',
#    'yes'],
#   'Negative'),
#  (['monaeltahawi',
#    'perhap',
#    'll',
#    'talk',
#    'racism',
#    're',
#    'ask',
#    'god',
#    'told',
#    'blackliveematt'],
#   'Negative'),
#  (['polit', 'correct', 'noth', 'bad', 'manner'], 'Neutral'),
#  (['donniewahlberg', 'enjoy', 'look', 'forward', 'democraticdeb', 'next'],
#   'Positive'),
#  ([], 'Negative'),
#  (['watch', 'nanosecond'], 'Negative'),
#  ([], 'Negative'),
#  (['mariacka', 'ask', 'tedcruz', 'two', 'question'], 'Negative'),
#  (['lot',
#    'creepi',
#    'plain',
#    'cloth',
#    'cop',
#    'bodi',
#    'men',
#    'protect',
#    'scottwalk'],
#   'Negative'),
#  (['rwsurfergirl',
#    "'d",
#    'realli',
#    'like',
#    'see',
#    'long',
#    'candid',
#    'given',
#    'speak',
#    'seem',
#    'fair',
#    'balanc',
#    'gopdebat'],
#   'Negative'),
#  (['bettyfckinwhit',
#    '-can',
#    'answer',
#    'direct',
#    'question',
#    '-i',
#    'presid',
#    '-so'],
#   'Negative'),
#  ([], 'Negative'),
#  (['trump',
#    'said',
#    'jebbush',
#    'true',
#    'gentleman',
#    'start',
#    'violent',
#    '69ing'],
#   'Negative'),
#  (['trump', 'done', 'last', 'night', 'end', 'stori'], 'Negative'),
#  (['foxnewspolit',
#    'realli',
#    'look',
#    'candid',
#    'attack',
#    'trump',
#    'notfair',
#    'notbalanc'],
#   'Negative'),
#  (['hadiyah',
#    'let',
#    'see',
#    'jeb',
#    'bush',
#    'tri',
#    'solv',
#    'common',
#    'core',
#    'math',
#    'problem'],
#   'Negative'),
#  (['writeintrump',
#    'hey',
#    'megan',
#    'kelli',
#    'ask',
#    'kelli',
#    'osbourn',
#    'attack',
#    'week',
#    'work'],
#   'Negative'),
#  (['rwsurfergirl',
#    'big',
#    'problem',
#    'face',
#    'democrat',
#    'get',
#    'hillari',
#    'sober',
#    'long',
#    'enough',
#    'toot'],
#   'Neutral'),
#  (['like',
#    'sophmor',
#    'bicker',
#    'back',
#    'forth',
#    'candid',
#    'presidenti',
#    'outnumberedfnc'],
#   'Negative'),
#  (['rwsurfergirl',
#    'break',
#    'brian',
#    'william',
#    'hand',
#    'chris',
#    'christi',
#    'donut',
#    'calm'],
#   'Neutral'),
#  (['ladysandersfarm', 'bush', 'lame', 'way', 'around'], 'Negative'),
#  (['tinaissa', 'think', 'megyn', 'kellli'], 'Negative'),
#  (['hey',
#    'plan',
#    'give',
#    'tedcruz',
#    'chanc',
#    'speak',
#    're',
#    'tri',
#    'margin',
#    'daili',
#    'cycl'],
#   'Negative'),
#  (['leapoverthat',
#    'noth',
#    'realli',
#    'refresh',
#    'hear',
#    'top',
#    '1',
#    'instruct',
#    'civilian',
#    'handl',
#    'cope',
#    'poverti'],
#   'Negative'),
#  ([], 'Negative'),
#  ([], 'Positive'),
#  (['trump',
#    'answer',
#    'megynkelli',
#    'question',
#    'insult',
#    'women',
#    'insult',
#    'ca',
#    'wait',
#    'til',
#    'start',
#    'rondarousey'],
#   'Neutral'),
#  (['think',
#    'donald',
#    'hillari',
#    "'s",
#    'biggest',
#    'paid',
#    'friend',
#    'lessgovmorefun'],
#   'Negative'),
#  (['quit',
#    'frank',
#    'disturb',
#    'thing',
#    'last',
#    'night',
#    "'s",
#    'look',
#    'terribl',
#    'adobo',
#    'ting',
#    'tan'],
#   'Negative'),
#  ([], 'Negative'),
#  (['trump', 'victim', 'use', 'law', 'like', 'hundr', 'hundr', 'peopl'],
#   'Negative'),
#  (['watch',
#    'seem',
#    'like',
#    'blacklivesdontmatt',
#    'bash',
#    'pbo',
#    'fail',
#    'polici',
#    'import'],
#   'Negative'),
#  (['love', 'scottwalk', 'ask', 'rhetor', 'hillari', 'clinton', 'go', 'lectur'],
#   'Positive'),
#  (['rwsurfergirl',
#    'obvious',
#    'tri',
#    'influenc',
#    'makeup',
#    'republican',
#    'field'],
#   'Negative'),
#  (['rwsurfergirl', 'disappoint', 'conduct', 'fair', 'balanc'], 'Negative'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['supermanhotmal',
#    'pres',
#    'obama',
#    'brain',
#    'littl',
#    'toe',
#    'total',
#    'fuck',
#    'idiot',
#    'whole',
#    'famili',
#    'combin'],
#   'Negative'),
#  (['govmikehuckabe',
#    'clue',
#    'kind',
#    'hard',
#    'work',
#    'commit',
#    'everi',
#    'member',
#    'militari',
#    'make',
#    'deptofdefens'],
#   'Negative'),
#  (['bnlieb',
#    'smear',
#    'oppon',
#    'whitegenocid',
#    'nazi',
#    'libzi',
#    'pervert',
#    'memoryoftheholocaust',
#    'weapon',
#    'guarante',
#    'genoci'],
#   'Negative'),
#  (['ericstonestreet', 'trump', 'cam', 'hand'], 'Negative'),
#  (['gretchencarlson',
#    'hillari',
#    'clinton',
#    'lie',
#    'benghazi',
#    'job',
#    'need',
#    'help',
#    'carlyfiorina',
#    'foxnewspolit'],
#   'Neutral'),
#  (['marisol_bello',
#    'wht',
#    'miss',
#    'journo',
#    'concern',
#    'abt',
#    'poverti',
#    'r',
#    'voters/candid',
#    'expect',
#    '2',
#    'talkpoverti'],
#   'Negative'),
#  (['guy',
#    'like',
#    'go',
#    'run',
#    'presid',
#    'republican',
#    'better',
#    'seat',
#    'meguylikem',
#    'republicandeb'],
#   'Negative'),
#  (['rwsurfergirl',
#    'obvious',
#    'tri',
#    'influenc',
#    'makeup',
#    'republican',
#    'field'],
#   'Negative'),
#  (['senatorshoshana',
#    'moment',
#    'randpaul',
#    'spoke',
#    'key',
#    'christi',
#    'could',
#    'disagre',
#    'add',
#    'tweak',
#    'bit',
#    "'s",
#    'rand',
#    "'s"],
#   'Negative'),
#  ([], 'Neutral'),
#  (['lizzwinstead',
#    'abl',
#    'call',
#    'women',
#    'pig',
#    'whore',
#    'take',
#    'america',
#    'back'],
#   'Negative'),
#  (['moder',
#    "'s",
#    'job',
#    'ask',
#    'tough',
#    'question',
#    'attack',
#    'candid',
#    'play',
#    'victim',
#    'megynkelli'],
#   'Negative'),
#  (['fergie_spud',
#    'would',
#    'far',
#    'better',
#    'job',
#    'frank_underwood',
#    'kevinspacey'],
#   'Neutral'),
#  ([], 'Negative'),
#  (['open', 'csi', 'miami', 'support', 'trump', 'appar'], 'Neutral'),
#  (['jamiaw',
#    'purpos',
#    'militari',
#    'kill',
#    'peopl',
#    'break',
#    'thing',
#    '-mike',
#    'huckabe',
#    'kkkorgop'],
#   'Negative'),
#  (['supermanhotmal',
#    'dear',
#    'senat',
#    'rubio',
#    'god',
#    'noth',
#    'republican',
#    'parti',
#    '...',
#    'get',
#    'right'],
#   'Negative'),
#  (['jamiaw',
#    'purpos',
#    'militari',
#    'kill',
#    'peopl',
#    'break',
#    'thing',
#    '-mike',
#    'huckabe',
#    'kkkorgop'],
#   'Neutral'),
#  (['keep',
#    'go',
#    'like',
#    'this-',
#    'wo',
#    'even',
#    'bother',
#    'go',
#    'poll',
#    'reinc',
#    "'s",
#    'promis',
#    'trumpcruz2016'],
#   'Negative'),
#  (['donniewahlberg', 'enjoy', 'look', 'forward', 'democraticdeb', 'next'],
#   'Positive'),
#  (['pres',
#    'obama',
#    'brain',
#    'littl',
#    'toe',
#    'total',
#    'fuck',
#    'idiot',
#    'whole',
#    'famili',
#    'combin',
#    'boom'],
#   'Negative'),
#  (['politicorog', 'trump', 'report', 'general', 'dishonest', 'lot'],
#   'Neutral'),
#  ([], 'Neutral'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  ([], 'Neutral'),
#  ([], 'Negative'),
#  (['housecracka',
#    'huge',
#    'differ',
#    'battl',
#    'foe',
#    'walk',
#    'blue',
#    'blue',
#    'ambush',
#    'megynkellydebatequest'],
#   'Negative'),
#  (['carlyfiorina',
#    'one',
#    'pois',
#    'grace',
#    'determin',
#    'woman',
#    'get',
#    'behind',
#    'day'],
#   'Positive'),
#  (['wilberforce91',
#    'one',
#    'favorit',
#    'thing',
#    'mani',
#    'candid',
#    've',
#    'seen',
#    'person',
#    'thank',
#    'libertyu'],
#   'Positive'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  (['writeintrump',
#    "'m",
#    'go',
#    'take',
#    'long',
#    'way',
#    'bridg',
#    'close',
#    'well',
#    'play',
#    'chris',
#    'christi',
#    'well',
#    'p'],
#   'Neutral'),
#  (['watch',
#    'megynkelli',
#    'ask',
#    'trump',
#    'sexist',
#    'stuff',
#    'could',
#    'easi',
#    'crowd',
#    'roar',
#    'misogyni'],
#   'Negative'),
#  (['rwsurfergirl',
#    'american',
#    'peopl',
#    'pick',
#    'next',
#    'presid',
#    'unit',
#    'state'],
#   'Negative'),
#  (['ivankatrump',
#    'call',
#    'father',
#    'comment',
#    'rosi',
#    'suppos',
#    'listen',
#    'shame',
#    've',
#    'got',
#    'daughter'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['palmaceiahome1',
#    'goal',
#    'last',
#    'night',
#    'take',
#    'trump',
#    'pave',
#    'way',
#    'rino',
#    'like',
#    'bush',
#    'kasich'],
#   'Neutral'),
#  (['rwsurfergirl',
#    'debat',
#    'rais',
#    'realdonaldtrump',
#    "'s",
#    'rate',
#    'afraid',
#    'trump',
#    'show'],
#   'Positive'),
#  (['msgoddessris', 'never', 'gone', 'bankrupt', 'wtf', 'read', 'lip', 'trump'],
#   'Negative'),
#  (['rwsurfergirl', 'candid', 'attack', 'realdonaldtrump', 'stope', 'speak'],
#   'Negative'),
#  ([], 'Negative'),
#  (['chrisshurley',
#    'outnumberedfnc',
#    'charleskrauthamm',
#    'fossil',
#    'love',
#    'megynkelli',
#    "'s",
#    'mind',
#    'realdonaldtrump',
#    'fro'],
#   'Neutral'),
#  (['cruz', 'complet', 'ignor'], 'Negative'),
#  (['horribl',
#    'first',
#    'question',
#    'realdonaldtrump',
#    'unprofession',
#    'design',
#    'put',
#    'bad',
#    'mood',
#    'destroy'],
#   'Negative'),
#  (['markmelin',
#    'could',
#    'watch',
#    'exampl',
#    'argu',
#    'broadcast',
#    'anyway',
#    'public',
#    'servic',
#    'ridicul'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['megynkelli',
#    'say',
#    'sake',
#    'argument',
#    'letmeplaythedevilsadvoc',
#    'mean',
#    'one',
#    'better',
#    'kellyfil'],
#   'Positive'),
#  ([], 'Negative'),
#  (['loudobbsnew', 'dobb', 'like', 'govmikehuckabe'], 'Positive'),
#  ([], 'Negative'),
#  (['focus',
#    'group',
#    'post',
#    'liber',
#    'eyesor',
#    'frankluntz',
#    'focus',
#    'group',
#    'disgrac',
#    'justic',
#    'wasteoftim'],
#   'Negative'),
#  (['minasmith64',
#    're',
#    'behav',
#    'like',
#    'dumb',
#    'feminist',
#    'blame',
#    'misogyni',
#    'person',
#    "'s",
#    'respons',
#    'unwarr',
#    'attack',
#    'gopdeba'],
#   'Negative'),
#  (['aw', 'jebbush', 'tote', 'come', 'later', 'good', 'cri', 'gotchu', 'boo'],
#   'Negative'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['ppact',
#    'sell',
#    'babi',
#    'part',
#    'profit',
#    'whatev',
#    'want',
#    'call',
#    'trump',
#    'ca',
#    'call',
#    'woman',
#    'slob',
#    'pc',
#    'trump2016'],
#   'Positive'),
#  (['think', 'trump', 'moder', 'would', 'good', 'role'], 'Positive'),
#  (['rwsurfergirl', 'govchristi', 'hug', 'obama', 'deserv', 'stage', 'tonight'],
#   'Negative'),
#  (['monaeltahawi',
#    'serious',
#    'voter',
#    'think',
#    'god',
#    'talk',
#    'presidenti',
#    'candid',
#    'christianbrotherhood'],
#   'Negative'),
#  (['marcorubio', 'last', 'night', "'s", 'even', 'close', 'well', 'done'],
#   'Positive'),
#  ([], 'Neutral'),
#  (['trump', 'go', 'claim', 'god', 'gave', 'campaign', 'contribut'],
#   'Negative'),
#  (['carson', 'go', 'seat', 'back', "'s", 'race', 'becuz', 'mofo', 'racist'],
#   'Negative'),
#  (['rwsurfergirl', 'megynkelli', 'pose', 'adult', 'pictures.should', 'bring'],
#   'Negative'),
#  (['rand', 'paul', 'vote', 'randpaul'], 'Positive'),
#  (['becom', 'accept', 'god', 'topic', 'polit', 'debat', 'countri', 'shame'],
#   'Negative'),
#  (['tweet',
#    'hard',
#    'gopcircus',
#    'thought',
#    'broke',
#    'finger',
#    'nope',
#    'disloc'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['jjauthor', 'megynkelli', 'star', 'megynkelli', 'bretbaier'], 'Positive'),
#  (['rwsurfergirl', 'candid', 'attack', 'realdonaldtrump', 'stope', 'speak'],
#   'Negative'),
#  (['mozgovaya',
#    '10',
#    'men',
#    'stage',
#    'discuss',
#    'one',
#    'woman',
#    'hillaryclinton'],
#   'Neutral'),
#  (['realdonaldtrump',
#    'megynkelli',
#    'bretbaier',
#    'mod',
#    'job',
#    'is2',
#    'ask',
#    'qs',
#    'know',
#    'answer',
#    '2',
#    'bait',
#    'target',
#    'candid',
#    'trump2016'],
#   'Positive'),
#  (['joeykram', 'aerosmith', 'head', 'cleveland', 'interest', 'motleycru'],
#   'Positive'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  (['show',
#    'trump',
#    'rosieodonnel',
#    'watch',
#    'republican',
#    'presidenti',
#    'candid'],
#   'Positive'),
#  (['amandagutterman',
#    'trump',
#    'want',
#    'treat',
#    'mexican',
#    'like',
#    'white',
#    'walker'],
#   'Negative'),
#  (['leecorsodrunk',
#    'presid',
#    'colleg',
#    'footbal',
#    'would',
#    'play',
#    'year',
#    'round',
#    "'d",
#    'fast',
#    'isi',
#    'everi',
#    'saturday',
#    'corso4presi'],
#   'Neutral'),
#  (['ashvsevildead',
#    'kind',
#    'go',
#    'meanwhil',
#    're',
#    'debat',
#    'best',
#    'drum',
#    'solo',
#    'time',
#    'hot',
#    'teacher',
#    'tom',
#    'sa'],
#   'Negative'),
#  (['cap', 'defeat', 'kamehameha', 'attack', 'surviv', 'spirit', 'bomb'],
#   'Neutral'),
#  (['jjauthor',
#    'realdonaldtrump',
#    'float',
#    'like',
#    'butterfli',
#    'sting',
#    'like',
#    'bee',
#    'beladonnarog',
#    'megynkelli'],
#   'Neutral'),
#  (['cheesencrackr',
#    '2/2',
#    'right',
#    'women',
#    'indigen',
#    'peopl',
#    'peopl',
#    'colour',
#    'peopl',
#    'practic',
#    'non-western',
#    'faith',
#    'cr'],
#   'Neutral'),
#  ([], 'Positive'),
#  (['couranto',
#    'rush',
#    'mock',
#    'megyn',
#    'kelli',
#    'self',
#    'serv',
#    'narcissist',
#    'kellyfil',
#    'foxdeb'],
#   'Negative'),
#  (['rwsurfergirl',
#    'ask',
#    'trump',
#    'legitim',
#    'question',
#    'look',
#    'wallac',
#    "'s",
#    'face',
#    'trump',
#    'nail'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['dickscuttlebutt',
#    'tyfys84',
#    'duffelblog',
#    'tl',
#    'dr',
#    'blah',
#    'blah',
#    'polit',
#    'blah',
#    'blah',
#    'whiskey',
#    'blah',
#    'silent',
#    'weep',
#    'blah',
#    'christi',
#    'fat'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['annemariew',
#    'poetinpoevill',
#    'know',
#    'aprx',
#    '700',
#    'law',
#    'govern',
#    'women',
#    "'s",
#    'bodi',
#    'one',
#    'govern',
#    'men',
#    "'s",
#    "'s",
#    'true.'],
#   'Negative'),
#  (['rwsurfergirl', 'megynkelli', 'pose', 'adult', 'pictures.should', 'bring'],
#   'Negative'),
#  (['lindsey',
#    'graham',
#    'never',
#    'met',
#    'war',
#    "'s",
#    'afraid',
#    'send',
#    'kid',
#    'via',
#    'johnfugelsang',
#    'ff'],
#   'Negative'),
#  (["'s", 'scari', 'touch', 'real', 'world', 'republican'], 'Negative'),
#  (['npr', "'m", 'sure', 'immigr', 'song', 'came', 'ledzepplin'], 'Positive'),
#  (['ericstonestreet', 'trump', 'cam', 'hand'], 'Negative'),
#  (['definit', 'topic', 'watch', 'last', 'night', 'thorough', 'entertain'],
#   'Neutral'),
#  ([], 'Positive'),
#  ([], 'Neutral'),
#  (['look',
#    'like',
#    're',
#    'skip',
#    'climat',
#    'chang',
#    "'s",
#    'like',
#    'talk',
#    'white',
#    'walker',
#    'king',
#    'land',
#    'debatewithberni'],
#   'Negative'),
#  (['vohanda',
#    'argu',
#    'hillari',
#    '1hr',
#    'ca',
#    'even',
#    'talk',
#    'polic',
#    'brutal',
#    'full',
#    'minut'],
#   'Negative'),
#  (['truthteamon',
#    'understand',
#    'statement',
#    'correct',
#    'mike',
#    'huckabe',
#    'believ',
#    'fertil',
#    'egg',
#    'abl',
#    'vote.',
#    'rwnj'],
#   'Negative'),
#  (['atlcav',
#    'fave',
#    'realli',
#    'well',
#    'last',
#    'night',
#    'marcorubio',
#    'johnkasich',
#    'realbencarson',
#    'carlyfiorina',
#    'rubio-kasich',
#    'ticket'],
#   'Positive'),
#  ([], 'Neutral'),
#  (['huckabe', 'attack', 'tran', 'medic', 'care'], 'Negative'),
#  (['exclud',
#    'woman',
#    'field',
#    'first',
#    'ask',
#    'trump',
#    'part',
#    'war',
#    'women',
#    'yep.'],
#   'Negative'),
#  ([], 'Neutral'),
#  ([], 'Negative'),
#  (['catch',
#    'last',
#    'night',
#    'vast',
#    'major',
#    'question',
#    'flip-flop',
#    'posit',
#    'span',
#    'across',
#    'year'],
#   'Negative'),
#  (['rwsurfergirl',
#    'think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'togeth',
#    'expos',
#    'set',
#    'job',
#    'get',
#    'rid',
#    'bush',
#    'rubio',
#    'g'],
#   'Positive'),
#  (['_alexandragold_',
#    '*root',
#    'small',
#    'businesses*',
#    '*campaign',
#    'almost',
#    'complet',
#    'fund',
#    'larg',
#    'corporations*'],
#   'Negative'),
#  ([], 'Neutral'),
#  ([], 'Neutral'),
#  (['1catherinesiena',
#    'glennbeck',
#    'patandstu',
#    'worst',
#    'appreci',
#    'theatric',
#    "'s",
#    'gopdeba'],
#   'Negative'),
#  (['trump',
#    'lead',
#    'among',
#    'male',
#    'voter',
#    '...',
#    'also',
#    'lead',
#    'among',
#    'femal',
#    'voter'],
#   'Positive'),
#  (['rwsurfergirl', 'disappoint', 'conduct', 'fair', 'balanc'], 'Negative'),
#  (['mention', 'climat', 'chang'], 'Negative'),
#  (['lillyrockwel',
#    'dog',
#    'bark',
#    'everi',
#    'time',
#    'doorbel',
#    'sound',
#    'tv',
#    'last',
#    'night',
#    'lot',
#    'bark',
#    'useabuzz'],
#   'Negative'),
#  (['everybodi', 'orang'], 'Negative'),
#  (['alexhalperin',
#    'nandelabra',
#    'thank',
#    'made',
#    'donat',
#    'everyon',
#    'need',
#    'donat',
#    'plan',
#    'parenthood',
#    'watch'],
#   'Positive'),
#  (['keep',
#    'hammer',
#    'accord',
#    'plan',
#    'great',
#    'car',
#    'fiorina',
#    'last',
#    'nightbut',
#    'rememb',
#    'word',
#    'said'],
#   'Negative'),
#  (['cat_1012000',
#    'thank',
#    'foxtv',
#    'hold',
#    'million',
#    'peopl',
#    'know',
#    're',
#    'better',
#    'balanc',
#    'msn',
#    'abc',
#    'cbs',
#    '...'],
#   'Positive'),
#  (['carson',
#    'get',
#    'zinger',
#    'end',
#    'ride',
#    'll',
#    'give',
#    'credit',
#    'medic',
#    'trailblaz'],
#   'Positive'),
#  (['rwsurfergirl', 'anyon', 'els', 'want', 'punch', 'chris', 'wallac', 'face'],
#   'Negative'),
#  (['katiepavlich',
#    're',
#    'alreadi',
#    'see',
#    'differ',
#    'senat',
#    'governor',
#    'senat',
#    'introduc',
#    'legisl',
#    'governor',
#    'got',
#    'thi'],
#   'Neutral'),
#  (['rwsurfergirl',
#    'american',
#    'peopl',
#    'pick',
#    'next',
#    'presid',
#    'unit',
#    'state'],
#   'Negative'),
#  (['take',
#    'call',
#    '77wabcradio',
#    'yesterday',
#    "'s",
#    'call',
#    '800',
#    '848',
#    '9222'],
#   'Neutral'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  (['polit', 'correct', '...', 'ai', 'nobodi', 'got', 'time', 'trump'],
#   'Negative'),
#  (['candid', 'honest', 'terrifi', 'one', 'actual', 'elect', 'countri', 'fuck'],
#   'Negative'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  (['rwsurfergirl',
#    'chris',
#    'wallac',
#    'ask',
#    'politican',
#    'financ',
#    'money',
#    'come'],
#   'Negative'),
#  (['rubio', 'good', 'job', 'last', 'night.'], 'Positive'),
#  (['wan',
#    'na',
#    'polit',
#    'wan',
#    'na',
#    'see',
#    'shit',
#    'show',
#    'predic',
#    'elect',
#    'watch'],
#   'Negative'),
#  (['cavaticat',
#    'watch',
#    'last',
#    'night',
#    'today',
#    'got',
#    'wake',
#    'still',
#    'like',
#    'human',
#    'general'],
#   'Negative'),
#  ([], 'Neutral'),
#  ([], 'Negative'),
#  (['nerdist', 'trump', "'s", 'realli', 'great', 'orang', 'new', 'orang'],
#   'Positive'),
#  (['need', 'stop', 'he-said', 'she-said', 'question'], 'Negative'),
#  (['guypbenson',
#    'guy',
#    'trump',
#    'shoot',
#    'messeng',
#    'meagan',
#    'kelli',
#    'last',
#    'night',
#    'must',
#    'habitu',
#    'respons'],
#   'Negative'),
#  (['cloudypiano', "'m", 'wait', 'accident', 'eat'], 'Negative'),
#  (['jebbush',
#    'good',
#    'communic',
#    'last',
#    'night',
#    "'s",
#    'sound',
#    'like',
#    'charli',
#    'brown',
#    "'s",
#    'teacher'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['ca',
#    'wait',
#    'snl',
#    'imperson',
#    'donald',
#    'trump',
#    'bringbackdarrellhammond'],
#   'Negative'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['mozgovaya',
#    '10',
#    'men',
#    'stage',
#    'discuss',
#    'one',
#    'woman',
#    'hillaryclinton'],
#   'Neutral'),
#  (['rwsurfergirl',
#    'wo',
#    'admit',
#    'republican',
#    'leader',
#    'right',
#    'mean',
#    'realdonaldtrump',
#    'double-digit',
#    'lead',
#    'gopd'],
#   'Neutral'),
#  (['ask', 'everyon', 'question', 'race', '...'], 'Negative'),
#  ([], 'Neutral'),
#  (['matthewherp',
#    'cruz',
#    'need',
#    'command',
#    'chief',
#    'make',
#    'clear',
#    'join',
#    'isi',
#    'sign',
#    'death',
#    'warrant'],
#   'Negative'),
#  (['rwsurfergirl', 'rubio', 'bush', 'threat', 'countri'], 'Negative'),
#  (['shannonrwatt',
#    'gun',
#    'violenc',
#    'cost',
#    'american',
#    '229b',
#    'annual',
#    'gunsens'],
#   'Negative'),
#  (['gop2016',
#    'plan',
#    'build',
#    'militari',
#    'cut',
#    'tax',
#    'ya',
#    'gon',
#    'na',
#    'pay',
#    'bake',
#    'sale',
#    'steal',
#    'ss'],
#   'Negative'),
#  (['monaeltahawi',
#    'candid',
#    'receiv',
#    'word',
#    'god',
#    'presidenti',
#    'hope',
#    'america',
#    'christian',
#    'brotherhood',
#    'america'],
#   'Negative'),
#  (['kelli', 'last', 'night', 'stop', 'clock'], 'Neutral'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['mcgrudder',
#    'gop2016deb',
#    'trump2016',
#    'trump2016',
#    'trump',
#    'scare',
#    'control',
#    'talk',
#    'abo'],
#   'Positive'),
#  (['kumailn', 'guy', 've', 'cure', 'racism', 'realiz', 'congrat'], 'Negative'),
#  (['bettyfckinwhit',
#    '-can',
#    'answer',
#    'direct',
#    'question',
#    '-i',
#    'presid',
#    '-so'],
#   'Negative'),
#  (['jordiemojordi', 'yall', 'better', 'lie', 'god', 's/he', 'talk', 'yall'],
#   'Negative'),
#  (['shadowbard',
#    'american',
#    'women',
#    'take',
#    'note',
#    'realdonaldtrump',
#    'justifi',
#    'piggish',
#    'attack',
#    'women',
#    '1',
#    'man',
#    'sta'],
#   'Negative'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['problem',
#    'polit',
#    'correct',
#    "'s",
#    'mani',
#    'american',
#    'anti-intellectu',
#    'ignor',
#    'usa'],
#   'Negative'),
#  (['rwsurfergirl',
#    'would',
#    'never',
#    'know',
#    'realdonaldtrump',
#    'frontrunn',
#    'watch'],
#   'Neutral'),
#  (['oriolesfanprobz',
#    "'m",
#    'disappoint',
#    'none',
#    'candid',
#    'ask',
#    'thought',
#    'defens',
#    'shift',
#    'basebal'],
#   'Negative'),
#  ([], 'Negative'),
#  (['damn', 'freeload', 'pimp'], 'Negative'),
#  (['jeffsimmons2050',
#    'takeaway',
#    'presenc',
#    'matter',
#    'see',
#    'presenc',
#    'blend',
#    'believ',
#    'articul',
#    'integr',
#    'w/',
#    'edg'],
#   'Negative'),
#  (['rwsurfergirl', 'candid', 'attack', 'realdonaldtrump', 'stope', 'speak'],
#   'Negative'),
#  (['akhenaten15',
#    'abort',
#    'problem',
#    'kill',
#    '575,000',
#    'iraqi',
#    'kid',
#    '2000',
#    'anoth',
#    '56,000',
#    'iraqi',
#    'kid'],
#   'Negative'),
#  (['monaeltahawi',
#    'candid',
#    'receiv',
#    'word',
#    'god',
#    'presidenti',
#    'hope',
#    'america',
#    'christian',
#    'brotherhood',
#    'america'],
#   'Negative'),
#  ([], 'Positive'),
#  ([], 'Neutral'),
#  (['warriorwoman91',
#    'love',
#    'megynkelli',
#    'hold',
#    'highest',
#    'posit',
#    'media',
#    'figur',
#    'ask',
#    'question',
#    'repub',
#    'war'],
#   'Positive'),
#  ([], 'Negative'),
#  (['zeitgeistghost',
#    'sane',
#    'person',
#    'think',
#    '1st',
#    'matter',
#    "'s",
#    'soulless',
#    'pitti',
#    'asshol'],
#   'Neutral'),
#  ([], 'Neutral'),
#  (['much',
#    'voter',
#    'care',
#    'lender',
#    'lost',
#    'money',
#    'realdonaldtrump',
#    'bankruptci',
#    'lzdebat'],
#   'Negative'),
#  ([], 'Negative'),
#  (['monaeltahawi',
#    'one',
#    'question',
#    'one',
#    'import',
#    'urgent',
#    'movement',
#    'us',
#    'today',
#    'long',
#    'time',
#    'one',
#    'question'],
#   'Neutral'),
#  (['megynkelli',
#    'krauthamm',
#    'winner',
#    'tedcruz',
#    'marcorubio',
#    'govmikehuckabe',
#    'chrischristi',
#    'kellyfil'],
#   'Neutral'),
#  (['usprezdeb',
#    '...',
#    'total',
#    'think',
#    'tan',
#    'trump',
#    'gaff',
#    'presidenti',
#    'candid'],
#   'Negative'),
#  (['anyon',
#    'use',
#    'god',
#    "'s",
#    'name',
#    'hate',
#    'wolf',
#    'sheep',
#    "'s",
#    'cloth',
#    'matthew',
#    '23:1-15',
#    'cruz',
#    'huckabe',
#    'men',
#    'god'],
#   'Negative'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  (['paulrieckhoff',
#    'yes',
#    'entitl',
#    'cic',
#    'potus',
#    'candid',
#    'excus',
#    'lack',
#    'nationalsecur',
#    'defens',
#    'va'],
#   'Negative'),
#  (['rwsurfergirl', 'candid', 'attack', 'realdonaldtrump', 'stope', 'speak'],
#   'Negative'),
#  ([], 'Negative'),
#  (['like',
#    'trump',
#    'less',
#    'morn',
#    'last',
#    'morn',
#    'although',
#    'realiz',
#    "'s",
#    'want',
#    'think'],
#   'Negative'),
#  (['woke', 'think', 'hilari', 'dream', 'realiz', 'watch', 'last', 'night'],
#   'Negative'),
#  (['berniesand',
#    'scottwalk',
#    'man',
#    'say',
#    'one',
#    'intellig',
#    'thing',
#    'mean',
#    '...',
#    'none',
#    'berniesand',
#    'feelthebern'],
#   'Negative'),
#  (['larryeld',
#    'trump',
#    'said',
#    'megyn',
#    'ask',
#    'nine',
#    'candid',
#    'plan',
#    'support',
#    'win',
#    'nomin',
#    'gopdebat'],
#   'Neutral'),
#  (['donaldtrump',
#    'know',
#    'usa',
#    'ca',
#    'declar',
#    'bankruptci',
#    'stiff',
#    'chines',
#    'creditor',
#    'askingforafriend'],
#   'Negative'),
#  ([], 'Negative'),
#  (['monaeltahawi',
#    'oh',
#    'boy',
#    'social',
#    'issu',
#    'code',
#    'control',
#    'women',
#    "'s",
#    'bodi',
#    'sexual',
#    'hold',
#    'tight',
#    'twitterland'],
#   'Negative'),
#  (['confus',
#    'republican',
#    'make',
#    'joke',
#    'republican',
#    'watch',
#    'inform',
#    'candid'],
#   'Neutral'),
#  (['drbhotchkin',
#    'lynch',
#    'black',
#    'folk',
#    'jesus',
#    'name',
#    "'s",
#    'relev',
#    'god',
#    'question',
#    'foxdeb',
#    'foxn'],
#   'Negative'),
#  (['rwsurfergirl',
#    'think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'togeth',
#    'expos',
#    'set',
#    'job',
#    'get',
#    'rid',
#    'bush',
#    'rubio',
#    'g'],
#   'Positive'),
#  ([], 'Neutral'),
#  (['mariacka',
#    'newsflash',
#    'jeb',
#    'wo',
#    'unit',
#    'countri',
#    'commoncor',
#    'pleas',
#    'lol'],
#   'Negative'),
#  (['base',
#    'rhetor',
#    'assum',
#    'donald',
#    'trump',
#    'look',
#    'megyn',
#    'kelli',
#    'see',
#    'miss',
#    'piggy.'],
#   'Negative'),
#  (['mitchellreport',
#    'capehartj',
#    'randpaul',
#    'good',
#    'point',
#    'turn',
#    'someth',
#    'sophomor',
#    'w/',
#    'hug',
#    'comment'],
#   'Negative'),
#  (['-er',
#    'vs',
#    'trump',
#    'glove',
#    'stay',
#    'except',
#    'fiorina',
#    'kick',
#    'curb',
#    'like',
#    'hp',
#    'employe'],
#   'Negative'),
#  (['want', 'defundpp', 'huckabe', 'want', 'legal', 'prostitut', 'drug'],
#   'Negative'),
#  (['chrisfranjola',
#    'thank',
#    'courag',
#    'coverag',
#    'sacrific',
#    'save',
#    'dread',
#    'even'],
#   'Negative'),
#  (['donniewahlberg', 'enjoy', 'look', 'forward', 'democraticdeb', 'next'],
#   'Positive'),
#  (['bamasever',
#    'megyn',
#    'kelli',
#    'worri',
#    'trump',
#    "'s",
#    'parti',
#    'loyalti',
#    'watch',
#    'transform',
#    'liber',
#    '3',
#    'hour'],
#   'Negative'),
#  (['supermanhotmal',
#    'dear',
#    'close',
#    'argument',
#    'none',
#    'candid',
#    'said',
#    'anyth',
#    'help',
#    'suffer',
#    'women'],
#   'Negative'),
#  (['women',
#    'serv',
#    'open',
#    'gay',
#    'transgend',
#    'militari',
#    'social',
#    'experi',
#    'accord',
#    'govmikehuckabe',
#    'late'],
#   'Negative'),
#  (['zoe_arch',
#    'wonder',
#    "'s",
#    'coincid',
#    'ironi',
#    'purpos',
#    'anniversari',
#    'hiroshima',
#    'bomb'],
#   'Neutral'),
#  ([], 'Negative'),
#  (['bourgeoisalien',
#    'ca',
#    'wait',
#    'end',
#    'wrestl',
#    'angri',
#    'meth',
#    'addict',
#    'bear',
#    'death',
#    'see',
#    'real'],
#   'Neutral'),
#  (['readi', '2016', 'gop2016', 'goodbyeobama', 'neveragain'], 'Positive'),
#  ([], 'Neutral'),
#  (['truli', 'greatest', 'show', 'earth', 'gopclowncar'], 'Negative'),
#  (['simsoph',
#    'quit',
#    'someth',
#    'watch',
#    'vs',
#    'canadian',
#    'pm',
#    'anyon',
#    'take',
#    'american',
#    'politician',
#    'serious'],
#   'Negative'),
#  (['supermanhotmal',
#    'dear',
#    'gov',
#    'walker',
#    'noth',
#    'brag',
#    'fuck',
#    'state',
#    'wisconsin',
#    'suck',
#    'koch',
#    '...',
#    'bitchasspoli'],
#   'Negative'),
#  (['supermanhotmal',
#    'translat',
#    'jeb',
#    'bush',
#    'fuck',
#    'florida',
#    'school',
#    'bad',
#    'still',
#    'recov',
#    'truth',
#    'live'],
#   'Negative'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['rwsurfergirl',
#    'think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'togeth',
#    'expos',
#    'set',
#    'job',
#    'get',
#    'rid',
#    'bush',
#    'rubio',
#    'g'],
#   'Neutral'),
#  ([], 'Negative'),
#  (['brios82',
#    'conserv',
#    'want',
#    'live',
#    'babi',
#    'rais',
#    'dead',
#    'soldier',
#    '-georg',
#    'carlin'],
#   'Negative'),
#  ([], 'Negative'),
#  (['whole',
#    'debacl',
#    'insult',
#    'everi',
#    'american',
#    'common',
#    'sens',
#    'idea',
#    'histori',
#    '...',
#    '...'],
#   'Negative'),
#  ([], 'Negative'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['fieldnegro',
#    'happiest',
#    'person',
#    'america',
#    'today',
#    'watch',
#    'debat',
#    'hrc'],
#   'Neutral'),
#  (['rwsurfergirl',
#    'chris',
#    'wallac',
#    'ask',
#    'politican',
#    'financ',
#    'money',
#    'come'],
#   'Negative'),
#  (['genethelawy', 'ted', 'cruz', 'leav'], 'Neutral'),
#  (['dear',
#    'moder',
#    'forgot',
#    'say',
#    'chines',
#    'hack',
#    'start',
#    'bush',
#    'admin',
#    '...'],
#   'Negative'),
#  (['rwsurfergirl',
#    'chris',
#    'wallac',
#    'ask',
#    'politican',
#    'financ',
#    'money',
#    'come'],
#   'Negative'),
#  (['the818', 'let', "'s", 'play', 'fast', 'distanc', 'trump', 'notm'],
#   'Negative'),
#  (['wow',
#    'everybodi',
#    "'s",
#    'tweet',
#    'megynkelli',
#    "'s",
#    'bad',
#    'treatment',
#    'realdonaldtrump',
#    'agre'],
#   'Negative'),
#  ([], 'Positive'),
#  (['chrchcurmudgeon',
#    "'d",
#    'vote',
#    'hologram',
#    'calvin',
#    'coolidg',
#    'moonwalk',
#    'across',
#    'stage',
#    'right',
#    'now.'],
#   'Negative'),
#  ([], 'Negative'),
#  ([], 'Neutral'),
#  ([], 'Neutral'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['glad', 'social', 'secur', 'debat', 'futur', 'gapol'], 'Positive'),
#  (['cruz', 'class', 'truth', 'get', 'vote'], 'Positive'),
#  ([], 'Negative'),
#  (['jessecox',
#    'even',
#    'god',
#    'roll',
#    'eye',
#    'respons',
#    'get',
#    'super',
#    'jesus',
#    'say',
#    '...',
#    'gopd'],
#   'Negative'),
#  (['bettyfckinwhit',
#    '-can',
#    'answer',
#    'direct',
#    'question',
#    '-i',
#    'presid',
#    '-so'],
#   'Negative'),
#  ([], 'Negative'),
#  ([], 'Neutral'),
#  (['pimp', 'drug', 'dealer'], 'Neutral'),
#  (['megynkelli',
#    'trump',
#    'simpli',
#    'ca',
#    'harm',
#    'impolitik',
#    'statement',
#    "'s",
#    'like',
#    'tri',
#    'drown',
#    'aquaman',
#    'donaldtrump'],
#   'Negative'),
#  (['love',
#    'hear',
#    'bencarson',
#    'debatequestionswewanttohear',
#    'make',
#    'perfect',
#    'sens',
#    'israel',
#    'awesom'],
#   'Positive'),
#  (['consequ',
#    'obama/clinton',
#    'admin',
#    '...',
#    'like',
#    'increas',
#    'diplomaci',
#    'ration',
#    'decision-mak',
#    'work',
#    'elimin',
#    'xenophobia'],
#   'Negative'),
#  (['ask', 'trump', 'question', 'get', 'squirrel'], 'Negative'),
#  (['carson',
#    'witti',
#    'articul',
#    'unlik',
#    'deserv',
#    'much',
#    'better',
#    'poll',
#    'rate',
#    'wo',
#    'make',
#    'past',
#    'new',
#    'hampshir'],
#   'Positive'),
#  ([], 'Positive'),
#  (['exjon', 'rubio', 'win'], 'Positive'),
#  (['_kingmalcolm', 'pro', 'life', 'unless', 'cop', 'involv', 'candid'],
#   'Negative'),
#  (['rwsurfergirl',
#    'chris',
#    'wallac',
#    'ask',
#    'politican',
#    'financ',
#    'money',
#    'come'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['ericstonestreet', 'trump', 'cam', 'hand'], 'Negative'),
#  ([], 'Negative'),
#  ([], 'Positive'),
#  ([], 'Neutral'),
#  (['livestream',
#    'blogger',
#    'make',
#    'sure',
#    'donald',
#    'trump',
#    'pull',
#    'rose',
#    'perot',
#    'clinton'],
#   'Negative'),
#  (['bring', 'hillaryclinton', 'need', 'someon', 'grown-up', 'barbarabox'],
#   'Positive'),
#  ([], 'Neutral'),
#  (['per',
#    'trump',
#    'believ',
#    "'s",
#    'mere',
#    'polit',
#    'correct',
#    'moral',
#    'right',
#    'treat',
#    'women',
#    'equal'],
#   'Negative'),
#  (['democrat', 'love', 'right'], 'Positive'),
#  (['salmasekela', 'self', 'righteous', 'hypocrit', 'tri', 'god', 'shameless'],
#   'Negative'),
#  (['sydneyvl24', 'cautious', 'optimist', 'feel', 'morn'], 'Positive'),
#  (['imoore8904',
#    'trump',
#    'support',
#    'tee',
#    'hee',
#    'laugh',
#    'insult',
#    'everyon',
#    'sun',
#    'cri',
#    'foul',
#    'megynkelli',
#    'call',
#    'shit'],
#   'Negative'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['michelejmartin',
#    'last',
#    'night',
#    'huge',
#    'tv',
#    'jonvoyag',
#    'battl',
#    'social',
#    'annarawsuh',
#    'ovrdrv',
#    'recap',
#    'h'],
#   'Neutral'),
#  (['bassem_masri',
#    'wow',
#    'run',
#    'blatant',
#    'run',
#    'bigotri',
#    'war',
#    'tortur',
#    'address',
#    'problem',
#    'home',
#    'kkkorgop',
#    'go'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['erictheteamst',
#    'walker',
#    'main',
#    'talk',
#    'point',
#    'took',
#    '100s',
#    '1000s',
#    'union',
#    'protest',
#    'wait',
#    'hear',
#    'hel'],
#   'Neutral'),
#  (['kavithadavidson', 'total', 'stay', 'tune', 'god', 'megyn'], 'Positive'),
#  (['chrischristi', 'make', 'even', 'proud', 'new', 'jersey'], 'Positive'),
#  (['megyn',
#    'kelli',
#    'need',
#    'work',
#    'msnbc',
#    'low',
#    'point',
#    'debate.',
#    'realdonaldtrump'],
#   'Negative'),
#  ([], 'Neutral'),
#  ([], 'Negative'),
#  (['ummmm', 'discuss', 'speakerboehn'], 'Neutral'),
#  (['kingsth',
#    "'s",
#    'seri',
#    '1',
#    'minut',
#    'opportun',
#    'avoid',
#    'answer',
#    'question',
#    'one',
#    'candid'],
#   'Negative'),
#  ([], 'Positive'),
#  (['stockwizards3',
#    'trump/carson',
#    'ticket',
#    'would',
#    'win',
#    'landslid',
#    '...',
#    'realdonaldtrump',
#    'seanhann',
#    'anncoult',
#    'republican',
#    'potus',
#    'trump2016'],
#   'Negative'),
#  (['walker',
#    'kept',
#    'point',
#    'tight',
#    'clean',
#    'want',
#    'see',
#    'run',
#    'clock',
#    'longer',
#    'next'],
#   'Positive'),
#  ([], 'Negative'),
#  (['adni', '3', 'goddeb', 'fs', 'famili', 'friend', 'facebook'], 'Neutral'),
#  ([], 'Neutral'),
#  (['rwsurfergirl',
#    'wonder',
#    '--',
#    'get',
#    'rid',
#    'trump',
#    'paul',
#    'cruz',
#    'carson'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['supermanhotmal',
#    'scott',
#    'walker',
#    'busi',
#    'iran',
#    'crook',
#    'koch',
#    'brother',
#    '...',
#    'way',
#    'go',
#    'dickhead',
#    'walker'],
#   'Negative'),
#  (['never',
#    'thought',
#    "'d",
#    'say',
#    'goddamnit',
#    'yo',
#    'megynkelli',
#    'chris',
#    'wallac',
#    'bretbaier',
#    '...',
#    'great',
#    'job',
#    'host',
#    'last',
#    'night'],
#   'Positive'),
#  (['last',
#    '15',
#    'min',
#    'insan',
#    'god',
#    'invok',
#    'mani',
#    'time',
#    'remind',
#    'isi',
#    'liber',
#    'secular',
#    'equalityforal'],
#   'Negative'),
#  (['tinapayson',
#    'tedcruz',
#    'look',
#    'like',
#    'charact',
#    'startrek',
#    'alway',
#    'tell',
#    'truth.'],
#   'Neutral'),
#  (['fieldnegro',
#    'happiest',
#    'person',
#    'america',
#    'today',
#    'watch',
#    'debat',
#    'hrc'],
#   'Positive'),
#  ([], 'Negative'),
#  (['mzdivah67',
#    'watch',
#    'seem',
#    'like',
#    'blacklivesdontmatt',
#    'bash',
#    'pbo',
#    'fail',
#    'polici',
#    'impo'],
#   'Negative'),
#  (['pboylen',
#    'scottwalk',
#    'russia',
#    'china',
#    'know',
#    'hillari',
#    'clinton',
#    "'s",
#    'email',
#    'congress',
#    'boom',
#    'rednationrais'],
#   'Neutral'),
#  ([], 'Positive'),
#  (['yes', 'jeb', 'bush', 'wear', 'spanx'], 'Negative'),
#  (["'m",
#    'honest',
#    'sure',
#    'quot',
#    'timelin',
#    'answer',
#    'peopl',
#    'joke',
#    'gopdebacl'],
#   'Neutral'),
#  (['lrihendri',
#    'tedcruz',
#    'presid',
#    'alway',
#    'tell',
#    'truth',
#    'said',
#    'would'],
#   'Positive'),
#  ([], 'Neutral'),
#  (['mariacka', 'ask', 'tedcruz', 'two', 'question'], 'Negative'),
#  (['rwsurfergirl',
#    'chris',
#    'wallac',
#    'ask',
#    'politican',
#    'financ',
#    'money',
#    'come'],
#   'Negative'),
#  (['rwsurfergirl',
#    'ask',
#    'trump',
#    'legitim',
#    'question',
#    'look',
#    'wallac',
#    "'s",
#    'face',
#    'trump',
#    'nail'],
#   'Positive'),
#  (['supermanhotmal',
#    'dear',
#    'moder',
#    'forgot',
#    'say',
#    'chines',
#    'hack',
#    'start',
#    'bush',
#    'admin',
#    '...'],
#   'Negative'),
#  (['conclus', 'yes', 'hate', 'america', '-trump'], 'Negative'),
#  (['writeintrump',
#    'knew',
#    'war',
#    'iraq',
#    'bad',
#    'idea',
#    'like',
#    'knew',
#    'let',
#    'blind',
#    'guy',
#    'cut',
#    'rand',
#    'paul',
#    "'s",
#    'hair',
#    'bad',
#    'idea'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['senpaulstrauss',
#    'gopdebacleit',
#    "'s",
#    'frighten',
#    '...',
#    'yet',
#    'ca',
#    'look',
#    'away',
#    'sendintheclown'],
#   'Negative'),
#  (['dr', 'carson', '...', 're', 'still', '...', 'neat', '...'], 'Positive'),
#  (['go', 'huck', 'tcot'], 'Positive'),
#  ([], 'Neutral'),
#  ([], 'Negative'),
#  (['rwsurfergirl',
#    'think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'togeth',
#    'expos',
#    'set',
#    'job',
#    'get',
#    'rid',
#    'bush',
#    'rubio',
#    'g'],
#   'Positive'),
#  (['wilberforce91',
#    'one',
#    'favorit',
#    'thing',
#    'mani',
#    'candid',
#    've',
#    'seen',
#    'person',
#    'thank',
#    'libertyu'],
#   'Neutral'),
#  (['donald',
#    'trump',
#    'realli',
#    'nasti',
#    'piec',
#    'work',
#    'hope',
#    'disappear',
#    'quick'],
#   'Negative'),
#  (['daveanthoni', 'chewbacca', 'roar', 'everi', 'would', 'fit', 'right'],
#   'Positive'),
#  (['melissapaige313',
#    'jeb',
#    'brother',
#    'made',
#    'child',
#    'left',
#    'behind',
#    '12',
#    'year'],
#   'Negative'),
#  (['bash', 'hillari', 'night', 'slick', 'willi', 'lovin'], 'Neutral'),
#  ([], 'Negative'),
#  (['guy',
#    'hillbillyvill',
#    'kentucki',
#    'randpaulsen',
#    'point',
#    'fat',
#    'guy',
#    'chrischisti',
#    'huggin',
#    'black',
#    'guy',
#    'lol'],
#   'Negative'),
#  (['rwsurfergirl',
#    'think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'togeth',
#    'expos',
#    'set',
#    'job',
#    'get',
#    'rid',
#    'bush',
#    'rubio',
#    'g'],
#   'Positive'),
#  (['trotalex',
#    'sorri',
#    'edhenri',
#    'offend',
#    'realdonaldtrump',
#    'woman',
#    'offend',
#    'megynkelli',
#    'kellyfil'],
#   'Negative'),
#  (['uptight',
#    'humourless',
#    'mean',
#    'spirit',
#    'pickl',
#    'ars',
#    'bunch',
#    'fool',
#    'without',
#    'redeem',
#    'qualiti',
#    'atheist'],
#   'Negative'),
#  (['chocol', 'chip', 'count', 'substitut', 'drink'], 'Neutral'),
#  ([], 'Neutral'),
#  ([], 'Neutral'),
#  ([], 'Neutral'),
#  (['rwsurfergirl',
#    'american',
#    'peopl',
#    'pick',
#    'next',
#    'presid',
#    'unit',
#    'state'],
#   'Negative'),
#  (['msignoril',
#    'ok',
#    'gave',
#    'us',
#    'lot',
#    'materi',
#    'tomorrow',
#    "'s",
#    'show',
#    '3-6',
#    'et',
#    'sxmprogress'],
#   'Neutral'),
#  ([], 'Neutral'),
#  (['mikewhitmor', 'watch', 'tonight', 'go', 'ask', 'figur'], 'Negative'),
#  (['ballet', 'along', 'candid', 'let', 'peopl', 'decid'], 'Neutral'),
#  ([], 'Neutral'),
#  (['ericbol',
#    'ppl',
#    'say',
#    'realdonaldtrump',
#    'need',
#    'specif',
#    'panel',
#    'give',
#    'type',
#    'question',
#    'oppon',
#    'rig'],
#   'Positive'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  ([], 'Positive'),
#  (['real',
#    'nitty-gritti',
#    'god',
#    'help',
#    'candid',
#    'oh',
#    'pleas',
#    'tell',
#    'us'],
#   'Neutral'),
#  ([], 'Negative'),
#  (['lhlamb', 'megynkelli', "'s", 'extens', 'twitter', 'feed'], 'Negative'),
#  (['mikandynothem',
#    'poor',
#    'peopl',
#    'vote',
#    'democrat',
#    '50',
#    'year',
#    're',
#    'still',
#    'poor',
#    'barkley',
#    'tcot',
#    'pjnet',
#    'ht'],
#   'Negative'),
#  (['sheetalsheth',
#    'stop',
#    'say',
#    'pro-lif',
#    'life',
#    'anti-choic',
#    'seem',
#    'appropri'],
#   'Neutral'),
#  (['rwsurfergirl', 'anyon', 'els', 'want', 'punch', 'chris', 'wallac', 'face'],
#   'Negative'),
#  (['deb_libbi',
#    'half',
#    'republican',
#    'base',
#    'dementia',
#    'probabl',
#    'found',
#    'rivet',
#    'confus',
#    'tv',
#    'w/the',
#    'toaster'],
#   'Negative'),
#  (['rwsurfergirl',
#    'think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'togeth',
#    'expos',
#    'set',
#    'job',
#    'get',
#    'rid',
#    'bush',
#    'rubio',
#    'g'],
#   'Negative'),
#  (['monaeltahawi',
#    'everi',
#    'time',
#    'say',
#    'wedg',
#    'issu',
#    'think',
#    'mean',
#    'wedgi'],
#   'Negative'),
#  (['rwsurfergirl',
#    'chris',
#    'wallac',
#    'ask',
#    'politican',
#    'financ',
#    'money',
#    'come'],
#   'Negative'),
#  (['monaeltahawi',
#    'one',
#    'question',
#    'one',
#    'import',
#    'urgent',
#    'movement',
#    'us',
#    'today',
#    'long',
#    'time',
#    'one',
#    'question'],
#   'Negative'),
#  (['get', 'fill', 'theview', 'ca', 'wait', 'dish'], 'Neutral'),
#  (['larryeld',
#    'trump',
#    'said',
#    'megyn',
#    'ask',
#    'nine',
#    'candid',
#    'plan',
#    'support',
#    'win',
#    'nomin',
#    'gopdebat'],
#   'Positive'),
#  (['rubio', 'mis-stat', 'abort', 'record', 'harm', 'among', 'conserv'],
#   'Negative'),
#  (['rwsurfergirl',
#    "'d",
#    'realli',
#    'like',
#    'see',
#    'long',
#    'candid',
#    'given',
#    'speak',
#    'seem',
#    'fair',
#    'balanc',
#    'gopdebat'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['freedomjames7', 'john', 'kasich', 'rino.'], 'Negative'),
#  (['jimnorton',
#    'point',
#    "'d",
#    'vote',
#    'whoever',
#    'fart',
#    'loudest',
#    'juiciest',
#    'mic',
#    'megankelli'],
#   'Negative'),
#  (['zac', 'still', 'notic', 'unfollow', 'tweet'], 'Neutral'),
#  ([], 'Neutral'),
#  (['kyleraccio',
#    'must',
#    'take',
#    'march',
#    'order',
#    'rnc',
#    'treatment',
#    'cruz',
#    'trump',
#    'carson'],
#   'Negative'),
#  (['rubio',
#    'cruz',
#    'carson',
#    'top',
#    'dawg',
#    'last',
#    'night',
#    "'s",
#    '-walker',
#    'huckabe',
#    'also',
#    'great',
#    'mments.'],
#   'Positive'),
#  (['keithboykin',
#    'wish',
#    'republican',
#    'would',
#    'stop',
#    'say',
#    'militari',
#    'small',
#    'spend',
#    'defens',
#    'everi',
#    'nation',
#    'pl'],
#   'Negative'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  (['rwsurfergirl', 'govchristi', 'hug', 'obama', 'deserv', 'stage', 'tonight'],
#   'Negative'),
#  (['coupl', 'like', 'one', 'megynkelli', 'vote', 'berni', 'sander'],
#   'Negative'),
#  (['donniewahlberg',
#    'democraticdeb',
#    'let',
#    "'s",
#    'hope',
#    'decent',
#    'set',
#    'candid',
#    'vote',
#    "'s"],
#   'Neutral'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['johnkasich',
#    'ohio',
#    'ohio',
#    'gave',
#    'us',
#    'boehner',
#    'thank',
#    'anoth',
#    'rhino'],
#   'Negative'),
#  (['thecrazyon',
#    'wmcinal',
#    'complet',
#    'thrown',
#    'away',
#    'separ',
#    'church',
#    'state'],
#   'Negative'),
#  (['supermanhotmal',
#    'dear',
#    'moder',
#    'forgot',
#    'say',
#    'chines',
#    'hack',
#    'start',
#    'bush',
#    'admin',
#    '...'],
#   'Negative'),
#  (['renomarki',
#    'foxdeb',
#    'absolut',
#    'need',
#    'long',
#    'wind',
#    'question',
#    'know',
#    'topic',
#    'ai',
#    'gotcha',
#    'game'],
#   'Negative'),
#  (['theworstpartofdepressioni',
#    'even',
#    'result',
#    'watch',
#    'gopclowncar',
#    'crash',
#    'make',
#    'smile',
#    '...'],
#   'Negative'),
#  (['rwsurfergirl', 'disappoint', 'conduct', 'fair', 'balanc'], 'Negative'),
#  ([], 'Positive'),
#  (['bettyfckinwhit',
#    '-can',
#    'answer',
#    'direct',
#    'question',
#    '-i',
#    'presid',
#    '-so'],
#   'Neutral'),
#  (['andi', 'moder', 'born', 'peopl'], 'Neutral'),
#  (['ericstonestreet', 'trump', 'cam', 'hand'], 'Neutral'),
#  (['rwsurfergirl', 'candid', 'attack', 'realdonaldtrump', 'stope', 'speak'],
#   'Negative'),
#  (['wait-',
#    'ben',
#    'carson',
#    'actual',
#    'debat',
#    'downtim',
#    'hope',
#    'brought',
#    'book'],
#   'Negative'),
#  (['rwsurfergirl',
#    'break',
#    'brian',
#    'william',
#    'hand',
#    'chris',
#    'christi',
#    'donut',
#    'calm'],
#   'Neutral'),
#  ([], 'Positive'),
#  (['rwsurfergirl', 'govchristi', 'hug', 'obama', 'deserv', 'stage', 'tonight'],
#   'Negative'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  (["'d",
#    'rather',
#    'go',
#    'swim',
#    'pool',
#    'kid',
#    'watch',
#    'll',
#    'get',
#    'analysi',
#    'tytnetwork',
#    'majorityfm',
#    'tomorrow'],
#   'Negative'),
#  (['bettybow', 'davids_brain', 'got', 'ta', 'love', 'logic', 'mind', 'boggl'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['rfs',
#    'support',
#    '73,000',
#    'iowa',
#    'job',
#    '852,000',
#    'across',
#    'us',
#    'candid',
#    'must',
#    'keep',
#    'job',
#    'secur',
#    'go',
#    'forward',
#    'law'],
#   'Neutral'),
#  ([], 'Negative'),
#  ([], 'Positive'),
#  ([], 'Negative'),
#  (['4gen234',
#    'cruz',
#    'littl',
#    'mic',
#    'time',
#    "'s",
#    'made',
#    'good',
#    'use',
#    'time',
#    'cruzcrew'],
#   'Positive'),
#  ([], 'Negative'),
#  (['jamiaw',
#    'purpos',
#    'militari',
#    'kill',
#    'peopl',
#    'break',
#    'thing',
#    '-mike',
#    'huckabe',
#    'kkkorgop'],
#   'Negative'),
#  (['hiphugh',
#    'america',
#    'stupid',
#    'mexico',
#    'realli',
#    'smart',
#    'elect',
#    're',
#    'stupid',
#    '~donald',
#    'trump'],
#   'Negative'),
#  (['jolemo376',
#    'think',
#    'everyth',
#    'could',
#    'derail',
#    'realdonaldtrump',
#    'newsflash',
#    'fail',
#    'megynk'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['trump',
#    'rail',
#    'lose',
#    'nomine',
#    'back',
#    'parti',
#    'ca',
#    'said',
#    'general',
#    'elect',
#    'back',
#    'countri'],
#   'Negative'),
#  (['colorofchang',
#    'let',
#    "'s",
#    'clear',
#    'nerv',
#    'donald',
#    'trump',
#    'hit',
#    'white',
#    'supremaci',
#    'trumphat'],
#   'Negative'),
#  (['felizrobertson', 'still', 'review', 'guyana', 'next', 'elect', 'mind'],
#   'Neutral'),
#  (['megynkelli',
#    'though',
#    'great',
#    'job',
#    'question',
#    'trump',
#    'ass',
#    'realli',
#    'shine',
#    'light'],
#   'Negative'),
#  (['elizabethnd04',
#    'lean',
#    'toward',
#    'carlyfiorina',
#    'get',
#    'kick',
#    '--',
#    'corpor',
#    'woman',
#    'fix',
#    'mess',
#    'll',
#    'see',
#    'dude',
#    'chang'],
#   'Neutral'),
#  (['therosseverett',
#    'guy',
#    'host',
#    'periscop',
#    'stream',
#    "'m",
#    'watch',
#    'took',
#    'bong',
#    'hit',
#    "'s",
#    'sane',
#    'th'],
#   'Neutral'),
#  (['salmasekela',
#    'senat',
#    'cruz',
#    'word',
#    'god',
#    'spit',
#    'tequila',
#    'damn',
#    'megyn',
#    'kelli',
#    'expens',
#    'kind'],
#   'Negative'),
#  (['ericstonestreet', 'trump', 'cam', 'hand'], 'Neutral'),
#  ([], 'Positive'),
#  (['supermanhotmal', 'one', 'crash', 'economi', 'way', 'want', 'thank', 'jeb'],
#   'Negative'),
#  (['mbaratz', 'trump', 'person', 'perform', 'art', 'serious', 'question'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['rep',
#    'r',
#    'like',
#    'minion',
#    'search',
#    '4',
#    'guy',
#    'act',
#    'evil',
#    '2',
#    'make',
#    'boss',
#    'realdonaldtrump',
#    'could',
#    'learn',
#    'movi'],
#   'Negative'),
#  (['tri',
#    'decid',
#    "'s",
#    'earli',
#    'come',
#    'back',
#    'twitter',
#    'fulltim',
#    'gon',
#    'na',
#    'wait',
#    'closer',
#    'elect',
#    'may',
#    'hook'],
#   'Neutral'),
#  (["'s", 'possibl', 'governorperri', 'know', 'go', 'ask', 'question'],
#   'Neutral'),
#  (['johnggalt',
#    'integr',
#    'show',
#    'frank',
#    'luntz',
#    'crap',
#    'say',
#    'abandon',
#    'entir',
#    'network',
#    'makeamericagreatagain',
#    'gopd'],
#   'Negative'),
#  (['shout-out',
#    'megynkelli',
#    'landslid',
#    'winner',
#    'last',
#    'night',
#    "'s",
#    'amaz',
#    'job',
#    'moder',
#    'thing'],
#   'Positive'),
#  (['momasteri',
#    'yes',
#    'trump',
#    'audienc',
#    "'s",
#    'hilari',
#    'call',
#    'women',
#    'fat',
#    'pig',
#    'tell',
#    'get',
#    'knee',
#    'laugh',
#    'aw'],
#   'Negative'),
#  ([], 'Positive'),
#  (['rwsurfergirl',
#    'would',
#    'never',
#    'know',
#    'realdonaldtrump',
#    'frontrunn',
#    'watch'],
#   'Neutral'),
#  (['ericstonestreet', 'trump', 'cam', 'hand'], 'Neutral'),
#  (['brittparker88', 'trump', 'joke', 'hate', 'peopl', 'support'], 'Negative'),
# ...
#   'Positive'),
#  (['rwsurfergirl', 'disappoint', 'conduct', 'fair', 'balanc'], 'Negative'),
#  (['lea_elenaa', 'comedi', 'central'], 'Negative'),
#  (['scrowder',
#    'talk',
#    'thing',
#    'specif',
#    'complet',
#    'massacr',
#    'happen',
#    'hand',
#    'car',
#    'fiorina',
#    'lwc'],
#   'Negative'),
#  (['annietiqu',
#    '116',
#    'minut',
#    'word',
#    'veteran',
#    'even',
#    'utter',
#    'tonight',
#    '2',
#    'hour',
#    'still',
#    'think',
#    'go'],
#   'Negative'),
#  ([], 'Positive'),
#  (['realdonaldtrump',
#    'alot',
#    'speakin',
#    'time',
#    'pretti',
#    'much',
#    'use',
#    'make',
#    'mockeri',
#    'presidenti',
#    'campaign'],
#   'Negative'),
#  (['mozgovaya',
#    '10',
#    'men',
#    'stage',
#    'discuss',
#    'one',
#    'woman',
#    'hillaryclinton'],
#   'Negative'),
#  (['msmallywelch',
#    'worst',
#    'miss',
#    'america',
#    'competit',
#    'ever',
#    'seen',
#    'thejoemos'],
#   'Negative'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['lpnation',
#    'lindseygrahamsc',
#    'send',
#    'troop',
#    'iraq',
#    'afghanistan',
#    'bet',
#    'countri',
#    'next',
#    'war'],
#   'Negative'),
#  (['jonathanfarrel7',
#    'luciabrawley',
#    'christian',
#    'litmus',
#    'test',
#    'let',
#    "'s",
#    'refer',
#    'constitut',
#    'shall',
#    'firstamend',
#    'f'],
#   'Neutral'),
#  (['jillbidenveep',
#    'way',
#    'women',
#    'hold',
#    'month',
#    'funer',
#    'period',
#    'like',
#    'flush',
#    'goldfish',
#    'gopd'],
#   'Negative'),
#  (['high',
#    'school',
#    'crush',
#    'comment',
#    'facebook',
#    'status',
#    "'m",
#    'pretti',
#    'sure',
#    'night',
#    'say',
#    '15yo',
#    'self'],
#   'Positive'),
#  ([], 'Positive'),
#  (['cristela9',
#    "'s",
#    'funni',
#    'even',
#    'latino',
#    'republican',
#    'presidenti',
#    'candid',
#    "'s",
#    'last',
#    'name',
#    'mean',
#    'blond',
#    'marcorubio'],
#   'Neutral'),
#  (['rwsurfergirl',
#    'cherri',
#    'pick',
#    'candid',
#    'jeb',
#    'get',
#    'softbal',
#    'question'],
#   'Negative'),
#  (['democracymatrz',
#    'trump',
#    'admit',
#    'buy',
#    'influenc',
#    'time',
#    'declar',
#    'need',
#    'campaign',
#    'financ',
#    'reform',
#    'gopd'],
#   'Negative'),
#  (['iesrec', 'person', 'gay', 'marriag', 'rand', 'paul', 'gun'], 'Negative'),
#  ([], 'Negative'),
#  (['rwsurfergirl',
#    'trump',
#    'got',
#    'right',
#    'nobodi',
#    'would',
#    'talk',
#    'immigr',
#    'until',
#    'brought'],
#   'Positive'),
#  ([], 'Positive'),
#  (['jordanbartel', 'rodney', 'ocean', 'citi', 'lifeguard', 'presid'],
#   'Neutral'),
#  (['thought', 'watch', 'msnbc', 'last', 'night', 'tmz', 'presidenti'],
#   'Negative'),
#  (['fingers_of_furi',
#    "'s",
#    'fewer',
#    'record',
#    'less',
#    'record',
#    'rand',
#    'paul',
#    'sorri',
#    'palli',
#    'presid',
#    'know',
#    'differ'],
#   'Negative'),
#  ([], 'Negative'),
#  (['rightwingpolok',
#    'face',
#    'time',
#    'megynkelli',
#    'cours',
#    'run',
#    'someth',
#    'need',
#    'to.'],
#   'Negative'),
#  (['rwsurfergirl',
#    "'d",
#    'realli',
#    'like',
#    'see',
#    'long',
#    'candid',
#    'given',
#    'speak',
#    'seem',
#    'fair',
#    'balanc',
#    'gopdebat'],
#   'Negative'),
#  ([], 'Negative'),
#  (['lrihendri',
#    'tedcruz',
#    'presid',
#    'alway',
#    'tell',
#    'truth',
#    'said',
#    'would'],
#   'Positive'),
#  (['summari',
#    'candid',
#    'last',
#    'night',
#    'mouth-breath',
#    'paste-',
#    'poster',
#    'children',
#    'banal',
#    'evil'],
#   'Negative'),
#  (['neurosurgeon', 'stupid'], 'Negative'),
#  (['themattfowl',
#    'mr.',
#    'trump',
#    'next',
#    'question',
#    'pleas',
#    'explain',
#    'pathet',
#    'take',
#    'stone',
#    'cold',
#    'stunner',
#    'htt'],
#   'Negative'),
#  (['rwsurfergirl',
#    'chris',
#    'wallac',
#    'ask',
#    'politican',
#    'financ',
#    'money',
#    'come'],
#   'Neutral'),
#  (['lrihendri',
#    'tedcruz',
#    'presid',
#    'alway',
#    'tell',
#    'truth',
#    'said',
#    'would'],
#   'Positive'),
#  (['rwsurfergirl', 'anyon', 'els', 'want', 'punch', 'chris', 'wallac', 'face'],
#   'Negative'),
#  ([], 'Negative'),
#  (['weeklystandard',
#    'jaycosttw',
#    'realdonaldtrump',
#    'attempt',
#    'put',
#    'hilari',
#    'desper',
#    'trump2016'],
#   'Negative'),
#  (['chroniclemik',
#    'walker',
#    'chang',
#    'postn',
#    'immig',
#    'need',
#    'secur',
#    'border',
#    'met',
#    'txgovabbott',
#    'know',
#    'txlege',
#    'txpolit'],
#   'Neutral'),
#  (['jamiaw', 'realdonaldtrump', 'see', 'previous', 'tweet'], 'Negative'),
#  ([], 'Positive'),
#  ([], 'Negative'),
#  (['rwsurfergirl',
#    'wonder',
#    '--',
#    'get',
#    'rid',
#    'trump',
#    'paul',
#    'cruz',
#    'carson'],
#   'Negative'),
#  (['ok',
#    'question',
#    'irrelev',
#    'ppl',
#    'concern',
#    'feel',
#    'get',
#    'hurt',
#    'make',
#    'america',
#    'great'],
#   'Negative'),
#  (['theladygrantham', 'donald', 'trump', 'dear', "'s", 'middl', 'class'],
#   'Negative'),
#  (['drunk', '2016'], 'Negative'),
#  (["'m", 'ai', 'bout', 'dem', 'big', 'ol', 'sloppi', 'abort', 'nuh-uh'],
#   'Negative'),
#  ([], 'Positive'),
#  ([], 'Neutral'),
#  (['louispeitzman',
#    "'m",
#    'answer',
#    'question',
#    'stori',
#    'hardship',
#    'parent',
#    'face'],
#   'Neutral'),
#  (['trump', 'adam', 'sandler', 'movi', 'makeamericafartagain'], 'Negative'),
#  (['fxnopinion', 'foxnewspolit', 'good', 'job'], 'Positive'),
#  (['danmoore755',
#    'one',
#    'trust',
#    'randpaul',
#    'randpaul',
#    'gop2016',
#    'usa',
#    'merica'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['lrihendri',
#    'tedcruz',
#    'presid',
#    'alway',
#    'tell',
#    'truth',
#    'said',
#    'would'],
#   'Positive'),
#  (['makinh15tori', 'lol', 'trump'], 'Negative'),
#  (['rwsurfergirl',
#    'ask',
#    'trump',
#    'legitim',
#    'question',
#    'look',
#    'wallac',
#    "'s",
#    'face',
#    'trump',
#    'nail'],
#   'Positive'),
#  (['rwsurfergirl',
#    'american',
#    'peopl',
#    'pick',
#    'next',
#    'presid',
#    'unit',
#    'state'],
#   'Negative'),
#  (['rwsurfergirl', 'tedcruz', 'realdonaldtrump', 'need', 'take', 'control'],
#   'Positive'),
#  (['cnn',
#    'cnnpolit',
#    '8',
#    'thing',
#    'take',
#    'away',
#    'one',
#    'bencarson',
#    "'s",
#    'shame'],
#   'Negative'),
#  (['foxnewsl',
#    'serious',
#    'tone',
#    'deaf',
#    'deliber',
#    'clue',
#    'blow',
#    'back',
#    'megynkelli',
#    "'m",
#    'fan'],
#   'Negative'),
#  (['basic', 'post', 'poll', 'busi', 'candid', 'beat', 'polit', 'candid'],
#   'Neutral'),
#  ([], 'Neutral'),
#  (['rwsurfergirl', 'jeb', 'bush', 'remind', 'elev', 'music', 'hear', 'listen'],
#   'Negative'),
#  (['last',
#    'night',
#    "'s",
#    'presidenti',
#    'debat',
#    'rich',
#    'corpor',
#    'ceo',
#    "'s",
#    'run',
#    'govern',
#    'anyway',
#    'transpar'],
#   'Negative'),
#  (['auditthemedia',
#    'us',
#    'could',
#    'stand',
#    'learn',
#    'lot',
#    'gedeb',
#    'format',
#    'bbc',
#    'much',
#    'better',
#    'job'],
#   'Negative'),
#  ([], 'Negative'),
#  (['go',
#    'ask',
#    'trump2016',
#    'polici',
#    'question',
#    'charact',
#    'smear',
#    'makeamericagreatagain'],
#   'Negative'),
#  (['rwsurfergirl',
#    'big',
#    'problem',
#    'face',
#    'democrat',
#    'get',
#    'hillari',
#    'sober',
#    'long',
#    'enough',
#    'toot'],
#   'Neutral'),
#  (['keep',
#    'congratul',
#    'great',
#    'job',
#    'media',
#    'use',
#    'power',
#    'slant',
#    'usual',
#    'real',
#    'media',
#    'real',
#    'educ'],
#   'Negative'),
#  (['gamma_ray239',
#    'disappoint',
#    'treat',
#    'differ',
#    'cnn',
#    'would',
#    'dictat',
#    'vs',
#    'repo'],
#   'Negative'),
#  ([], 'Neutral'),
#  ([], 'Positive'),
#  (['billhemm',
#    'marthamaccallum',
#    'kudo',
#    'bill',
#    'martha',
#    'excel',
#    'moder',
#    'prime',
#    'time',
#    'team',
#    'aw',
#    'comparison'],
#   'Positive'),
#  (['rwsurfergirl', 'thank', 're', 'rais', 'realdonaldtrump', "'s", 'rate'],
#   'Positive'),
#  (['rwsurfergirl',
#    'ask',
#    'trump',
#    'legitim',
#    'question',
#    'look',
#    'wallac',
#    "'s",
#    'face',
#    'trump',
#    'nail'],
#   'Positive'),
#  (['fix', 'new', 'jersey', 'first', 'chrischristi'], 'Negative'),
#  ([], 'Positive'),
#  ([], 'Neutral'),
#  (['rwsurfergirl', 'candid', 'attack', 'realdonaldtrump', 'stope', 'speak'],
#   'Positive'),
#  ([], 'Negative'),
#  (['obamaagenda', 'baracksback', 'um..dur', 'derp'], 'Neutral'),
#  ([], 'Negative'),
#  (['rwsurfergirl',
#    'american',
#    'peopl',
#    'pick',
#    'next',
#    'presid',
#    'unit',
#    'state'],
#   'Negative'),
#  (['lot',
#    'candid',
#    'defend',
#    'plannedparenthood',
#    'never',
#    'mention',
#    'take',
#    'away',
#    'rapist',
#    "'s",
#    'parent',
#    'right'],
#   'Negative'),
#  ([], 'Positive'),
#  (['lol', 'bencarson', 'serious', 'answer', 'question'], 'Negative'),
#  (['stephenstephan', 'rubio', 'basic', 'life', 'sacr', 'prolif'], 'Positive'),
#  ([], 'Neutral'),
#  (['rwsurfergirl',
#    'think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'togeth',
#    'expos',
#    'set',
#    'job',
#    'get',
#    'rid',
#    'bush',
#    'rubio',
#    'g'],
#   'Neutral'),
#  (['nathanhaynes24',
#    'last',
#    'night',
#    "'s",
#    'realbencarson',
#    'govmikehuckabe',
#    'emerg',
#    'top',
#    'two'],
#   'Positive'),
#  ([], 'Neutral'),
#  (['ljcambria',
#    'realdonaldtrump',
#    'forget',
#    'vote',
#    'especislli',
#    'go',
#    'independ',
#    'lulz',
#    'huckster',
#    'rnc'],
#   'Positive'),
#  (['anergo_teach', 'serious', 'trump', 'danger', 'whole', 'world'],
#   'Negative'),
#  (['trump', 're', 'avoid', 'question'], 'Negative'),
#  (['randpaul', 'got', 'clock', 'clean', 'last', 'night', 'bye', 'bye'],
#   'Negative'),
#  ([], 'Negative'),
#  (['oh', 'understand', 'movi', 'idiocraci', 'actual', 'documentari'],
#   'Negative'),
#  (['donniewahlberg', 'enjoy', 'look', 'forward', 'democraticdeb', 'next'],
#   'Positive'),
#  ([], 'Neutral'),
#  (['rubio', 'hard', 'keep', 'script', '...'], 'Negative'),
#  ([], 'Negative'),
#  (['berinszoka',
#    'rand',
#    'want',
#    'gun',
#    'marriag',
#    'regist',
#    'washingtonagre',
#    '...',
#    'know',
#    'marriag',
#    'regist',
#    'state',
#    'r'],
#   'Negative'),
#  ([], 'Negative'),
#  (['themadston',
#    'bum',
#    'get',
#    'watch',
#    'singl',
#    'candid',
#    'flounder',
#    'climat',
#    'chang'],
#   'Negative'),
#  (['rwsurfergirl',
#    'think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'togeth',
#    'expos',
#    'set',
#    'job',
#    'get',
#    'rid',
#    'bush',
#    'rubio',
#    'g'],
#   'Negative'),
#  ([], 'Neutral'),
#  (['goddessjaz',
#    'discuss',
#    'racist',
#    'polic',
#    'violenc',
#    'finish',
#    'type',
#    'tweet',
#    'kkkorgop'],
#   'Negative'),
#  (['promis', 'free', 'pizza', 'everi', 'friday', 'homework', 'ever'],
#   'Neutral'),
#  (['typic',
#    'plan',
#    'make',
#    'life',
#    'better',
#    'plenti',
#    'increas',
#    'pain',
#    'miseri',
#    'p2'],
#   'Negative'),
#  (['jeb',
#    'bush',
#    'rand',
#    'paul',
#    'one',
#    'see',
#    'odd',
#    'rise',
#    'though',
#    'bush',
#    "'s",
#    'price',
#    'trim',
#    'end'],
#   'Positive'),
#  ([], 'Negative'),
#  (['llamo',
#    'sprightlymag',
#    'consid',
#    'ca',
#    'blame',
#    'might',
#    'need',
#    'join',
#    'thank'],
#   'Negative'),
#  ([], 'Neutral'),
#  ([], 'Negative'),
#  ([], 'Neutral'),
#  (['reassur',
#    'affin',
#    'republican',
#    'kurdish',
#    'milit',
#    'elect',
#    'presid',
#    'jindal',
#    'said',
#    'll',
#    'arm',
#    'kurd',
#    'i.e',
#    'pyd'],
#   'Positive'),
#  (['monaeltahawi',
#    'serious',
#    'voter',
#    'think',
#    'god',
#    'talk',
#    'presidenti',
#    'candid',
#    'christianbrotherhood'],
#   'Negative'),
#  (['amymek',
#    'freedom',
#    'free',
#    'must',
#    'fight',
#    'everi',
#    'day',
#    'ben',
#    'carson'],
#   'Neutral'),
#  ([], 'Positive'),
#  (['supermanhotmal',
#    'donald',
#    'trump',
#    'never',
#    'gone',
#    'bankrupt',
#    '...',
#    'realli',
#    'donald',
#    'realli',
#    'donald',
#    'fuck',
#    'liar',
#    '...'],
#   'Negative'),
#  (['laural4705',
#    'opinion',
#    'cruz',
#    'best',
#    'close',
#    'remark',
#    'explain',
#    'plan',
#    'vision',
#    'america',
#    'passion',
#    'de'],
#   'Positive'),
#  (["'m", 'still', 'stare', 'megynkelli', 'bae'], 'Positive'),
#  (['jamiaw',
#    'purpos',
#    'militari',
#    'kill',
#    'peopl',
#    'break',
#    'thing',
#    '-mike',
#    'huckabe',
#    'kkkorgop'],
#   'Neutral'),
#  (['bucksexton',
#    'hey',
#    'jeb',
#    'earn',
#    'legal',
#    'status',
#    'amnesti',
#    've',
#    'play',
#    'game'],
#   'Neutral'),
#  (['rwsurfergirl',
#    'think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'togeth',
#    'expos',
#    'set',
#    'job',
#    'get',
#    'rid',
#    'bush',
#    'rubio',
#    'g'],
#   'Positive'),
#  ([], 'Neutral'),
#  (['dynamodream',
#    'realdonaldtrump',
#    'megynkelli',
#    'megyn',
#    'kelli',
#    'also',
#    'roll',
#    'eye',
#    'watch',
#    'rate',
#    'drop',
#    'drastic'],
#   'Neutral'),
#  (['old',
#    'white',
#    'rich',
#    'conserv',
#    'dude',
#    'parad',
#    "'s",
#    'childhood',
#    'nightmar',
#    'mine'],
#   'Negative'),
#  ([], 'Negative'),
#  (['huckabe', 'propos', 'pimp', 'tax'], 'Neutral'),
#  (['candid', 'claim', 'speak', 'direct', 'god', '...'], 'Neutral'),
#  (['maddow',
#    'everyon',
#    'watch',
#    'debatewithberni',
#    '--',
#    'senschum',
#    'fri',
#    'night',
#    'dump',
#    'thur',
#    'irand'],
#   'Neutral'),
#  ([], 'Neutral'),
#  (['bruneski',
#    'upstair',
#    'put',
#    'kid',
#    'bed',
#    'mani',
#    'question',
#    'climat',
#    'chang',
#    'miss',
#    'gopclowncar'],
#   'Neutral'),
#  (['salmasekela', 'kasich', 'awar', "'s", 'make', 'sens'], 'Positive'),
#  ([], 'Neutral'),
#  (['republican',
#    'primari',
#    "'s",
#    'think',
#    'govern',
#    'new',
#    'realiti',
#    'show',
#    'debatewithberni'],
#   'Negative'),
#  (['although',
#    'occasion',
#    'dick',
#    'realdonaldtrump',
#    'sure',
#    'know',
#    'keep',
#    'polit',
#    'debat',
#    'aliv',
#    'excit'],
#   'Negative'),
#  (['take',
#    'care',
#    'peopl',
#    've',
#    'work',
#    'hard',
#    'play',
#    'rule',
#    'wrong',
#    'christi',
#    're',
#    'pay',
#    'nj',
#    'pension'],
#   'Negative'),
#  ([], 'Negative'),
#  ([], 'Positive'),
#  (['rwsurfergirl', 'megynkelli', 'pose', 'adult', 'pictures.should', 'bring'],
#   'Negative'),
#  (['mzdivah67',
#    'watch',
#    'seem',
#    'like',
#    'blacklivesdontmatt',
#    'bash',
#    'pbo',
#    'fail',
#    'polici',
#    'impo'],
#   'Negative'),
#  (['rwsurfergirl', 'disappoint', 'conduct', 'fair', 'balanc'], 'Negative'),
#  (['rwsurfergirl',
#    'think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'togeth',
#    'expos',
#    'set',
#    'job',
#    'get',
#    'rid',
#    'bush',
#    'rubio',
#    'g'],
#   'Positive'),
#  ([], 'Neutral'),
#  (['cat_1012000',
#    'thank',
#    'foxtv',
#    'hold',
#    'million',
#    'peopl',
#    'know',
#    're',
#    'better',
#    'balanc',
#    'msn',
#    'abc',
#    'cbs',
#    '...'],
#   'Negative'),
#  (['salmasekela',
#    'senat',
#    'cruz',
#    'word',
#    'god',
#    'spit',
#    'tequila',
#    'damn',
#    'megyn',
#    'kelli',
#    'expens',
#    'kind'],
#   'Negative'),
#  (['leasavoy',
#    'overal',
#    'view',
#    '...',
#    'stay',
#    'home',
#    'work',
#    'candid',
#    'choic',
#    'chang',
#    '1',
#    'iota.',
#    'cruzcrew'],
#   'Negative'),
#  (['danmoore755',
#    'republican',
#    'candid',
#    'close',
#    'love',
#    'god',
#    'democrat',
#    'would',
#    'never',
#    '...',
#    'sayin',
#    'gop2016',
#    'gopd'],
#   'Negative'),
#  ([], 'Positive'),
#  (['lrihendri',
#    'tedcruz',
#    'presid',
#    'alway',
#    'tell',
#    'truth',
#    'said',
#    'would'],
#   'Positive'),
#  (['piti', 'parti'], 'Negative'),
#  ([], 'Negative'),
#  (['tedcruz', 'get', 'vote', 'tonight', 'dr.', 'carson', 'close', 'second'],
#   'Positive'),
#  (['say',
#    'school',
#    'local',
#    'state',
#    'run',
#    'keep',
#    'receiv',
#    'fed',
#    'money',
#    'matter'],
#   'Negative'),
#  (['rwsurfergirl',
#    'tonight',
#    'learn',
#    'govchristi',
#    'think',
#    'remov',
#    'civil',
#    'right',
#    'fight',
#    'terror'],
#   'Negative'),
#  (['ira',
#    'point',
#    'talk',
#    '9/11',
#    'gone',
#    'longer',
#    'pretti',
#    'littl',
#    'liar'],
#   'Negative'),
#  (['ericstonestreet', 'trump', 'cam', 'hand'], 'Negative'),
#  ([], 'Negative'),
#  ([], 'Negative'),
#  ([], 'Positive'),
#  (['rumpfshak',
#    'never',
#    'gone',
#    'bankrupt',
#    'say',
#    'trump',
#    'multipl',
#    'busi',
#    'went',
#    'thru',
#    'bankruptci',
#    'screw',
#    'creditor'],
#   'Negative'),
#  (['chump/trump',
#    'ignor',
#    'presidenti',
#    'class',
#    'money',
#    'clear',
#    'money',
#    'ca',
#    'buy',
#    'u',
#    'class',
#    'skip',
#    'digniti'],
#   'Negative'),
#  ...]

# %%
#build a list of tuples (BOW_dict, label) for all tweets
train_bow = [(build_bow_features(tuple[0]), tuple[1]) for tuple in train]
test_bow = [(build_bow_features(tuple[0]), tuple[1]) for tuple in test]

# %%
print(len(train_bow),len(test_bow))
# Out:
# 12483 1388

# %%
train_bow
# Out:
# [({}, 'Negative'),
#  ({'jjauthor': True,
#    'polici': True,
#    'barack': True,
#    'obama': True,
#    'manag': True,
#    'provid': True,
#    'neither': True,
#    'peac': True,
#    'prosper': True,
#    'realdonaldtrump': True,
#    'tedcruz': True},
#   'Negative'),
#  ({'dougstanhop': True,
#    'hillari': True,
#    'come': True,
#    'everi': True,
#    'angl': True,
#    'strike': True,
#    'ground': True,
#    'pound': True,
#    'arm': True,
#    'bar': True,
#    "'s": True,
#    'unstopp': True,
#    'think': True,
#    'wr': True},
#   'Neutral'),
#  ({'lrihendri': True,
#    'tedcruz': True,
#    'presid': True,
#    'alway': True,
#    'tell': True,
#    'truth': True,
#    'said': True,
#    'would': True},
#   'Neutral'),
#  ({'lukewearechang': True,
#    'evid': True,
#    'hack': True,
#    'talk': True,
#    'come': True,
#    'syria': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'tatianak': True,
#    'fact': True,
#    'wasnt': True,
#    'even': True,
#    'liter': True,
#    'pundit': True,
#    'say': True,
#    'rememb': True,
#    'time': True,
#    'said': True,
#    'x': True,
#    'bish': True,
#    'bout': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'rwsurfergirl': True,
#    'thank': True,
#    're': True,
#    'rais': True,
#    'realdonaldtrump': True,
#    "'s": True,
#    'rate': True},
#   'Negative'),
#  ({'order': True,
#    'cruz': True,
#    'rubio': True,
#    'carson': True,
#    'walker': True,
#    'think': True,
#    'rand': True,
#    'okay': True,
#    'trump': True,
#    'hurt': True,
#    'jeb': True,
#    'much': True},
#   'Positive'),
#  ({'fieldnegro': True,
#    'happiest': True,
#    'person': True,
#    'america': True,
#    'today': True,
#    'watch': True,
#    'debat': True,
#    'hrc': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'wo': True,
#    'admit': True,
#    'republican': True,
#    'leader': True,
#    'right': True,
#    'mean': True,
#    'realdonaldtrump': True,
#    'double-digit': True,
#    'lead': True,
#    'gopd': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Positive'),
#  ({'rwsurfergirl': True,
#    'thank': True,
#    're': True,
#    'rais': True,
#    'realdonaldtrump': True,
#    "'s": True,
#    'rate': True},
#   'Positive'),
#  ({'chaunceydevega': True,
#    'kasich': True,
#    'enough': True,
#    'sociopath': True,
#    'kill': True,
#    'useless': True,
#    'eater': True,
#    'type': True,
#    'nomine': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'smethani': True,
#    'sure': True,
#    'god': True,
#    'told': True,
#    'run': True,
#    'tooth': True,
#    'fairi': True,
#    'agre': True,
#    'teletubbi': True,
#    'vote': True,
#    'yes': True},
#   'Negative'),
#  ({'monaeltahawi': True,
#    'perhap': True,
#    'll': True,
#    'talk': True,
#    'racism': True,
#    're': True,
#    'ask': True,
#    'god': True,
#    'told': True,
#    'blackliveematt': True},
#   'Negative'),
#  ({'polit': True, 'correct': True, 'noth': True, 'bad': True, 'manner': True},
#   'Neutral'),
#  ({'donniewahlberg': True,
#    'enjoy': True,
#    'look': True,
#    'forward': True,
#    'democraticdeb': True,
#    'next': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'watch': True, 'nanosecond': True}, 'Negative'),
#  ({}, 'Negative'),
#  ({'mariacka': True,
#    'ask': True,
#    'tedcruz': True,
#    'two': True,
#    'question': True},
#   'Negative'),
#  ({'lot': True,
#    'creepi': True,
#    'plain': True,
#    'cloth': True,
#    'cop': True,
#    'bodi': True,
#    'men': True,
#    'protect': True,
#    'scottwalk': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    "'d": True,
#    'realli': True,
#    'like': True,
#    'see': True,
#    'long': True,
#    'candid': True,
#    'given': True,
#    'speak': True,
#    'seem': True,
#    'fair': True,
#    'balanc': True,
#    'gopdebat': True},
#   'Negative'),
#  ({'bettyfckinwhit': True,
#    '-can': True,
#    'answer': True,
#    'direct': True,
#    'question': True,
#    '-i': True,
#    'presid': True,
#    '-so': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'trump': True,
#    'said': True,
#    'jebbush': True,
#    'true': True,
#    'gentleman': True,
#    'start': True,
#    'violent': True,
#    '69ing': True},
#   'Negative'),
#  ({'trump': True,
#    'done': True,
#    'last': True,
#    'night': True,
#    'end': True,
#    'stori': True},
#   'Negative'),
#  ({'foxnewspolit': True,
#    'realli': True,
#    'look': True,
#    'candid': True,
#    'attack': True,
#    'trump': True,
#    'notfair': True,
#    'notbalanc': True},
#   'Negative'),
#  ({'hadiyah': True,
#    'let': True,
#    'see': True,
#    'jeb': True,
#    'bush': True,
#    'tri': True,
#    'solv': True,
#    'common': True,
#    'core': True,
#    'math': True,
#    'problem': True},
#   'Negative'),
#  ({'writeintrump': True,
#    'hey': True,
#    'megan': True,
#    'kelli': True,
#    'ask': True,
#    'osbourn': True,
#    'attack': True,
#    'week': True,
#    'work': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'big': True,
#    'problem': True,
#    'face': True,
#    'democrat': True,
#    'get': True,
#    'hillari': True,
#    'sober': True,
#    'long': True,
#    'enough': True,
#    'toot': True},
#   'Neutral'),
#  ({'like': True,
#    'sophmor': True,
#    'bicker': True,
#    'back': True,
#    'forth': True,
#    'candid': True,
#    'presidenti': True,
#    'outnumberedfnc': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'break': True,
#    'brian': True,
#    'william': True,
#    'hand': True,
#    'chris': True,
#    'christi': True,
#    'donut': True,
#    'calm': True},
#   'Neutral'),
#  ({'ladysandersfarm': True,
#    'bush': True,
#    'lame': True,
#    'way': True,
#    'around': True},
#   'Negative'),
#  ({'tinaissa': True, 'think': True, 'megyn': True, 'kellli': True},
#   'Negative'),
#  ({'hey': True,
#    'plan': True,
#    'give': True,
#    'tedcruz': True,
#    'chanc': True,
#    'speak': True,
#    're': True,
#    'tri': True,
#    'margin': True,
#    'daili': True,
#    'cycl': True},
#   'Negative'),
#  ({'leapoverthat': True,
#    'noth': True,
#    'realli': True,
#    'refresh': True,
#    'hear': True,
#    'top': True,
#    '1': True,
#    'instruct': True,
#    'civilian': True,
#    'handl': True,
#    'cope': True,
#    'poverti': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Positive'),
#  ({'trump': True,
#    'answer': True,
#    'megynkelli': True,
#    'question': True,
#    'insult': True,
#    'women': True,
#    'ca': True,
#    'wait': True,
#    'til': True,
#    'start': True,
#    'rondarousey': True},
#   'Neutral'),
#  ({'think': True,
#    'donald': True,
#    'hillari': True,
#    "'s": True,
#    'biggest': True,
#    'paid': True,
#    'friend': True,
#    'lessgovmorefun': True},
#   'Negative'),
#  ({'quit': True,
#    'frank': True,
#    'disturb': True,
#    'thing': True,
#    'last': True,
#    'night': True,
#    "'s": True,
#    'look': True,
#    'terribl': True,
#    'adobo': True,
#    'ting': True,
#    'tan': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'trump': True,
#    'victim': True,
#    'use': True,
#    'law': True,
#    'like': True,
#    'hundr': True,
#    'peopl': True},
#   'Negative'),
#  ({'watch': True,
#    'seem': True,
#    'like': True,
#    'blacklivesdontmatt': True,
#    'bash': True,
#    'pbo': True,
#    'fail': True,
#    'polici': True,
#    'import': True},
#   'Negative'),
#  ({'love': True,
#    'scottwalk': True,
#    'ask': True,
#    'rhetor': True,
#    'hillari': True,
#    'clinton': True,
#    'go': True,
#    'lectur': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'obvious': True,
#    'tri': True,
#    'influenc': True,
#    'makeup': True,
#    'republican': True,
#    'field': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'disappoint': True,
#    'conduct': True,
#    'fair': True,
#    'balanc': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'supermanhotmal': True,
#    'pres': True,
#    'obama': True,
#    'brain': True,
#    'littl': True,
#    'toe': True,
#    'total': True,
#    'fuck': True,
#    'idiot': True,
#    'whole': True,
#    'famili': True,
#    'combin': True},
#   'Negative'),
#  ({'govmikehuckabe': True,
#    'clue': True,
#    'kind': True,
#    'hard': True,
#    'work': True,
#    'commit': True,
#    'everi': True,
#    'member': True,
#    'militari': True,
#    'make': True,
#    'deptofdefens': True},
#   'Negative'),
#  ({'bnlieb': True,
#    'smear': True,
#    'oppon': True,
#    'whitegenocid': True,
#    'nazi': True,
#    'libzi': True,
#    'pervert': True,
#    'memoryoftheholocaust': True,
#    'weapon': True,
#    'guarante': True,
#    'genoci': True},
#   'Negative'),
#  ({'ericstonestreet': True, 'trump': True, 'cam': True, 'hand': True},
#   'Negative'),
#  ({'gretchencarlson': True,
#    'hillari': True,
#    'clinton': True,
#    'lie': True,
#    'benghazi': True,
#    'job': True,
#    'need': True,
#    'help': True,
#    'carlyfiorina': True,
#    'foxnewspolit': True},
#   'Neutral'),
#  ({'marisol_bello': True,
#    'wht': True,
#    'miss': True,
#    'journo': True,
#    'concern': True,
#    'abt': True,
#    'poverti': True,
#    'r': True,
#    'voters/candid': True,
#    'expect': True,
#    '2': True,
#    'talkpoverti': True},
#   'Negative'),
#  ({'guy': True,
#    'like': True,
#    'go': True,
#    'run': True,
#    'presid': True,
#    'republican': True,
#    'better': True,
#    'seat': True,
#    'meguylikem': True,
#    'republicandeb': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'obvious': True,
#    'tri': True,
#    'influenc': True,
#    'makeup': True,
#    'republican': True,
#    'field': True},
#   'Negative'),
#  ({'senatorshoshana': True,
#    'moment': True,
#    'randpaul': True,
#    'spoke': True,
#    'key': True,
#    'christi': True,
#    'could': True,
#    'disagre': True,
#    'add': True,
#    'tweak': True,
#    'bit': True,
#    "'s": True,
#    'rand': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'lizzwinstead': True,
#    'abl': True,
#    'call': True,
#    'women': True,
#    'pig': True,
#    'whore': True,
#    'take': True,
#    'america': True,
#    'back': True},
#   'Negative'),
#  ({'moder': True,
#    "'s": True,
#    'job': True,
#    'ask': True,
#    'tough': True,
#    'question': True,
#    'attack': True,
#    'candid': True,
#    'play': True,
#    'victim': True,
#    'megynkelli': True},
#   'Negative'),
#  ({'fergie_spud': True,
#    'would': True,
#    'far': True,
#    'better': True,
#    'job': True,
#    'frank_underwood': True,
#    'kevinspacey': True},
#   'Neutral'),
#  ({}, 'Negative'),
#  ({'open': True,
#    'csi': True,
#    'miami': True,
#    'support': True,
#    'trump': True,
#    'appar': True},
#   'Neutral'),
#  ({'jamiaw': True,
#    'purpos': True,
#    'militari': True,
#    'kill': True,
#    'peopl': True,
#    'break': True,
#    'thing': True,
#    '-mike': True,
#    'huckabe': True,
#    'kkkorgop': True},
#   'Negative'),
#  ({'supermanhotmal': True,
#    'dear': True,
#    'senat': True,
#    'rubio': True,
#    'god': True,
#    'noth': True,
#    'republican': True,
#    'parti': True,
#    '...': True,
#    'get': True,
#    'right': True},
#   'Negative'),
#  ({'jamiaw': True,
#    'purpos': True,
#    'militari': True,
#    'kill': True,
#    'peopl': True,
#    'break': True,
#    'thing': True,
#    '-mike': True,
#    'huckabe': True,
#    'kkkorgop': True},
#   'Neutral'),
#  ({'keep': True,
#    'go': True,
#    'like': True,
#    'this-': True,
#    'wo': True,
#    'even': True,
#    'bother': True,
#    'poll': True,
#    'reinc': True,
#    "'s": True,
#    'promis': True,
#    'trumpcruz2016': True},
#   'Negative'),
#  ({'donniewahlberg': True,
#    'enjoy': True,
#    'look': True,
#    'forward': True,
#    'democraticdeb': True,
#    'next': True},
#   'Positive'),
#  ({'pres': True,
#    'obama': True,
#    'brain': True,
#    'littl': True,
#    'toe': True,
#    'total': True,
#    'fuck': True,
#    'idiot': True,
#    'whole': True,
#    'famili': True,
#    'combin': True,
#    'boom': True},
#   'Negative'),
#  ({'politicorog': True,
#    'trump': True,
#    'report': True,
#    'general': True,
#    'dishonest': True,
#    'lot': True},
#   'Neutral'),
#  ({}, 'Neutral'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Negative'),
#  ({'housecracka': True,
#    'huge': True,
#    'differ': True,
#    'battl': True,
#    'foe': True,
#    'walk': True,
#    'blue': True,
#    'ambush': True,
#    'megynkellydebatequest': True},
#   'Negative'),
#  ({'carlyfiorina': True,
#    'one': True,
#    'pois': True,
#    'grace': True,
#    'determin': True,
#    'woman': True,
#    'get': True,
#    'behind': True,
#    'day': True},
#   'Positive'),
#  ({'wilberforce91': True,
#    'one': True,
#    'favorit': True,
#    'thing': True,
#    'mani': True,
#    'candid': True,
#    've': True,
#    'seen': True,
#    'person': True,
#    'thank': True,
#    'libertyu': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({'writeintrump': True,
#    "'m": True,
#    'go': True,
#    'take': True,
#    'long': True,
#    'way': True,
#    'bridg': True,
#    'close': True,
#    'well': True,
#    'play': True,
#    'chris': True,
#    'christi': True,
#    'p': True},
#   'Neutral'),
#  ({'watch': True,
#    'megynkelli': True,
#    'ask': True,
#    'trump': True,
#    'sexist': True,
#    'stuff': True,
#    'could': True,
#    'easi': True,
#    'crowd': True,
#    'roar': True,
#    'misogyni': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'american': True,
#    'peopl': True,
#    'pick': True,
#    'next': True,
#    'presid': True,
#    'unit': True,
#    'state': True},
#   'Negative'),
#  ({'ivankatrump': True,
#    'call': True,
#    'father': True,
#    'comment': True,
#    'rosi': True,
#    'suppos': True,
#    'listen': True,
#    'shame': True,
#    've': True,
#    'got': True,
#    'daughter': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'palmaceiahome1': True,
#    'goal': True,
#    'last': True,
#    'night': True,
#    'take': True,
#    'trump': True,
#    'pave': True,
#    'way': True,
#    'rino': True,
#    'like': True,
#    'bush': True,
#    'kasich': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'debat': True,
#    'rais': True,
#    'realdonaldtrump': True,
#    "'s": True,
#    'rate': True,
#    'afraid': True,
#    'trump': True,
#    'show': True},
#   'Positive'),
#  ({'msgoddessris': True,
#    'never': True,
#    'gone': True,
#    'bankrupt': True,
#    'wtf': True,
#    'read': True,
#    'lip': True,
#    'trump': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'candid': True,
#    'attack': True,
#    'realdonaldtrump': True,
#    'stope': True,
#    'speak': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'chrisshurley': True,
#    'outnumberedfnc': True,
#    'charleskrauthamm': True,
#    'fossil': True,
#    'love': True,
#    'megynkelli': True,
#    "'s": True,
#    'mind': True,
#    'realdonaldtrump': True,
#    'fro': True},
#   'Neutral'),
#  ({'cruz': True, 'complet': True, 'ignor': True}, 'Negative'),
#  ({'horribl': True,
#    'first': True,
#    'question': True,
#    'realdonaldtrump': True,
#    'unprofession': True,
#    'design': True,
#    'put': True,
#    'bad': True,
#    'mood': True,
#    'destroy': True},
#   'Negative'),
#  ({'markmelin': True,
#    'could': True,
#    'watch': True,
#    'exampl': True,
#    'argu': True,
#    'broadcast': True,
#    'anyway': True,
#    'public': True,
#    'servic': True,
#    'ridicul': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'megynkelli': True,
#    'say': True,
#    'sake': True,
#    'argument': True,
#    'letmeplaythedevilsadvoc': True,
#    'mean': True,
#    'one': True,
#    'better': True,
#    'kellyfil': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'loudobbsnew': True, 'dobb': True, 'like': True, 'govmikehuckabe': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'focus': True,
#    'group': True,
#    'post': True,
#    'liber': True,
#    'eyesor': True,
#    'frankluntz': True,
#    'disgrac': True,
#    'justic': True,
#    'wasteoftim': True},
#   'Negative'),
#  ({'minasmith64': True,
#    're': True,
#    'behav': True,
#    'like': True,
#    'dumb': True,
#    'feminist': True,
#    'blame': True,
#    'misogyni': True,
#    'person': True,
#    "'s": True,
#    'respons': True,
#    'unwarr': True,
#    'attack': True,
#    'gopdeba': True},
#   'Negative'),
#  ({'aw': True,
#    'jebbush': True,
#    'tote': True,
#    'come': True,
#    'later': True,
#    'good': True,
#    'cri': True,
#    'gotchu': True,
#    'boo': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'ppact': True,
#    'sell': True,
#    'babi': True,
#    'part': True,
#    'profit': True,
#    'whatev': True,
#    'want': True,
#    'call': True,
#    'trump': True,
#    'ca': True,
#    'woman': True,
#    'slob': True,
#    'pc': True,
#    'trump2016': True},
#   'Positive'),
#  ({'think': True,
#    'trump': True,
#    'moder': True,
#    'would': True,
#    'good': True,
#    'role': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'govchristi': True,
#    'hug': True,
#    'obama': True,
#    'deserv': True,
#    'stage': True,
#    'tonight': True},
#   'Negative'),
#  ({'monaeltahawi': True,
#    'serious': True,
#    'voter': True,
#    'think': True,
#    'god': True,
#    'talk': True,
#    'presidenti': True,
#    'candid': True,
#    'christianbrotherhood': True},
#   'Negative'),
#  ({'marcorubio': True,
#    'last': True,
#    'night': True,
#    "'s": True,
#    'even': True,
#    'close': True,
#    'well': True,
#    'done': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'trump': True,
#    'go': True,
#    'claim': True,
#    'god': True,
#    'gave': True,
#    'campaign': True,
#    'contribut': True},
#   'Negative'),
#  ({'carson': True,
#    'go': True,
#    'seat': True,
#    'back': True,
#    "'s": True,
#    'race': True,
#    'becuz': True,
#    'mofo': True,
#    'racist': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'megynkelli': True,
#    'pose': True,
#    'adult': True,
#    'pictures.should': True,
#    'bring': True},
#   'Negative'),
#  ({'rand': True, 'paul': True, 'vote': True, 'randpaul': True}, 'Positive'),
#  ({'becom': True,
#    'accept': True,
#    'god': True,
#    'topic': True,
#    'polit': True,
#    'debat': True,
#    'countri': True,
#    'shame': True},
#   'Negative'),
#  ({'tweet': True,
#    'hard': True,
#    'gopcircus': True,
#    'thought': True,
#    'broke': True,
#    'finger': True,
#    'nope': True,
#    'disloc': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'jjauthor': True, 'megynkelli': True, 'star': True, 'bretbaier': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'candid': True,
#    'attack': True,
#    'realdonaldtrump': True,
#    'stope': True,
#    'speak': True},
#   'Negative'),
#  ({'mozgovaya': True,
#    '10': True,
#    'men': True,
#    'stage': True,
#    'discuss': True,
#    'one': True,
#    'woman': True,
#    'hillaryclinton': True},
#   'Neutral'),
#  ({'realdonaldtrump': True,
#    'megynkelli': True,
#    'bretbaier': True,
#    'mod': True,
#    'job': True,
#    'is2': True,
#    'ask': True,
#    'qs': True,
#    'know': True,
#    'answer': True,
#    '2': True,
#    'bait': True,
#    'target': True,
#    'candid': True,
#    'trump2016': True},
#   'Positive'),
#  ({'joeykram': True,
#    'aerosmith': True,
#    'head': True,
#    'cleveland': True,
#    'interest': True,
#    'motleycru': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({'show': True,
#    'trump': True,
#    'rosieodonnel': True,
#    'watch': True,
#    'republican': True,
#    'presidenti': True,
#    'candid': True},
#   'Positive'),
#  ({'amandagutterman': True,
#    'trump': True,
#    'want': True,
#    'treat': True,
#    'mexican': True,
#    'like': True,
#    'white': True,
#    'walker': True},
#   'Negative'),
#  ({'leecorsodrunk': True,
#    'presid': True,
#    'colleg': True,
#    'footbal': True,
#    'would': True,
#    'play': True,
#    'year': True,
#    'round': True,
#    "'d": True,
#    'fast': True,
#    'isi': True,
#    'everi': True,
#    'saturday': True,
#    'corso4presi': True},
#   'Neutral'),
#  ({'ashvsevildead': True,
#    'kind': True,
#    'go': True,
#    'meanwhil': True,
#    're': True,
#    'debat': True,
#    'best': True,
#    'drum': True,
#    'solo': True,
#    'time': True,
#    'hot': True,
#    'teacher': True,
#    'tom': True,
#    'sa': True},
#   'Negative'),
#  ({'cap': True,
#    'defeat': True,
#    'kamehameha': True,
#    'attack': True,
#    'surviv': True,
#    'spirit': True,
#    'bomb': True},
#   'Neutral'),
#  ({'jjauthor': True,
#    'realdonaldtrump': True,
#    'float': True,
#    'like': True,
#    'butterfli': True,
#    'sting': True,
#    'bee': True,
#    'beladonnarog': True,
#    'megynkelli': True},
#   'Neutral'),
#  ({'cheesencrackr': True,
#    '2/2': True,
#    'right': True,
#    'women': True,
#    'indigen': True,
#    'peopl': True,
#    'colour': True,
#    'practic': True,
#    'non-western': True,
#    'faith': True,
#    'cr': True},
#   'Neutral'),
#  ({}, 'Positive'),
#  ({'couranto': True,
#    'rush': True,
#    'mock': True,
#    'megyn': True,
#    'kelli': True,
#    'self': True,
#    'serv': True,
#    'narcissist': True,
#    'kellyfil': True,
#    'foxdeb': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'ask': True,
#    'trump': True,
#    'legitim': True,
#    'question': True,
#    'look': True,
#    'wallac': True,
#    "'s": True,
#    'face': True,
#    'nail': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'dickscuttlebutt': True,
#    'tyfys84': True,
#    'duffelblog': True,
#    'tl': True,
#    'dr': True,
#    'blah': True,
#    'polit': True,
#    'whiskey': True,
#    'silent': True,
#    'weep': True,
#    'christi': True,
#    'fat': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'annemariew': True,
#    'poetinpoevill': True,
#    'know': True,
#    'aprx': True,
#    '700': True,
#    'law': True,
#    'govern': True,
#    'women': True,
#    "'s": True,
#    'bodi': True,
#    'one': True,
#    'men': True,
#    'true.': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'megynkelli': True,
#    'pose': True,
#    'adult': True,
#    'pictures.should': True,
#    'bring': True},
#   'Negative'),
#  ({'lindsey': True,
#    'graham': True,
#    'never': True,
#    'met': True,
#    'war': True,
#    "'s": True,
#    'afraid': True,
#    'send': True,
#    'kid': True,
#    'via': True,
#    'johnfugelsang': True,
#    'ff': True},
#   'Negative'),
#  ({"'s": True,
#    'scari': True,
#    'touch': True,
#    'real': True,
#    'world': True,
#    'republican': True},
#   'Negative'),
#  ({'npr': True,
#    "'m": True,
#    'sure': True,
#    'immigr': True,
#    'song': True,
#    'came': True,
#    'ledzepplin': True},
#   'Positive'),
#  ({'ericstonestreet': True, 'trump': True, 'cam': True, 'hand': True},
#   'Negative'),
#  ({'definit': True,
#    'topic': True,
#    'watch': True,
#    'last': True,
#    'night': True,
#    'thorough': True,
#    'entertain': True},
#   'Neutral'),
#  ({}, 'Positive'),
#  ({}, 'Neutral'),
#  ({'look': True,
#    'like': True,
#    're': True,
#    'skip': True,
#    'climat': True,
#    'chang': True,
#    "'s": True,
#    'talk': True,
#    'white': True,
#    'walker': True,
#    'king': True,
#    'land': True,
#    'debatewithberni': True},
#   'Negative'),
#  ({'vohanda': True,
#    'argu': True,
#    'hillari': True,
#    '1hr': True,
#    'ca': True,
#    'even': True,
#    'talk': True,
#    'polic': True,
#    'brutal': True,
#    'full': True,
#    'minut': True},
#   'Negative'),
#  ({'truthteamon': True,
#    'understand': True,
#    'statement': True,
#    'correct': True,
#    'mike': True,
#    'huckabe': True,
#    'believ': True,
#    'fertil': True,
#    'egg': True,
#    'abl': True,
#    'vote.': True,
#    'rwnj': True},
#   'Negative'),
#  ({'atlcav': True,
#    'fave': True,
#    'realli': True,
#    'well': True,
#    'last': True,
#    'night': True,
#    'marcorubio': True,
#    'johnkasich': True,
#    'realbencarson': True,
#    'carlyfiorina': True,
#    'rubio-kasich': True,
#    'ticket': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'huckabe': True, 'attack': True, 'tran': True, 'medic': True, 'care': True},
#   'Negative'),
#  ({'exclud': True,
#    'woman': True,
#    'field': True,
#    'first': True,
#    'ask': True,
#    'trump': True,
#    'part': True,
#    'war': True,
#    'women': True,
#    'yep.': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Negative'),
#  ({'catch': True,
#    'last': True,
#    'night': True,
#    'vast': True,
#    'major': True,
#    'question': True,
#    'flip-flop': True,
#    'posit': True,
#    'span': True,
#    'across': True,
#    'year': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Positive'),
#  ({'_alexandragold_': True,
#    '*root': True,
#    'small': True,
#    'businesses*': True,
#    '*campaign': True,
#    'almost': True,
#    'complet': True,
#    'fund': True,
#    'larg': True,
#    'corporations*': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Neutral'),
#  ({'1catherinesiena': True,
#    'glennbeck': True,
#    'patandstu': True,
#    'worst': True,
#    'appreci': True,
#    'theatric': True,
#    "'s": True,
#    'gopdeba': True},
#   'Negative'),
#  ({'trump': True,
#    'lead': True,
#    'among': True,
#    'male': True,
#    'voter': True,
#    '...': True,
#    'also': True,
#    'femal': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'disappoint': True,
#    'conduct': True,
#    'fair': True,
#    'balanc': True},
#   'Negative'),
#  ({'mention': True, 'climat': True, 'chang': True}, 'Negative'),
#  ({'lillyrockwel': True,
#    'dog': True,
#    'bark': True,
#    'everi': True,
#    'time': True,
#    'doorbel': True,
#    'sound': True,
#    'tv': True,
#    'last': True,
#    'night': True,
#    'lot': True,
#    'useabuzz': True},
#   'Negative'),
#  ({'everybodi': True, 'orang': True}, 'Negative'),
#  ({'alexhalperin': True,
#    'nandelabra': True,
#    'thank': True,
#    'made': True,
#    'donat': True,
#    'everyon': True,
#    'need': True,
#    'plan': True,
#    'parenthood': True,
#    'watch': True},
#   'Positive'),
#  ({'keep': True,
#    'hammer': True,
#    'accord': True,
#    'plan': True,
#    'great': True,
#    'car': True,
#    'fiorina': True,
#    'last': True,
#    'nightbut': True,
#    'rememb': True,
#    'word': True,
#    'said': True},
#   'Negative'),
#  ({'cat_1012000': True,
#    'thank': True,
#    'foxtv': True,
#    'hold': True,
#    'million': True,
#    'peopl': True,
#    'know': True,
#    're': True,
#    'better': True,
#    'balanc': True,
#    'msn': True,
#    'abc': True,
#    'cbs': True,
#    '...': True},
#   'Positive'),
#  ({'carson': True,
#    'get': True,
#    'zinger': True,
#    'end': True,
#    'ride': True,
#    'll': True,
#    'give': True,
#    'credit': True,
#    'medic': True,
#    'trailblaz': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'anyon': True,
#    'els': True,
#    'want': True,
#    'punch': True,
#    'chris': True,
#    'wallac': True,
#    'face': True},
#   'Negative'),
#  ({'katiepavlich': True,
#    're': True,
#    'alreadi': True,
#    'see': True,
#    'differ': True,
#    'senat': True,
#    'governor': True,
#    'introduc': True,
#    'legisl': True,
#    'got': True,
#    'thi': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'american': True,
#    'peopl': True,
#    'pick': True,
#    'next': True,
#    'presid': True,
#    'unit': True,
#    'state': True},
#   'Negative'),
#  ({'take': True,
#    'call': True,
#    '77wabcradio': True,
#    'yesterday': True,
#    "'s": True,
#    '800': True,
#    '848': True,
#    '9222': True},
#   'Neutral'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({'polit': True,
#    'correct': True,
#    '...': True,
#    'ai': True,
#    'nobodi': True,
#    'got': True,
#    'time': True,
#    'trump': True},
#   'Negative'),
#  ({'candid': True,
#    'honest': True,
#    'terrifi': True,
#    'one': True,
#    'actual': True,
#    'elect': True,
#    'countri': True,
#    'fuck': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({'rwsurfergirl': True,
#    'chris': True,
#    'wallac': True,
#    'ask': True,
#    'politican': True,
#    'financ': True,
#    'money': True,
#    'come': True},
#   'Negative'),
#  ({'rubio': True, 'good': True, 'job': True, 'last': True, 'night.': True},
#   'Positive'),
#  ({'wan': True,
#    'na': True,
#    'polit': True,
#    'see': True,
#    'shit': True,
#    'show': True,
#    'predic': True,
#    'elect': True,
#    'watch': True},
#   'Negative'),
#  ({'cavaticat': True,
#    'watch': True,
#    'last': True,
#    'night': True,
#    'today': True,
#    'got': True,
#    'wake': True,
#    'still': True,
#    'like': True,
#    'human': True,
#    'general': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Negative'),
#  ({'nerdist': True,
#    'trump': True,
#    "'s": True,
#    'realli': True,
#    'great': True,
#    'orang': True,
#    'new': True},
#   'Positive'),
#  ({'need': True,
#    'stop': True,
#    'he-said': True,
#    'she-said': True,
#    'question': True},
#   'Negative'),
#  ({'guypbenson': True,
#    'guy': True,
#    'trump': True,
#    'shoot': True,
#    'messeng': True,
#    'meagan': True,
#    'kelli': True,
#    'last': True,
#    'night': True,
#    'must': True,
#    'habitu': True,
#    'respons': True},
#   'Negative'),
#  ({'cloudypiano': True,
#    "'m": True,
#    'wait': True,
#    'accident': True,
#    'eat': True},
#   'Negative'),
#  ({'jebbush': True,
#    'good': True,
#    'communic': True,
#    'last': True,
#    'night': True,
#    "'s": True,
#    'sound': True,
#    'like': True,
#    'charli': True,
#    'brown': True,
#    'teacher': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'ca': True,
#    'wait': True,
#    'snl': True,
#    'imperson': True,
#    'donald': True,
#    'trump': True,
#    'bringbackdarrellhammond': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'mozgovaya': True,
#    '10': True,
#    'men': True,
#    'stage': True,
#    'discuss': True,
#    'one': True,
#    'woman': True,
#    'hillaryclinton': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'wo': True,
#    'admit': True,
#    'republican': True,
#    'leader': True,
#    'right': True,
#    'mean': True,
#    'realdonaldtrump': True,
#    'double-digit': True,
#    'lead': True,
#    'gopd': True},
#   'Neutral'),
#  ({'ask': True, 'everyon': True, 'question': True, 'race': True, '...': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'matthewherp': True,
#    'cruz': True,
#    'need': True,
#    'command': True,
#    'chief': True,
#    'make': True,
#    'clear': True,
#    'join': True,
#    'isi': True,
#    'sign': True,
#    'death': True,
#    'warrant': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'rubio': True,
#    'bush': True,
#    'threat': True,
#    'countri': True},
#   'Negative'),
#  ({'shannonrwatt': True,
#    'gun': True,
#    'violenc': True,
#    'cost': True,
#    'american': True,
#    '229b': True,
#    'annual': True,
#    'gunsens': True},
#   'Negative'),
#  ({'gop2016': True,
#    'plan': True,
#    'build': True,
#    'militari': True,
#    'cut': True,
#    'tax': True,
#    'ya': True,
#    'gon': True,
#    'na': True,
#    'pay': True,
#    'bake': True,
#    'sale': True,
#    'steal': True,
#    'ss': True},
#   'Negative'),
#  ({'monaeltahawi': True,
#    'candid': True,
#    'receiv': True,
#    'word': True,
#    'god': True,
#    'presidenti': True,
#    'hope': True,
#    'america': True,
#    'christian': True,
#    'brotherhood': True},
#   'Negative'),
#  ({'kelli': True, 'last': True, 'night': True, 'stop': True, 'clock': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'mcgrudder': True,
#    'gop2016deb': True,
#    'trump2016': True,
#    'trump': True,
#    'scare': True,
#    'control': True,
#    'talk': True,
#    'abo': True},
#   'Positive'),
#  ({'kumailn': True,
#    'guy': True,
#    've': True,
#    'cure': True,
#    'racism': True,
#    'realiz': True,
#    'congrat': True},
#   'Negative'),
#  ({'bettyfckinwhit': True,
#    '-can': True,
#    'answer': True,
#    'direct': True,
#    'question': True,
#    '-i': True,
#    'presid': True,
#    '-so': True},
#   'Negative'),
#  ({'jordiemojordi': True,
#    'yall': True,
#    'better': True,
#    'lie': True,
#    'god': True,
#    's/he': True,
#    'talk': True},
#   'Negative'),
#  ({'shadowbard': True,
#    'american': True,
#    'women': True,
#    'take': True,
#    'note': True,
#    'realdonaldtrump': True,
#    'justifi': True,
#    'piggish': True,
#    'attack': True,
#    '1': True,
#    'man': True,
#    'sta': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'problem': True,
#    'polit': True,
#    'correct': True,
#    "'s": True,
#    'mani': True,
#    'american': True,
#    'anti-intellectu': True,
#    'ignor': True,
#    'usa': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'would': True,
#    'never': True,
#    'know': True,
#    'realdonaldtrump': True,
#    'frontrunn': True,
#    'watch': True},
#   'Neutral'),
#  ({'oriolesfanprobz': True,
#    "'m": True,
#    'disappoint': True,
#    'none': True,
#    'candid': True,
#    'ask': True,
#    'thought': True,
#    'defens': True,
#    'shift': True,
#    'basebal': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'damn': True, 'freeload': True, 'pimp': True}, 'Negative'),
#  ({'jeffsimmons2050': True,
#    'takeaway': True,
#    'presenc': True,
#    'matter': True,
#    'see': True,
#    'blend': True,
#    'believ': True,
#    'articul': True,
#    'integr': True,
#    'w/': True,
#    'edg': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'candid': True,
#    'attack': True,
#    'realdonaldtrump': True,
#    'stope': True,
#    'speak': True},
#   'Negative'),
#  ({'akhenaten15': True,
#    'abort': True,
#    'problem': True,
#    'kill': True,
#    '575,000': True,
#    'iraqi': True,
#    'kid': True,
#    '2000': True,
#    'anoth': True,
#    '56,000': True},
#   'Negative'),
#  ({'monaeltahawi': True,
#    'candid': True,
#    'receiv': True,
#    'word': True,
#    'god': True,
#    'presidenti': True,
#    'hope': True,
#    'america': True,
#    'christian': True,
#    'brotherhood': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({}, 'Neutral'),
#  ({'warriorwoman91': True,
#    'love': True,
#    'megynkelli': True,
#    'hold': True,
#    'highest': True,
#    'posit': True,
#    'media': True,
#    'figur': True,
#    'ask': True,
#    'question': True,
#    'repub': True,
#    'war': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'zeitgeistghost': True,
#    'sane': True,
#    'person': True,
#    'think': True,
#    '1st': True,
#    'matter': True,
#    "'s": True,
#    'soulless': True,
#    'pitti': True,
#    'asshol': True},
#   'Neutral'),
#  ({}, 'Neutral'),
#  ({'much': True,
#    'voter': True,
#    'care': True,
#    'lender': True,
#    'lost': True,
#    'money': True,
#    'realdonaldtrump': True,
#    'bankruptci': True,
#    'lzdebat': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'monaeltahawi': True,
#    'one': True,
#    'question': True,
#    'import': True,
#    'urgent': True,
#    'movement': True,
#    'us': True,
#    'today': True,
#    'long': True,
#    'time': True},
#   'Neutral'),
#  ({'megynkelli': True,
#    'krauthamm': True,
#    'winner': True,
#    'tedcruz': True,
#    'marcorubio': True,
#    'govmikehuckabe': True,
#    'chrischristi': True,
#    'kellyfil': True},
#   'Neutral'),
#  ({'usprezdeb': True,
#    '...': True,
#    'total': True,
#    'think': True,
#    'tan': True,
#    'trump': True,
#    'gaff': True,
#    'presidenti': True,
#    'candid': True},
#   'Negative'),
#  ({'anyon': True,
#    'use': True,
#    'god': True,
#    "'s": True,
#    'name': True,
#    'hate': True,
#    'wolf': True,
#    'sheep': True,
#    'cloth': True,
#    'matthew': True,
#    '23:1-15': True,
#    'cruz': True,
#    'huckabe': True,
#    'men': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({'paulrieckhoff': True,
#    'yes': True,
#    'entitl': True,
#    'cic': True,
#    'potus': True,
#    'candid': True,
#    'excus': True,
#    'lack': True,
#    'nationalsecur': True,
#    'defens': True,
#    'va': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'candid': True,
#    'attack': True,
#    'realdonaldtrump': True,
#    'stope': True,
#    'speak': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'like': True,
#    'trump': True,
#    'less': True,
#    'morn': True,
#    'last': True,
#    'although': True,
#    'realiz': True,
#    "'s": True,
#    'want': True,
#    'think': True},
#   'Negative'),
#  ({'woke': True,
#    'think': True,
#    'hilari': True,
#    'dream': True,
#    'realiz': True,
#    'watch': True,
#    'last': True,
#    'night': True},
#   'Negative'),
#  ({'berniesand': True,
#    'scottwalk': True,
#    'man': True,
#    'say': True,
#    'one': True,
#    'intellig': True,
#    'thing': True,
#    'mean': True,
#    '...': True,
#    'none': True,
#    'feelthebern': True},
#   'Negative'),
#  ({'larryeld': True,
#    'trump': True,
#    'said': True,
#    'megyn': True,
#    'ask': True,
#    'nine': True,
#    'candid': True,
#    'plan': True,
#    'support': True,
#    'win': True,
#    'nomin': True,
#    'gopdebat': True},
#   'Neutral'),
#  ({'donaldtrump': True,
#    'know': True,
#    'usa': True,
#    'ca': True,
#    'declar': True,
#    'bankruptci': True,
#    'stiff': True,
#    'chines': True,
#    'creditor': True,
#    'askingforafriend': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'monaeltahawi': True,
#    'oh': True,
#    'boy': True,
#    'social': True,
#    'issu': True,
#    'code': True,
#    'control': True,
#    'women': True,
#    "'s": True,
#    'bodi': True,
#    'sexual': True,
#    'hold': True,
#    'tight': True,
#    'twitterland': True},
#   'Negative'),
#  ({'confus': True,
#    'republican': True,
#    'make': True,
#    'joke': True,
#    'watch': True,
#    'inform': True,
#    'candid': True},
#   'Neutral'),
#  ({'drbhotchkin': True,
#    'lynch': True,
#    'black': True,
#    'folk': True,
#    'jesus': True,
#    'name': True,
#    "'s": True,
#    'relev': True,
#    'god': True,
#    'question': True,
#    'foxdeb': True,
#    'foxn': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'mariacka': True,
#    'newsflash': True,
#    'jeb': True,
#    'wo': True,
#    'unit': True,
#    'countri': True,
#    'commoncor': True,
#    'pleas': True,
#    'lol': True},
#   'Negative'),
#  ({'base': True,
#    'rhetor': True,
#    'assum': True,
#    'donald': True,
#    'trump': True,
#    'look': True,
#    'megyn': True,
#    'kelli': True,
#    'see': True,
#    'miss': True,
#    'piggy.': True},
#   'Negative'),
#  ({'mitchellreport': True,
#    'capehartj': True,
#    'randpaul': True,
#    'good': True,
#    'point': True,
#    'turn': True,
#    'someth': True,
#    'sophomor': True,
#    'w/': True,
#    'hug': True,
#    'comment': True},
#   'Negative'),
#  ({'-er': True,
#    'vs': True,
#    'trump': True,
#    'glove': True,
#    'stay': True,
#    'except': True,
#    'fiorina': True,
#    'kick': True,
#    'curb': True,
#    'like': True,
#    'hp': True,
#    'employe': True},
#   'Negative'),
#  ({'want': True,
#    'defundpp': True,
#    'huckabe': True,
#    'legal': True,
#    'prostitut': True,
#    'drug': True},
#   'Negative'),
#  ({'chrisfranjola': True,
#    'thank': True,
#    'courag': True,
#    'coverag': True,
#    'sacrific': True,
#    'save': True,
#    'dread': True,
#    'even': True},
#   'Negative'),
#  ({'donniewahlberg': True,
#    'enjoy': True,
#    'look': True,
#    'forward': True,
#    'democraticdeb': True,
#    'next': True},
#   'Positive'),
#  ({'bamasever': True,
#    'megyn': True,
#    'kelli': True,
#    'worri': True,
#    'trump': True,
#    "'s": True,
#    'parti': True,
#    'loyalti': True,
#    'watch': True,
#    'transform': True,
#    'liber': True,
#    '3': True,
#    'hour': True},
#   'Negative'),
#  ({'supermanhotmal': True,
#    'dear': True,
#    'close': True,
#    'argument': True,
#    'none': True,
#    'candid': True,
#    'said': True,
#    'anyth': True,
#    'help': True,
#    'suffer': True,
#    'women': True},
#   'Negative'),
#  ({'women': True,
#    'serv': True,
#    'open': True,
#    'gay': True,
#    'transgend': True,
#    'militari': True,
#    'social': True,
#    'experi': True,
#    'accord': True,
#    'govmikehuckabe': True,
#    'late': True},
#   'Negative'),
#  ({'zoe_arch': True,
#    'wonder': True,
#    "'s": True,
#    'coincid': True,
#    'ironi': True,
#    'purpos': True,
#    'anniversari': True,
#    'hiroshima': True,
#    'bomb': True},
#   'Neutral'),
#  ({}, 'Negative'),
#  ({'bourgeoisalien': True,
#    'ca': True,
#    'wait': True,
#    'end': True,
#    'wrestl': True,
#    'angri': True,
#    'meth': True,
#    'addict': True,
#    'bear': True,
#    'death': True,
#    'see': True,
#    'real': True},
#   'Neutral'),
#  ({'readi': True,
#    '2016': True,
#    'gop2016': True,
#    'goodbyeobama': True,
#    'neveragain': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'truli': True,
#    'greatest': True,
#    'show': True,
#    'earth': True,
#    'gopclowncar': True},
#   'Negative'),
#  ({'simsoph': True,
#    'quit': True,
#    'someth': True,
#    'watch': True,
#    'vs': True,
#    'canadian': True,
#    'pm': True,
#    'anyon': True,
#    'take': True,
#    'american': True,
#    'politician': True,
#    'serious': True},
#   'Negative'),
#  ({'supermanhotmal': True,
#    'dear': True,
#    'gov': True,
#    'walker': True,
#    'noth': True,
#    'brag': True,
#    'fuck': True,
#    'state': True,
#    'wisconsin': True,
#    'suck': True,
#    'koch': True,
#    '...': True,
#    'bitchasspoli': True},
#   'Negative'),
#  ({'supermanhotmal': True,
#    'translat': True,
#    'jeb': True,
#    'bush': True,
#    'fuck': True,
#    'florida': True,
#    'school': True,
#    'bad': True,
#    'still': True,
#    'recov': True,
#    'truth': True,
#    'live': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Neutral'),
#  ({}, 'Negative'),
#  ({'brios82': True,
#    'conserv': True,
#    'want': True,
#    'live': True,
#    'babi': True,
#    'rais': True,
#    'dead': True,
#    'soldier': True,
#    '-georg': True,
#    'carlin': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'whole': True,
#    'debacl': True,
#    'insult': True,
#    'everi': True,
#    'american': True,
#    'common': True,
#    'sens': True,
#    'idea': True,
#    'histori': True,
#    '...': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'fieldnegro': True,
#    'happiest': True,
#    'person': True,
#    'america': True,
#    'today': True,
#    'watch': True,
#    'debat': True,
#    'hrc': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'chris': True,
#    'wallac': True,
#    'ask': True,
#    'politican': True,
#    'financ': True,
#    'money': True,
#    'come': True},
#   'Negative'),
#  ({'genethelawy': True, 'ted': True, 'cruz': True, 'leav': True}, 'Neutral'),
#  ({'dear': True,
#    'moder': True,
#    'forgot': True,
#    'say': True,
#    'chines': True,
#    'hack': True,
#    'start': True,
#    'bush': True,
#    'admin': True,
#    '...': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'chris': True,
#    'wallac': True,
#    'ask': True,
#    'politican': True,
#    'financ': True,
#    'money': True,
#    'come': True},
#   'Negative'),
#  ({'the818': True,
#    'let': True,
#    "'s": True,
#    'play': True,
#    'fast': True,
#    'distanc': True,
#    'trump': True,
#    'notm': True},
#   'Negative'),
#  ({'wow': True,
#    'everybodi': True,
#    "'s": True,
#    'tweet': True,
#    'megynkelli': True,
#    'bad': True,
#    'treatment': True,
#    'realdonaldtrump': True,
#    'agre': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({'chrchcurmudgeon': True,
#    "'d": True,
#    'vote': True,
#    'hologram': True,
#    'calvin': True,
#    'coolidg': True,
#    'moonwalk': True,
#    'across': True,
#    'stage': True,
#    'right': True,
#    'now.': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Neutral'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'glad': True,
#    'social': True,
#    'secur': True,
#    'debat': True,
#    'futur': True,
#    'gapol': True},
#   'Positive'),
#  ({'cruz': True, 'class': True, 'truth': True, 'get': True, 'vote': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'jessecox': True,
#    'even': True,
#    'god': True,
#    'roll': True,
#    'eye': True,
#    'respons': True,
#    'get': True,
#    'super': True,
#    'jesus': True,
#    'say': True,
#    '...': True,
#    'gopd': True},
#   'Negative'),
#  ({'bettyfckinwhit': True,
#    '-can': True,
#    'answer': True,
#    'direct': True,
#    'question': True,
#    '-i': True,
#    'presid': True,
#    '-so': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Neutral'),
#  ({'pimp': True, 'drug': True, 'dealer': True}, 'Neutral'),
#  ({'megynkelli': True,
#    'trump': True,
#    'simpli': True,
#    'ca': True,
#    'harm': True,
#    'impolitik': True,
#    'statement': True,
#    "'s": True,
#    'like': True,
#    'tri': True,
#    'drown': True,
#    'aquaman': True,
#    'donaldtrump': True},
#   'Negative'),
#  ({'love': True,
#    'hear': True,
#    'bencarson': True,
#    'debatequestionswewanttohear': True,
#    'make': True,
#    'perfect': True,
#    'sens': True,
#    'israel': True,
#    'awesom': True},
#   'Positive'),
#  ({'consequ': True,
#    'obama/clinton': True,
#    'admin': True,
#    '...': True,
#    'like': True,
#    'increas': True,
#    'diplomaci': True,
#    'ration': True,
#    'decision-mak': True,
#    'work': True,
#    'elimin': True,
#    'xenophobia': True},
#   'Negative'),
#  ({'ask': True,
#    'trump': True,
#    'question': True,
#    'get': True,
#    'squirrel': True},
#   'Negative'),
#  ({'carson': True,
#    'witti': True,
#    'articul': True,
#    'unlik': True,
#    'deserv': True,
#    'much': True,
#    'better': True,
#    'poll': True,
#    'rate': True,
#    'wo': True,
#    'make': True,
#    'past': True,
#    'new': True,
#    'hampshir': True},
#   'Positive'),
#  ({}, 'Positive'),
#  ({'exjon': True, 'rubio': True, 'win': True}, 'Positive'),
#  ({'_kingmalcolm': True,
#    'pro': True,
#    'life': True,
#    'unless': True,
#    'cop': True,
#    'involv': True,
#    'candid': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'chris': True,
#    'wallac': True,
#    'ask': True,
#    'politican': True,
#    'financ': True,
#    'money': True,
#    'come': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'ericstonestreet': True, 'trump': True, 'cam': True, 'hand': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Positive'),
#  ({}, 'Neutral'),
#  ({'livestream': True,
#    'blogger': True,
#    'make': True,
#    'sure': True,
#    'donald': True,
#    'trump': True,
#    'pull': True,
#    'rose': True,
#    'perot': True,
#    'clinton': True},
#   'Negative'),
#  ({'bring': True,
#    'hillaryclinton': True,
#    'need': True,
#    'someon': True,
#    'grown-up': True,
#    'barbarabox': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'per': True,
#    'trump': True,
#    'believ': True,
#    "'s": True,
#    'mere': True,
#    'polit': True,
#    'correct': True,
#    'moral': True,
#    'right': True,
#    'treat': True,
#    'women': True,
#    'equal': True},
#   'Negative'),
#  ({'democrat': True, 'love': True, 'right': True}, 'Positive'),
#  ({'salmasekela': True,
#    'self': True,
#    'righteous': True,
#    'hypocrit': True,
#    'tri': True,
#    'god': True,
#    'shameless': True},
#   'Negative'),
#  ({'sydneyvl24': True,
#    'cautious': True,
#    'optimist': True,
#    'feel': True,
#    'morn': True},
#   'Positive'),
#  ({'imoore8904': True,
#    'trump': True,
#    'support': True,
#    'tee': True,
#    'hee': True,
#    'laugh': True,
#    'insult': True,
#    'everyon': True,
#    'sun': True,
#    'cri': True,
#    'foul': True,
#    'megynkelli': True,
#    'call': True,
#    'shit': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'michelejmartin': True,
#    'last': True,
#    'night': True,
#    'huge': True,
#    'tv': True,
#    'jonvoyag': True,
#    'battl': True,
#    'social': True,
#    'annarawsuh': True,
#    'ovrdrv': True,
#    'recap': True,
#    'h': True},
#   'Neutral'),
#  ({'bassem_masri': True,
#    'wow': True,
#    'run': True,
#    'blatant': True,
#    'bigotri': True,
#    'war': True,
#    'tortur': True,
#    'address': True,
#    'problem': True,
#    'home': True,
#    'kkkorgop': True,
#    'go': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'erictheteamst': True,
#    'walker': True,
#    'main': True,
#    'talk': True,
#    'point': True,
#    'took': True,
#    '100s': True,
#    '1000s': True,
#    'union': True,
#    'protest': True,
#    'wait': True,
#    'hear': True,
#    'hel': True},
#   'Neutral'),
#  ({'kavithadavidson': True,
#    'total': True,
#    'stay': True,
#    'tune': True,
#    'god': True,
#    'megyn': True},
#   'Positive'),
#  ({'chrischristi': True,
#    'make': True,
#    'even': True,
#    'proud': True,
#    'new': True,
#    'jersey': True},
#   'Positive'),
#  ({'megyn': True,
#    'kelli': True,
#    'need': True,
#    'work': True,
#    'msnbc': True,
#    'low': True,
#    'point': True,
#    'debate.': True,
#    'realdonaldtrump': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Negative'),
# ...
#    'make': True,
#    'america': True,
#    'great': True},
#   'Negative'),
#  ({'theladygrantham': True,
#    'donald': True,
#    'trump': True,
#    'dear': True,
#    "'s": True,
#    'middl': True,
#    'class': True},
#   'Negative'),
#  ({'drunk': True, '2016': True}, 'Negative'),
#  ({"'m": True,
#    'ai': True,
#    'bout': True,
#    'dem': True,
#    'big': True,
#    'ol': True,
#    'sloppi': True,
#    'abort': True,
#    'nuh-uh': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({}, 'Neutral'),
#  ({'louispeitzman': True,
#    "'m": True,
#    'answer': True,
#    'question': True,
#    'stori': True,
#    'hardship': True,
#    'parent': True,
#    'face': True},
#   'Neutral'),
#  ({'trump': True,
#    'adam': True,
#    'sandler': True,
#    'movi': True,
#    'makeamericafartagain': True},
#   'Negative'),
#  ({'fxnopinion': True, 'foxnewspolit': True, 'good': True, 'job': True},
#   'Positive'),
#  ({'danmoore755': True,
#    'one': True,
#    'trust': True,
#    'randpaul': True,
#    'gop2016': True,
#    'usa': True,
#    'merica': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'lrihendri': True,
#    'tedcruz': True,
#    'presid': True,
#    'alway': True,
#    'tell': True,
#    'truth': True,
#    'said': True,
#    'would': True},
#   'Positive'),
#  ({'makinh15tori': True, 'lol': True, 'trump': True}, 'Negative'),
#  ({'rwsurfergirl': True,
#    'ask': True,
#    'trump': True,
#    'legitim': True,
#    'question': True,
#    'look': True,
#    'wallac': True,
#    "'s": True,
#    'face': True,
#    'nail': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'american': True,
#    'peopl': True,
#    'pick': True,
#    'next': True,
#    'presid': True,
#    'unit': True,
#    'state': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'tedcruz': True,
#    'realdonaldtrump': True,
#    'need': True,
#    'take': True,
#    'control': True},
#   'Positive'),
#  ({'cnn': True,
#    'cnnpolit': True,
#    '8': True,
#    'thing': True,
#    'take': True,
#    'away': True,
#    'one': True,
#    'bencarson': True,
#    "'s": True,
#    'shame': True},
#   'Negative'),
#  ({'foxnewsl': True,
#    'serious': True,
#    'tone': True,
#    'deaf': True,
#    'deliber': True,
#    'clue': True,
#    'blow': True,
#    'back': True,
#    'megynkelli': True,
#    "'m": True,
#    'fan': True},
#   'Negative'),
#  ({'basic': True,
#    'post': True,
#    'poll': True,
#    'busi': True,
#    'candid': True,
#    'beat': True,
#    'polit': True},
#   'Neutral'),
#  ({}, 'Neutral'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'last': True,
#    'night': True,
#    "'s": True,
#    'presidenti': True,
#    'debat': True,
#    'rich': True,
#    'corpor': True,
#    'ceo': True,
#    'run': True,
#    'govern': True,
#    'anyway': True,
#    'transpar': True},
#   'Negative'),
#  ({'auditthemedia': True,
#    'us': True,
#    'could': True,
#    'stand': True,
#    'learn': True,
#    'lot': True,
#    'gedeb': True,
#    'format': True,
#    'bbc': True,
#    'much': True,
#    'better': True,
#    'job': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'go': True,
#    'ask': True,
#    'trump2016': True,
#    'polici': True,
#    'question': True,
#    'charact': True,
#    'smear': True,
#    'makeamericagreatagain': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'big': True,
#    'problem': True,
#    'face': True,
#    'democrat': True,
#    'get': True,
#    'hillari': True,
#    'sober': True,
#    'long': True,
#    'enough': True,
#    'toot': True},
#   'Neutral'),
#  ({'keep': True,
#    'congratul': True,
#    'great': True,
#    'job': True,
#    'media': True,
#    'use': True,
#    'power': True,
#    'slant': True,
#    'usual': True,
#    'real': True,
#    'educ': True},
#   'Negative'),
#  ({'gamma_ray239': True,
#    'disappoint': True,
#    'treat': True,
#    'differ': True,
#    'cnn': True,
#    'would': True,
#    'dictat': True,
#    'vs': True,
#    'repo': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Positive'),
#  ({'billhemm': True,
#    'marthamaccallum': True,
#    'kudo': True,
#    'bill': True,
#    'martha': True,
#    'excel': True,
#    'moder': True,
#    'prime': True,
#    'time': True,
#    'team': True,
#    'aw': True,
#    'comparison': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'thank': True,
#    're': True,
#    'rais': True,
#    'realdonaldtrump': True,
#    "'s": True,
#    'rate': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'ask': True,
#    'trump': True,
#    'legitim': True,
#    'question': True,
#    'look': True,
#    'wallac': True,
#    "'s": True,
#    'face': True,
#    'nail': True},
#   'Positive'),
#  ({'fix': True,
#    'new': True,
#    'jersey': True,
#    'first': True,
#    'chrischristi': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({}, 'Neutral'),
#  ({'rwsurfergirl': True,
#    'candid': True,
#    'attack': True,
#    'realdonaldtrump': True,
#    'stope': True,
#    'speak': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'obamaagenda': True, 'baracksback': True, 'um..dur': True, 'derp': True},
#   'Neutral'),
#  ({}, 'Negative'),
#  ({'rwsurfergirl': True,
#    'american': True,
#    'peopl': True,
#    'pick': True,
#    'next': True,
#    'presid': True,
#    'unit': True,
#    'state': True},
#   'Negative'),
#  ({'lot': True,
#    'candid': True,
#    'defend': True,
#    'plannedparenthood': True,
#    'never': True,
#    'mention': True,
#    'take': True,
#    'away': True,
#    'rapist': True,
#    "'s": True,
#    'parent': True,
#    'right': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({'lol': True,
#    'bencarson': True,
#    'serious': True,
#    'answer': True,
#    'question': True},
#   'Negative'),
#  ({'stephenstephan': True,
#    'rubio': True,
#    'basic': True,
#    'life': True,
#    'sacr': True,
#    'prolif': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Neutral'),
#  ({'nathanhaynes24': True,
#    'last': True,
#    'night': True,
#    "'s": True,
#    'realbencarson': True,
#    'govmikehuckabe': True,
#    'emerg': True,
#    'top': True,
#    'two': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'ljcambria': True,
#    'realdonaldtrump': True,
#    'forget': True,
#    'vote': True,
#    'especislli': True,
#    'go': True,
#    'independ': True,
#    'lulz': True,
#    'huckster': True,
#    'rnc': True},
#   'Positive'),
#  ({'anergo_teach': True,
#    'serious': True,
#    'trump': True,
#    'danger': True,
#    'whole': True,
#    'world': True},
#   'Negative'),
#  ({'trump': True, 're': True, 'avoid': True, 'question': True}, 'Negative'),
#  ({'randpaul': True,
#    'got': True,
#    'clock': True,
#    'clean': True,
#    'last': True,
#    'night': True,
#    'bye': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'oh': True,
#    'understand': True,
#    'movi': True,
#    'idiocraci': True,
#    'actual': True,
#    'documentari': True},
#   'Negative'),
#  ({'donniewahlberg': True,
#    'enjoy': True,
#    'look': True,
#    'forward': True,
#    'democraticdeb': True,
#    'next': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'rubio': True, 'hard': True, 'keep': True, 'script': True, '...': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'berinszoka': True,
#    'rand': True,
#    'want': True,
#    'gun': True,
#    'marriag': True,
#    'regist': True,
#    'washingtonagre': True,
#    '...': True,
#    'know': True,
#    'state': True,
#    'r': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'themadston': True,
#    'bum': True,
#    'get': True,
#    'watch': True,
#    'singl': True,
#    'candid': True,
#    'flounder': True,
#    'climat': True,
#    'chang': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'goddessjaz': True,
#    'discuss': True,
#    'racist': True,
#    'polic': True,
#    'violenc': True,
#    'finish': True,
#    'type': True,
#    'tweet': True,
#    'kkkorgop': True},
#   'Negative'),
#  ({'promis': True,
#    'free': True,
#    'pizza': True,
#    'everi': True,
#    'friday': True,
#    'homework': True,
#    'ever': True},
#   'Neutral'),
#  ({'typic': True,
#    'plan': True,
#    'make': True,
#    'life': True,
#    'better': True,
#    'plenti': True,
#    'increas': True,
#    'pain': True,
#    'miseri': True,
#    'p2': True},
#   'Negative'),
#  ({'jeb': True,
#    'bush': True,
#    'rand': True,
#    'paul': True,
#    'one': True,
#    'see': True,
#    'odd': True,
#    'rise': True,
#    'though': True,
#    "'s": True,
#    'price': True,
#    'trim': True,
#    'end': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'llamo': True,
#    'sprightlymag': True,
#    'consid': True,
#    'ca': True,
#    'blame': True,
#    'might': True,
#    'need': True,
#    'join': True,
#    'thank': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Negative'),
#  ({}, 'Neutral'),
#  ({'reassur': True,
#    'affin': True,
#    'republican': True,
#    'kurdish': True,
#    'milit': True,
#    'elect': True,
#    'presid': True,
#    'jindal': True,
#    'said': True,
#    'll': True,
#    'arm': True,
#    'kurd': True,
#    'i.e': True,
#    'pyd': True},
#   'Positive'),
#  ({'monaeltahawi': True,
#    'serious': True,
#    'voter': True,
#    'think': True,
#    'god': True,
#    'talk': True,
#    'presidenti': True,
#    'candid': True,
#    'christianbrotherhood': True},
#   'Negative'),
#  ({'amymek': True,
#    'freedom': True,
#    'free': True,
#    'must': True,
#    'fight': True,
#    'everi': True,
#    'day': True,
#    'ben': True,
#    'carson': True},
#   'Neutral'),
#  ({}, 'Positive'),
#  ({'supermanhotmal': True,
#    'donald': True,
#    'trump': True,
#    'never': True,
#    'gone': True,
#    'bankrupt': True,
#    '...': True,
#    'realli': True,
#    'fuck': True,
#    'liar': True},
#   'Negative'),
#  ({'laural4705': True,
#    'opinion': True,
#    'cruz': True,
#    'best': True,
#    'close': True,
#    'remark': True,
#    'explain': True,
#    'plan': True,
#    'vision': True,
#    'america': True,
#    'passion': True,
#    'de': True},
#   'Positive'),
#  ({"'m": True, 'still': True, 'stare': True, 'megynkelli': True, 'bae': True},
#   'Positive'),
#  ({'jamiaw': True,
#    'purpos': True,
#    'militari': True,
#    'kill': True,
#    'peopl': True,
#    'break': True,
#    'thing': True,
#    '-mike': True,
#    'huckabe': True,
#    'kkkorgop': True},
#   'Neutral'),
#  ({'bucksexton': True,
#    'hey': True,
#    'jeb': True,
#    'earn': True,
#    'legal': True,
#    'status': True,
#    'amnesti': True,
#    've': True,
#    'play': True,
#    'game': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'dynamodream': True,
#    'realdonaldtrump': True,
#    'megynkelli': True,
#    'megyn': True,
#    'kelli': True,
#    'also': True,
#    'roll': True,
#    'eye': True,
#    'watch': True,
#    'rate': True,
#    'drop': True,
#    'drastic': True},
#   'Neutral'),
#  ({'old': True,
#    'white': True,
#    'rich': True,
#    'conserv': True,
#    'dude': True,
#    'parad': True,
#    "'s": True,
#    'childhood': True,
#    'nightmar': True,
#    'mine': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'huckabe': True, 'propos': True, 'pimp': True, 'tax': True}, 'Neutral'),
#  ({'candid': True,
#    'claim': True,
#    'speak': True,
#    'direct': True,
#    'god': True,
#    '...': True},
#   'Neutral'),
#  ({'maddow': True,
#    'everyon': True,
#    'watch': True,
#    'debatewithberni': True,
#    '--': True,
#    'senschum': True,
#    'fri': True,
#    'night': True,
#    'dump': True,
#    'thur': True,
#    'irand': True},
#   'Neutral'),
#  ({}, 'Neutral'),
#  ({'bruneski': True,
#    'upstair': True,
#    'put': True,
#    'kid': True,
#    'bed': True,
#    'mani': True,
#    'question': True,
#    'climat': True,
#    'chang': True,
#    'miss': True,
#    'gopclowncar': True},
#   'Neutral'),
#  ({'salmasekela': True,
#    'kasich': True,
#    'awar': True,
#    "'s": True,
#    'make': True,
#    'sens': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'republican': True,
#    'primari': True,
#    "'s": True,
#    'think': True,
#    'govern': True,
#    'new': True,
#    'realiti': True,
#    'show': True,
#    'debatewithberni': True},
#   'Negative'),
#  ({'although': True,
#    'occasion': True,
#    'dick': True,
#    'realdonaldtrump': True,
#    'sure': True,
#    'know': True,
#    'keep': True,
#    'polit': True,
#    'debat': True,
#    'aliv': True,
#    'excit': True},
#   'Negative'),
#  ({'take': True,
#    'care': True,
#    'peopl': True,
#    've': True,
#    'work': True,
#    'hard': True,
#    'play': True,
#    'rule': True,
#    'wrong': True,
#    'christi': True,
#    're': True,
#    'pay': True,
#    'nj': True,
#    'pension': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Positive'),
#  ({'rwsurfergirl': True,
#    'megynkelli': True,
#    'pose': True,
#    'adult': True,
#    'pictures.should': True,
#    'bring': True},
#   'Negative'),
#  ({'mzdivah67': True,
#    'watch': True,
#    'seem': True,
#    'like': True,
#    'blacklivesdontmatt': True,
#    'bash': True,
#    'pbo': True,
#    'fail': True,
#    'polici': True,
#    'impo': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'disappoint': True,
#    'conduct': True,
#    'fair': True,
#    'balanc': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'cat_1012000': True,
#    'thank': True,
#    'foxtv': True,
#    'hold': True,
#    'million': True,
#    'peopl': True,
#    'know': True,
#    're': True,
#    'better': True,
#    'balanc': True,
#    'msn': True,
#    'abc': True,
#    'cbs': True,
#    '...': True},
#   'Negative'),
#  ({'salmasekela': True,
#    'senat': True,
#    'cruz': True,
#    'word': True,
#    'god': True,
#    'spit': True,
#    'tequila': True,
#    'damn': True,
#    'megyn': True,
#    'kelli': True,
#    'expens': True,
#    'kind': True},
#   'Negative'),
#  ({'leasavoy': True,
#    'overal': True,
#    'view': True,
#    '...': True,
#    'stay': True,
#    'home': True,
#    'work': True,
#    'candid': True,
#    'choic': True,
#    'chang': True,
#    '1': True,
#    'iota.': True,
#    'cruzcrew': True},
#   'Negative'),
#  ({'danmoore755': True,
#    'republican': True,
#    'candid': True,
#    'close': True,
#    'love': True,
#    'god': True,
#    'democrat': True,
#    'would': True,
#    'never': True,
#    '...': True,
#    'sayin': True,
#    'gop2016': True,
#    'gopd': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({'lrihendri': True,
#    'tedcruz': True,
#    'presid': True,
#    'alway': True,
#    'tell': True,
#    'truth': True,
#    'said': True,
#    'would': True},
#   'Positive'),
#  ({'piti': True, 'parti': True}, 'Negative'),
#  ({}, 'Negative'),
#  ({'tedcruz': True,
#    'get': True,
#    'vote': True,
#    'tonight': True,
#    'dr.': True,
#    'carson': True,
#    'close': True,
#    'second': True},
#   'Positive'),
#  ({'say': True,
#    'school': True,
#    'local': True,
#    'state': True,
#    'run': True,
#    'keep': True,
#    'receiv': True,
#    'fed': True,
#    'money': True,
#    'matter': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'tonight': True,
#    'learn': True,
#    'govchristi': True,
#    'think': True,
#    'remov': True,
#    'civil': True,
#    'right': True,
#    'fight': True,
#    'terror': True},
#   'Negative'),
#  ({'ira': True,
#    'point': True,
#    'talk': True,
#    '9/11': True,
#    'gone': True,
#    'longer': True,
#    'pretti': True,
#    'littl': True,
#    'liar': True},
#   'Negative'),
#  ({'ericstonestreet': True, 'trump': True, 'cam': True, 'hand': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Positive'),
#  ({'rumpfshak': True,
#    'never': True,
#    'gone': True,
#    'bankrupt': True,
#    'say': True,
#    'trump': True,
#    'multipl': True,
#    'busi': True,
#    'went': True,
#    'thru': True,
#    'bankruptci': True,
#    'screw': True,
#    'creditor': True},
#   'Negative'),
#  ({'chump/trump': True,
#    'ignor': True,
#    'presidenti': True,
#    'class': True,
#    'money': True,
#    'clear': True,
#    'ca': True,
#    'buy': True,
#    'u': True,
#    'skip': True,
#    'digniti': True},
#   'Negative'),
#  ...]

# %% [markdown]
# ## Train the model

# %%
sentiment_classifier = NaiveBayesClassifier.train(train_bow)

# %%
nltk.classify.util.accuracy(sentiment_classifier, train_bow)*100
# Out:
# 71.41712729311864

# %%
X_train = train_bow
y_train = train_bow
X_train
# Out:
# [({}, 'Negative'),
#  ({'jjauthor': True,
#    'polici': True,
#    'barack': True,
#    'obama': True,
#    'manag': True,
#    'provid': True,
#    'neither': True,
#    'peac': True,
#    'prosper': True,
#    'realdonaldtrump': True,
#    'tedcruz': True},
#   'Negative'),
#  ({'dougstanhop': True,
#    'hillari': True,
#    'come': True,
#    'everi': True,
#    'angl': True,
#    'strike': True,
#    'ground': True,
#    'pound': True,
#    'arm': True,
#    'bar': True,
#    "'s": True,
#    'unstopp': True,
#    'think': True,
#    'wr': True},
#   'Neutral'),
#  ({'lrihendri': True,
#    'tedcruz': True,
#    'presid': True,
#    'alway': True,
#    'tell': True,
#    'truth': True,
#    'said': True,
#    'would': True},
#   'Neutral'),
#  ({'lukewearechang': True,
#    'evid': True,
#    'hack': True,
#    'talk': True,
#    'come': True,
#    'syria': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'tatianak': True,
#    'fact': True,
#    'wasnt': True,
#    'even': True,
#    'liter': True,
#    'pundit': True,
#    'say': True,
#    'rememb': True,
#    'time': True,
#    'said': True,
#    'x': True,
#    'bish': True,
#    'bout': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'rwsurfergirl': True,
#    'thank': True,
#    're': True,
#    'rais': True,
#    'realdonaldtrump': True,
#    "'s": True,
#    'rate': True},
#   'Negative'),
#  ({'order': True,
#    'cruz': True,
#    'rubio': True,
#    'carson': True,
#    'walker': True,
#    'think': True,
#    'rand': True,
#    'okay': True,
#    'trump': True,
#    'hurt': True,
#    'jeb': True,
#    'much': True},
#   'Positive'),
#  ({'fieldnegro': True,
#    'happiest': True,
#    'person': True,
#    'america': True,
#    'today': True,
#    'watch': True,
#    'debat': True,
#    'hrc': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'wo': True,
#    'admit': True,
#    'republican': True,
#    'leader': True,
#    'right': True,
#    'mean': True,
#    'realdonaldtrump': True,
#    'double-digit': True,
#    'lead': True,
#    'gopd': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Positive'),
#  ({'rwsurfergirl': True,
#    'thank': True,
#    're': True,
#    'rais': True,
#    'realdonaldtrump': True,
#    "'s": True,
#    'rate': True},
#   'Positive'),
#  ({'chaunceydevega': True,
#    'kasich': True,
#    'enough': True,
#    'sociopath': True,
#    'kill': True,
#    'useless': True,
#    'eater': True,
#    'type': True,
#    'nomine': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'smethani': True,
#    'sure': True,
#    'god': True,
#    'told': True,
#    'run': True,
#    'tooth': True,
#    'fairi': True,
#    'agre': True,
#    'teletubbi': True,
#    'vote': True,
#    'yes': True},
#   'Negative'),
#  ({'monaeltahawi': True,
#    'perhap': True,
#    'll': True,
#    'talk': True,
#    'racism': True,
#    're': True,
#    'ask': True,
#    'god': True,
#    'told': True,
#    'blackliveematt': True},
#   'Negative'),
#  ({'polit': True, 'correct': True, 'noth': True, 'bad': True, 'manner': True},
#   'Neutral'),
#  ({'donniewahlberg': True,
#    'enjoy': True,
#    'look': True,
#    'forward': True,
#    'democraticdeb': True,
#    'next': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'watch': True, 'nanosecond': True}, 'Negative'),
#  ({}, 'Negative'),
#  ({'mariacka': True,
#    'ask': True,
#    'tedcruz': True,
#    'two': True,
#    'question': True},
#   'Negative'),
#  ({'lot': True,
#    'creepi': True,
#    'plain': True,
#    'cloth': True,
#    'cop': True,
#    'bodi': True,
#    'men': True,
#    'protect': True,
#    'scottwalk': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    "'d": True,
#    'realli': True,
#    'like': True,
#    'see': True,
#    'long': True,
#    'candid': True,
#    'given': True,
#    'speak': True,
#    'seem': True,
#    'fair': True,
#    'balanc': True,
#    'gopdebat': True},
#   'Negative'),
#  ({'bettyfckinwhit': True,
#    '-can': True,
#    'answer': True,
#    'direct': True,
#    'question': True,
#    '-i': True,
#    'presid': True,
#    '-so': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'trump': True,
#    'said': True,
#    'jebbush': True,
#    'true': True,
#    'gentleman': True,
#    'start': True,
#    'violent': True,
#    '69ing': True},
#   'Negative'),
#  ({'trump': True,
#    'done': True,
#    'last': True,
#    'night': True,
#    'end': True,
#    'stori': True},
#   'Negative'),
#  ({'foxnewspolit': True,
#    'realli': True,
#    'look': True,
#    'candid': True,
#    'attack': True,
#    'trump': True,
#    'notfair': True,
#    'notbalanc': True},
#   'Negative'),
#  ({'hadiyah': True,
#    'let': True,
#    'see': True,
#    'jeb': True,
#    'bush': True,
#    'tri': True,
#    'solv': True,
#    'common': True,
#    'core': True,
#    'math': True,
#    'problem': True},
#   'Negative'),
#  ({'writeintrump': True,
#    'hey': True,
#    'megan': True,
#    'kelli': True,
#    'ask': True,
#    'osbourn': True,
#    'attack': True,
#    'week': True,
#    'work': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'big': True,
#    'problem': True,
#    'face': True,
#    'democrat': True,
#    'get': True,
#    'hillari': True,
#    'sober': True,
#    'long': True,
#    'enough': True,
#    'toot': True},
#   'Neutral'),
#  ({'like': True,
#    'sophmor': True,
#    'bicker': True,
#    'back': True,
#    'forth': True,
#    'candid': True,
#    'presidenti': True,
#    'outnumberedfnc': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'break': True,
#    'brian': True,
#    'william': True,
#    'hand': True,
#    'chris': True,
#    'christi': True,
#    'donut': True,
#    'calm': True},
#   'Neutral'),
#  ({'ladysandersfarm': True,
#    'bush': True,
#    'lame': True,
#    'way': True,
#    'around': True},
#   'Negative'),
#  ({'tinaissa': True, 'think': True, 'megyn': True, 'kellli': True},
#   'Negative'),
#  ({'hey': True,
#    'plan': True,
#    'give': True,
#    'tedcruz': True,
#    'chanc': True,
#    'speak': True,
#    're': True,
#    'tri': True,
#    'margin': True,
#    'daili': True,
#    'cycl': True},
#   'Negative'),
#  ({'leapoverthat': True,
#    'noth': True,
#    'realli': True,
#    'refresh': True,
#    'hear': True,
#    'top': True,
#    '1': True,
#    'instruct': True,
#    'civilian': True,
#    'handl': True,
#    'cope': True,
#    'poverti': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Positive'),
#  ({'trump': True,
#    'answer': True,
#    'megynkelli': True,
#    'question': True,
#    'insult': True,
#    'women': True,
#    'ca': True,
#    'wait': True,
#    'til': True,
#    'start': True,
#    'rondarousey': True},
#   'Neutral'),
#  ({'think': True,
#    'donald': True,
#    'hillari': True,
#    "'s": True,
#    'biggest': True,
#    'paid': True,
#    'friend': True,
#    'lessgovmorefun': True},
#   'Negative'),
#  ({'quit': True,
#    'frank': True,
#    'disturb': True,
#    'thing': True,
#    'last': True,
#    'night': True,
#    "'s": True,
#    'look': True,
#    'terribl': True,
#    'adobo': True,
#    'ting': True,
#    'tan': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'trump': True,
#    'victim': True,
#    'use': True,
#    'law': True,
#    'like': True,
#    'hundr': True,
#    'peopl': True},
#   'Negative'),
#  ({'watch': True,
#    'seem': True,
#    'like': True,
#    'blacklivesdontmatt': True,
#    'bash': True,
#    'pbo': True,
#    'fail': True,
#    'polici': True,
#    'import': True},
#   'Negative'),
#  ({'love': True,
#    'scottwalk': True,
#    'ask': True,
#    'rhetor': True,
#    'hillari': True,
#    'clinton': True,
#    'go': True,
#    'lectur': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'obvious': True,
#    'tri': True,
#    'influenc': True,
#    'makeup': True,
#    'republican': True,
#    'field': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'disappoint': True,
#    'conduct': True,
#    'fair': True,
#    'balanc': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'supermanhotmal': True,
#    'pres': True,
#    'obama': True,
#    'brain': True,
#    'littl': True,
#    'toe': True,
#    'total': True,
#    'fuck': True,
#    'idiot': True,
#    'whole': True,
#    'famili': True,
#    'combin': True},
#   'Negative'),
#  ({'govmikehuckabe': True,
#    'clue': True,
#    'kind': True,
#    'hard': True,
#    'work': True,
#    'commit': True,
#    'everi': True,
#    'member': True,
#    'militari': True,
#    'make': True,
#    'deptofdefens': True},
#   'Negative'),
#  ({'bnlieb': True,
#    'smear': True,
#    'oppon': True,
#    'whitegenocid': True,
#    'nazi': True,
#    'libzi': True,
#    'pervert': True,
#    'memoryoftheholocaust': True,
#    'weapon': True,
#    'guarante': True,
#    'genoci': True},
#   'Negative'),
#  ({'ericstonestreet': True, 'trump': True, 'cam': True, 'hand': True},
#   'Negative'),
#  ({'gretchencarlson': True,
#    'hillari': True,
#    'clinton': True,
#    'lie': True,
#    'benghazi': True,
#    'job': True,
#    'need': True,
#    'help': True,
#    'carlyfiorina': True,
#    'foxnewspolit': True},
#   'Neutral'),
#  ({'marisol_bello': True,
#    'wht': True,
#    'miss': True,
#    'journo': True,
#    'concern': True,
#    'abt': True,
#    'poverti': True,
#    'r': True,
#    'voters/candid': True,
#    'expect': True,
#    '2': True,
#    'talkpoverti': True},
#   'Negative'),
#  ({'guy': True,
#    'like': True,
#    'go': True,
#    'run': True,
#    'presid': True,
#    'republican': True,
#    'better': True,
#    'seat': True,
#    'meguylikem': True,
#    'republicandeb': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'obvious': True,
#    'tri': True,
#    'influenc': True,
#    'makeup': True,
#    'republican': True,
#    'field': True},
#   'Negative'),
#  ({'senatorshoshana': True,
#    'moment': True,
#    'randpaul': True,
#    'spoke': True,
#    'key': True,
#    'christi': True,
#    'could': True,
#    'disagre': True,
#    'add': True,
#    'tweak': True,
#    'bit': True,
#    "'s": True,
#    'rand': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'lizzwinstead': True,
#    'abl': True,
#    'call': True,
#    'women': True,
#    'pig': True,
#    'whore': True,
#    'take': True,
#    'america': True,
#    'back': True},
#   'Negative'),
#  ({'moder': True,
#    "'s": True,
#    'job': True,
#    'ask': True,
#    'tough': True,
#    'question': True,
#    'attack': True,
#    'candid': True,
#    'play': True,
#    'victim': True,
#    'megynkelli': True},
#   'Negative'),
#  ({'fergie_spud': True,
#    'would': True,
#    'far': True,
#    'better': True,
#    'job': True,
#    'frank_underwood': True,
#    'kevinspacey': True},
#   'Neutral'),
#  ({}, 'Negative'),
#  ({'open': True,
#    'csi': True,
#    'miami': True,
#    'support': True,
#    'trump': True,
#    'appar': True},
#   'Neutral'),
#  ({'jamiaw': True,
#    'purpos': True,
#    'militari': True,
#    'kill': True,
#    'peopl': True,
#    'break': True,
#    'thing': True,
#    '-mike': True,
#    'huckabe': True,
#    'kkkorgop': True},
#   'Negative'),
#  ({'supermanhotmal': True,
#    'dear': True,
#    'senat': True,
#    'rubio': True,
#    'god': True,
#    'noth': True,
#    'republican': True,
#    'parti': True,
#    '...': True,
#    'get': True,
#    'right': True},
#   'Negative'),
#  ({'jamiaw': True,
#    'purpos': True,
#    'militari': True,
#    'kill': True,
#    'peopl': True,
#    'break': True,
#    'thing': True,
#    '-mike': True,
#    'huckabe': True,
#    'kkkorgop': True},
#   'Neutral'),
#  ({'keep': True,
#    'go': True,
#    'like': True,
#    'this-': True,
#    'wo': True,
#    'even': True,
#    'bother': True,
#    'poll': True,
#    'reinc': True,
#    "'s": True,
#    'promis': True,
#    'trumpcruz2016': True},
#   'Negative'),
#  ({'donniewahlberg': True,
#    'enjoy': True,
#    'look': True,
#    'forward': True,
#    'democraticdeb': True,
#    'next': True},
#   'Positive'),
#  ({'pres': True,
#    'obama': True,
#    'brain': True,
#    'littl': True,
#    'toe': True,
#    'total': True,
#    'fuck': True,
#    'idiot': True,
#    'whole': True,
#    'famili': True,
#    'combin': True,
#    'boom': True},
#   'Negative'),
#  ({'politicorog': True,
#    'trump': True,
#    'report': True,
#    'general': True,
#    'dishonest': True,
#    'lot': True},
#   'Neutral'),
#  ({}, 'Neutral'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Negative'),
#  ({'housecracka': True,
#    'huge': True,
#    'differ': True,
#    'battl': True,
#    'foe': True,
#    'walk': True,
#    'blue': True,
#    'ambush': True,
#    'megynkellydebatequest': True},
#   'Negative'),
#  ({'carlyfiorina': True,
#    'one': True,
#    'pois': True,
#    'grace': True,
#    'determin': True,
#    'woman': True,
#    'get': True,
#    'behind': True,
#    'day': True},
#   'Positive'),
#  ({'wilberforce91': True,
#    'one': True,
#    'favorit': True,
#    'thing': True,
#    'mani': True,
#    'candid': True,
#    've': True,
#    'seen': True,
#    'person': True,
#    'thank': True,
#    'libertyu': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({'writeintrump': True,
#    "'m": True,
#    'go': True,
#    'take': True,
#    'long': True,
#    'way': True,
#    'bridg': True,
#    'close': True,
#    'well': True,
#    'play': True,
#    'chris': True,
#    'christi': True,
#    'p': True},
#   'Neutral'),
#  ({'watch': True,
#    'megynkelli': True,
#    'ask': True,
#    'trump': True,
#    'sexist': True,
#    'stuff': True,
#    'could': True,
#    'easi': True,
#    'crowd': True,
#    'roar': True,
#    'misogyni': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'american': True,
#    'peopl': True,
#    'pick': True,
#    'next': True,
#    'presid': True,
#    'unit': True,
#    'state': True},
#   'Negative'),
#  ({'ivankatrump': True,
#    'call': True,
#    'father': True,
#    'comment': True,
#    'rosi': True,
#    'suppos': True,
#    'listen': True,
#    'shame': True,
#    've': True,
#    'got': True,
#    'daughter': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'palmaceiahome1': True,
#    'goal': True,
#    'last': True,
#    'night': True,
#    'take': True,
#    'trump': True,
#    'pave': True,
#    'way': True,
#    'rino': True,
#    'like': True,
#    'bush': True,
#    'kasich': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'debat': True,
#    'rais': True,
#    'realdonaldtrump': True,
#    "'s": True,
#    'rate': True,
#    'afraid': True,
#    'trump': True,
#    'show': True},
#   'Positive'),
#  ({'msgoddessris': True,
#    'never': True,
#    'gone': True,
#    'bankrupt': True,
#    'wtf': True,
#    'read': True,
#    'lip': True,
#    'trump': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'candid': True,
#    'attack': True,
#    'realdonaldtrump': True,
#    'stope': True,
#    'speak': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'chrisshurley': True,
#    'outnumberedfnc': True,
#    'charleskrauthamm': True,
#    'fossil': True,
#    'love': True,
#    'megynkelli': True,
#    "'s": True,
#    'mind': True,
#    'realdonaldtrump': True,
#    'fro': True},
#   'Neutral'),
#  ({'cruz': True, 'complet': True, 'ignor': True}, 'Negative'),
#  ({'horribl': True,
#    'first': True,
#    'question': True,
#    'realdonaldtrump': True,
#    'unprofession': True,
#    'design': True,
#    'put': True,
#    'bad': True,
#    'mood': True,
#    'destroy': True},
#   'Negative'),
#  ({'markmelin': True,
#    'could': True,
#    'watch': True,
#    'exampl': True,
#    'argu': True,
#    'broadcast': True,
#    'anyway': True,
#    'public': True,
#    'servic': True,
#    'ridicul': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'megynkelli': True,
#    'say': True,
#    'sake': True,
#    'argument': True,
#    'letmeplaythedevilsadvoc': True,
#    'mean': True,
#    'one': True,
#    'better': True,
#    'kellyfil': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'loudobbsnew': True, 'dobb': True, 'like': True, 'govmikehuckabe': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'focus': True,
#    'group': True,
#    'post': True,
#    'liber': True,
#    'eyesor': True,
#    'frankluntz': True,
#    'disgrac': True,
#    'justic': True,
#    'wasteoftim': True},
#   'Negative'),
#  ({'minasmith64': True,
#    're': True,
#    'behav': True,
#    'like': True,
#    'dumb': True,
#    'feminist': True,
#    'blame': True,
#    'misogyni': True,
#    'person': True,
#    "'s": True,
#    'respons': True,
#    'unwarr': True,
#    'attack': True,
#    'gopdeba': True},
#   'Negative'),
#  ({'aw': True,
#    'jebbush': True,
#    'tote': True,
#    'come': True,
#    'later': True,
#    'good': True,
#    'cri': True,
#    'gotchu': True,
#    'boo': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'ppact': True,
#    'sell': True,
#    'babi': True,
#    'part': True,
#    'profit': True,
#    'whatev': True,
#    'want': True,
#    'call': True,
#    'trump': True,
#    'ca': True,
#    'woman': True,
#    'slob': True,
#    'pc': True,
#    'trump2016': True},
#   'Positive'),
#  ({'think': True,
#    'trump': True,
#    'moder': True,
#    'would': True,
#    'good': True,
#    'role': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'govchristi': True,
#    'hug': True,
#    'obama': True,
#    'deserv': True,
#    'stage': True,
#    'tonight': True},
#   'Negative'),
#  ({'monaeltahawi': True,
#    'serious': True,
#    'voter': True,
#    'think': True,
#    'god': True,
#    'talk': True,
#    'presidenti': True,
#    'candid': True,
#    'christianbrotherhood': True},
#   'Negative'),
#  ({'marcorubio': True,
#    'last': True,
#    'night': True,
#    "'s": True,
#    'even': True,
#    'close': True,
#    'well': True,
#    'done': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'trump': True,
#    'go': True,
#    'claim': True,
#    'god': True,
#    'gave': True,
#    'campaign': True,
#    'contribut': True},
#   'Negative'),
#  ({'carson': True,
#    'go': True,
#    'seat': True,
#    'back': True,
#    "'s": True,
#    'race': True,
#    'becuz': True,
#    'mofo': True,
#    'racist': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'megynkelli': True,
#    'pose': True,
#    'adult': True,
#    'pictures.should': True,
#    'bring': True},
#   'Negative'),
#  ({'rand': True, 'paul': True, 'vote': True, 'randpaul': True}, 'Positive'),
#  ({'becom': True,
#    'accept': True,
#    'god': True,
#    'topic': True,
#    'polit': True,
#    'debat': True,
#    'countri': True,
#    'shame': True},
#   'Negative'),
#  ({'tweet': True,
#    'hard': True,
#    'gopcircus': True,
#    'thought': True,
#    'broke': True,
#    'finger': True,
#    'nope': True,
#    'disloc': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'jjauthor': True, 'megynkelli': True, 'star': True, 'bretbaier': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'candid': True,
#    'attack': True,
#    'realdonaldtrump': True,
#    'stope': True,
#    'speak': True},
#   'Negative'),
#  ({'mozgovaya': True,
#    '10': True,
#    'men': True,
#    'stage': True,
#    'discuss': True,
#    'one': True,
#    'woman': True,
#    'hillaryclinton': True},
#   'Neutral'),
#  ({'realdonaldtrump': True,
#    'megynkelli': True,
#    'bretbaier': True,
#    'mod': True,
#    'job': True,
#    'is2': True,
#    'ask': True,
#    'qs': True,
#    'know': True,
#    'answer': True,
#    '2': True,
#    'bait': True,
#    'target': True,
#    'candid': True,
#    'trump2016': True},
#   'Positive'),
#  ({'joeykram': True,
#    'aerosmith': True,
#    'head': True,
#    'cleveland': True,
#    'interest': True,
#    'motleycru': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({'show': True,
#    'trump': True,
#    'rosieodonnel': True,
#    'watch': True,
#    'republican': True,
#    'presidenti': True,
#    'candid': True},
#   'Positive'),
#  ({'amandagutterman': True,
#    'trump': True,
#    'want': True,
#    'treat': True,
#    'mexican': True,
#    'like': True,
#    'white': True,
#    'walker': True},
#   'Negative'),
#  ({'leecorsodrunk': True,
#    'presid': True,
#    'colleg': True,
#    'footbal': True,
#    'would': True,
#    'play': True,
#    'year': True,
#    'round': True,
#    "'d": True,
#    'fast': True,
#    'isi': True,
#    'everi': True,
#    'saturday': True,
#    'corso4presi': True},
#   'Neutral'),
#  ({'ashvsevildead': True,
#    'kind': True,
#    'go': True,
#    'meanwhil': True,
#    're': True,
#    'debat': True,
#    'best': True,
#    'drum': True,
#    'solo': True,
#    'time': True,
#    'hot': True,
#    'teacher': True,
#    'tom': True,
#    'sa': True},
#   'Negative'),
#  ({'cap': True,
#    'defeat': True,
#    'kamehameha': True,
#    'attack': True,
#    'surviv': True,
#    'spirit': True,
#    'bomb': True},
#   'Neutral'),
#  ({'jjauthor': True,
#    'realdonaldtrump': True,
#    'float': True,
#    'like': True,
#    'butterfli': True,
#    'sting': True,
#    'bee': True,
#    'beladonnarog': True,
#    'megynkelli': True},
#   'Neutral'),
#  ({'cheesencrackr': True,
#    '2/2': True,
#    'right': True,
#    'women': True,
#    'indigen': True,
#    'peopl': True,
#    'colour': True,
#    'practic': True,
#    'non-western': True,
#    'faith': True,
#    'cr': True},
#   'Neutral'),
#  ({}, 'Positive'),
#  ({'couranto': True,
#    'rush': True,
#    'mock': True,
#    'megyn': True,
#    'kelli': True,
#    'self': True,
#    'serv': True,
#    'narcissist': True,
#    'kellyfil': True,
#    'foxdeb': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'ask': True,
#    'trump': True,
#    'legitim': True,
#    'question': True,
#    'look': True,
#    'wallac': True,
#    "'s": True,
#    'face': True,
#    'nail': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'dickscuttlebutt': True,
#    'tyfys84': True,
#    'duffelblog': True,
#    'tl': True,
#    'dr': True,
#    'blah': True,
#    'polit': True,
#    'whiskey': True,
#    'silent': True,
#    'weep': True,
#    'christi': True,
#    'fat': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'annemariew': True,
#    'poetinpoevill': True,
#    'know': True,
#    'aprx': True,
#    '700': True,
#    'law': True,
#    'govern': True,
#    'women': True,
#    "'s": True,
#    'bodi': True,
#    'one': True,
#    'men': True,
#    'true.': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'megynkelli': True,
#    'pose': True,
#    'adult': True,
#    'pictures.should': True,
#    'bring': True},
#   'Negative'),
#  ({'lindsey': True,
#    'graham': True,
#    'never': True,
#    'met': True,
#    'war': True,
#    "'s": True,
#    'afraid': True,
#    'send': True,
#    'kid': True,
#    'via': True,
#    'johnfugelsang': True,
#    'ff': True},
#   'Negative'),
#  ({"'s": True,
#    'scari': True,
#    'touch': True,
#    'real': True,
#    'world': True,
#    'republican': True},
#   'Negative'),
#  ({'npr': True,
#    "'m": True,
#    'sure': True,
#    'immigr': True,
#    'song': True,
#    'came': True,
#    'ledzepplin': True},
#   'Positive'),
#  ({'ericstonestreet': True, 'trump': True, 'cam': True, 'hand': True},
#   'Negative'),
#  ({'definit': True,
#    'topic': True,
#    'watch': True,
#    'last': True,
#    'night': True,
#    'thorough': True,
#    'entertain': True},
#   'Neutral'),
#  ({}, 'Positive'),
#  ({}, 'Neutral'),
#  ({'look': True,
#    'like': True,
#    're': True,
#    'skip': True,
#    'climat': True,
#    'chang': True,
#    "'s": True,
#    'talk': True,
#    'white': True,
#    'walker': True,
#    'king': True,
#    'land': True,
#    'debatewithberni': True},
#   'Negative'),
#  ({'vohanda': True,
#    'argu': True,
#    'hillari': True,
#    '1hr': True,
#    'ca': True,
#    'even': True,
#    'talk': True,
#    'polic': True,
#    'brutal': True,
#    'full': True,
#    'minut': True},
#   'Negative'),
#  ({'truthteamon': True,
#    'understand': True,
#    'statement': True,
#    'correct': True,
#    'mike': True,
#    'huckabe': True,
#    'believ': True,
#    'fertil': True,
#    'egg': True,
#    'abl': True,
#    'vote.': True,
#    'rwnj': True},
#   'Negative'),
#  ({'atlcav': True,
#    'fave': True,
#    'realli': True,
#    'well': True,
#    'last': True,
#    'night': True,
#    'marcorubio': True,
#    'johnkasich': True,
#    'realbencarson': True,
#    'carlyfiorina': True,
#    'rubio-kasich': True,
#    'ticket': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'huckabe': True, 'attack': True, 'tran': True, 'medic': True, 'care': True},
#   'Negative'),
#  ({'exclud': True,
#    'woman': True,
#    'field': True,
#    'first': True,
#    'ask': True,
#    'trump': True,
#    'part': True,
#    'war': True,
#    'women': True,
#    'yep.': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Negative'),
#  ({'catch': True,
#    'last': True,
#    'night': True,
#    'vast': True,
#    'major': True,
#    'question': True,
#    'flip-flop': True,
#    'posit': True,
#    'span': True,
#    'across': True,
#    'year': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Positive'),
#  ({'_alexandragold_': True,
#    '*root': True,
#    'small': True,
#    'businesses*': True,
#    '*campaign': True,
#    'almost': True,
#    'complet': True,
#    'fund': True,
#    'larg': True,
#    'corporations*': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Neutral'),
#  ({'1catherinesiena': True,
#    'glennbeck': True,
#    'patandstu': True,
#    'worst': True,
#    'appreci': True,
#    'theatric': True,
#    "'s": True,
#    'gopdeba': True},
#   'Negative'),
#  ({'trump': True,
#    'lead': True,
#    'among': True,
#    'male': True,
#    'voter': True,
#    '...': True,
#    'also': True,
#    'femal': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'disappoint': True,
#    'conduct': True,
#    'fair': True,
#    'balanc': True},
#   'Negative'),
#  ({'mention': True, 'climat': True, 'chang': True}, 'Negative'),
#  ({'lillyrockwel': True,
#    'dog': True,
#    'bark': True,
#    'everi': True,
#    'time': True,
#    'doorbel': True,
#    'sound': True,
#    'tv': True,
#    'last': True,
#    'night': True,
#    'lot': True,
#    'useabuzz': True},
#   'Negative'),
#  ({'everybodi': True, 'orang': True}, 'Negative'),
#  ({'alexhalperin': True,
#    'nandelabra': True,
#    'thank': True,
#    'made': True,
#    'donat': True,
#    'everyon': True,
#    'need': True,
#    'plan': True,
#    'parenthood': True,
#    'watch': True},
#   'Positive'),
#  ({'keep': True,
#    'hammer': True,
#    'accord': True,
#    'plan': True,
#    'great': True,
#    'car': True,
#    'fiorina': True,
#    'last': True,
#    'nightbut': True,
#    'rememb': True,
#    'word': True,
#    'said': True},
#   'Negative'),
#  ({'cat_1012000': True,
#    'thank': True,
#    'foxtv': True,
#    'hold': True,
#    'million': True,
#    'peopl': True,
#    'know': True,
#    're': True,
#    'better': True,
#    'balanc': True,
#    'msn': True,
#    'abc': True,
#    'cbs': True,
#    '...': True},
#   'Positive'),
#  ({'carson': True,
#    'get': True,
#    'zinger': True,
#    'end': True,
#    'ride': True,
#    'll': True,
#    'give': True,
#    'credit': True,
#    'medic': True,
#    'trailblaz': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'anyon': True,
#    'els': True,
#    'want': True,
#    'punch': True,
#    'chris': True,
#    'wallac': True,
#    'face': True},
#   'Negative'),
#  ({'katiepavlich': True,
#    're': True,
#    'alreadi': True,
#    'see': True,
#    'differ': True,
#    'senat': True,
#    'governor': True,
#    'introduc': True,
#    'legisl': True,
#    'got': True,
#    'thi': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'american': True,
#    'peopl': True,
#    'pick': True,
#    'next': True,
#    'presid': True,
#    'unit': True,
#    'state': True},
#   'Negative'),
#  ({'take': True,
#    'call': True,
#    '77wabcradio': True,
#    'yesterday': True,
#    "'s": True,
#    '800': True,
#    '848': True,
#    '9222': True},
#   'Neutral'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({'polit': True,
#    'correct': True,
#    '...': True,
#    'ai': True,
#    'nobodi': True,
#    'got': True,
#    'time': True,
#    'trump': True},
#   'Negative'),
#  ({'candid': True,
#    'honest': True,
#    'terrifi': True,
#    'one': True,
#    'actual': True,
#    'elect': True,
#    'countri': True,
#    'fuck': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({'rwsurfergirl': True,
#    'chris': True,
#    'wallac': True,
#    'ask': True,
#    'politican': True,
#    'financ': True,
#    'money': True,
#    'come': True},
#   'Negative'),
#  ({'rubio': True, 'good': True, 'job': True, 'last': True, 'night.': True},
#   'Positive'),
#  ({'wan': True,
#    'na': True,
#    'polit': True,
#    'see': True,
#    'shit': True,
#    'show': True,
#    'predic': True,
#    'elect': True,
#    'watch': True},
#   'Negative'),
#  ({'cavaticat': True,
#    'watch': True,
#    'last': True,
#    'night': True,
#    'today': True,
#    'got': True,
#    'wake': True,
#    'still': True,
#    'like': True,
#    'human': True,
#    'general': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Negative'),
#  ({'nerdist': True,
#    'trump': True,
#    "'s": True,
#    'realli': True,
#    'great': True,
#    'orang': True,
#    'new': True},
#   'Positive'),
#  ({'need': True,
#    'stop': True,
#    'he-said': True,
#    'she-said': True,
#    'question': True},
#   'Negative'),
#  ({'guypbenson': True,
#    'guy': True,
#    'trump': True,
#    'shoot': True,
#    'messeng': True,
#    'meagan': True,
#    'kelli': True,
#    'last': True,
#    'night': True,
#    'must': True,
#    'habitu': True,
#    'respons': True},
#   'Negative'),
#  ({'cloudypiano': True,
#    "'m": True,
#    'wait': True,
#    'accident': True,
#    'eat': True},
#   'Negative'),
#  ({'jebbush': True,
#    'good': True,
#    'communic': True,
#    'last': True,
#    'night': True,
#    "'s": True,
#    'sound': True,
#    'like': True,
#    'charli': True,
#    'brown': True,
#    'teacher': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'ca': True,
#    'wait': True,
#    'snl': True,
#    'imperson': True,
#    'donald': True,
#    'trump': True,
#    'bringbackdarrellhammond': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'mozgovaya': True,
#    '10': True,
#    'men': True,
#    'stage': True,
#    'discuss': True,
#    'one': True,
#    'woman': True,
#    'hillaryclinton': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'wo': True,
#    'admit': True,
#    'republican': True,
#    'leader': True,
#    'right': True,
#    'mean': True,
#    'realdonaldtrump': True,
#    'double-digit': True,
#    'lead': True,
#    'gopd': True},
#   'Neutral'),
#  ({'ask': True, 'everyon': True, 'question': True, 'race': True, '...': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'matthewherp': True,
#    'cruz': True,
#    'need': True,
#    'command': True,
#    'chief': True,
#    'make': True,
#    'clear': True,
#    'join': True,
#    'isi': True,
#    'sign': True,
#    'death': True,
#    'warrant': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'rubio': True,
#    'bush': True,
#    'threat': True,
#    'countri': True},
#   'Negative'),
#  ({'shannonrwatt': True,
#    'gun': True,
#    'violenc': True,
#    'cost': True,
#    'american': True,
#    '229b': True,
#    'annual': True,
#    'gunsens': True},
#   'Negative'),
#  ({'gop2016': True,
#    'plan': True,
#    'build': True,
#    'militari': True,
#    'cut': True,
#    'tax': True,
#    'ya': True,
#    'gon': True,
#    'na': True,
#    'pay': True,
#    'bake': True,
#    'sale': True,
#    'steal': True,
#    'ss': True},
#   'Negative'),
#  ({'monaeltahawi': True,
#    'candid': True,
#    'receiv': True,
#    'word': True,
#    'god': True,
#    'presidenti': True,
#    'hope': True,
#    'america': True,
#    'christian': True,
#    'brotherhood': True},
#   'Negative'),
#  ({'kelli': True, 'last': True, 'night': True, 'stop': True, 'clock': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'mcgrudder': True,
#    'gop2016deb': True,
#    'trump2016': True,
#    'trump': True,
#    'scare': True,
#    'control': True,
#    'talk': True,
#    'abo': True},
#   'Positive'),
#  ({'kumailn': True,
#    'guy': True,
#    've': True,
#    'cure': True,
#    'racism': True,
#    'realiz': True,
#    'congrat': True},
#   'Negative'),
#  ({'bettyfckinwhit': True,
#    '-can': True,
#    'answer': True,
#    'direct': True,
#    'question': True,
#    '-i': True,
#    'presid': True,
#    '-so': True},
#   'Negative'),
#  ({'jordiemojordi': True,
#    'yall': True,
#    'better': True,
#    'lie': True,
#    'god': True,
#    's/he': True,
#    'talk': True},
#   'Negative'),
#  ({'shadowbard': True,
#    'american': True,
#    'women': True,
#    'take': True,
#    'note': True,
#    'realdonaldtrump': True,
#    'justifi': True,
#    'piggish': True,
#    'attack': True,
#    '1': True,
#    'man': True,
#    'sta': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'problem': True,
#    'polit': True,
#    'correct': True,
#    "'s": True,
#    'mani': True,
#    'american': True,
#    'anti-intellectu': True,
#    'ignor': True,
#    'usa': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'would': True,
#    'never': True,
#    'know': True,
#    'realdonaldtrump': True,
#    'frontrunn': True,
#    'watch': True},
#   'Neutral'),
#  ({'oriolesfanprobz': True,
#    "'m": True,
#    'disappoint': True,
#    'none': True,
#    'candid': True,
#    'ask': True,
#    'thought': True,
#    'defens': True,
#    'shift': True,
#    'basebal': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'damn': True, 'freeload': True, 'pimp': True}, 'Negative'),
#  ({'jeffsimmons2050': True,
#    'takeaway': True,
#    'presenc': True,
#    'matter': True,
#    'see': True,
#    'blend': True,
#    'believ': True,
#    'articul': True,
#    'integr': True,
#    'w/': True,
#    'edg': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'candid': True,
#    'attack': True,
#    'realdonaldtrump': True,
#    'stope': True,
#    'speak': True},
#   'Negative'),
#  ({'akhenaten15': True,
#    'abort': True,
#    'problem': True,
#    'kill': True,
#    '575,000': True,
#    'iraqi': True,
#    'kid': True,
#    '2000': True,
#    'anoth': True,
#    '56,000': True},
#   'Negative'),
#  ({'monaeltahawi': True,
#    'candid': True,
#    'receiv': True,
#    'word': True,
#    'god': True,
#    'presidenti': True,
#    'hope': True,
#    'america': True,
#    'christian': True,
#    'brotherhood': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({}, 'Neutral'),
#  ({'warriorwoman91': True,
#    'love': True,
#    'megynkelli': True,
#    'hold': True,
#    'highest': True,
#    'posit': True,
#    'media': True,
#    'figur': True,
#    'ask': True,
#    'question': True,
#    'repub': True,
#    'war': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'zeitgeistghost': True,
#    'sane': True,
#    'person': True,
#    'think': True,
#    '1st': True,
#    'matter': True,
#    "'s": True,
#    'soulless': True,
#    'pitti': True,
#    'asshol': True},
#   'Neutral'),
#  ({}, 'Neutral'),
#  ({'much': True,
#    'voter': True,
#    'care': True,
#    'lender': True,
#    'lost': True,
#    'money': True,
#    'realdonaldtrump': True,
#    'bankruptci': True,
#    'lzdebat': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'monaeltahawi': True,
#    'one': True,
#    'question': True,
#    'import': True,
#    'urgent': True,
#    'movement': True,
#    'us': True,
#    'today': True,
#    'long': True,
#    'time': True},
#   'Neutral'),
#  ({'megynkelli': True,
#    'krauthamm': True,
#    'winner': True,
#    'tedcruz': True,
#    'marcorubio': True,
#    'govmikehuckabe': True,
#    'chrischristi': True,
#    'kellyfil': True},
#   'Neutral'),
#  ({'usprezdeb': True,
#    '...': True,
#    'total': True,
#    'think': True,
#    'tan': True,
#    'trump': True,
#    'gaff': True,
#    'presidenti': True,
#    'candid': True},
#   'Negative'),
#  ({'anyon': True,
#    'use': True,
#    'god': True,
#    "'s": True,
#    'name': True,
#    'hate': True,
#    'wolf': True,
#    'sheep': True,
#    'cloth': True,
#    'matthew': True,
#    '23:1-15': True,
#    'cruz': True,
#    'huckabe': True,
#    'men': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({'paulrieckhoff': True,
#    'yes': True,
#    'entitl': True,
#    'cic': True,
#    'potus': True,
#    'candid': True,
#    'excus': True,
#    'lack': True,
#    'nationalsecur': True,
#    'defens': True,
#    'va': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'candid': True,
#    'attack': True,
#    'realdonaldtrump': True,
#    'stope': True,
#    'speak': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'like': True,
#    'trump': True,
#    'less': True,
#    'morn': True,
#    'last': True,
#    'although': True,
#    'realiz': True,
#    "'s": True,
#    'want': True,
#    'think': True},
#   'Negative'),
#  ({'woke': True,
#    'think': True,
#    'hilari': True,
#    'dream': True,
#    'realiz': True,
#    'watch': True,
#    'last': True,
#    'night': True},
#   'Negative'),
#  ({'berniesand': True,
#    'scottwalk': True,
#    'man': True,
#    'say': True,
#    'one': True,
#    'intellig': True,
#    'thing': True,
#    'mean': True,
#    '...': True,
#    'none': True,
#    'feelthebern': True},
#   'Negative'),
#  ({'larryeld': True,
#    'trump': True,
#    'said': True,
#    'megyn': True,
#    'ask': True,
#    'nine': True,
#    'candid': True,
#    'plan': True,
#    'support': True,
#    'win': True,
#    'nomin': True,
#    'gopdebat': True},
#   'Neutral'),
#  ({'donaldtrump': True,
#    'know': True,
#    'usa': True,
#    'ca': True,
#    'declar': True,
#    'bankruptci': True,
#    'stiff': True,
#    'chines': True,
#    'creditor': True,
#    'askingforafriend': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'monaeltahawi': True,
#    'oh': True,
#    'boy': True,
#    'social': True,
#    'issu': True,
#    'code': True,
#    'control': True,
#    'women': True,
#    "'s": True,
#    'bodi': True,
#    'sexual': True,
#    'hold': True,
#    'tight': True,
#    'twitterland': True},
#   'Negative'),
#  ({'confus': True,
#    'republican': True,
#    'make': True,
#    'joke': True,
#    'watch': True,
#    'inform': True,
#    'candid': True},
#   'Neutral'),
#  ({'drbhotchkin': True,
#    'lynch': True,
#    'black': True,
#    'folk': True,
#    'jesus': True,
#    'name': True,
#    "'s": True,
#    'relev': True,
#    'god': True,
#    'question': True,
#    'foxdeb': True,
#    'foxn': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'mariacka': True,
#    'newsflash': True,
#    'jeb': True,
#    'wo': True,
#    'unit': True,
#    'countri': True,
#    'commoncor': True,
#    'pleas': True,
#    'lol': True},
#   'Negative'),
#  ({'base': True,
#    'rhetor': True,
#    'assum': True,
#    'donald': True,
#    'trump': True,
#    'look': True,
#    'megyn': True,
#    'kelli': True,
#    'see': True,
#    'miss': True,
#    'piggy.': True},
#   'Negative'),
#  ({'mitchellreport': True,
#    'capehartj': True,
#    'randpaul': True,
#    'good': True,
#    'point': True,
#    'turn': True,
#    'someth': True,
#    'sophomor': True,
#    'w/': True,
#    'hug': True,
#    'comment': True},
#   'Negative'),
#  ({'-er': True,
#    'vs': True,
#    'trump': True,
#    'glove': True,
#    'stay': True,
#    'except': True,
#    'fiorina': True,
#    'kick': True,
#    'curb': True,
#    'like': True,
#    'hp': True,
#    'employe': True},
#   'Negative'),
#  ({'want': True,
#    'defundpp': True,
#    'huckabe': True,
#    'legal': True,
#    'prostitut': True,
#    'drug': True},
#   'Negative'),
#  ({'chrisfranjola': True,
#    'thank': True,
#    'courag': True,
#    'coverag': True,
#    'sacrific': True,
#    'save': True,
#    'dread': True,
#    'even': True},
#   'Negative'),
#  ({'donniewahlberg': True,
#    'enjoy': True,
#    'look': True,
#    'forward': True,
#    'democraticdeb': True,
#    'next': True},
#   'Positive'),
#  ({'bamasever': True,
#    'megyn': True,
#    'kelli': True,
#    'worri': True,
#    'trump': True,
#    "'s": True,
#    'parti': True,
#    'loyalti': True,
#    'watch': True,
#    'transform': True,
#    'liber': True,
#    '3': True,
#    'hour': True},
#   'Negative'),
#  ({'supermanhotmal': True,
#    'dear': True,
#    'close': True,
#    'argument': True,
#    'none': True,
#    'candid': True,
#    'said': True,
#    'anyth': True,
#    'help': True,
#    'suffer': True,
#    'women': True},
#   'Negative'),
#  ({'women': True,
#    'serv': True,
#    'open': True,
#    'gay': True,
#    'transgend': True,
#    'militari': True,
#    'social': True,
#    'experi': True,
#    'accord': True,
#    'govmikehuckabe': True,
#    'late': True},
#   'Negative'),
#  ({'zoe_arch': True,
#    'wonder': True,
#    "'s": True,
#    'coincid': True,
#    'ironi': True,
#    'purpos': True,
#    'anniversari': True,
#    'hiroshima': True,
#    'bomb': True},
#   'Neutral'),
#  ({}, 'Negative'),
#  ({'bourgeoisalien': True,
#    'ca': True,
#    'wait': True,
#    'end': True,
#    'wrestl': True,
#    'angri': True,
#    'meth': True,
#    'addict': True,
#    'bear': True,
#    'death': True,
#    'see': True,
#    'real': True},
#   'Neutral'),
#  ({'readi': True,
#    '2016': True,
#    'gop2016': True,
#    'goodbyeobama': True,
#    'neveragain': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'truli': True,
#    'greatest': True,
#    'show': True,
#    'earth': True,
#    'gopclowncar': True},
#   'Negative'),
#  ({'simsoph': True,
#    'quit': True,
#    'someth': True,
#    'watch': True,
#    'vs': True,
#    'canadian': True,
#    'pm': True,
#    'anyon': True,
#    'take': True,
#    'american': True,
#    'politician': True,
#    'serious': True},
#   'Negative'),
#  ({'supermanhotmal': True,
#    'dear': True,
#    'gov': True,
#    'walker': True,
#    'noth': True,
#    'brag': True,
#    'fuck': True,
#    'state': True,
#    'wisconsin': True,
#    'suck': True,
#    'koch': True,
#    '...': True,
#    'bitchasspoli': True},
#   'Negative'),
#  ({'supermanhotmal': True,
#    'translat': True,
#    'jeb': True,
#    'bush': True,
#    'fuck': True,
#    'florida': True,
#    'school': True,
#    'bad': True,
#    'still': True,
#    'recov': True,
#    'truth': True,
#    'live': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Neutral'),
#  ({}, 'Negative'),
#  ({'brios82': True,
#    'conserv': True,
#    'want': True,
#    'live': True,
#    'babi': True,
#    'rais': True,
#    'dead': True,
#    'soldier': True,
#    '-georg': True,
#    'carlin': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'whole': True,
#    'debacl': True,
#    'insult': True,
#    'everi': True,
#    'american': True,
#    'common': True,
#    'sens': True,
#    'idea': True,
#    'histori': True,
#    '...': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'fieldnegro': True,
#    'happiest': True,
#    'person': True,
#    'america': True,
#    'today': True,
#    'watch': True,
#    'debat': True,
#    'hrc': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'chris': True,
#    'wallac': True,
#    'ask': True,
#    'politican': True,
#    'financ': True,
#    'money': True,
#    'come': True},
#   'Negative'),
#  ({'genethelawy': True, 'ted': True, 'cruz': True, 'leav': True}, 'Neutral'),
#  ({'dear': True,
#    'moder': True,
#    'forgot': True,
#    'say': True,
#    'chines': True,
#    'hack': True,
#    'start': True,
#    'bush': True,
#    'admin': True,
#    '...': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'chris': True,
#    'wallac': True,
#    'ask': True,
#    'politican': True,
#    'financ': True,
#    'money': True,
#    'come': True},
#   'Negative'),
#  ({'the818': True,
#    'let': True,
#    "'s": True,
#    'play': True,
#    'fast': True,
#    'distanc': True,
#    'trump': True,
#    'notm': True},
#   'Negative'),
#  ({'wow': True,
#    'everybodi': True,
#    "'s": True,
#    'tweet': True,
#    'megynkelli': True,
#    'bad': True,
#    'treatment': True,
#    'realdonaldtrump': True,
#    'agre': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({'chrchcurmudgeon': True,
#    "'d": True,
#    'vote': True,
#    'hologram': True,
#    'calvin': True,
#    'coolidg': True,
#    'moonwalk': True,
#    'across': True,
#    'stage': True,
#    'right': True,
#    'now.': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Neutral'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'glad': True,
#    'social': True,
#    'secur': True,
#    'debat': True,
#    'futur': True,
#    'gapol': True},
#   'Positive'),
#  ({'cruz': True, 'class': True, 'truth': True, 'get': True, 'vote': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'jessecox': True,
#    'even': True,
#    'god': True,
#    'roll': True,
#    'eye': True,
#    'respons': True,
#    'get': True,
#    'super': True,
#    'jesus': True,
#    'say': True,
#    '...': True,
#    'gopd': True},
#   'Negative'),
#  ({'bettyfckinwhit': True,
#    '-can': True,
#    'answer': True,
#    'direct': True,
#    'question': True,
#    '-i': True,
#    'presid': True,
#    '-so': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Neutral'),
#  ({'pimp': True, 'drug': True, 'dealer': True}, 'Neutral'),
#  ({'megynkelli': True,
#    'trump': True,
#    'simpli': True,
#    'ca': True,
#    'harm': True,
#    'impolitik': True,
#    'statement': True,
#    "'s": True,
#    'like': True,
#    'tri': True,
#    'drown': True,
#    'aquaman': True,
#    'donaldtrump': True},
#   'Negative'),
#  ({'love': True,
#    'hear': True,
#    'bencarson': True,
#    'debatequestionswewanttohear': True,
#    'make': True,
#    'perfect': True,
#    'sens': True,
#    'israel': True,
#    'awesom': True},
#   'Positive'),
#  ({'consequ': True,
#    'obama/clinton': True,
#    'admin': True,
#    '...': True,
#    'like': True,
#    'increas': True,
#    'diplomaci': True,
#    'ration': True,
#    'decision-mak': True,
#    'work': True,
#    'elimin': True,
#    'xenophobia': True},
#   'Negative'),
#  ({'ask': True,
#    'trump': True,
#    'question': True,
#    'get': True,
#    'squirrel': True},
#   'Negative'),
#  ({'carson': True,
#    'witti': True,
#    'articul': True,
#    'unlik': True,
#    'deserv': True,
#    'much': True,
#    'better': True,
#    'poll': True,
#    'rate': True,
#    'wo': True,
#    'make': True,
#    'past': True,
#    'new': True,
#    'hampshir': True},
#   'Positive'),
#  ({}, 'Positive'),
#  ({'exjon': True, 'rubio': True, 'win': True}, 'Positive'),
#  ({'_kingmalcolm': True,
#    'pro': True,
#    'life': True,
#    'unless': True,
#    'cop': True,
#    'involv': True,
#    'candid': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'chris': True,
#    'wallac': True,
#    'ask': True,
#    'politican': True,
#    'financ': True,
#    'money': True,
#    'come': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'ericstonestreet': True, 'trump': True, 'cam': True, 'hand': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Positive'),
#  ({}, 'Neutral'),
#  ({'livestream': True,
#    'blogger': True,
#    'make': True,
#    'sure': True,
#    'donald': True,
#    'trump': True,
#    'pull': True,
#    'rose': True,
#    'perot': True,
#    'clinton': True},
#   'Negative'),
#  ({'bring': True,
#    'hillaryclinton': True,
#    'need': True,
#    'someon': True,
#    'grown-up': True,
#    'barbarabox': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'per': True,
#    'trump': True,
#    'believ': True,
#    "'s": True,
#    'mere': True,
#    'polit': True,
#    'correct': True,
#    'moral': True,
#    'right': True,
#    'treat': True,
#    'women': True,
#    'equal': True},
#   'Negative'),
#  ({'democrat': True, 'love': True, 'right': True}, 'Positive'),
#  ({'salmasekela': True,
#    'self': True,
#    'righteous': True,
#    'hypocrit': True,
#    'tri': True,
#    'god': True,
#    'shameless': True},
#   'Negative'),
#  ({'sydneyvl24': True,
#    'cautious': True,
#    'optimist': True,
#    'feel': True,
#    'morn': True},
#   'Positive'),
#  ({'imoore8904': True,
#    'trump': True,
#    'support': True,
#    'tee': True,
#    'hee': True,
#    'laugh': True,
#    'insult': True,
#    'everyon': True,
#    'sun': True,
#    'cri': True,
#    'foul': True,
#    'megynkelli': True,
#    'call': True,
#    'shit': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'michelejmartin': True,
#    'last': True,
#    'night': True,
#    'huge': True,
#    'tv': True,
#    'jonvoyag': True,
#    'battl': True,
#    'social': True,
#    'annarawsuh': True,
#    'ovrdrv': True,
#    'recap': True,
#    'h': True},
#   'Neutral'),
#  ({'bassem_masri': True,
#    'wow': True,
#    'run': True,
#    'blatant': True,
#    'bigotri': True,
#    'war': True,
#    'tortur': True,
#    'address': True,
#    'problem': True,
#    'home': True,
#    'kkkorgop': True,
#    'go': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'erictheteamst': True,
#    'walker': True,
#    'main': True,
#    'talk': True,
#    'point': True,
#    'took': True,
#    '100s': True,
#    '1000s': True,
#    'union': True,
#    'protest': True,
#    'wait': True,
#    'hear': True,
#    'hel': True},
#   'Neutral'),
#  ({'kavithadavidson': True,
#    'total': True,
#    'stay': True,
#    'tune': True,
#    'god': True,
#    'megyn': True},
#   'Positive'),
#  ({'chrischristi': True,
#    'make': True,
#    'even': True,
#    'proud': True,
#    'new': True,
#    'jersey': True},
#   'Positive'),
#  ({'megyn': True,
#    'kelli': True,
#    'need': True,
#    'work': True,
#    'msnbc': True,
#    'low': True,
#    'point': True,
#    'debate.': True,
#    'realdonaldtrump': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Negative'),
# ...
#    'make': True,
#    'america': True,
#    'great': True},
#   'Negative'),
#  ({'theladygrantham': True,
#    'donald': True,
#    'trump': True,
#    'dear': True,
#    "'s": True,
#    'middl': True,
#    'class': True},
#   'Negative'),
#  ({'drunk': True, '2016': True}, 'Negative'),
#  ({"'m": True,
#    'ai': True,
#    'bout': True,
#    'dem': True,
#    'big': True,
#    'ol': True,
#    'sloppi': True,
#    'abort': True,
#    'nuh-uh': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({}, 'Neutral'),
#  ({'louispeitzman': True,
#    "'m": True,
#    'answer': True,
#    'question': True,
#    'stori': True,
#    'hardship': True,
#    'parent': True,
#    'face': True},
#   'Neutral'),
#  ({'trump': True,
#    'adam': True,
#    'sandler': True,
#    'movi': True,
#    'makeamericafartagain': True},
#   'Negative'),
#  ({'fxnopinion': True, 'foxnewspolit': True, 'good': True, 'job': True},
#   'Positive'),
#  ({'danmoore755': True,
#    'one': True,
#    'trust': True,
#    'randpaul': True,
#    'gop2016': True,
#    'usa': True,
#    'merica': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'lrihendri': True,
#    'tedcruz': True,
#    'presid': True,
#    'alway': True,
#    'tell': True,
#    'truth': True,
#    'said': True,
#    'would': True},
#   'Positive'),
#  ({'makinh15tori': True, 'lol': True, 'trump': True}, 'Negative'),
#  ({'rwsurfergirl': True,
#    'ask': True,
#    'trump': True,
#    'legitim': True,
#    'question': True,
#    'look': True,
#    'wallac': True,
#    "'s": True,
#    'face': True,
#    'nail': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'american': True,
#    'peopl': True,
#    'pick': True,
#    'next': True,
#    'presid': True,
#    'unit': True,
#    'state': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'tedcruz': True,
#    'realdonaldtrump': True,
#    'need': True,
#    'take': True,
#    'control': True},
#   'Positive'),
#  ({'cnn': True,
#    'cnnpolit': True,
#    '8': True,
#    'thing': True,
#    'take': True,
#    'away': True,
#    'one': True,
#    'bencarson': True,
#    "'s": True,
#    'shame': True},
#   'Negative'),
#  ({'foxnewsl': True,
#    'serious': True,
#    'tone': True,
#    'deaf': True,
#    'deliber': True,
#    'clue': True,
#    'blow': True,
#    'back': True,
#    'megynkelli': True,
#    "'m": True,
#    'fan': True},
#   'Negative'),
#  ({'basic': True,
#    'post': True,
#    'poll': True,
#    'busi': True,
#    'candid': True,
#    'beat': True,
#    'polit': True},
#   'Neutral'),
#  ({}, 'Neutral'),
#  ({'rwsurfergirl': True,
#    'jeb': True,
#    'bush': True,
#    'remind': True,
#    'elev': True,
#    'music': True,
#    'hear': True,
#    'listen': True},
#   'Negative'),
#  ({'last': True,
#    'night': True,
#    "'s": True,
#    'presidenti': True,
#    'debat': True,
#    'rich': True,
#    'corpor': True,
#    'ceo': True,
#    'run': True,
#    'govern': True,
#    'anyway': True,
#    'transpar': True},
#   'Negative'),
#  ({'auditthemedia': True,
#    'us': True,
#    'could': True,
#    'stand': True,
#    'learn': True,
#    'lot': True,
#    'gedeb': True,
#    'format': True,
#    'bbc': True,
#    'much': True,
#    'better': True,
#    'job': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'go': True,
#    'ask': True,
#    'trump2016': True,
#    'polici': True,
#    'question': True,
#    'charact': True,
#    'smear': True,
#    'makeamericagreatagain': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'big': True,
#    'problem': True,
#    'face': True,
#    'democrat': True,
#    'get': True,
#    'hillari': True,
#    'sober': True,
#    'long': True,
#    'enough': True,
#    'toot': True},
#   'Neutral'),
#  ({'keep': True,
#    'congratul': True,
#    'great': True,
#    'job': True,
#    'media': True,
#    'use': True,
#    'power': True,
#    'slant': True,
#    'usual': True,
#    'real': True,
#    'educ': True},
#   'Negative'),
#  ({'gamma_ray239': True,
#    'disappoint': True,
#    'treat': True,
#    'differ': True,
#    'cnn': True,
#    'would': True,
#    'dictat': True,
#    'vs': True,
#    'repo': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Positive'),
#  ({'billhemm': True,
#    'marthamaccallum': True,
#    'kudo': True,
#    'bill': True,
#    'martha': True,
#    'excel': True,
#    'moder': True,
#    'prime': True,
#    'time': True,
#    'team': True,
#    'aw': True,
#    'comparison': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'thank': True,
#    're': True,
#    'rais': True,
#    'realdonaldtrump': True,
#    "'s": True,
#    'rate': True},
#   'Positive'),
#  ({'rwsurfergirl': True,
#    'ask': True,
#    'trump': True,
#    'legitim': True,
#    'question': True,
#    'look': True,
#    'wallac': True,
#    "'s": True,
#    'face': True,
#    'nail': True},
#   'Positive'),
#  ({'fix': True,
#    'new': True,
#    'jersey': True,
#    'first': True,
#    'chrischristi': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({}, 'Neutral'),
#  ({'rwsurfergirl': True,
#    'candid': True,
#    'attack': True,
#    'realdonaldtrump': True,
#    'stope': True,
#    'speak': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'obamaagenda': True, 'baracksback': True, 'um..dur': True, 'derp': True},
#   'Neutral'),
#  ({}, 'Negative'),
#  ({'rwsurfergirl': True,
#    'american': True,
#    'peopl': True,
#    'pick': True,
#    'next': True,
#    'presid': True,
#    'unit': True,
#    'state': True},
#   'Negative'),
#  ({'lot': True,
#    'candid': True,
#    'defend': True,
#    'plannedparenthood': True,
#    'never': True,
#    'mention': True,
#    'take': True,
#    'away': True,
#    'rapist': True,
#    "'s": True,
#    'parent': True,
#    'right': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({'lol': True,
#    'bencarson': True,
#    'serious': True,
#    'answer': True,
#    'question': True},
#   'Negative'),
#  ({'stephenstephan': True,
#    'rubio': True,
#    'basic': True,
#    'life': True,
#    'sacr': True,
#    'prolif': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Neutral'),
#  ({'nathanhaynes24': True,
#    'last': True,
#    'night': True,
#    "'s": True,
#    'realbencarson': True,
#    'govmikehuckabe': True,
#    'emerg': True,
#    'top': True,
#    'two': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'ljcambria': True,
#    'realdonaldtrump': True,
#    'forget': True,
#    'vote': True,
#    'especislli': True,
#    'go': True,
#    'independ': True,
#    'lulz': True,
#    'huckster': True,
#    'rnc': True},
#   'Positive'),
#  ({'anergo_teach': True,
#    'serious': True,
#    'trump': True,
#    'danger': True,
#    'whole': True,
#    'world': True},
#   'Negative'),
#  ({'trump': True, 're': True, 'avoid': True, 'question': True}, 'Negative'),
#  ({'randpaul': True,
#    'got': True,
#    'clock': True,
#    'clean': True,
#    'last': True,
#    'night': True,
#    'bye': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'oh': True,
#    'understand': True,
#    'movi': True,
#    'idiocraci': True,
#    'actual': True,
#    'documentari': True},
#   'Negative'),
#  ({'donniewahlberg': True,
#    'enjoy': True,
#    'look': True,
#    'forward': True,
#    'democraticdeb': True,
#    'next': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'rubio': True, 'hard': True, 'keep': True, 'script': True, '...': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'berinszoka': True,
#    'rand': True,
#    'want': True,
#    'gun': True,
#    'marriag': True,
#    'regist': True,
#    'washingtonagre': True,
#    '...': True,
#    'know': True,
#    'state': True,
#    'r': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'themadston': True,
#    'bum': True,
#    'get': True,
#    'watch': True,
#    'singl': True,
#    'candid': True,
#    'flounder': True,
#    'climat': True,
#    'chang': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({'goddessjaz': True,
#    'discuss': True,
#    'racist': True,
#    'polic': True,
#    'violenc': True,
#    'finish': True,
#    'type': True,
#    'tweet': True,
#    'kkkorgop': True},
#   'Negative'),
#  ({'promis': True,
#    'free': True,
#    'pizza': True,
#    'everi': True,
#    'friday': True,
#    'homework': True,
#    'ever': True},
#   'Neutral'),
#  ({'typic': True,
#    'plan': True,
#    'make': True,
#    'life': True,
#    'better': True,
#    'plenti': True,
#    'increas': True,
#    'pain': True,
#    'miseri': True,
#    'p2': True},
#   'Negative'),
#  ({'jeb': True,
#    'bush': True,
#    'rand': True,
#    'paul': True,
#    'one': True,
#    'see': True,
#    'odd': True,
#    'rise': True,
#    'though': True,
#    "'s": True,
#    'price': True,
#    'trim': True,
#    'end': True},
#   'Positive'),
#  ({}, 'Negative'),
#  ({'llamo': True,
#    'sprightlymag': True,
#    'consid': True,
#    'ca': True,
#    'blame': True,
#    'might': True,
#    'need': True,
#    'join': True,
#    'thank': True},
#   'Negative'),
#  ({}, 'Neutral'),
#  ({}, 'Negative'),
#  ({}, 'Neutral'),
#  ({'reassur': True,
#    'affin': True,
#    'republican': True,
#    'kurdish': True,
#    'milit': True,
#    'elect': True,
#    'presid': True,
#    'jindal': True,
#    'said': True,
#    'll': True,
#    'arm': True,
#    'kurd': True,
#    'i.e': True,
#    'pyd': True},
#   'Positive'),
#  ({'monaeltahawi': True,
#    'serious': True,
#    'voter': True,
#    'think': True,
#    'god': True,
#    'talk': True,
#    'presidenti': True,
#    'candid': True,
#    'christianbrotherhood': True},
#   'Negative'),
#  ({'amymek': True,
#    'freedom': True,
#    'free': True,
#    'must': True,
#    'fight': True,
#    'everi': True,
#    'day': True,
#    'ben': True,
#    'carson': True},
#   'Neutral'),
#  ({}, 'Positive'),
#  ({'supermanhotmal': True,
#    'donald': True,
#    'trump': True,
#    'never': True,
#    'gone': True,
#    'bankrupt': True,
#    '...': True,
#    'realli': True,
#    'fuck': True,
#    'liar': True},
#   'Negative'),
#  ({'laural4705': True,
#    'opinion': True,
#    'cruz': True,
#    'best': True,
#    'close': True,
#    'remark': True,
#    'explain': True,
#    'plan': True,
#    'vision': True,
#    'america': True,
#    'passion': True,
#    'de': True},
#   'Positive'),
#  ({"'m": True, 'still': True, 'stare': True, 'megynkelli': True, 'bae': True},
#   'Positive'),
#  ({'jamiaw': True,
#    'purpos': True,
#    'militari': True,
#    'kill': True,
#    'peopl': True,
#    'break': True,
#    'thing': True,
#    '-mike': True,
#    'huckabe': True,
#    'kkkorgop': True},
#   'Neutral'),
#  ({'bucksexton': True,
#    'hey': True,
#    'jeb': True,
#    'earn': True,
#    'legal': True,
#    'status': True,
#    'amnesti': True,
#    've': True,
#    'play': True,
#    'game': True},
#   'Neutral'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'dynamodream': True,
#    'realdonaldtrump': True,
#    'megynkelli': True,
#    'megyn': True,
#    'kelli': True,
#    'also': True,
#    'roll': True,
#    'eye': True,
#    'watch': True,
#    'rate': True,
#    'drop': True,
#    'drastic': True},
#   'Neutral'),
#  ({'old': True,
#    'white': True,
#    'rich': True,
#    'conserv': True,
#    'dude': True,
#    'parad': True,
#    "'s": True,
#    'childhood': True,
#    'nightmar': True,
#    'mine': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({'huckabe': True, 'propos': True, 'pimp': True, 'tax': True}, 'Neutral'),
#  ({'candid': True,
#    'claim': True,
#    'speak': True,
#    'direct': True,
#    'god': True,
#    '...': True},
#   'Neutral'),
#  ({'maddow': True,
#    'everyon': True,
#    'watch': True,
#    'debatewithberni': True,
#    '--': True,
#    'senschum': True,
#    'fri': True,
#    'night': True,
#    'dump': True,
#    'thur': True,
#    'irand': True},
#   'Neutral'),
#  ({}, 'Neutral'),
#  ({'bruneski': True,
#    'upstair': True,
#    'put': True,
#    'kid': True,
#    'bed': True,
#    'mani': True,
#    'question': True,
#    'climat': True,
#    'chang': True,
#    'miss': True,
#    'gopclowncar': True},
#   'Neutral'),
#  ({'salmasekela': True,
#    'kasich': True,
#    'awar': True,
#    "'s": True,
#    'make': True,
#    'sens': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'republican': True,
#    'primari': True,
#    "'s": True,
#    'think': True,
#    'govern': True,
#    'new': True,
#    'realiti': True,
#    'show': True,
#    'debatewithberni': True},
#   'Negative'),
#  ({'although': True,
#    'occasion': True,
#    'dick': True,
#    'realdonaldtrump': True,
#    'sure': True,
#    'know': True,
#    'keep': True,
#    'polit': True,
#    'debat': True,
#    'aliv': True,
#    'excit': True},
#   'Negative'),
#  ({'take': True,
#    'care': True,
#    'peopl': True,
#    've': True,
#    'work': True,
#    'hard': True,
#    'play': True,
#    'rule': True,
#    'wrong': True,
#    'christi': True,
#    're': True,
#    'pay': True,
#    'nj': True,
#    'pension': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Positive'),
#  ({'rwsurfergirl': True,
#    'megynkelli': True,
#    'pose': True,
#    'adult': True,
#    'pictures.should': True,
#    'bring': True},
#   'Negative'),
#  ({'mzdivah67': True,
#    'watch': True,
#    'seem': True,
#    'like': True,
#    'blacklivesdontmatt': True,
#    'bash': True,
#    'pbo': True,
#    'fail': True,
#    'polici': True,
#    'impo': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'disappoint': True,
#    'conduct': True,
#    'fair': True,
#    'balanc': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'think': True,
#    'cruz': True,
#    'trump': True,
#    'need': True,
#    'band': True,
#    'togeth': True,
#    'expos': True,
#    'set': True,
#    'job': True,
#    'get': True,
#    'rid': True,
#    'bush': True,
#    'rubio': True,
#    'g': True},
#   'Positive'),
#  ({}, 'Neutral'),
#  ({'cat_1012000': True,
#    'thank': True,
#    'foxtv': True,
#    'hold': True,
#    'million': True,
#    'peopl': True,
#    'know': True,
#    're': True,
#    'better': True,
#    'balanc': True,
#    'msn': True,
#    'abc': True,
#    'cbs': True,
#    '...': True},
#   'Negative'),
#  ({'salmasekela': True,
#    'senat': True,
#    'cruz': True,
#    'word': True,
#    'god': True,
#    'spit': True,
#    'tequila': True,
#    'damn': True,
#    'megyn': True,
#    'kelli': True,
#    'expens': True,
#    'kind': True},
#   'Negative'),
#  ({'leasavoy': True,
#    'overal': True,
#    'view': True,
#    '...': True,
#    'stay': True,
#    'home': True,
#    'work': True,
#    'candid': True,
#    'choic': True,
#    'chang': True,
#    '1': True,
#    'iota.': True,
#    'cruzcrew': True},
#   'Negative'),
#  ({'danmoore755': True,
#    'republican': True,
#    'candid': True,
#    'close': True,
#    'love': True,
#    'god': True,
#    'democrat': True,
#    'would': True,
#    'never': True,
#    '...': True,
#    'sayin': True,
#    'gop2016': True,
#    'gopd': True},
#   'Negative'),
#  ({}, 'Positive'),
#  ({'lrihendri': True,
#    'tedcruz': True,
#    'presid': True,
#    'alway': True,
#    'tell': True,
#    'truth': True,
#    'said': True,
#    'would': True},
#   'Positive'),
#  ({'piti': True, 'parti': True}, 'Negative'),
#  ({}, 'Negative'),
#  ({'tedcruz': True,
#    'get': True,
#    'vote': True,
#    'tonight': True,
#    'dr.': True,
#    'carson': True,
#    'close': True,
#    'second': True},
#   'Positive'),
#  ({'say': True,
#    'school': True,
#    'local': True,
#    'state': True,
#    'run': True,
#    'keep': True,
#    'receiv': True,
#    'fed': True,
#    'money': True,
#    'matter': True},
#   'Negative'),
#  ({'rwsurfergirl': True,
#    'tonight': True,
#    'learn': True,
#    'govchristi': True,
#    'think': True,
#    'remov': True,
#    'civil': True,
#    'right': True,
#    'fight': True,
#    'terror': True},
#   'Negative'),
#  ({'ira': True,
#    'point': True,
#    'talk': True,
#    '9/11': True,
#    'gone': True,
#    'longer': True,
#    'pretti': True,
#    'littl': True,
#    'liar': True},
#   'Negative'),
#  ({'ericstonestreet': True, 'trump': True, 'cam': True, 'hand': True},
#   'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Negative'),
#  ({}, 'Positive'),
#  ({'rumpfshak': True,
#    'never': True,
#    'gone': True,
#    'bankrupt': True,
#    'say': True,
#    'trump': True,
#    'multipl': True,
#    'busi': True,
#    'went': True,
#    'thru': True,
#    'bankruptci': True,
#    'screw': True,
#    'creditor': True},
#   'Negative'),
#  ({'chump/trump': True,
#    'ignor': True,
#    'presidenti': True,
#    'class': True,
#    'money': True,
#    'clear': True,
#    'ca': True,
#    'buy': True,
#    'u': True,
#    'skip': True,
#    'digniti': True},
#   'Negative'),
#  ...]

# %%
from sklearn.neural_network import MLPClassifier

SK = MLPClassifier(alpha=0.1,hidden_layer_sizes=(10), random_state=1)
SK.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-e47708709ed4> in <module>
#       2
#       3 SK = MLPClassifier(alpha=0.1,hidden_layer_sizes=(10), random_state=1)
# ----> 4 SK.fit(X_train, Y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in fit(self, X, y)
#     980         """
#     981         return self._fit(X, y, incremental=(self.warm_start and
# --> 982                                             hasattr(self, "classes_")))
#     983
#     984     @property
#
# ~\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in _fit(self, X, y, incremental)
#     321                              hidden_layer_sizes)
#     322
# --> 323         X, y = self._validate_input(X, y, incremental)
#     324         n_samples, n_features = X.shape
#     325
#
# ~\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in _validate_input(self, X, y, incremental)
#     917     def _validate_input(self, X, y, incremental):
#     918         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 919                          multi_output=True)
#     920         if y.ndim == 2 and y.shape[1] == 1:
#     921             y = column_or_1d(y, warn=True)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     519                     "Reshape your data either using array.reshape(-1, 1) if "
#     520                     "your data has a single feature or array.reshape(1, -1) "
# --> 521                     "if it contains a single sample.".format(array))
#     522
#     523         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[{} 'Negative'].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
import keras
from keras.utils.np_utils import to_categorical


train_bow = to_categorical(y_train)
train[:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-c881c173f2fa> in <module>
#       4 X_train = train_bow[0]
#       5 y_train = train_bow[1]
# ----> 6 train_bow = to_categorical(y_train)
#       7 train[:3]
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\np_utils.py in to_categorical(y, num_classes, dtype)
#      67
#      68   """
# ---> 69   y = np.array(y, dtype='int')
#      70   input_shape = y.shape
#      71   if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'dict'

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras import optimizers

N = train_bow[1]
H = 100
K = 10

model = Sequential()
model.add(Dense(H, input_dim=N))
model.add(Activation("tanh"))
model.add(Dense(K))
model.add(Activation("softmax"))

model.compile(optimizer=optimizers.SGD(lr=0.1),
              loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(train_bow[0], train_bow[1], epochs=15, batch_size=32);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in make_shape(v, arg_name)
#     210   try:
# --> 211     shape = tensor_shape.as_shape(v)
#     212   except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in as_shape(shape)
#    1234   else:
# -> 1235     return TensorShape(shape)
#    1236
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in __init__(self, dims)
#     755     if isinstance(dims, (tuple, list)):  # Most common case.
# --> 756       self._dims = [Dimension(d) for d in dims]
#     757     elif dims is None:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in <listcomp>(.0)
#     755     if isinstance(dims, (tuple, list)):  # Most common case.
# --> 756       self._dims = [Dimension(d) for d in dims]
#     757     elif dims is None:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py in __init__(self, value)
#     203                       "an __index__ method, got value '{0!r}' with type '{1!r}'"
# --> 204                       .format(value, type(value))), None)
#     205       if self._value < 0:
#
# ~\Anaconda3\lib\site-packages\six.py in raise_from(value, from_value)
#
# TypeError: Dimension value must be integer or None or have an __index__ method, got value '({'jjauthor': True, 'polici': True, 'barack': True, 'obama': True, 'manag': True, 'provid': True, 'neither': True, 'peac': True, 'prosper': True, 'realdonaldtrump': True, 'tedcruz': True}, 'Negative')' with type '<class 'tuple'>'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-311e6408a0dd> in <module>
#       8
#       9 model = Sequential()
# ---> 10 model.add(Dense(H, input_dim=N))
#      11 model.add(Activation("tanh"))
#      12 model.add(Dense(K))
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     200           # Instantiate an input layer.
#     201           x = input_layer.Input(
# --> 202               batch_shape=batch_shape, dtype=dtype, name=layer.name + '_input')
#     203           # This will build the current layer
#     204           # and create the node connecting the current layer
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_layer.py in Input(shape, batch_size, name, dtype, sparse, tensor, ragged, **kwargs)
#     309     input_layer_config.update(
#     310         {'batch_size': batch_size, 'input_shape': shape})
# --> 311   input_layer = InputLayer(**input_layer_config)
#     312
#     313   # Return tensor including `_keras_history`.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_layer.py in __init__(self, input_shape, batch_size, dtype, input_tensor, sparse, name, ragged, **kwargs)
#     158             name=self.name,
#     159             sparse=sparse,
# --> 160             ragged=ragged)
#     161
#     162       self.is_placeholder = True
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in placeholder(shape, ndim, dtype, sparse, name, ragged)
#    1221                                expand_composites=True)
#    1222       else:
# -> 1223         x = array_ops.placeholder(dtype, shape=shape, name=name)
#    1224
#    1225   if context.executing_eagerly():
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py in placeholder(dtype, shape, name)
#    3098                        "eager execution.")
#    3099
# -> 3100   return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#    3101
#    3102
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in placeholder(dtype, shape, name)
#    6805   if shape is None:
#    6806     shape = None
# -> 6807   shape = _execute.make_shape(shape, "shape")
#    6808   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    6809         "Placeholder", dtype=dtype, shape=shape, name=name)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in make_shape(v, arg_name)
#     211     shape = tensor_shape.as_shape(v)
#     212   except TypeError as e:
# --> 213     raise TypeError("Error converting %s to a TensorShape: %s." % (arg_name, e))
#     214   except ValueError as e:
#     215     raise ValueError("Error converting %s to a TensorShape: %s." % (arg_name,
#
# TypeError: Error converting shape to a TensorShape: Dimension value must be integer or None or have an __index__ method, got value '({'jjauthor': True, 'polici': True, 'barack': True, 'obama': True, 'manag': True, 'provid': True, 'neither': True, 'peac': True, 'prosper': True, 'realdonaldtrump': True, 'tedcruz': True}, 'Negative')' with type '<class 'tuple'>'.
